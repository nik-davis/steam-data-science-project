# %% [markdown]
# # Steam Data Cleaning (Part 1)

# %% [markdown]
# *This is part of a larger series of posts on downloading, processing and analysing data from the steam store - (add links and desc here)*
#
# **TODO**: genre and categories section writeup
#
# Currently our downloaded data is not in a very usable or useful state. Many of the columns contain lengthy strings or missing values, both of which are crippling to analysis and especially to any machine learning techniques we may wish to implement.
#
# The main aims of this project are to investigate various sales and play-time statistics for games from the steam store, and see how different features of games may have an effect on the success of those games. Keeping this in mind will help inform our decisions about how to handle the various columns in our data set, however it may be a good idea to keep columns which may not seem useful to this particular project in order to provide a robust data set for future analysis projects.
#
# To begin with, we'll import our libraries and set some options, then take a look at the downloaded data from the steam api. Once that is taken care of we will move on to the steamspy data and repeat the process. Hopefully by the end we will have clean data sets to use in the next step, exploratory analysis and visualisation.
#
# ### Aims:
# - Improve functions
# - Prepare notebook for delivery
#
# ### (Raw) Data Dictionary
#
# Sort out data dictionary
#
# API and data dictionary:
# https://steamspy.com/api.php
#
# ### Future ideas:
# - pc requirements analysis over time
# - picture analysis
# - keyword/recommender analysis
# - categories could make table in a database all on its own, perhaps in future
# - for genres (and categories?) could create main genre, selected from list of key genres, allowing hybrids like action_adventure if contains both
# - remove titles over £60/100?

# %%
# load extensions and magics

# http://raw.github.com/jrjohansson/version_information/master/version_information.py
# %load_ext version_information
# %reload_ext version_information

# %version_information numpy, pandas
# Out:
# Software versions
# Python 3.7.3 64bit [MSC v.1900 64 bit (AMD64)]
# IPython 7.5.0
# OS Windows 10 10.0.17763 SP0
# numpy 1.16.3
# pandas 0.24.2
# Fri May 24 12:07:27 2019 GMT Summer Time

# %%
# import libraries
from ast import literal_eval
import itertools
import time
import re

import numpy as np
import pandas as pd

# %%
# customisations
pd.set_option("max_columns", 100)
# pd.reset_option("max_columns")

# %% [markdown]
# ## Cleaning steam data
#
# ### Import Data
#
# We begin by importing the raw steam data we generated previously in data collection, which can be viewed by following the link to `../deliver/1-data-collection.ipynb` below. From a quick inspection of the data, we can see that we have a mixture of numeric and string columns, plenty of missing values, and a number of columns stored as dictionaries.

# %%
from IPython.display import FileLink
FileLink("../notebooks/1-data-collection.ipynb")
# Out:
# C:\Users\nikda\OneDrive\Documents\ds\projects\2019-04-23-steam\notebooks\1-data-collection.ipynb

# %%
raw_steam_data = pd.read_csv('../data/raw/steam_app_data.csv')

print('Rows:', raw_steam_data.shape[0])
print('Columns:', raw_steam_data.shape[1])
raw_steam_data.head()
# Out:
# Rows: 29235
# Columns: 39
#    type                       name  steam_appid  required_age is_free  \
# 0  game             Counter-Strike           10           0.0   False
# 1  game      Team Fortress Classic           20           0.0   False
# 2  game              Day of Defeat           30           0.0   False
# 3  game         Deathmatch Classic           40           0.0   False
# 4  game  Half-Life: Opposing Force           50           0.0   False
#
#   controller_support  dlc                               detailed_description  \
# 0                NaN  NaN  Play the world's number 1 online action game. ...
# 1                NaN  NaN  One of the most popular online action games of...
# 2                NaN  NaN  Enlist in an intense brand of Axis vs. Allied ...
# 3                NaN  NaN  Enjoy fast-paced multiplayer gaming with Death...
# 4                NaN  NaN  Return to the Black Mesa Research Facility as ...
#
#                                       about_the_game  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                    short_description  fullgame  \
# 0  Play the world's number 1 online action game. ...       NaN
# 1  One of the most popular online action games of...       NaN
# 2  Enlist in an intense brand of Axis vs. Allied ...       NaN
# 3  Enjoy fast-paced multiplayer gaming with Death...       NaN
# 4  Return to the Black Mesa Research Facility as ...       NaN
#
#                                  supported_languages  \
# 0  English<strong>*</strong>, French<strong>*</st...
# 1  English, French, German, Italian, Spanish - Sp...
# 2  English, French, German, Italian, Spanish - Spain
# 3  English, French, German, Italian, Spanish - Sp...
# 4                    English, French, German, Korean
#
#                                         header_image  \
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...
#
#                        website  \
# 0                          NaN
# 1                          NaN
# 2  http://www.dayofdefeat.com/
# 3                          NaN
# 4                          NaN
#
#                                      pc_requirements  \
# 0  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 1  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 2  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 3  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 4  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
#
#                                     mac_requirements  \
# 0  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 1  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 2  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 3  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 4  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
#
#                                   linux_requirements legal_notice drm_notice  \
# 0  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...          NaN        NaN
# 1  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...          NaN        NaN
# 2  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...          NaN        NaN
# 3  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...          NaN        NaN
# 4  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...          NaN        NaN
#
#   ext_user_account_notice            developers publishers demos  \
# 0                     NaN             ['Valve']  ['Valve']   NaN
# 1                     NaN             ['Valve']  ['Valve']   NaN
# 2                     NaN             ['Valve']  ['Valve']   NaN
# 3                     NaN             ['Valve']  ['Valve']   NaN
# 4                     NaN  ['Gearbox Software']  ['Valve']   NaN
#
#                                       price_overview packages  \
# 0  {'currency': 'GBP', 'initial': 719, 'final': 7...      [7]
# 1  {'currency': 'GBP', 'initial': 399, 'final': 3...     [29]
# 2  {'currency': 'GBP', 'initial': 399, 'final': 3...     [30]
# 3  {'currency': 'GBP', 'initial': 399, 'final': 3...     [31]
# 4  {'currency': 'GBP', 'initial': 399, 'final': 3...     [32]
#
#                                       package_groups  \
# 0  [{'name': 'default', 'title': 'Buy Counter-Str...
# 1  [{'name': 'default', 'title': 'Buy Team Fortre...
# 2  [{'name': 'default', 'title': 'Buy Day of Defe...
# 3  [{'name': 'default', 'title': 'Buy Deathmatch ...
# 4  [{'name': 'default', 'title': 'Buy Half-Life: ...
#
#                                        platforms  \
# 0  {'windows': True, 'mac': True, 'linux': True}
# 1  {'windows': True, 'mac': True, 'linux': True}
# 2  {'windows': True, 'mac': True, 'linux': True}
# 3  {'windows': True, 'mac': True, 'linux': True}
# 4  {'windows': True, 'mac': True, 'linux': True}
#
#                                           metacritic reviews  \
# 0  {'score': 88, 'url': 'https://www.metacritic.c...     NaN
# 1                                                NaN     NaN
# 2  {'score': 79, 'url': 'https://www.metacritic.c...     NaN
# 3                                                NaN     NaN
# 4                                                NaN     NaN
#
#                                           categories  \
# 0  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 1  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 2  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 3  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 4  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                    genres  \
# 0  [{'id': '1', 'description': 'Action'}]
# 1  [{'id': '1', 'description': 'Action'}]
# 2  [{'id': '1', 'description': 'Action'}]
# 3  [{'id': '1', 'description': 'Action'}]
# 4  [{'id': '1', 'description': 'Action'}]
#
#                                          screenshots movies   recommendations  \
# 0  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 65735}
# 1  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN   {'total': 2802}
# 2  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN   {'total': 1992}
# 3  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN    {'total': 931}
# 4  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN   {'total': 4355}
#
#    achievements                                   release_date  \
# 0  {'total': 0}  {'coming_soon': False, 'date': '1 Nov, 2000'}
# 1  {'total': 0}  {'coming_soon': False, 'date': '1 Apr, 1999'}
# 2  {'total': 0}  {'coming_soon': False, 'date': '1 May, 2003'}
# 3  {'total': 0}  {'coming_soon': False, 'date': '1 Jun, 2001'}
# 4  {'total': 0}  {'coming_soon': False, 'date': '1 Nov, 1999'}
#
#                                         support_info  \
# 0  {'url': 'http://steamcommunity.com/app/10', 'e...
# 1                           {'url': '', 'email': ''}
# 2                           {'url': '', 'email': ''}
# 3                           {'url': '', 'email': ''}
# 4  {'url': 'https://help.steampowered.com', 'emai...
#
#                                           background  \
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...
#
#                                  content_descriptors
# 0  {'ids': [2, 5], 'notes': 'Includes intense vio...
# 1  {'ids': [2, 5], 'notes': 'Includes intense vio...
# 2                         {'ids': [], 'notes': None}
# 3                         {'ids': [], 'notes': None}
# 4                         {'ids': [], 'notes': None}

# %% [markdown]
# We can chain the `isnull()` and `sum()` methods to easily see how many missing values we have in each column. Immediately we can see that a number of columns have over 20,000 rows with missing data, and in a data set of almost 30,000 rows these are unlikely to provide any useful information.

# %%
raw_steam_data.isnull().sum()
# Out:
# type                         149
# name                           1
# steam_appid                    0
# required_age                 149
# is_free                      149
# controller_support         23237
# dlc                        24260
# detailed_description         175
# about_the_game               175
# short_description            175
# fullgame                   29235
# supported_languages          163
# header_image                 149
# website                     9983
# pc_requirements              149
# mac_requirements             149
# linux_requirements           149
# legal_notice               19168
# drm_notice                 29077
# ext_user_account_notice    28723
# developers                   264
# publishers                   149
# demos                      27096
# price_overview              3712
# packages                    3370
# package_groups               149
# platforms                    149
# metacritic                 26254
# reviews                    23330
# categories                   714
# genres                       196
# screenshots                  177
# movies                      2078
# recommendations            22507
# achievements                2381
# release_date                 149
# support_info                 149
# background                   177
# content_descriptors          149
# dtype: int64

# %% [markdown]
# ## Defining Functions
#
# We will most likely have to handle each column differently and individually, so we will write some functions to keep our methodology oragnised, and help iteratively develop the process.
#
#
# ### Initial processing
#
# Our first function, `process_null_cols`, will remove the columns with more than 50% missing values, taking care of the null counts we saw previously. We then look at the type and name columns, thinning out our data set a little by removing apps without either.
#
# In the data collection stage, if no information was returned for an app we just stored the name and steam_appid. As seen below, these rows contain no other information so we definitely need to remove them.

# %%
# columns to be dropped
raw_steam_data.columns[raw_steam_data.isnull().sum() > (len(raw_steam_data) * 0.5)]
# Out:
# Index(['controller_support', 'dlc', 'fullgame', 'legal_notice', 'drm_notice',
#        'ext_user_account_notice', 'demos', 'metacritic', 'reviews',
#        'recommendations'],
#       dtype='object')

# %%
print('Rows to remove:', raw_steam_data[raw_steam_data['type'].isnull()].shape[0])

raw_steam_data[raw_steam_data['type'].isnull()].head()
# Out:
# Rows to remove: 149
#     type                       name  steam_appid  required_age is_free  \
# 26   NaN  Half-Life: Opposing Force          852           NaN     NaN
# 147  NaN  Half-Life: Opposing Force         4330           NaN     NaN
# 256  NaN  Half-Life: Opposing Force         8740           NaN     NaN
# 264  NaN  Half-Life: Opposing Force         8955           NaN     NaN
# 336  NaN  Half-Life: Opposing Force        11610           NaN     NaN
#
#     controller_support  dlc detailed_description about_the_game  \
# 26                 NaN  NaN                  NaN            NaN
# 147                NaN  NaN                  NaN            NaN
# 256                NaN  NaN                  NaN            NaN
# 264                NaN  NaN                  NaN            NaN
# 336                NaN  NaN                  NaN            NaN
#
#     short_description  fullgame supported_languages header_image website  \
# 26                NaN       NaN                 NaN          NaN     NaN
# 147               NaN       NaN                 NaN          NaN     NaN
# 256               NaN       NaN                 NaN          NaN     NaN
# 264               NaN       NaN                 NaN          NaN     NaN
# 336               NaN       NaN                 NaN          NaN     NaN
#
#     pc_requirements mac_requirements linux_requirements legal_notice  \
# 26              NaN              NaN                NaN          NaN
# 147             NaN              NaN                NaN          NaN
# 256             NaN              NaN                NaN          NaN
# 264             NaN              NaN                NaN          NaN
# 336             NaN              NaN                NaN          NaN
#
#     drm_notice ext_user_account_notice developers publishers demos  \
# 26         NaN                     NaN        NaN        NaN   NaN
# 147        NaN                     NaN        NaN        NaN   NaN
# 256        NaN                     NaN        NaN        NaN   NaN
# 264        NaN                     NaN        NaN        NaN   NaN
# 336        NaN                     NaN        NaN        NaN   NaN
#
#     price_overview packages package_groups platforms metacritic reviews  \
# 26             NaN      NaN            NaN       NaN        NaN     NaN
# 147            NaN      NaN            NaN       NaN        NaN     NaN
# 256            NaN      NaN            NaN       NaN        NaN     NaN
# 264            NaN      NaN            NaN       NaN        NaN     NaN
# 336            NaN      NaN            NaN       NaN        NaN     NaN
#
#     categories genres screenshots movies recommendations achievements  \
# 26         NaN    NaN         NaN    NaN             NaN          NaN
# 147        NaN    NaN         NaN    NaN             NaN          NaN
# 256        NaN    NaN         NaN    NaN             NaN          NaN
# 264        NaN    NaN         NaN    NaN             NaN          NaN
# 336        NaN    NaN         NaN    NaN             NaN          NaN
#
#     release_date support_info background content_descriptors
# 26           NaN          NaN        NaN                 NaN
# 147          NaN          NaN        NaN                 NaN
# 256          NaN          NaN        NaN                 NaN
# 264          NaN          NaN        NaN                 NaN
# 336          NaN          NaN        NaN                 NaN

# %% [markdown]
# We can look at the counts of unique values in a column by using the pandas [Series.value_counts](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.value_counts.html) method.
#
# Once the null rows are removed, we can see that all the other rows have 'game' as their type, meaning this column isn't of any use and can be safely dropped.

# %%
raw_steam_data['type'].value_counts(dropna=False)
# Out:
# game    29086
# NaN       149
# Name: type, dtype: int64

# %% [markdown]
# In the name column we have a couple of rows without a title (or 'none' as the title). It looks like these can be safely removed.

# %%
raw_steam_data[(raw_steam_data['name'].isnull()) | (raw_steam_data['name'] == 'none')]
# Out:
#       type  name  steam_appid  required_age is_free controller_support  dlc  \
# 4918  game  none       339860           0.0   False                NaN  NaN
# 6779  game  none       385020           0.0   False                NaN  NaN
# 7235  game   NaN       396420           0.0    True                NaN  NaN
# 7350  game  none       398970           0.0   False                NaN  NaN
#
#                                    detailed_description  \
# 4918                                                NaN
# 6779                   - discontinued - (please remove)
# 7235  Spookeningは3Dの恐怖ゲームで、あなたは毎夜に死んでゴーストとして復活します。<b...
# 7350                                                NaN
#
#                                          about_the_game  \
# 4918                                                NaN
# 6779                   - discontinued - (please remove)
# 7235  Spookeningは3Dの恐怖ゲームで、あなたは毎夜に死んでゴーストとして復活します。<b...
# 7350                                                NaN
#
#                                       short_description  fullgame  \
# 4918                                                NaN       NaN
# 6779                   - discontinued - (please remove)       NaN
# 7235  Spookeningは3Dの恐怖ゲームで、あなたは毎夜に死んでゴーストとして復活します。 村...       NaN
# 7350                                                NaN       NaN
#
#                                     supported_languages  \
# 4918  English<strong>*</strong><br><strong>*</strong...
# 6779  English, French, Italian, German, Spanish - Sp...
# 7235                                                NaN
# 7350  English<strong>*</strong><br><strong>*</strong...
#
#                                            header_image website  \
# 4918  https://steamcdn-a.akamaihd.net/steam/apps/339...     NaN
# 6779  https://steamcdn-a.akamaihd.net/steam/apps/385...     NaN
# 7235  https://steamcdn-a.akamaihd.net/steam/apps/396...     NaN
# 7350  https://steamcdn-a.akamaihd.net/steam/apps/398...     NaN
#
#                                         pc_requirements  \
# 4918  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 6779  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 7235  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 7350  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                        mac_requirements  \
# 4918                                                 []
# 6779  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 7235                                                 []
# 7350  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                      linux_requirements legal_notice  \
# 4918                                                 []          NaN
# 6779  {'minimum': '<strong>Minimum:</strong><br><ul ...          NaN
# 7235                                                 []          NaN
# 7350  {'minimum': '<strong>Minimum:</strong><br><ul ...          NaN
#
#      drm_notice ext_user_account_notice developers publishers  \
# 4918        NaN                     NaN        NaN       ['']
# 6779        NaN                     NaN   ['none']       ['']
# 7235        NaN                     NaN        NaN       ['']
# 7350        NaN                     NaN   ['none']   ['none']
#
#                                        demos price_overview packages  \
# 4918                                     NaN            NaN      NaN
# 6779                                     NaN            NaN      NaN
# 7235                                     NaN            NaN      NaN
# 7350  [{'appid': 516340, 'description': ''}]            NaN      NaN
#
#      package_groups                                        platforms  \
# 4918             []  {'windows': True, 'mac': False, 'linux': False}
# 6779             []    {'windows': True, 'mac': True, 'linux': True}
# 7235             []  {'windows': True, 'mac': False, 'linux': False}
# 7350             []    {'windows': True, 'mac': True, 'linux': True}
#
#      metacritic reviews                                         categories  \
# 4918        NaN     NaN  [{'id': 2, 'description': 'Single-player'}, {'...
# 6779        NaN     NaN  [{'id': 2, 'description': 'Single-player'}, {'...
# 7235        NaN     NaN                                                NaN
# 7350        NaN     NaN  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                                  genres screenshots movies  \
# 4918  [{'id': '25', 'description': 'Adventure'}, {'i...         NaN    NaN
# 6779  [{'id': '4', 'description': 'Casual'}, {'id': ...         NaN    NaN
# 7235                                                NaN         NaN    NaN
# 7350  [{'id': '25', 'description': 'Adventure'}, {'i...         NaN    NaN
#
#      recommendations                                       achievements  \
# 4918             NaN  {'total': 3, 'highlighted': [{'name': 'Master ...
# 6779             NaN                                       {'total': 0}
# 7235             NaN                                       {'total': 0}
# 7350             NaN  {'total': 35, 'highlighted': [{'name': "They'v...
#
#                                         release_date  \
# 4918  {'coming_soon': False, 'date': '27 Feb, 2015'}
# 6779   {'coming_soon': False, 'date': '4 Nov, 2015'}
# 7235   {'coming_soon': False, 'date': '1 Nov, 2016'}
# 7350   {'coming_soon': False, 'date': '5 Nov, 2015'}
#
#                   support_info background         content_descriptors
# 4918  {'url': '', 'email': ''}        NaN  {'ids': [], 'notes': None}
# 6779  {'url': '', 'email': ''}        NaN  {'ids': [], 'notes': None}
# 7235  {'url': '', 'email': ''}        NaN  {'ids': [], 'notes': None}
# 7350  {'url': '', 'email': ''}        NaN  {'ids': [], 'notes': None}

# %% [markdown]
# We also have some duplicated rows, likely caused by errors or overlapping in our data collection process. As we know for certain that all AppIDs should be unique, we can safely remove these duplicates straight away.

# %%
raw_steam_data[raw_steam_data.duplicated()].head()
# Out:
#      type                     name  steam_appid  required_age is_free  \
# 31   game  SiN Episodes: Emergence         1300           0.0   False
# 32   game  SiN Episodes: Emergence         1300           0.0   False
# 356  game   Jagged Alliance 2 Gold         1620           0.0   False
# 493  game       Crazy Machines 1.5        18430           0.0   False
# 494  game       Crazy Machines 1.5        18430           0.0   False
#
#     controller_support  dlc  \
# 31                 NaN  NaN
# 32                 NaN  NaN
# 356                NaN  NaN
# 493                NaN  NaN
# 494                NaN  NaN
#
#                                   detailed_description  \
# 31   You are John Blade, commander of HardCorps, an...
# 32   You are John Blade, commander of HardCorps, an...
# 356  <p>The small country of Arulco has been taken ...
# 493  Create Your Own Zany &quot;Rube Goldberg&quot;...
# 494  Create Your Own Zany &quot;Rube Goldberg&quot;...
#
#                                         about_the_game  \
# 31   You are John Blade, commander of HardCorps, an...
# 32   You are John Blade, commander of HardCorps, an...
# 356  <p>The small country of Arulco has been taken ...
# 493  Create Your Own Zany &quot;Rube Goldberg&quot;...
# 494  Create Your Own Zany &quot;Rube Goldberg&quot;...
#
#                                      short_description  fullgame  \
# 31   You are John Blade, commander of HardCorps, an...       NaN
# 32   You are John Blade, commander of HardCorps, an...       NaN
# 356  The small country of Arulco has been taken ove...       NaN
# 493  Create Your Own Zany &quot;Rube Goldberg&quot;...       NaN
# 494  Create Your Own Zany &quot;Rube Goldberg&quot;...       NaN
#
#           supported_languages  \
# 31   English, Russian, French
# 32   English, Russian, French
# 356                   English
# 493                   English
# 494                   English
#
#                                           header_image  \
# 31   https://steamcdn-a.akamaihd.net/steam/apps/130...
# 32   https://steamcdn-a.akamaihd.net/steam/apps/130...
# 356  https://steamcdn-a.akamaihd.net/steam/apps/162...
# 493  https://steamcdn-a.akamaihd.net/steam/apps/184...
# 494  https://steamcdn-a.akamaihd.net/steam/apps/184...
#
#                              website  \
# 31                               NaN
# 32                               NaN
# 356  http://www.jaggedalliance2.com/
# 493                              NaN
# 494                              NaN
#
#                                        pc_requirements mac_requirements  \
# 31   {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...               []
# 32   {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...               []
# 356  {'minimum': '<p><strong>Minimum Configuration:...               []
# 493  {'minimum': '<ul class="bb_ul"><li><strong>OS:...               []
# 494  {'minimum': '<ul class="bb_ul"><li><strong>OS:...               []
#
#     linux_requirements legal_notice drm_notice ext_user_account_notice  \
# 31                  []          NaN        NaN                     NaN
# 32                  []          NaN        NaN                     NaN
# 356                 []          NaN        NaN                     NaN
# 493                 []          NaN        NaN                     NaN
# 494                 []          NaN        NaN                     NaN
#
#                    developers                publishers demos  \
# 31   ['Ritual Entertainment']  ['Ritual Entertainment']   NaN
# 32   ['Ritual Entertainment']  ['Ritual Entertainment']   NaN
# 356        ['Strategy First']        ['Strategy First']   NaN
# 493         ['Fakt Software']            ['Viva Media']   NaN
# 494         ['Fakt Software']            ['Viva Media']   NaN
#
#                                         price_overview       packages  \
# 31   {'currency': 'GBP', 'initial': 719, 'final': 7...           [70]
# 32   {'currency': 'GBP', 'initial': 719, 'final': 7...           [70]
# 356  {'currency': 'GBP', 'initial': 1499, 'final': ...           [94]
# 493  {'currency': 'GBP', 'initial': 699, 'final': 6...  [1242, 58401]
# 494  {'currency': 'GBP', 'initial': 699, 'final': 6...  [1242, 58401]
#
#                                         package_groups  \
# 31   [{'name': 'default', 'title': 'Buy SiN Episode...
# 32   [{'name': 'default', 'title': 'Buy SiN Episode...
# 356  [{'name': 'default', 'title': 'Buy Jagged Alli...
# 493  [{'name': 'default', 'title': 'Buy Crazy Machi...
# 494  [{'name': 'default', 'title': 'Buy Crazy Machi...
#
#                                            platforms  \
# 31   {'windows': True, 'mac': False, 'linux': False}
# 32   {'windows': True, 'mac': False, 'linux': False}
# 356  {'windows': True, 'mac': False, 'linux': False}
# 493  {'windows': True, 'mac': False, 'linux': False}
# 494  {'windows': True, 'mac': False, 'linux': False}
#
#                                             metacritic reviews  \
# 31   {'score': 75, 'url': 'https://www.metacritic.c...     NaN
# 32   {'score': 75, 'url': 'https://www.metacritic.c...     NaN
# 356                                                NaN     NaN
# 493  {'score': 78, 'url': 'https://www.metacritic.c...     NaN
# 494  {'score': 78, 'url': 'https://www.metacritic.c...     NaN
#
#                                             categories  \
# 31   [{'id': 2, 'description': 'Single-player'}, {'...
# 32   [{'id': 2, 'description': 'Single-player'}, {'...
# 356        [{'id': 2, 'description': 'Single-player'}]
# 493        [{'id': 2, 'description': 'Single-player'}]
# 494        [{'id': 2, 'description': 'Single-player'}]
#
#                                                 genres  \
# 31              [{'id': '1', 'description': 'Action'}]
# 32              [{'id': '1', 'description': 'Action'}]
# 356           [{'id': '2', 'description': 'Strategy'}]
# 493  [{'id': '4', 'description': 'Casual'}, {'id': ...
# 494  [{'id': '4', 'description': 'Casual'}, {'id': ...
#
#                                            screenshots movies recommendations  \
# 31   [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 265}
# 32   [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 265}
# 356  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             NaN
# 493  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             NaN
# 494  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             NaN
#
#      achievements                                    release_date  \
# 31   {'total': 0}  {'coming_soon': False, 'date': '10 May, 2006'}
# 32   {'total': 0}  {'coming_soon': False, 'date': '10 May, 2006'}
# 356  {'total': 0}   {'coming_soon': False, 'date': '6 Jul, 2006'}
# 493  {'total': 0}  {'coming_soon': False, 'date': '12 Dec, 2008'}
# 494  {'total': 0}  {'coming_soon': False, 'date': '12 Dec, 2008'}
#
#                  support_info  \
# 31   {'url': '', 'email': ''}
# 32   {'url': '', 'email': ''}
# 356  {'url': '', 'email': ''}
# 493  {'url': '', 'email': ''}
# 494  {'url': '', 'email': ''}
#
#                                             background  \
# 31   https://steamcdn-a.akamaihd.net/steam/apps/130...
# 32   https://steamcdn-a.akamaihd.net/steam/apps/130...
# 356  https://steamcdn-a.akamaihd.net/steam/apps/162...
# 493  https://steamcdn-a.akamaihd.net/steam/apps/184...
# 494  https://steamcdn-a.akamaihd.net/steam/apps/184...
#
#             content_descriptors
# 31   {'ids': [], 'notes': None}
# 32   {'ids': [], 'notes': None}
# 356  {'ids': [], 'notes': None}
# 493  {'ids': [], 'notes': None}
# 494  {'ids': [], 'notes': None}

# %% [markdown]
# Here we define and run our functions to handle everything we just looked at. We also define a general `process` function which will run all of our processing functions on the data set, allowing us to slowly add to it as we build out to processing more columns. Finally we run this function on our raw data, inspecting the first few rows and viewing how many rows and columns we have dropped.

# %%
def process_null_cols(df, thresh=0.5):
    """Drop columns with more than a certain proportion of missing values (Default 50%)."""
    cutoff_count = len(df) * thresh
    
    return df.dropna(thresh=cutoff_count, axis=1)


def drop_null_rows(df, col):
    """Drop rows with null values in a particular column."""
    return df[df[col].notnull()]


def process_type(df):
    """Remove rows with null values for type column, then drop the column."""
    df = drop_null_rows(df, 'type')
    df = df.drop('type', axis=1)
    
    return df
    
    
def process_name(df):
    """Remove rows with null values or 'none' in name column."""
    df = drop_null_rows(df, 'name')
    df = df[df['name'] != 'none']
    
    return df


def process(df):
    """Process data set. Will eventually contain calls to all functions we write."""
    
    # Copy the input dataframe to avoid accidentally modifying original data
    df = df.copy()
    
    # Remove duplicate rows - all appids should be unique
    df = df.drop_duplicates()
    
    # Remove collumns with more than 50% null values
    df = process_null_cols(df)
    
    # Process rest of columns
    df = process_type(df)
    df = process_name(df)
    
    return df

print(raw_steam_data.shape)
steam_data = process(raw_steam_data)
print(steam_data.shape)
steam_data.head()
# Out:
# (29235, 39)
# (29075, 28)
#                         name  steam_appid  required_age is_free  \
# 0             Counter-Strike           10           0.0   False
# 1      Team Fortress Classic           20           0.0   False
# 2              Day of Defeat           30           0.0   False
# 3         Deathmatch Classic           40           0.0   False
# 4  Half-Life: Opposing Force           50           0.0   False
#
#                                 detailed_description  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                       about_the_game  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                    short_description  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                  supported_languages  \
# 0  English<strong>*</strong>, French<strong>*</st...
# 1  English, French, German, Italian, Spanish - Sp...
# 2  English, French, German, Italian, Spanish - Spain
# 3  English, French, German, Italian, Spanish - Sp...
# 4                    English, French, German, Korean
#
#                                         header_image  \
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...
#
#                        website  \
# 0                          NaN
# 1                          NaN
# 2  http://www.dayofdefeat.com/
# 3                          NaN
# 4                          NaN
#
#                                      pc_requirements  \
# 0  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 1  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 2  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 3  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 4  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
#
#                                     mac_requirements  \
# 0  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 1  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 2  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 3  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 4  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
#
#                                   linux_requirements            developers  \
# 0  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 1  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 2  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 3  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 4  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...  ['Gearbox Software']
#
#   publishers                                     price_overview packages  \
# 0  ['Valve']  {'currency': 'GBP', 'initial': 719, 'final': 7...      [7]
# 1  ['Valve']  {'currency': 'GBP', 'initial': 399, 'final': 3...     [29]
# 2  ['Valve']  {'currency': 'GBP', 'initial': 399, 'final': 3...     [30]
# 3  ['Valve']  {'currency': 'GBP', 'initial': 399, 'final': 3...     [31]
# 4  ['Valve']  {'currency': 'GBP', 'initial': 399, 'final': 3...     [32]
#
#                                       package_groups  \
# 0  [{'name': 'default', 'title': 'Buy Counter-Str...
# 1  [{'name': 'default', 'title': 'Buy Team Fortre...
# 2  [{'name': 'default', 'title': 'Buy Day of Defe...
# 3  [{'name': 'default', 'title': 'Buy Deathmatch ...
# 4  [{'name': 'default', 'title': 'Buy Half-Life: ...
#
#                                        platforms  \
# 0  {'windows': True, 'mac': True, 'linux': True}
# 1  {'windows': True, 'mac': True, 'linux': True}
# 2  {'windows': True, 'mac': True, 'linux': True}
# 3  {'windows': True, 'mac': True, 'linux': True}
# 4  {'windows': True, 'mac': True, 'linux': True}
#
#                                           categories  \
# 0  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 1  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 2  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 3  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 4  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                    genres  \
# 0  [{'id': '1', 'description': 'Action'}]
# 1  [{'id': '1', 'description': 'Action'}]
# 2  [{'id': '1', 'description': 'Action'}]
# 3  [{'id': '1', 'description': 'Action'}]
# 4  [{'id': '1', 'description': 'Action'}]
#
#                                          screenshots movies  achievements  \
# 0  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 1  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 2  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 3  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 4  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
#
#                                     release_date  \
# 0  {'coming_soon': False, 'date': '1 Nov, 2000'}
# 1  {'coming_soon': False, 'date': '1 Apr, 1999'}
# 2  {'coming_soon': False, 'date': '1 May, 2003'}
# 3  {'coming_soon': False, 'date': '1 Jun, 2001'}
# 4  {'coming_soon': False, 'date': '1 Nov, 1999'}
#
#                                         support_info  \
# 0  {'url': 'http://steamcommunity.com/app/10', 'e...
# 1                           {'url': '', 'email': ''}
# 2                           {'url': '', 'email': ''}
# 3                           {'url': '', 'email': ''}
# 4  {'url': 'https://help.steampowered.com', 'emai...
#
#                                           background  \
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...
#
#                                  content_descriptors
# 0  {'ids': [2, 5], 'notes': 'Includes intense vio...
# 1  {'ids': [2, 5], 'notes': 'Includes intense vio...
# 2                         {'ids': [], 'notes': None}
# 3                         {'ids': [], 'notes': None}
# 4                         {'ids': [], 'notes': None}

# %% [markdown]
# ### Processing age
#
# The next column we will look at is 'required_age'. We can see that it is already stored as integers, and values range from 0 to 20, with one likely error (1818).

# %%
steam_data['required_age'].value_counts().sort_index()
# Out:
# 0.0       28431
# 1.0           1
# 3.0          10
# 4.0           2
# 5.0           1
# 6.0           1
# 7.0           8
# 10.0          3
# 11.0          4
# 12.0         72
# 13.0         21
# 14.0          4
# 15.0         39
# 16.0        141
# 17.0         47
# 18.0        288
# 20.0          1
# 1818.0        1
# Name: required_age, dtype: int64

# %% [markdown]
# Whilst fairly useful in its current state, we may benefit from reducing the number of categories that ages fall into. Instead of comparing games rated as 5, 6, 7 or 8, we could compare games rated 5+ or 8+, for example.
#
# To decide which categories (or bins) we should use, we will look at the [PEGI age ratings](https://pegi.info/) as this is the system used in the United Kingdom, where we're performing our analysis. We can see that ratings fall into one of five categories (3, 7, 12, 16, 18), defining the minimum age required to buy a game.
#
# Using this to inform our decision, we can use the [pandas.cut](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.cut.html) function to sort our data into each of these categories. As our erroneous row (1818) is most likely meant to be rated 18 anyway, we can set our upper bound above this value to catch it inside this category.

# %%
def process_age(df):
    """Format ratings in age column to be in line with the PEGI Age Ratings system."""
    # PEGI Age ratings: 3, 7, 12, 16, 18
    cut_points = [-1, 3, 7, 12, 16, 2000]
    label_values = [3, 7, 12, 16, 18]
    
    df['required_age'] = pd.cut(df['required_age'], bins=cut_points, labels=label_values)
    
    return df


def process(df):
    """Process data set. Will eventually contain calls to all functions we write."""
    
    # Copy the input dataframe to avoid accidentally modifying original data
    df = df.copy()
    
    # Remove duplicate rows - all appids should be unique
    df = df.drop_duplicates()
    
    # Remove collumns with more than 50% null values
    df = process_null_cols(df)
    
    # Process rest of columns
    df = process_type(df)
    df = process_name(df)
    df = process_age(df)
    
    return df


steam_data = process(raw_steam_data)
steam_data['required_age'].value_counts().sort_index()
# Out:
# 3     28442
# 7        12
# 12       79
# 16      205
# 18      337
# Name: required_age, dtype: int64

# %% [markdown]
# ### Processing the platforms column
#
# Whilst we could look at the next column in our dataframe, is_free, it would make sense that this is intrinsically linked to the price_overview column. Ultimately we may wish to combine these columns into one, where free games have a price of 0. Looking at the price_overview column, we can see it is stored in a dictionary-like structure, with multiple keys and values. Handling this may be quite tricky, so instead we'll look at a simpler example.
#
# The platforms column appears to contain a key for each of the main operating systems - windows, mac and linux - and corresponding boolean value, set to True or False depending on whether it is available on that platform. This should be a reasonably straighforward place to start, and we can separate this data out into three columns, one for each platform, filled with boolean values.

# %%
steam_data['platforms'].head()
# Out:
# 0    {'windows': True, 'mac': True, 'linux': True}
# 1    {'windows': True, 'mac': True, 'linux': True}
# 2    {'windows': True, 'mac': True, 'linux': True}
# 3    {'windows': True, 'mac': True, 'linux': True}
# 4    {'windows': True, 'mac': True, 'linux': True}
# Name: platforms, dtype: object

# %% [markdown]
# So far the cleaning process has been relatively simple, requiring mainly checking for null values and dropping some rows or columns. Already we can see that handling the platforms will be a little more complex.
#
# Our first hurdle is getting python to recognise the data in the columns as dictionaries rather than just strings. This will allow us to access the different values separately, without having to do some unnecessarily complicated string formatting. As we can see below, even though the data looks like a dictionary it is in fact stored as a string.

# %%
print(type(steam_data['platforms'].iloc[0]))

steam_data['platforms'].iloc[0]
# Out:
# <class 'str'>
# "{'windows': True, 'mac': True, 'linux': True}"

# %% [markdown]
# We can get around this using the handy [literal_eval](https://docs.python.org/3/library/ast.html#ast.literal_eval) function from the in-built `ast` module. As the name suggests, this will allow us to evaluate the string, and index into it as a
# dictionary.

# %%
print(type(literal_eval(steam_data['platforms'].iloc[0])))

literal_eval(steam_data['platforms'].iloc[0])['windows']
# Out:
# <class 'dict'>
# True

# %% [markdown]
# We also need to check for null values, but fortunately there aren't any in this column.

# %%
steam_data['platforms'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Putting this all together, we'll be using the pandas [Series.apply](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.apply.html) method to help us quickly evaluate all of the rows, then we'll be calling `apply` again for each platform to create our new columns.
#
# We could return the True/False value directly and store the values as boolean types, but since we'll be exporting the cleaned data to a csv file, let's store them as integers as this should reduce the file size slightly. Setting True as 1 and False as 0 can still be interpreted as a boolean type, but less data is used to store the information.

# %%
def process_platforms(df):
    """Split platforms column into separate boolean columns for each platform."""
    # evaluate values in platforms column, so can index into dictionaries
    df['platforms'] = df['platforms'].apply(lambda x: literal_eval(x))
    
    # loop across keys, the platforms, which we'll turn into columns
    for platform in df['platforms'][0].keys():
        # set 1 if value for platform in original column is True, or 0 if it is False
        df[platform] = df['platforms'].apply(lambda x: 1 if x[platform] else 0)
    
    # remove the original platforms column
    df = df.drop('platforms', axis=1)
    
    return df


def process(df):
    """Process data set. Will eventually contain calls to all functions we write."""
    
    # Copy the input dataframe to avoid accidentally modifying original data
    df = df.copy()
    
    # Remove duplicate rows - all appids should be unique
    df = df.drop_duplicates()
    
    # Remove collumns with more than 50% null values
    df = process_null_cols(df)
    
    # Process rest of columns
    df = process_type(df)
    df = process_name(df)
    df = process_age(df)
    df = process_platforms(df)
    
    return df


steam_data = process(raw_steam_data)
steam_data[['name', 'windows', 'mac', 'linux']].head()
# Out:
#                         name  windows  mac  linux
# 0             Counter-Strike        1    1      1
# 1      Team Fortress Classic        1    1      1
# 2              Day of Defeat        1    1      1
# 3         Deathmatch Classic        1    1      1
# 4  Half-Life: Opposing Force        1    1      1

# %% [markdown]
# ### Processing price
#
# Now we have built up some intuition around how to deal with the data stored as dictionaries, let's return to the `is_free` and `price_overview` columns as we should now be able to handle them.
#
# First let's check how many null values there are in `price_overview`.

# %%
steam_data['price_overview'].isnull().sum()
# Out:
# 3559

# %% [markdown]
# Whilst that looks like a lot, we have to consider the impact that the `is_free` column might be having. Before jumping to conclusions let's check if there any rows with `is_free` marked as True and null values in the `price_overview` column.

# %%
free_and_null_price = steam_data[(steam_data['is_free']) & (steam_data['price_overview'].isnull())]

print(free_and_null_price.shape[0])
free_and_null_price.head()
# Out:
# 2713
#                                 name  steam_appid required_age is_free  \
# 14           Half-Life 2: Lost Coast          340            3    True
# 19                   Team Fortress 2          440            3    True
# 22                            Dota 2          570            3    True
# 24                       Alien Swarm          630            3    True
# 25  Counter-Strike: Global Offensive          730            3    True
#
#                                  detailed_description  \
# 14  Originally planned as a section of the Highway...
# 19  <h1>The Jungle Inferno Update</h1><p><a href="...
# 22  <strong>The most-played game on Steam.</strong...
# 24  Alien Swarm is a game and Source SDK release f...
# 25  Counter-Strike: Global Offensive (CS: GO) expa...
#
#                                        about_the_game  \
# 14  Originally planned as a section of the Highway...
# 19  <p><strong>"The most fun you can have online"<...
# 22  <strong>The most-played game on Steam.</strong...
# 24  Alien Swarm is a game and Source SDK release f...
# 25  Counter-Strike: Global Offensive (CS: GO) expa...
#
#                                     short_description  \
# 14  Originally planned as a section of the Highway...
# 19  Nine distinct classes provide a broad range of...
# 22  Every day, millions of players worldwide enter...
# 24  Co-operative multiplayer game and complete cod...
# 25  Counter-Strike: Global Offensive (CS: GO) expa...
#
#                                   supported_languages  \
# 14  English, French, German, Italian, Spanish - Sp...
# 19  English<strong>*</strong>, Danish, Dutch, Finn...
# 22  Bulgarian, Czech, Danish, Dutch, English<stron...
# 24                                            English
# 25  Czech, Danish, Dutch, English<strong>*</strong...
#
#                                          header_image  \
# 14  https://steamcdn-a.akamaihd.net/steam/apps/340...
# 19  https://steamcdn-a.akamaihd.net/steam/apps/440...
# 22  https://steamcdn-a.akamaihd.net/steam/apps/570...
# 24  https://steamcdn-a.akamaihd.net/steam/apps/630...
# 25  https://steamcdn-a.akamaihd.net/steam/apps/730...
#
#                             website  \
# 14        http://www.half-life2.com
# 19     http://www.teamfortress.com/
# 22            http://www.dota2.com/
# 24        http://www.alienswarm.com
# 25  http://blog.counter-strike.net/
#
#                                       pc_requirements  \
# 14  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 19  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 22  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 24  {'minimum': '<strong>Minimum:</strong><br>\t\t...
# 25  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                      mac_requirements  \
# 14                                                 []
# 19  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 22  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 24                                                 []
# 25  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                    linux_requirements  \
# 14                                                 []
# 19  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 22  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 24                                                 []
# 25  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                 developers publishers price_overview  \
# 14                               ['Valve']  ['Valve']            NaN
# 19                               ['Valve']  ['Valve']            NaN
# 22                               ['Valve']  ['Valve']            NaN
# 24                               ['Valve']  ['Valve']            NaN
# 25  ['Valve', 'Hidden Path Entertainment']  ['Valve']            NaN
#
#                    packages  \
# 14                      NaN
# 19    [197845, 330198, 469]
# 22         [197846, 330209]
# 24                      NaN
# 25  [329385, 298963, 54029]
#
#                                        package_groups  \
# 14                                                 []
# 19  [{'name': 'default', 'title': 'Buy Team Fortre...
# 22  [{'name': 'default', 'title': 'Buy Dota 2', 'd...
# 24                                                 []
# 25  [{'name': 'default', 'title': 'Buy Counter-Str...
#
#                                            categories  \
# 14  [{'id': 2, 'description': 'Single-player'}, {'...
# 19  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 22  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 24  [{'id': 2, 'description': 'Single-player'}, {'...
# 25  [{'id': 1, 'description': 'Multi-player'}, {'i...
#
#                                                genres  \
# 14             [{'id': '1', 'description': 'Action'}]
# 19  [{'id': '1', 'description': 'Action'}, {'id': ...
# 22  [{'id': '1', 'description': 'Action'}, {'id': ...
# 24             [{'id': '1', 'description': 'Action'}]
# 25  [{'id': '1', 'description': 'Action'}, {'id': ...
#
#                                           screenshots  \
# 14  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 19  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 22  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 24  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 25  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
#
#                                                movies  \
# 14                                                NaN
# 19  [{'id': 256698790, 'name': 'Jungle Inferno', '...
# 22  [{'id': 256692021, 'name': 'Dota 2 - Join the ...
# 24                                                NaN
# 25  [{'id': 81958, 'name': 'CS:GO Trailer Long', '...
#
#                                          achievements  \
# 14                                       {'total': 0}
# 19  {'total': 520, 'highlighted': [{'name': 'Head ...
# 22                                                NaN
# 24  {'total': 66, 'highlighted': [{'name': 'Clear ...
# 25  {'total': 167, 'highlighted': [{'name': 'Someo...
#
#                                       release_date  \
# 14  {'coming_soon': False, 'date': '27 Oct, 2005'}
# 19  {'coming_soon': False, 'date': '10 Oct, 2007'}
# 22   {'coming_soon': False, 'date': '9 Jul, 2013'}
# 24  {'coming_soon': False, 'date': '19 Jul, 2010'}
# 25  {'coming_soon': False, 'date': '21 Aug, 2012'}
#
#                                          support_info  \
# 14                           {'url': '', 'email': ''}
# 19  {'url': 'http://steamcommunity.com/app/440', '...
# 22      {'url': 'http://dev.dota2.com/', 'email': ''}
# 24                           {'url': '', 'email': ''}
# 25                           {'url': '', 'email': ''}
#
#                                            background  \
# 14  https://steamcdn-a.akamaihd.net/steam/apps/340...
# 19  https://steamcdn-a.akamaihd.net/steam/apps/440...
# 22  https://steamcdn-a.akamaihd.net/steam/apps/570...
# 24  https://steamcdn-a.akamaihd.net/steam/apps/630...
# 25  https://steamcdn-a.akamaihd.net/steam/apps/730...
#
#                                   content_descriptors  windows  mac  linux
# 14                         {'ids': [], 'notes': None}        1    1      1
# 19  {'ids': [2, 5], 'notes': 'Includes cartoon vio...        1    1      1
# 22                         {'ids': [], 'notes': None}        1    1      1
# 24                         {'ids': [], 'notes': None}        1    0      0
# 25  {'ids': [2, 5], 'notes': 'Includes intense vio...        1    1      1

# %% [markdown]
# Turns out this accounts for most of our null values in the `price_overview` column, meaning we can handle these by setting our final price as 0. This means that there are almost 850 rows which aren't free but have null values in the `price_overview` column. Let's investigate those.

# %%
not_free_and_null_price = steam_data[(steam_data['is_free'] == False) & (steam_data['price_overview'].isnull())]

not_free_and_null_price.head()
# Out:
#                                   name  steam_appid required_age is_free  \
# 63             The Ship: Single Player         2420            3   False
# 75   RollerCoaster Tycoon® 3: Platinum         2700            3   False
# 220                          BioShock™         7670            3   False
# 234       Sam & Max 101: Culture Shock         8200            3   False
# 235   Sam & Max 102: Situation: Comedy         8210            3   False
#
#                                   detailed_description  \
# 63   For PC gamers who enjoy multiplayer games with...
# 75   Rollercoaster Tycoon 3 Platinum combines the e...
# 220  <h1>Special Offer</h1><p>Buying BioShock™ also...
# 234  <strong>Sam &amp; Max: Episode 1 - Culture Sho...
# 235  <strong>Sam &amp; Max: Episode 2 - Situation: ...
#
#                                         about_the_game  \
# 63   For PC gamers who enjoy multiplayer games with...
# 75   Rollercoaster Tycoon 3 Platinum combines the e...
# 220  BioShock is a shooter unlike any you've ever p...
# 234  <strong>Sam &amp; Max: Episode 1 - Culture Sho...
# 235  <strong>Sam &amp; Max: Episode 2 - Situation: ...
#
#                                      short_description  \
# 63   The Ship is a murder mystery alternative to tr...
# 75   Rollercoaster Tycoon 3 Platinum combines the e...
# 220  BioShock is a shooter unlike any you've ever p...
# 234  Sam &amp; Max: Episode 1 - Culture Shock - The...
# 235  Sam &amp; Max: Episode 2 - Situation: Comedy -...
#
#                                    supported_languages  \
# 63   English, French, German, Italian, Spanish - Sp...
# 75   English, French, Italian, German, Spanish - Sp...
# 220  English<strong>*</strong>, French<strong>*</st...
# 234                   English, French, German, Italian
# 235                           English, German, Italian
#
#                                           header_image  \
# 63   https://steamcdn-a.akamaihd.net/steam/apps/242...
# 75   https://steamcdn-a.akamaihd.net/steam/apps/270...
# 220  https://steamcdn-a.akamaihd.net/steam/apps/767...
# 234  https://steamcdn-a.akamaihd.net/steam/apps/820...
# 235  https://steamcdn-a.akamaihd.net/steam/apps/821...
#
#                                                website  \
# 63   http://www.blazinggriffin.com/games/the-ship-m...
# 75   http://www.atari.com/rollercoastertycoon/us/in...
# 220                        http://www.BioShockGame.com
# 234          http://store.steampowered.com/app/901660/
# 235          http://store.steampowered.com/app/901660/
#
#                                        pc_requirements  \
# 63   {'minimum': '<strong>Minimum:</strong> 1.8 GHz...
# 75   {'minimum': '<strong>Minimum: </strong><br>\t\...
# 220  {'minimum': '<h2 class="bb_tag"><strong>Minimu...
# 234  {'minimum': 'Windows XP or Vista, 1.5GHz proce...
# 235  {'minimum': 'Windows XP or Vista, 1.5GHz proce...
#
#                                       mac_requirements linux_requirements  \
# 63                                                  []                 []
# 75   {'minimum': '<ul class="bb_ul"><li><strong>OS:...                 []
# 220      {'minimum': 'Please See BioShock Remastered'}                 []
# 234                                                 []                 []
# 235                                                 []                 []
#
#                         developers                publishers price_overview  \
# 63             ['Outerlight Ltd.']  ['Blazing Griffin Ltd.']            NaN
# 75     ['Frontier', 'Aspyr (Mac)']  ['Atari', 'Aspyr (Mac)']            NaN
# 220  ['2K Boston', '2K Australia']                    ['2K']            NaN
# 234             ['Telltale Games']        ['Telltale Games']            NaN
# 235             ['Telltale Games']        ['Telltale Games']            NaN
#
#           packages                                     package_groups  \
# 63         [56669]  [{'name': 'default', 'title': 'Buy The Ship: S...
# 75             NaN                                                 []
# 220  [451, 127633]  [{'name': 'default', 'title': 'Buy BioShock™',...
# 234     [357, 539]  [{'name': 'default', 'title': 'Buy Sam & Max 1...
# 235     [358, 539]  [{'name': 'default', 'title': 'Buy Sam & Max 1...
#
#                                             categories  \
# 63         [{'id': 2, 'description': 'Single-player'}]
# 75         [{'id': 2, 'description': 'Single-player'}]
# 220  [{'id': 2, 'description': 'Single-player'}, {'...
# 234        [{'id': 2, 'description': 'Single-player'}]
# 235        [{'id': 2, 'description': 'Single-player'}]
#
#                                                 genres  \
# 63   [{'id': '1', 'description': 'Action'}, {'id': ...
# 75   [{'id': '28', 'description': 'Simulation'}, {'...
# 220  [{'id': '1', 'description': 'Action'}, {'id': ...
# 234  [{'id': '1', 'description': 'Action'}, {'id': ...
# 235  [{'id': '1', 'description': 'Action'}, {'id': ...
#
#                                            screenshots  \
# 63   [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 75   [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 220  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 234  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 235  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
#
#                                                 movies  achievements  \
# 63   [{'id': 2035597, 'name': 'the Ship:  Intro', '...  {'total': 0}
# 75                                                 NaN  {'total': 0}
# 220                                                NaN  {'total': 0}
# 234                                                NaN  {'total': 0}
# 235                                                NaN  {'total': 0}
#
#                                        release_date  \
# 63   {'coming_soon': False, 'date': '20 Nov, 2006'}
# 75   {'coming_soon': False, 'date': '12 Mar, 2008'}
# 220  {'coming_soon': False, 'date': '21 Aug, 2007'}
# 234  {'coming_soon': False, 'date': '15 Jun, 2007'}
# 235  {'coming_soon': False, 'date': '15 Jun, 2007'}
#
#                                           support_info  \
# 63                            {'url': '', 'email': ''}
# 75   {'url': 'http://www.atari.com/support/atari', ...
# 220             {'url': 'support.2k.com', 'email': ''}
# 234                           {'url': '', 'email': ''}
# 235                           {'url': '', 'email': ''}
#
#                                             background  \
# 63   https://steamcdn-a.akamaihd.net/steam/apps/242...
# 75   https://steamcdn-a.akamaihd.net/steam/apps/270...
# 220  https://steamcdn-a.akamaihd.net/steam/apps/767...
# 234  https://steamcdn-a.akamaihd.net/steam/apps/820...
# 235  https://steamcdn-a.akamaihd.net/steam/apps/821...
#
#             content_descriptors  windows  mac  linux
# 63   {'ids': [], 'notes': None}        1    0      0
# 75   {'ids': [], 'notes': None}        1    1      0
# 220  {'ids': [], 'notes': None}        1    0      0
# 234  {'ids': [], 'notes': None}        1    0      0
# 235  {'ids': [], 'notes': None}        1    0      0

# %% [markdown]
# The first few rows contain big, well-known games which appear to have pretty complete data. It looks like we can rule out data errors, so let's dig a little deeper and see if we can find out what is going on.
#
# We'll start by looking at the store pages for some of these titles. The url to an app on the steam website follows this structure:
#
#     https://store.steampowered.com/app/[steam_appid]
#
# This means we can easily generate these links using our above filter. We'll wrap it up in a function in case we want to use it later.

# %%
def print_steam_links(df):
    """Print links to store page for apps in a dataframe."""
    url_base = "https://store.steampowered.com/app/"
    
    for i, row in df.iterrows():
        appid = row['steam_appid']
        name = row['name']
        
        print(name + ':', url_base + str(appid))
        

print_steam_links(not_free_and_null_price[:5])
# Out:
# The Ship: Single Player: https://store.steampowered.com/app/2420
# RollerCoaster Tycoon® 3: Platinum: https://store.steampowered.com/app/2700
# BioShock™: https://store.steampowered.com/app/7670
# Sam & Max 101: Culture Shock: https://store.steampowered.com/app/8200
# Sam & Max 102: Situation: Comedy: https://store.steampowered.com/app/8210

# %% [markdown]
# For these games we can conclude that:
#
# - The Ship: Single Player is a tutorial, and comes as part of The Ship: Murder Party
# - RollerCoaster Tycoon 3: Platinum has been removed from steam (and another game website: gog)
#   - "A spokesperson for GOG told Eurogamer it pulled the game "due to expiring licensing rights", and stressed it'll talk with "new distribution rights holders" to bring the game back as soon as possible." Source: [Eurogamer](https://www.eurogamer.net/articles/2018-05-09-rollercoaster-tycoon-3-pulled-from-steam-gog)
# - BioShock has been replaced by BioShock Remastered
# - Sam & Max 101 is sold as part of a season, and this can be found in the `package_groups` column
#
# So we have a couple of options here. We could just drop these rows, we could try to figure out the price based on the package_groups column, or we could leave them for now and return to them later, which is what we will do. It may be that some or all of these rows are removed later in the cleaning process for other reasons.
#
# Below we can view the games with similar names to the games we investigated, to help get an idea of what is happening.

# %%
steam_data[steam_data['name'].str.contains("The Ship:")]
# Out:
#                          name  steam_appid required_age is_free  \
# 62     The Ship: Murder Party         2400            3    True
# 63    The Ship: Single Player         2420            3   False
# 6722       The Ship: Remasted       383790            3   False
#
#                                    detailed_description  \
# 62    <h1>Finding a Server</h1><p><strong>Ahoy Shipm...
# 63    For PC gamers who enjoy multiplayer games with...
# 6722  <h1>Now Includes World Leaders!</h1><p>Not onl...
#
#                                          about_the_game  \
# 62    <strong>This package includes a tutorial, The ...
# 63    For PC gamers who enjoy multiplayer games with...
# 6722  The Ship: Remasted is a remake of the classic ...
#
#                                       short_description  \
# 62            The Ship is a murder mystery multiplayer.
# 63    The Ship is a murder mystery alternative to tr...
# 6722  You find yourself aboard a series of luxury 19...
#
#                                     supported_languages  \
# 62    English, French, German, Italian, Spanish - Sp...
# 63    English, French, German, Italian, Spanish - Sp...
# 6722  English<strong>*</strong><br><strong>*</strong...
#
#                                            header_image  \
# 62    https://steamcdn-a.akamaihd.net/steam/apps/240...
# 63    https://steamcdn-a.akamaihd.net/steam/apps/242...
# 6722  https://steamcdn-a.akamaihd.net/steam/apps/383...
#
#                                                 website  \
# 62    http://www.blazinggriffin.com/games/the-ship-m...
# 63    http://www.blazinggriffin.com/games/the-ship-m...
# 6722  http://www.blazinggriffin.com/games/the-ship-r...
#
#                                         pc_requirements  \
# 62    {'minimum': '<strong>Minimum:</strong> 1.8 GHz...
# 63    {'minimum': '<strong>Minimum:</strong> 1.8 GHz...
# 6722  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                        mac_requirements  \
# 62                                                   []
# 63                                                   []
# 6722  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                      linux_requirements           developers  \
# 62                                                   []  ['Outerlight Ltd.']
# 63                                                   []  ['Outerlight Ltd.']
# 6722  {'minimum': '<strong>Minimum:</strong><br><ul ...  ['Blazing Griffin']
#
#                     publishers  \
# 62    ['Blazing Griffin Ltd.']
# 63    ['Blazing Griffin Ltd.']
# 6722       ['Blazing Griffin']
#
#                                          price_overview  packages  \
# 62    {'currency': 'GBP', 'initial': 699, 'final': 6...   [56669]
# 63                                                  NaN   [56669]
# 6722  {'currency': 'GBP', 'initial': 699, 'final': 6...  [253227]
#
#                                          package_groups  \
# 62    [{'name': 'default', 'title': 'Buy The Ship: M...
# 63    [{'name': 'default', 'title': 'Buy The Ship: S...
# 6722  [{'name': 'default', 'title': 'Buy The Ship: R...
#
#                                              categories  \
# 62    [{'id': 2, 'description': 'Single-player'}, {'...
# 63          [{'id': 2, 'description': 'Single-player'}]
# 6722  [{'id': 1, 'description': 'Multi-player'}, {'i...
#
#                                                  genres  \
# 62    [{'id': '1', 'description': 'Action'}, {'id': ...
# 63    [{'id': '1', 'description': 'Action'}, {'id': ...
# 6722  [{'id': '1', 'description': 'Action'}, {'id': ...
#
#                                             screenshots  \
# 62    [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 63    [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 6722  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
#
#                                                  movies  \
# 62    [{'id': 2034912, 'name': 'Single Player Intro'...
# 63    [{'id': 2035597, 'name': 'the Ship:  Intro', '...
# 6722  [{'id': 256673834, 'name': 'All Aboard!', 'thu...
#
#                                            achievements  \
# 62                                         {'total': 0}
# 63                                         {'total': 0}
# 6722  {'total': 22, 'highlighted': [{'name': 'Gone o...
#
#                                         release_date  \
# 62    {'coming_soon': False, 'date': '11 Jul, 2006'}
# 63    {'coming_soon': False, 'date': '20 Nov, 2006'}
# 6722  {'coming_soon': False, 'date': '31 Oct, 2016'}
#
#                                            support_info  \
# 62    {'url': 'http://www.blazinggriffin.com/', 'ema...
# 63                             {'url': '', 'email': ''}
# 6722  {'url': 'http://www.blazinggriffin.com/', 'ema...
#
#                                              background  \
# 62    https://steamcdn-a.akamaihd.net/steam/apps/240...
# 63    https://steamcdn-a.akamaihd.net/steam/apps/242...
# 6722  https://steamcdn-a.akamaihd.net/steam/apps/383...
#
#              content_descriptors  windows  mac  linux
# 62    {'ids': [], 'notes': None}        1    0      0
# 63    {'ids': [], 'notes': None}        1    0      0
# 6722  {'ids': [], 'notes': None}        1    1      1

# %%
steam_data[steam_data['name'].str.contains("BioShock™")]
# Out:
#                         name  steam_appid required_age is_free  \
# 220                BioShock™         7670            3   False
# 7734    BioShock™ Remastered       409710           18   False
# 7735  BioShock™ 2 Remastered       409720           18   False
#
#                                    detailed_description  \
# 220   <h1>Special Offer</h1><p>Buying BioShock™ also...
# 7734  <h1>Special Offer</h1><p>Buying BioShock™ Rema...
# 7735  <h1>Special Offer</h1><p>Buying BioShock 2™ Re...
#
#                                          about_the_game  \
# 220   BioShock is a shooter unlike any you've ever p...
# 7734  BioShock is a shooter unlike any you've ever p...
# 7735  BioShock 2 provides players with the perfect b...
#
#                                       short_description  \
# 220   BioShock is a shooter unlike any you've ever p...
# 7734  BioShock is a shooter unlike any other, loaded...
# 7735  In BioShock 2, you step into the boots of the ...
#
#                                     supported_languages  \
# 220   English<strong>*</strong>, French<strong>*</st...
# 7734  English<strong>*</strong>, French<strong>*</st...
# 7735  English<strong>*</strong>, French<strong>*</st...
#
#                                            header_image  \
# 220   https://steamcdn-a.akamaihd.net/steam/apps/767...
# 7734  https://steamcdn-a.akamaihd.net/steam/apps/409...
# 7735  https://steamcdn-a.akamaihd.net/steam/apps/409...
#
#                            website  \
# 220    http://www.BioShockGame.com
# 7734   http://www.BioShockGame.com
# 7735  http://www.bioshockgame.com/
#
#                                         pc_requirements  \
# 220   {'minimum': '<h2 class="bb_tag"><strong>Minimu...
# 7734  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 7735  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                        mac_requirements  \
# 220       {'minimum': 'Please See BioShock Remastered'}
# 7734  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 7735  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                      linux_requirements  \
# 220                                                  []
# 7734  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 7735  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                              developers  \
# 220                       ['2K Boston', '2K Australia']
# 7734  ['2K Boston', '2K Australia', 'Blind Squirrel'...
# 7735  ['2K Marin', '2K China', 'Digital Extremes', '...
#
#                              publishers  \
# 220                              ['2K']
# 7734  ['2K', 'Feral Interactive (Mac)']
# 7735                             ['2K']
#
#                                          price_overview         packages  \
# 220                                                 NaN    [451, 127633]
# 7734  {'currency': 'GBP', 'initial': 999, 'final': 9...    [451, 127633]
# 7735  {'currency': 'GBP', 'initial': 1399, 'final': ...  [81419, 127633]
#
#                                          package_groups  \
# 220   [{'name': 'default', 'title': 'Buy BioShock™',...
# 7734  [{'name': 'default', 'title': 'Buy BioShock™ R...
# 7735  [{'name': 'default', 'title': 'Buy BioShock™ 2...
#
#                                              categories  \
# 220   [{'id': 2, 'description': 'Single-player'}, {'...
# 7734  [{'id': 2, 'description': 'Single-player'}, {'...
# 7735  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                                  genres  \
# 220   [{'id': '1', 'description': 'Action'}, {'id': ...
# 7734  [{'id': '1', 'description': 'Action'}, {'id': ...
# 7735  [{'id': '1', 'description': 'Action'}, {'id': ...
#
#                                             screenshots movies  \
# 220   [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN
# 7734  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN
# 7735  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN
#
#                                            achievements  \
# 220                                        {'total': 0}
# 7734  {'total': 65, 'highlighted': [{'name': 'Comple...
# 7735  {'total': 53, 'highlighted': [{'name': "Daddy'...
#
#                                         release_date  \
# 220   {'coming_soon': False, 'date': '21 Aug, 2007'}
# 7734  {'coming_soon': False, 'date': '15 Sep, 2016'}
# 7735  {'coming_soon': False, 'date': '15 Sep, 2016'}
#
#                                 support_info  \
# 220   {'url': 'support.2k.com', 'email': ''}
# 7734  {'url': 'support.2k.com', 'email': ''}
# 7735  {'url': 'support.2k.com', 'email': ''}
#
#                                              background  \
# 220   https://steamcdn-a.akamaihd.net/steam/apps/767...
# 7734  https://steamcdn-a.akamaihd.net/steam/apps/409...
# 7735  https://steamcdn-a.akamaihd.net/steam/apps/409...
#
#               content_descriptors  windows  mac  linux
# 220    {'ids': [], 'notes': None}        1    0      0
# 7734   {'ids': [], 'notes': None}        1    1      0
# 7735  {'ids': [5], 'notes': None}        1    0      0

# %%
steam_data[steam_data['name'].str.contains("Sam & Max 1")]
# Out:
#                                                   name  steam_appid  \
# 234                       Sam & Max 101: Culture Shock         8200
# 235                   Sam & Max 102: Situation: Comedy         8210
# 236  Sam & Max 103: The Mole, the Mob and the Meatball         8220
# 237               Sam & Max 104: Abe Lincoln Must Die!         8230
# 238                         Sam & Max 105: Reality 2.0         8240
# 239             Sam & Max 106: Bright Side of the Moon         8250
#
#     required_age is_free                               detailed_description  \
# 234            3   False  <strong>Sam &amp; Max: Episode 1 - Culture Sho...
# 235            3   False  <strong>Sam &amp; Max: Episode 2 - Situation: ...
# 236            3   False  <strong>Sam &amp; Max Episode 3 - The Mole, Th...
# 237            3   False  <strong>Sam &amp; Max Episode 4 - Abe Lincoln ...
# 238            3   False  With an internet crisis looming and a viral vi...
# 239            3   False  <strong>Sam &amp; Max: Episode 6 - Bright Side...
#
#                                         about_the_game  \
# 234  <strong>Sam &amp; Max: Episode 1 - Culture Sho...
# 235  <strong>Sam &amp; Max: Episode 2 - Situation: ...
# 236  <strong>Sam &amp; Max Episode 3 - The Mole, Th...
# 237  <strong>Sam &amp; Max Episode 4 - Abe Lincoln ...
# 238  With an internet crisis looming and a viral vi...
# 239  <strong>Sam &amp; Max: Episode 6 - Bright Side...
#
#                                      short_description  \
# 234  Sam &amp; Max: Episode 1 - Culture Shock - The...
# 235  Sam &amp; Max: Episode 2 - Situation: Comedy -...
# 236  Sam &amp; Max Episode 3 - The Mole, The Mob, a...
# 237  Sam &amp; Max Episode 4 - Abe Lincoln Must Die...
# 238  With an internet crisis looming and a viral vi...
# 239  Sam &amp; Max: Episode 6 - Bright Side of the ...
#
#                   supported_languages  \
# 234  English, French, German, Italian
# 235          English, German, Italian
# 236  English, French, German, Italian
# 237  English, French, German, Italian
# 238  English, French, German, Italian
# 239  English, French, German, Italian
#
#                                           header_image  \
# 234  https://steamcdn-a.akamaihd.net/steam/apps/820...
# 235  https://steamcdn-a.akamaihd.net/steam/apps/821...
# 236  https://steamcdn-a.akamaihd.net/steam/apps/822...
# 237  https://steamcdn-a.akamaihd.net/steam/apps/823...
# 238  https://steamcdn-a.akamaihd.net/steam/apps/824...
# 239  https://steamcdn-a.akamaihd.net/steam/apps/825...
#
#                                        website  \
# 234  http://store.steampowered.com/app/901660/
# 235  http://store.steampowered.com/app/901660/
# 236  http://store.steampowered.com/app/901660/
# 237  http://store.steampowered.com/app/901660/
# 238  http://store.steampowered.com/app/901660/
# 239  http://store.steampowered.com/app/901660/
#
#                                        pc_requirements mac_requirements  \
# 234  {'minimum': 'Windows XP or Vista, 1.5GHz proce...               []
# 235  {'minimum': 'Windows XP or Vista, 1.5GHz proce...               []
# 236  {'minimum': 'Windows XP or Vista, 1.5GHz proce...               []
# 237  {'minimum': 'Windows XP or Vista, 1.5GHz proce...               []
# 238  {'minimum': 'Windows XP or Vista, 1.5GHz proce...               []
# 239  {'minimum': 'Windows XP or Vista, 1.5GHz proce...               []
#
#     linux_requirements          developers          publishers price_overview  \
# 234                 []  ['Telltale Games']  ['Telltale Games']            NaN
# 235                 []  ['Telltale Games']  ['Telltale Games']            NaN
# 236                 []  ['Telltale Games']  ['Telltale Games']            NaN
# 237                 []  ['Telltale Games']  ['Telltale Games']            NaN
# 238                 []  ['Telltale Games']  ['Telltale Games']            NaN
# 239                 []  ['Telltale Games']  ['Telltale Games']            NaN
#
#        packages                                     package_groups  \
# 234  [357, 539]  [{'name': 'default', 'title': 'Buy Sam & Max 1...
# 235  [358, 539]  [{'name': 'default', 'title': 'Buy Sam & Max 1...
# 236  [359, 539]  [{'name': 'default', 'title': 'Buy Sam & Max 1...
# 237  [360, 539]  [{'name': 'default', 'title': 'Buy Sam & Max 1...
# 238  [361, 539]  [{'name': 'default', 'title': 'Buy Sam & Max 1...
# 239  [362, 539]  [{'name': 'default', 'title': 'Buy Sam & Max 1...
#
#                                       categories  \
# 234  [{'id': 2, 'description': 'Single-player'}]
# 235  [{'id': 2, 'description': 'Single-player'}]
# 236  [{'id': 2, 'description': 'Single-player'}]
# 237  [{'id': 2, 'description': 'Single-player'}]
# 238  [{'id': 2, 'description': 'Single-player'}]
# 239  [{'id': 2, 'description': 'Single-player'}]
#
#                                                 genres  \
# 234  [{'id': '1', 'description': 'Action'}, {'id': ...
# 235  [{'id': '1', 'description': 'Action'}, {'id': ...
# 236  [{'id': '1', 'description': 'Action'}, {'id': ...
# 237  [{'id': '1', 'description': 'Action'}, {'id': ...
# 238  [{'id': '1', 'description': 'Action'}, {'id': ...
# 239  [{'id': '1', 'description': 'Action'}, {'id': ...
#
#                                            screenshots movies  achievements  \
# 234  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 235  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 236  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 237  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 238  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 239  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
#
#                                        release_date              support_info  \
# 234  {'coming_soon': False, 'date': '15 Jun, 2007'}  {'url': '', 'email': ''}
# 235  {'coming_soon': False, 'date': '15 Jun, 2007'}  {'url': '', 'email': ''}
# 236  {'coming_soon': False, 'date': '15 Jun, 2007'}  {'url': '', 'email': ''}
# 237  {'coming_soon': False, 'date': '15 Jun, 2007'}  {'url': '', 'email': ''}
# 238  {'coming_soon': False, 'date': '15 Jun, 2007'}  {'url': '', 'email': ''}
# 239  {'coming_soon': False, 'date': '15 Jun, 2007'}  {'url': '', 'email': ''}
#
#                                             background  \
# 234  https://steamcdn-a.akamaihd.net/steam/apps/820...
# 235  https://steamcdn-a.akamaihd.net/steam/apps/821...
# 236  https://steamcdn-a.akamaihd.net/steam/apps/822...
# 237  https://steamcdn-a.akamaihd.net/steam/apps/823...
# 238  https://steamcdn-a.akamaihd.net/steam/apps/824...
# 239  https://steamcdn-a.akamaihd.net/steam/apps/825...
#
#             content_descriptors  windows  mac  linux
# 234  {'ids': [], 'notes': None}        1    0      0
# 235  {'ids': [], 'notes': None}        1    0      0
# 236  {'ids': [], 'notes': None}        1    0      0
# 237  {'ids': [], 'notes': None}        1    0      0
# 238  {'ids': [], 'notes': None}        1    0      0
# 239  {'ids': [], 'notes': None}        1    0      0

# %% [markdown]
# Finally if we take a look at the data for the first row, we can see that we have a variety of formats in which our price is stored. We have a `currency`, which is GBP, perfect as we are performing our analysis in the UK. Next we have a number of different values for the price so which one do we use?

# %%
steam_data['price_overview'][0]
# Out:
# "{'currency': 'GBP', 'initial': 719, 'final': 719, 'discount_percent': 0, 'initial_formatted': '', 'final_formatted': '£7.19'}"

# %% [markdown]
# If we inspect another row, we see that there is an active discount, applying an 80% discount to the title. It looks like `initial` contains to normal price before discount, and `final` contains the discounted price. `initial_formatted` and `final_formatted` contain the price displayed in the currency. We don't have to worry about these, as we'll be storing the price as an integer (or float) and if we really wanted, could format it like this when printing.
#
# With all this in mind, it looks like we'll be checking the value under the currency key, and using the value in the initial key.

# %%
steam_data['price_overview'][37]
# Out:
# "{'currency': 'GBP', 'initial': 2299, 'final': 459, 'discount_percent': 80, 'initial_formatted': '£22.99', 'final_formatted': '£4.59'}"

# %% [markdown]
# Now the preliminary investigation is complete we can begin definining our function.
#
# We start by evaluating the strings using literal_eval as before, however if there is a null value (caught by the try/except block) we return a properly formatted dictionary with -1 for the `initial` value. This will allow us to fill in a value of 0 for free games, then be left with an easily targetable value for the null rows.

# %%
def process_price(df):
    df = df.copy()
        
    def parse_price(x):
        try:
            return literal_eval(x)
        except ValueError:
            return {'currency': 'GBP', 'initial': -1}
    
    # evaluate as dictionary and set to -1 if missing
    df['price_overview'] = df['price_overview'].apply(parse_price)
    
    # Create columns from currency and initial values
    df['currency'] = df['price_overview'].apply(lambda x: x['currency'])
    df['price'] = df['price_overview'].apply(lambda x: x['initial'])
    
    # Set price of free games to 0
    df.loc[df['is_free'], 'price'] = 0
    
    return df

price_data = process_price(steam_data)[['name', 'currency', 'price']]
price_data.head()
# Out:
#                         name currency  price
# 0             Counter-Strike      GBP    719
# 1      Team Fortress Classic      GBP    399
# 2              Day of Defeat      GBP    399
# 3         Deathmatch Classic      GBP    399
# 4  Half-Life: Opposing Force      GBP    399

# %% [markdown]
# We're almost finished here, bet let's check if any games don't have GBP listed as the currency.

# %%
price_data[price_data['currency'] != 'GBP']
# Out:
#                                       name currency  price
# 991     Robin Hood: The Legend of Sherwood      USD    799
# 5767   Assassin’s Creed® Chronicles: India      EUR    999
# 27593                     Mortal Kombat 11      USD   5999
# 27995                         Pagan Online      EUR   2699

# %% [markdown]
# For some reason we have four games listed in either USD or EUR. We could use the current exchange rate to try and convert them into GBP, however as there are only four rows we will simply drop them.
#
# We will also divide prices by 100 so they are displayed as floats in pounds.

# %%
def process_price(df):
    """Process price_overview column into formatted price column."""
    df = df.copy()
    
    def parse_price(x):
        try:
            return literal_eval(x)
        except ValueError:
            return {'currency': 'GBP', 'initial': -1}
    
    # evaluate as dictionary and set to -1 if missing
    df['price_overview'] = df['price_overview'].apply(parse_price)
    
    # create columns from currency and initial values
    df['currency'] = df['price_overview'].apply(lambda x: x['currency'])
    df['price'] = df['price_overview'].apply(lambda x: x['initial'])
    
    # set price of free games to 0
    df.loc[df['is_free'], 'price'] = 0
    
    # remove non-GBP rows
    df = df[df['currency'] == 'GBP']
    
    # change price to display in pounds (only applying to rows with a value greater than 0)
    df.loc[df['price'] > 0, 'price'] /= 100
    
    # remove columns no longer needed
    df = df.drop(['is_free', 'currency', 'price_overview'], axis=1)
    
    return df


def process(df):
    """Process data set. Will eventually contain calls to all functions we write."""
    
    # Copy the input dataframe to avoid accidentally modifying original data
    df = df.copy()
    
    # Remove duplicate rows - all appids should be unique
    df = df.drop_duplicates()
    
    # Remove collumns with more than 50% null values
    df = process_null_cols(df)
    
    # Process rest of columns
    df = process_type(df)
    df = process_name(df)
    df = process_age(df)
    df = process_platforms(df)
    df = process_price(df)
    
    return df


steam_data = process(raw_steam_data)
steam_data[['name', 'price']].head()
# Out:
#                         name  price
# 0             Counter-Strike   7.19
# 1      Team Fortress Classic   3.99
# 2              Day of Defeat   3.99
# 3         Deathmatch Classic   3.99
# 4  Half-Life: Opposing Force   3.99

# %% [markdown]
# ### Processing Description Columns
#
# Next we have a series of columns with descriptive text about each game: `detailed_description`, `about_the_game` and `short_description`. These columns could be used as the basis for an interesting recommender or key-word analysis project, however they are not required in our current project and should be removed from our final data set as they take up large amounts of space.
#
# In case we find some anomalies, let's inspect these columns anyway.

# %%
steam_data[['detailed_description', 'about_the_game', 'short_description']].isnull().sum()
# Out:
# detailed_description    24
# about_the_game          24
# short_description       24
# dtype: int64

# %% [markdown]
# It looks like we have 24 rows with missing data for these columns, and chances are the 24 rows with missing `detailed_description` are the rows with missing `about_the_game` and `short_description` data too.
#
# By inspecting the individual rows below, we can see that this is true - all rows with missing data in one description column have missing data in the other too.

# %%
steam_data[steam_data['detailed_description'].isnull()]
# Out:
#                                                     name  steam_appid  \
# 97                                    Bejeweled 2 Deluxe         3300
# 98                                        Chuzzle Deluxe         3310
# 99                                  Insaniquarium Deluxe         3320
# 101                                      AstroPop Deluxe         3340
# 102                                     Bejeweled Deluxe         3350
# 103                                    Big Money! Deluxe         3360
# 104                                      Dynomite Deluxe         3380
# 105                              Feeding Frenzy 2 Deluxe         3390
# 106                                  Hammer Heads Deluxe         3400
# 108                                     Iggle Pop Deluxe         3420
# 109                                  Pizza Frenzy Deluxe         3430
# 110                                  Rocket Mania Deluxe         3440
# 111                                  Typer Shark! Deluxe         3450
# 112                                    Talismania Deluxe         3460
# 249    Strong Bad's Cool Game for Attractive People: ...         8350
# 250    Strong Bad's Cool Game for Attractive People: ...         8360
# 251    Strong Bad's Cool Game for Attractive People: ...         8370
# 252    Strong Bad's Cool Game for Attractive People: ...         8380
# 1233              Back to the Future: Ep 2 - Get Tannen!        94500
# 1234            Back to the Future: Ep 3 - Citizen Brown        94510
# 1235           Back to the Future: Ep 4 - Double Visions        94520
# 1236                 Back to the Future: Ep 5 - OUTATIME        94530
# 8781                        Tower Unite Dedicated Server       439660
# 16560                      Enshrouded World: Home Truths       658440
#
#       required_age detailed_description about_the_game short_description  \
# 97               3                  NaN            NaN               NaN
# 98               3                  NaN            NaN               NaN
# 99               3                  NaN            NaN               NaN
# 101              3                  NaN            NaN               NaN
# 102              3                  NaN            NaN               NaN
# 103              3                  NaN            NaN               NaN
# 104              3                  NaN            NaN               NaN
# 105              3                  NaN            NaN               NaN
# 106              3                  NaN            NaN               NaN
# 108              3                  NaN            NaN               NaN
# 109              3                  NaN            NaN               NaN
# 110              3                  NaN            NaN               NaN
# 111              3                  NaN            NaN               NaN
# 112              3                  NaN            NaN               NaN
# 249              3                  NaN            NaN               NaN
# 250              3                  NaN            NaN               NaN
# 251              3                  NaN            NaN               NaN
# 252              3                  NaN            NaN               NaN
# 1233             3                  NaN            NaN               NaN
# 1234             3                  NaN            NaN               NaN
# 1235             3                  NaN            NaN               NaN
# 1236             3                  NaN            NaN               NaN
# 8781             3                  NaN            NaN               NaN
# 16560            3                  NaN            NaN               NaN
#
#                                      supported_languages  \
# 97     English, French, German, Italian, Spanish - Spain
# 98     English, French, German, Italian, Spanish - Spain
# 99                                               English
# 101                                              English
# 102                                              English
# 103                                              English
# 104                                              English
# 105                                              English
# 106                                              English
# 108                                              English
# 109                                              English
# 110                                              English
# 111                                              English
# 112                                              English
# 249                                                  NaN
# 250                                                  NaN
# 251                                                  NaN
# 252                                                  NaN
# 1233                                                 NaN
# 1234                                                 NaN
# 1235                                                 NaN
# 1236                                                 NaN
# 8781                                                 NaN
# 16560  English<strong>*</strong><br><strong>*</strong...
#
#                                             header_image website  \
# 97     https://steamcdn-a.akamaihd.net/steam/apps/330...     NaN
# 98     https://steamcdn-a.akamaihd.net/steam/apps/331...     NaN
# 99     https://steamcdn-a.akamaihd.net/steam/apps/332...     NaN
# 101    https://steamcdn-a.akamaihd.net/steam/apps/334...     NaN
# 102    https://steamcdn-a.akamaihd.net/steam/apps/335...     NaN
# 103    https://steamcdn-a.akamaihd.net/steam/apps/336...     NaN
# 104    https://steamcdn-a.akamaihd.net/steam/apps/338...     NaN
# 105    https://steamcdn-a.akamaihd.net/steam/apps/339...     NaN
# 106    https://steamcdn-a.akamaihd.net/steam/apps/340...     NaN
# 108    https://steamcdn-a.akamaihd.net/steam/apps/342...     NaN
# 109    https://steamcdn-a.akamaihd.net/steam/apps/343...     NaN
# 110    https://steamcdn-a.akamaihd.net/steam/apps/344...     NaN
# 111    https://steamcdn-a.akamaihd.net/steam/apps/345...     NaN
# 112    https://steamcdn-a.akamaihd.net/steam/apps/346...     NaN
# 249    https://steamcdn-a.akamaihd.net/steam/apps/835...     NaN
# 250    https://steamcdn-a.akamaihd.net/steam/apps/836...     NaN
# 251    https://steamcdn-a.akamaihd.net/steam/apps/837...     NaN
# 252    https://steamcdn-a.akamaihd.net/steam/apps/838...     NaN
# 1233   https://steamcdn-a.akamaihd.net/steam/apps/945...     NaN
# 1234   https://steamcdn-a.akamaihd.net/steam/apps/945...     NaN
# 1235   https://steamcdn-a.akamaihd.net/steam/apps/945...     NaN
# 1236   https://steamcdn-a.akamaihd.net/steam/apps/945...     NaN
# 8781   https://steamcdn-a.akamaihd.net/steam/apps/439...     NaN
# 16560  https://steamcdn-a.akamaihd.net/steam/apps/658...     NaN
#
#                                          pc_requirements  \
# 97     {'minimum': '<p><strong>Minimum Requirements:<...
# 98     {'minimum': '<p><strong>Minimum Requirements:<...
# 99     {'minimum': '<strong>Minimum Requirements:</st...
# 101    {'minimum': '<p><strong>Minimum Requirements:<...
# 102    {'minimum': '<p><strong>Minimum Requirements:<...
# 103    {'minimum': '<p><strong>Minimum Requirements:<...
# 104    {'minimum': '<p><strong>Minimum Requirements:<...
# 105    {'minimum': '<p><strong>Minimum Requirements:<...
# 106    {'minimum': '<p><strong>Minimum Requirements:<...
# 108    {'minimum': '<p><strong>Minimum Requirements:<...
# 109    {'minimum': '<p><strong>Minimum Requirements:<...
# 110    {'minimum': '<p><strong>Minimum Requirements:<...
# 111    {'minimum': '<p><strong>Minimum Requirements:<...
# 112    {'minimum': '<p><strong>Minimum Requirements:<...
# 249                                                   []
# 250                                                   []
# 251                                                   []
# 252                                                   []
# 1233                                                  []
# 1234                                                  []
# 1235                                                  []
# 1236                                                  []
# 8781                                                  []
# 16560                                                 []
#
#                                         mac_requirements  \
# 97     {'minimum': '<ul>\n\t<li><strong>OS:</strong> ...
# 98     {'minimum': '<ul>\n\t<li><strong>OS:</strong> ...
# 99                                                    []
# 101                                                   []
# 102                                                   []
# 103                                                   []
# 104                                                   []
# 105                                                   []
# 106                                                   []
# 108                                                   []
# 109                                                   []
# 110                                                   []
# 111                                                   []
# 112                                                   []
# 249                                                   []
# 250                                                   []
# 251                                                   []
# 252                                                   []
# 1233                                                  []
# 1234                                                  []
# 1235                                                  []
# 1236                                                  []
# 8781                                                  []
# 16560                                                 []
#
#                                       linux_requirements  \
# 97                                                    []
# 98                                                    []
# 99                                                    []
# 101                                                   []
# 102                                                   []
# 103                                                   []
# 104                                                   []
# 105                                                   []
# 106                                                   []
# 108                                                   []
# 109                                                   []
# 110                                                   []
# 111                                                   []
# 112                                                   []
# 249                                                   []
# 250                                                   []
# 251                                                   []
# 252                                                   []
# 1233                                                  []
# 1234                                                  []
# 1235                                                  []
# 1236                                                  []
# 8781                                                  []
# 16560  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                    developers              publishers        packages  \
# 97     ['PopCap Games, Inc.']  ['PopCap Games, Inc.']     [121, 1160]
# 98     ['PopCap Games, Inc.']  ['PopCap Games, Inc.']           [126]
# 99     ['PopCap Games, Inc.']  ['PopCap Games, Inc.']     [127, 1160]
# 101    ['PopCap Games, Inc.']  ['PopCap Games, Inc.']           [132]
# 102    ['PopCap Games, Inc.']  ['PopCap Games, Inc.']           [122]
# 103    ['PopCap Games, Inc.']  ['PopCap Games, Inc.']           [136]
# 104    ['PopCap Games, Inc.']  ['PopCap Games, Inc.']           [128]
# 105    ['PopCap Games, Inc.']  ['PopCap Games, Inc.']           [124]
# 106    ['PopCap Games, Inc.']  ['PopCap Games, Inc.']           [135]
# 108    ['PopCap Games, Inc.']  ['PopCap Games, Inc.']           [129]
# 109    ['PopCap Games, Inc.']  ['PopCap Games, Inc.']           [130]
# 110    ['PopCap Games, Inc.']  ['PopCap Games, Inc.']           [134]
# 111    ['PopCap Games, Inc.']  ['PopCap Games, Inc.']           [131]
# 112    ['PopCap Games, Inc.']  ['PopCap Games, Inc.']           [137]
# 249        ['Telltale Games']      ['Telltale Games']  [109598, 1253]
# 250        ['Telltale Games']      ['Telltale Games']  [109599, 1253]
# 251        ['Telltale Games']      ['Telltale Games']  [109600, 1253]
# 252        ['Telltale Games']      ['Telltale Games']  [109601, 1253]
# 1233       ['Telltale Games']      ['Telltale Games']             NaN
# 1234       ['Telltale Games']      ['Telltale Games']             NaN
# 1235       ['Telltale Games']      ['Telltale Games']             NaN
# 1236       ['Telltale Games']      ['Telltale Games']             NaN
# 8781                      NaN                    ['']             NaN
# 16560                     NaN                    ['']             NaN
#
#                                           package_groups  \
# 97     [{'name': 'default', 'title': 'Buy Bejeweled 2...
# 98     [{'name': 'default', 'title': 'Buy Chuzzle Del...
# 99     [{'name': 'default', 'title': 'Buy Insaniquari...
# 101    [{'name': 'default', 'title': 'Buy AstroPop De...
# 102    [{'name': 'default', 'title': 'Buy Bejeweled D...
# 103    [{'name': 'default', 'title': 'Buy Big Money! ...
# 104    [{'name': 'default', 'title': 'Buy Dynomite De...
# 105    [{'name': 'default', 'title': 'Buy Feeding Fre...
# 106    [{'name': 'default', 'title': 'Buy Hammer Head...
# 108    [{'name': 'default', 'title': 'Buy Iggle Pop D...
# 109    [{'name': 'default', 'title': 'Buy Pizza Frenz...
# 110    [{'name': 'default', 'title': 'Buy Rocket Mani...
# 111    [{'name': 'default', 'title': 'Buy Typer Shark...
# 112    [{'name': 'default', 'title': 'Buy Talismania ...
# 249    [{'name': 'default', 'title': "Buy Strong Bad'...
# 250    [{'name': 'default', 'title': "Buy Strong Bad'...
# 251    [{'name': 'default', 'title': "Buy Strong Bad'...
# 252    [{'name': 'default', 'title': "Buy Strong Bad'...
# 1233                                                  []
# 1234                                                  []
# 1235                                                  []
# 1236                                                  []
# 8781                                                  []
# 16560                                                 []
#
#                                         categories  \
# 97     [{'id': 2, 'description': 'Single-player'}]
# 98     [{'id': 2, 'description': 'Single-player'}]
# 99     [{'id': 2, 'description': 'Single-player'}]
# 101    [{'id': 2, 'description': 'Single-player'}]
# 102    [{'id': 2, 'description': 'Single-player'}]
# 103    [{'id': 2, 'description': 'Single-player'}]
# 104    [{'id': 2, 'description': 'Single-player'}]
# 105    [{'id': 2, 'description': 'Single-player'}]
# 106    [{'id': 2, 'description': 'Single-player'}]
# 108    [{'id': 2, 'description': 'Single-player'}]
# 109    [{'id': 2, 'description': 'Single-player'}]
# 110    [{'id': 2, 'description': 'Single-player'}]
# 111    [{'id': 2, 'description': 'Single-player'}]
# 112    [{'id': 2, 'description': 'Single-player'}]
# 249                                            NaN
# 250                                            NaN
# 251                                            NaN
# 252                                            NaN
# 1233                                           NaN
# 1234                                           NaN
# 1235                                           NaN
# 1236                                           NaN
# 8781                                           NaN
# 16560  [{'id': 2, 'description': 'Single-player'}]
#
#                                            genres  \
# 97         [{'id': '4', 'description': 'Casual'}]
# 98         [{'id': '4', 'description': 'Casual'}]
# 99         [{'id': '4', 'description': 'Casual'}]
# 101        [{'id': '4', 'description': 'Casual'}]
# 102        [{'id': '4', 'description': 'Casual'}]
# 103        [{'id': '4', 'description': 'Casual'}]
# 104        [{'id': '4', 'description': 'Casual'}]
# 105        [{'id': '4', 'description': 'Casual'}]
# 106        [{'id': '4', 'description': 'Casual'}]
# 108        [{'id': '4', 'description': 'Casual'}]
# 109        [{'id': '4', 'description': 'Casual'}]
# 110        [{'id': '4', 'description': 'Casual'}]
# 111        [{'id': '4', 'description': 'Casual'}]
# 112        [{'id': '4', 'description': 'Casual'}]
# 249    [{'id': '25', 'description': 'Adventure'}]
# 250    [{'id': '25', 'description': 'Adventure'}]
# 251    [{'id': '25', 'description': 'Adventure'}]
# 252    [{'id': '25', 'description': 'Adventure'}]
# 1233                                          NaN
# 1234                                          NaN
# 1235                                          NaN
# 1236                                          NaN
# 8781                                          NaN
# 16560      [{'id': '1', 'description': 'Action'}]
#
#                                              screenshots movies  \
# 97     [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN
# 98     [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN
# 99     [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN
# 101    [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN
# 102    [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN
# 103    [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN
# 104    [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN
# 105    [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN
# 106    [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN
# 108    [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN
# 109    [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN
# 110    [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN
# 111    [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN
# 112    [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN
# 249                                                  NaN    NaN
# 250                                                  NaN    NaN
# 251                                                  NaN    NaN
# 252                                                  NaN    NaN
# 1233                                                 NaN    NaN
# 1234                                                 NaN    NaN
# 1235                                                 NaN    NaN
# 1236                                                 NaN    NaN
# 8781   [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN
# 16560                                                NaN    NaN
#
#                                             achievements  \
# 97                                          {'total': 0}
# 98                                          {'total': 0}
# 99                                          {'total': 0}
# 101                                         {'total': 0}
# 102                                         {'total': 0}
# 103                                         {'total': 0}
# 104                                         {'total': 0}
# 105                                         {'total': 0}
# 106                                         {'total': 0}
# 108                                         {'total': 0}
# 109                                         {'total': 0}
# 110                                         {'total': 0}
# 111                                         {'total': 0}
# 112                                         {'total': 0}
# 249                                         {'total': 0}
# 250                                         {'total': 0}
# 251                                         {'total': 0}
# 252                                         {'total': 0}
# 1233                                        {'total': 0}
# 1234                                        {'total': 0}
# 1235                                        {'total': 0}
# 1236                                        {'total': 0}
# 8781                                        {'total': 0}
# 16560  {'total': 10, 'highlighted': [{'name': 'Bona F...
#
#                                          release_date  \
# 97     {'coming_soon': False, 'date': '30 Aug, 2006'}
# 98     {'coming_soon': False, 'date': '30 Aug, 2006'}
# 99     {'coming_soon': False, 'date': '30 Aug, 2006'}
# 101    {'coming_soon': False, 'date': '30 Aug, 2006'}
# 102    {'coming_soon': False, 'date': '30 Aug, 2006'}
# 103    {'coming_soon': False, 'date': '30 Aug, 2006'}
# 104    {'coming_soon': False, 'date': '30 Aug, 2006'}
# 105    {'coming_soon': False, 'date': '30 Aug, 2006'}
# 106    {'coming_soon': False, 'date': '30 Aug, 2006'}
# 108    {'coming_soon': False, 'date': '30 Aug, 2006'}
# 109    {'coming_soon': False, 'date': '30 Aug, 2006'}
# 110    {'coming_soon': False, 'date': '30 Aug, 2006'}
# 111    {'coming_soon': False, 'date': '30 Aug, 2006'}
# 112    {'coming_soon': False, 'date': '30 Aug, 2006'}
# 249                {'coming_soon': False, 'date': ''}
# 250                {'coming_soon': False, 'date': ''}
# 251                {'coming_soon': False, 'date': ''}
# 252                {'coming_soon': False, 'date': ''}
# 1233               {'coming_soon': False, 'date': ''}
# 1234               {'coming_soon': False, 'date': ''}
# 1235               {'coming_soon': False, 'date': ''}
# 1236               {'coming_soon': False, 'date': ''}
# 8781   {'coming_soon': False, 'date': '29 Mar, 2016'}
# 16560  {'coming_soon': False, 'date': '26 Feb, 2018'}
#
#                                             support_info  \
# 97                              {'url': '', 'email': ''}
# 98                              {'url': '', 'email': ''}
# 99                              {'url': '', 'email': ''}
# 101                             {'url': '', 'email': ''}
# 102                             {'url': '', 'email': ''}
# 103                             {'url': '', 'email': ''}
# 104                             {'url': '', 'email': ''}
# 105                             {'url': '', 'email': ''}
# 106                             {'url': '', 'email': ''}
# 108                             {'url': '', 'email': ''}
# 109                             {'url': '', 'email': ''}
# 110                             {'url': '', 'email': ''}
# 111                             {'url': '', 'email': ''}
# 112                             {'url': '', 'email': ''}
# 249                             {'url': '', 'email': ''}
# 250                             {'url': '', 'email': ''}
# 251                             {'url': '', 'email': ''}
# 252                             {'url': '', 'email': ''}
# 1233                            {'url': '', 'email': ''}
# 1234                            {'url': '', 'email': ''}
# 1235                            {'url': '', 'email': ''}
# 1236                            {'url': '', 'email': ''}
# 8781                            {'url': '', 'email': ''}
# 16560  {'url': '', 'email': 'enshroudedworld@gmail.com'}
#
#                                               background  \
# 97     https://steamcdn-a.akamaihd.net/steam/apps/330...
# 98     https://steamcdn-a.akamaihd.net/steam/apps/331...
# 99     https://steamcdn-a.akamaihd.net/steam/apps/332...
# 101    https://steamcdn-a.akamaihd.net/steam/apps/334...
# 102    https://steamcdn-a.akamaihd.net/steam/apps/335...
# 103    https://steamcdn-a.akamaihd.net/steam/apps/336...
# 104    https://steamcdn-a.akamaihd.net/steam/apps/338...
# 105    https://steamcdn-a.akamaihd.net/steam/apps/339...
# 106    https://steamcdn-a.akamaihd.net/steam/apps/340...
# 108    https://steamcdn-a.akamaihd.net/steam/apps/342...
# 109    https://steamcdn-a.akamaihd.net/steam/apps/343...
# 110    https://steamcdn-a.akamaihd.net/steam/apps/344...
# 111    https://steamcdn-a.akamaihd.net/steam/apps/345...
# 112    https://steamcdn-a.akamaihd.net/steam/apps/346...
# 249                                                  NaN
# 250                                                  NaN
# 251                                                  NaN
# 252                                                  NaN
# 1233                                                 NaN
# 1234                                                 NaN
# 1235                                                 NaN
# 1236                                                 NaN
# 8781   https://steamcdn-a.akamaihd.net/steam/apps/439...
# 16560                                                NaN
#
#               content_descriptors  windows  mac  linux  price
# 97     {'ids': [], 'notes': None}        1    1      0   4.25
# 98     {'ids': [], 'notes': None}        1    1      0   4.25
# 99     {'ids': [], 'notes': None}        1    0      0   4.25
# 101    {'ids': [], 'notes': None}        1    0      0   4.25
# 102    {'ids': [], 'notes': None}        1    0      0   4.25
# 103    {'ids': [], 'notes': None}        1    0      0   4.25
# 104    {'ids': [], 'notes': None}        1    0      0   4.25
# 105    {'ids': [], 'notes': None}        1    0      0   4.25
# 106    {'ids': [], 'notes': None}        1    0      0   4.25
# 108    {'ids': [], 'notes': None}        1    0      0   4.25
# 109    {'ids': [], 'notes': None}        1    0      0   4.25
# 110    {'ids': [], 'notes': None}        1    0      0   4.25
# 111    {'ids': [], 'notes': None}        1    0      0   4.25
# 112    {'ids': [], 'notes': None}        1    0      0   4.25
# 249    {'ids': [], 'notes': None}        1    0      0  -1.00
# 250    {'ids': [], 'notes': None}        1    0      0  -1.00
# 251    {'ids': [], 'notes': None}        1    0      0  -1.00
# 252    {'ids': [], 'notes': None}        1    0      0  -1.00
# 1233   {'ids': [], 'notes': None}        1    1      0  -1.00
# 1234   {'ids': [], 'notes': None}        1    1      0  -1.00
# 1235   {'ids': [], 'notes': None}        1    1      0  -1.00
# 1236   {'ids': [], 'notes': None}        1    1      0  -1.00
# 8781   {'ids': [], 'notes': None}        1    0      0  -1.00
# 16560  {'ids': [], 'notes': None}        1    0      0  -1.00

# %% [markdown]
# Browsing these games it looks like about half are old PopCap games from 2006 and about half are from Telltale Games, similar to the Sam & Max title we encountered in the previous section.
#
# There is also a dedicated server and a game which is now unlisted on the steam store. It would definitely be best to remove these two.
#
# Let's remove these rows for now, but we can reintroduce them later if we wish.
#
# As stated, the description columns may be useful for future projects, so before we remove them from this data set we will export them as a csv file. We will include the steam_appid column in this export as it will allow us to match up these rows with rows in our primary data set later on, using a merge (or a join in SQL). We will write a short function to handle this, which we can re-use later on if we have any more dataframes that need exporting.

# %%
def export_data(df, filename):
    """Export dataframe to csv file, filename prepended with 'steam_'.
    
    filename : str without file extension
    """
    filepath = '../data/exports/steam_' + filename + '.csv'
    formatted_name = filename.replace('_', ' ')
    
    df.to_csv(filepath, index=False)
    print("Exported {} to '{}'".format(formatted_name, filepath))

    
def process_descriptions(df, export=False):
    """Export descriptions to external csv file then remove these columns."""
    # remove rows with missing description data
    df = df[df['detailed_description'].notnull()].copy()
    
    if export:
        # create dataframe of description columns and export to csv
        description_data = df[['steam_appid', 'detailed_description', 'about_the_game', 'short_description']]
        
        export_data(description_data, filename='description_data')
    
    # drop description columns from main dataframe
    df = df.drop(['detailed_description', 'about_the_game', 'short_description'], axis=1)
    
    return df


def process(df):
    """Process data set. Will eventually contain calls to all functions we write."""
    
    # Copy the input dataframe to avoid accidentally modifying original data
    df = df.copy()
    
    # Remove duplicate rows - all appids should be unique
    df = df.drop_duplicates()
    
    # Remove collumns with more than 50% null values
    df = process_null_cols(df)
    
    # Process rest of columns
    df = process_type(df)
    df = process_name(df)
    df = process_age(df)
    df = process_platforms(df)
    df = process_price(df)
    df = process_descriptions(df, export=True)
    
    return df


steam_data = process(raw_steam_data)
steam_data.head()
# Out:
# Exported description data to '../data/exports/steam_description_data.csv'
#                         name  steam_appid required_age  \
# 0             Counter-Strike           10            3
# 1      Team Fortress Classic           20            3
# 2              Day of Defeat           30            3
# 3         Deathmatch Classic           40            3
# 4  Half-Life: Opposing Force           50            3
#
#                                  supported_languages  \
# 0  English<strong>*</strong>, French<strong>*</st...
# 1  English, French, German, Italian, Spanish - Sp...
# 2  English, French, German, Italian, Spanish - Spain
# 3  English, French, German, Italian, Spanish - Sp...
# 4                    English, French, German, Korean
#
#                                         header_image  \
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...
#
#                        website  \
# 0                          NaN
# 1                          NaN
# 2  http://www.dayofdefeat.com/
# 3                          NaN
# 4                          NaN
#
#                                      pc_requirements  \
# 0  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 1  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 2  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 3  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 4  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
#
#                                     mac_requirements  \
# 0  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 1  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 2  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 3  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 4  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
#
#                                   linux_requirements            developers  \
# 0  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 1  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 2  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 3  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 4  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...  ['Gearbox Software']
#
#   publishers packages                                     package_groups  \
# 0  ['Valve']      [7]  [{'name': 'default', 'title': 'Buy Counter-Str...
# 1  ['Valve']     [29]  [{'name': 'default', 'title': 'Buy Team Fortre...
# 2  ['Valve']     [30]  [{'name': 'default', 'title': 'Buy Day of Defe...
# 3  ['Valve']     [31]  [{'name': 'default', 'title': 'Buy Deathmatch ...
# 4  ['Valve']     [32]  [{'name': 'default', 'title': 'Buy Half-Life: ...
#
#                                           categories  \
# 0  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 1  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 2  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 3  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 4  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                    genres  \
# 0  [{'id': '1', 'description': 'Action'}]
# 1  [{'id': '1', 'description': 'Action'}]
# 2  [{'id': '1', 'description': 'Action'}]
# 3  [{'id': '1', 'description': 'Action'}]
# 4  [{'id': '1', 'description': 'Action'}]
#
#                                          screenshots movies  achievements  \
# 0  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 1  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 2  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 3  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 4  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
#
#                                     release_date  \
# 0  {'coming_soon': False, 'date': '1 Nov, 2000'}
# 1  {'coming_soon': False, 'date': '1 Apr, 1999'}
# 2  {'coming_soon': False, 'date': '1 May, 2003'}
# 3  {'coming_soon': False, 'date': '1 Jun, 2001'}
# 4  {'coming_soon': False, 'date': '1 Nov, 1999'}
#
#                                         support_info  \
# 0  {'url': 'http://steamcommunity.com/app/10', 'e...
# 1                           {'url': '', 'email': ''}
# 2                           {'url': '', 'email': ''}
# 3                           {'url': '', 'email': ''}
# 4  {'url': 'https://help.steampowered.com', 'emai...
#
#                                           background  \
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...
#
#                                  content_descriptors  windows  mac  linux  \
# 0  {'ids': [2, 5], 'notes': 'Includes intense vio...        1    1      1
# 1  {'ids': [2, 5], 'notes': 'Includes intense vio...        1    1      1
# 2                         {'ids': [], 'notes': None}        1    1      1
# 3                         {'ids': [], 'notes': None}        1    1      1
# 4                         {'ids': [], 'notes': None}        1    1      1
#
#    price
# 0   7.19
# 1   3.99
# 2   3.99
# 3   3.99
# 4   3.99

# %%
# inspect exported data
pd.read_csv('../data/exports/steam_description_data.csv').head()
# Out:
#    steam_appid                               detailed_description  \
# 0           10  Play the world's number 1 online action game. ...
# 1           20  One of the most popular online action games of...
# 2           30  Enlist in an intense brand of Axis vs. Allied ...
# 3           40  Enjoy fast-paced multiplayer gaming with Death...
# 4           50  Return to the Black Mesa Research Facility as ...
#
#                                       about_the_game  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                    short_description
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...

# %% [markdown]
# ### Processing Langauges
#
# The next column is supported_languages. As we will be performing the analysis for an English company, we are only interested in apps that are in English. Whilst we could remove non-english apps at this stage, instead we will create a column marking english apps with a boolean value - True or False.
#
# We begin as usual by looking for rows with null values.

# %%
steam_data['supported_languages'].isnull().sum()
# Out:
# 4

# %% [markdown]
# Taking a closer look at these apps, it's possible one or two are not in english. As there are only 4 rows affected we will go ahead and remove these from the data set.

# %%
steam_data[steam_data['supported_languages'].isnull()]
# Out:
#                   name  steam_appid required_age supported_languages  \
# 4866          Subsiege       338640            3                 NaN
# 14560  MARS VR(全球使命VR)       596560            3                 NaN
# 16386     Numberline 2       654970            3                 NaN
# 26855        SNUSE 221       948070            3                 NaN
#
#                                             header_image  \
# 4866   https://steamcdn-a.akamaihd.net/steam/apps/338...
# 14560  https://steamcdn-a.akamaihd.net/steam/apps/596...
# 16386  https://steamcdn-a.akamaihd.net/steam/apps/654...
# 26855  https://steamcdn-a.akamaihd.net/steam/apps/948...
#
#                          website  \
# 4866   http://subsiege-game.com/
# 14560   http://qqsm.zygames.com/
# 16386                        NaN
# 26855                        NaN
#
#                                          pc_requirements  \
# 4866   {'minimum': '<strong>Minimum:</strong><br><ul ...
# 14560  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 16386  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 26855  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                         mac_requirements  \
# 4866                                                  []
# 14560  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 16386                                                 []
# 26855                                                 []
#
#                                       linux_requirements  \
# 4866                                                  []
# 14560  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 16386                                                 []
# 26855                                                 []
#
#                                               developers  \
# 4866                                 ['Icebird Studios']
# 14560  ['Ying Pei Digital Technology Shanghai Co., Li...
# 16386                         ['V34D4R', 'Egor Magurin']
# 26855                                       ['SNUSE GM']
#
#                                     publishers  packages  \
# 4866                       ['Icebird Studios']   [56500]
# 14560  ['SHANGHAI ZHENYOU TECHNOLOGY CO.,LTD']  [156314]
# 16386                      ['Indovers Studio']  [184646]
# 26855                             ['SNUSE GM']  [308421]
#
#                                           package_groups  \
# 4866   [{'name': 'default', 'title': 'Buy Subsiege', ...
# 14560  [{'name': 'default', 'title': 'Buy MARS VR(全球使...
# 16386  [{'name': 'default', 'title': 'Buy Numberline ...
# 26855  [{'name': 'default', 'title': 'Buy SNUSE 221',...
#
#                                         categories  \
# 4866                                           NaN
# 14560  [{'id': 2, 'description': 'Single-player'}]
# 16386  [{'id': 2, 'description': 'Single-player'}]
# 26855  [{'id': 2, 'description': 'Single-player'}]
#
#                                                   genres  \
# 4866                                                 NaN
# 14560  [{'id': '73', 'description': 'Violent'}, {'id'...
# 16386  [{'id': '4', 'description': 'Casual'}, {'id': ...
# 26855  [{'id': '25', 'description': 'Adventure'}, {'i...
#
#                                              screenshots  \
# 4866   [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 14560  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 16386  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 26855  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
#
#                                                   movies  \
# 4866   [{'id': 256729398, 'name': 'Release Trailer', ...
# 14560  [{'id': 256681371, 'name': 'marsvr', 'thumbnai...
# 16386  [{'id': 256687192, 'name': 'Numberline 2 Trail...
# 26855  [{'id': 256745662, 'name': 'snuse', 'thumbnail...
#
#                                             achievements  \
# 4866                                        {'total': 0}
# 14560                                       {'total': 0}
# 16386  {'total': 60, 'highlighted': [{'name': '1st le...
# 26855                                       {'total': 0}
#
#                                          release_date  \
# 4866    {'coming_soon': False, 'date': '7 Sep, 2018'}
# 14560   {'coming_soon': False, 'date': '5 Apr, 2017'}
# 16386  {'coming_soon': False, 'date': '14 Jul, 2017'}
# 26855   {'coming_soon': False, 'date': '2 Apr, 2019'}
#
#                                             support_info  \
# 4866   {'url': 'http://subsiege-game.com/', 'email': ...
# 14560  {'url': 'http://www.zygames.com/contact', 'ema...
# 16386    {'url': '', 'email': 'radaew.zhenya@yandex.ru'}
# 26855             {'url': 'vk.com/nilow_i', 'email': ''}
#
#                                               background  \
# 4866   https://steamcdn-a.akamaihd.net/steam/apps/338...
# 14560  https://steamcdn-a.akamaihd.net/steam/apps/596...
# 16386  https://steamcdn-a.akamaihd.net/steam/apps/654...
# 26855  https://steamcdn-a.akamaihd.net/steam/apps/948...
#
#               content_descriptors  windows  mac  linux  price
# 4866   {'ids': [], 'notes': None}        1    0      0  17.89
# 14560  {'ids': [], 'notes': None}        1    0      0   1.99
# 16386  {'ids': [], 'notes': None}        1    0      0   1.59
# 26855  {'ids': [], 'notes': None}        1    0      0   0.79

# %% [markdown]
# By looking at the value for the first row and the values for the most common rows, it looks like languages are stored as a string which can be anything from a comma-separated list of languages to a mix of html and headings. It seems reasonably safe to assume that if the app is in English, the word English will appear somewhere in this string. With this in mind we can simply search the string and return a value based on the result.

# %%
print(steam_data['supported_languages'][0])
steam_data['supported_languages'].value_counts().head(10)
# Out:
# English<strong>*</strong>, French<strong>*</strong>, German<strong>*</strong>, Italian<strong>*</strong>, Spanish - Spain<strong>*</strong>, Simplified Chinese<strong>*</strong>, Traditional Chinese<strong>*</strong>, Korean<strong>*</strong><br><strong>*</strong>languages with full audio support
# English                                                                                                        8702
# English<strong>*</strong><br><strong>*</strong>languages with full audio support                               7669
# English, Russian                                                                                                719
# English, Simplified Chinese                                                                                     291
# English, Japanese                                                                                               239
# English<strong>*</strong>, Russian<strong>*</strong><br><strong>*</strong>languages with full audio support     227
# English, French, Italian, German, Spanish - Spain                                                               188
# Simplified Chinese                                                                                              168
# English, German                                                                                                 167
# English, French                                                                                                 149
# Name: supported_languages, dtype: int64

# %%
def process_language(df):
    """Process supported_languages column into a boolean 'is english' column."""
    df = df.copy()
    
    # drop rows with missing language data
    df = df.dropna(subset=['supported_languages'])
    
    df['english'] = df['supported_languages'].apply(lambda x: 1 if 'english' in x.lower() else 0)
    df = df.drop('supported_languages', axis=1)
    
    return df


def process(df):
    """Process data set. Will eventually contain calls to all functions we write."""
    
    # Copy the input dataframe to avoid accidentally modifying original data
    df = df.copy()
    
    # Remove duplicate rows - all appids should be unique
    df = df.drop_duplicates()
    
    # Remove collumns with more than 50% null values
    df = process_null_cols(df)
    
    # Process rest of columns
    df = process_type(df)
    df = process_name(df)
    df = process_age(df)
    df = process_platforms(df)
    df = process_price(df)
    df = process_descriptions(df)
    df = process_language(df)
    
    return df


steam_data = process(raw_steam_data)
steam_data[['name', 'english']].head()
# Out:
#                         name  english
# 0             Counter-Strike        1
# 1      Team Fortress Classic        1
# 2              Day of Defeat        1
# 3         Deathmatch Classic        1
# 4  Half-Life: Opposing Force        1

# %% [markdown]
# Before moving on, we can take a quick look at our results and see that most of our apps are in English.

# %%
steam_data['english'].value_counts(dropna=False)
# Out:
# 1    28500
# 0      543
# Name: english, dtype: int64

# %% [markdown]
# ### Processing image columns
#
# Similar to our description columns, we have three columns that appear to contain links to various images: `header_image`, `screenshots` and `background`. We will treat these in almost the same way, exporting the contents to a csv file then removing the columns from our data set.
#
# Whilst we won't be needed this data for our current project, it could open the door to some interesting image analysis in the future.
#
# First we check for missing values.

# %%
image_cols = ['header_image', 'screenshots', 'background']

for col in image_cols:
    print(col+':', steam_data[col].isnull().sum())
# Out:
# header_image: 0
# screenshots: 15
# background: 15

# %% [markdown]
# Again it is likely that the 15 rows with missing screenshots data are the same rows with missing background data.
#
# Seen below, some rows have missing `pc_requirements`, some have missing release_dates (blank string in the `date` part of release_date), and most have -1 for price, meaning we couldn't find any price data earlier.
#
# It seems like it would be a good idea to remove these rows before proceeding.

# %%
steam_data[steam_data['screenshots'].isnull()]
# Out:
#                                                name  steam_appid required_age  \
# 652           Sam & Max 302: The Tomb of Sammun-Mak        31230            3
# 653          Sam & Max 303: They Stole Max's Brain!        31240            3
# 654    Sam & Max 304: Beyond the Alley of the Dolls        31250            3
# 655    Sam & Max 305: The City That Dares Not Sleep        31260            3
# 1238                              Hector: Episode 1        94600            3
# 1239                              Hector: Episode 2        94610            3
# 5218                                   Into The War       346370            3
# 7970                               The Light Empire       416220            3
# 9408                          A Land Fit For Heroes       456210            3
# 19481                                       JumpSky       731910            3
# 21937                                      God Test       797660            3
# 24874                               Girl and Goblin       880510            3
# 25694                                    1bit Pzzle       907680            3
# 25696                   Arida: Backland's Awakening       907760            3
# 26851                      Nukalypse: The Final War       947940            3
#
#                                             header_image  \
# 652    https://steamcdn-a.akamaihd.net/steam/apps/312...
# 653    https://steamcdn-a.akamaihd.net/steam/apps/312...
# 654    https://steamcdn-a.akamaihd.net/steam/apps/312...
# 655    https://steamcdn-a.akamaihd.net/steam/apps/312...
# 1238   https://steamcdn-a.akamaihd.net/steam/apps/946...
# 1239   https://steamcdn-a.akamaihd.net/steam/apps/946...
# 5218   https://steamcdn-a.akamaihd.net/steam/apps/346...
# 7970   https://steamcdn-a.akamaihd.net/steam/apps/416...
# 9408   https://steamcdn-a.akamaihd.net/steam/apps/456...
# 19481  https://steamcdn-a.akamaihd.net/steam/apps/731...
# 21937  https://steamcdn-a.akamaihd.net/steam/apps/797...
# 24874  https://steamcdn-a.akamaihd.net/steam/apps/880...
# 25694  https://steamcdn-a.akamaihd.net/steam/apps/907...
# 25696  https://steamcdn-a.akamaihd.net/steam/apps/907...
# 26851  https://steamcdn-a.akamaihd.net/steam/apps/947...
#
#                                    website  \
# 652                                    NaN
# 653                                    NaN
# 654                                    NaN
# 655                                    NaN
# 1238                                   NaN
# 1239   http://www.telltalegames.com/hector
# 5218                                   NaN
# 7970                                   NaN
# 9408           http://landfitforheroes.com
# 19481                                  NaN
# 21937                                  NaN
# 24874                                  NaN
# 25694                                  NaN
# 25696             http://www.aridagame.com
# 26851                                  NaN
#
#                                          pc_requirements  \
# 652                                                   []
# 653                                                   []
# 654                                                   []
# 655                                                   []
# 1238   {'minimum': '<strong>Минимальные:</strong><br>...
# 1239   {'minimum': 'Minimum:<br>\t\t\t\t\t\t\t\t\t\t\...
# 5218   {'minimum': '<strong>Minimum:</strong><br><ul ...
# 7970   {'minimum': '<strong>Minimum:</strong><br><ul ...
# 9408   {'minimum': '<strong>Minimum:</strong><br><ul ...
# 19481                                                 []
# 21937  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 24874  {'minimum': '<strong>最低配置:</strong><br><ul cla...
# 25694  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 25696  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 26851  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                         mac_requirements  \
# 652                                                   []
# 653                                                   []
# 654                                                   []
# 655                                                   []
# 1238   {'minimum': '<strong>Минимальные:</strong><br>...
# 1239                                                  []
# 5218                                                  []
# 7970                                                  []
# 9408                                                  []
# 19481  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 21937                                                 []
# 24874                                                 []
# 25694                                                 []
# 25696  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 26851  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                       linux_requirements  \
# 652                                                   []
# 653                                                   []
# 654                                                   []
# 655                                                   []
# 1238                                                  []
# 1239                                                  []
# 5218                                                  []
# 7970                                                  []
# 9408                                                  []
# 19481  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 21937                                                 []
# 24874                                                 []
# 25694                                                 []
# 25696  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 26851  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                    developers              publishers         packages  \
# 652        ['Telltale Games']      ['Telltale Games']   [109586, 4172]
# 653        ['Telltale Games']      ['Telltale Games']   [109587, 4172]
# 654        ['Telltale Games']      ['Telltale Games']   [109588, 4172]
# 655        ['Telltale Games']      ['Telltale Games']   [109589, 4172]
# 1238        ['Straandlooper']                    ['']          [11279]
# 1239        ['Straandlooper']                    ['']  [109595, 11279]
# 5218   ['Small Town Studios']  ['Small Town Studios']              NaN
# 7970                 ['Jemy']                ['Jemy']          [83871]
# 9408   ['Liber Primus Games']  ['Liber Primus Games']              NaN
# 19481                ['none']                ['none']              NaN
# 21937            ['God Test']            ['God Test']              NaN
# 24874        ['Inverse Game']        ['Inverse Game']         [279573]
# 25694                ['1bit']                ['1bit']              NaN
# 25696       ['Aoca Game Lab']       ['Aoca Game Lab']              NaN
# 26851   ['Zion Games Studio']   ['Zion Games Studio']              NaN
#
#                                           package_groups  \
# 652    [{'name': 'default', 'title': 'Buy Sam & Max 3...
# 653    [{'name': 'default', 'title': "Buy Sam & Max 3...
# 654    [{'name': 'default', 'title': 'Buy Sam & Max 3...
# 655    [{'name': 'default', 'title': 'Buy Sam & Max 3...
# 1238   [{'name': 'default', 'title': 'Buy Hector: Epi...
# 1239   [{'name': 'default', 'title': 'Buy Hector: Epi...
# 5218                                                  []
# 7970   [{'name': 'default', 'title': 'Buy The Light E...
# 9408                                                  []
# 19481                                                 []
# 21937                                                 []
# 24874  [{'name': 'default', 'title': 'Buy Girl and Go...
# 25694                                                 []
# 25696                                                 []
# 26851                                                 []
#
#                                               categories  \
# 652          [{'id': 2, 'description': 'Single-player'}]
# 653          [{'id': 2, 'description': 'Single-player'}]
# 654          [{'id': 2, 'description': 'Single-player'}]
# 655          [{'id': 2, 'description': 'Single-player'}]
# 1238                                                 NaN
# 1239         [{'id': 2, 'description': 'Single-player'}]
# 5218   [{'id': 1, 'description': 'Multi-player'}, {'i...
# 7970   [{'id': 2, 'description': 'Single-player'}, {'...
# 9408   [{'id': 2, 'description': 'Single-player'}, {'...
# 19481        [{'id': 2, 'description': 'Single-player'}]
# 21937  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 24874  [{'id': 2, 'description': 'Single-player'}, {'...
# 25694        [{'id': 2, 'description': 'Single-player'}]
# 25696  [{'id': 2, 'description': 'Single-player'}, {'...
# 26851  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                                   genres screenshots  \
# 652           [{'id': '25', 'description': 'Adventure'}]         NaN
# 653           [{'id': '25', 'description': 'Adventure'}]         NaN
# 654           [{'id': '25', 'description': 'Adventure'}]         NaN
# 655           [{'id': '25', 'description': 'Adventure'}]         NaN
# 1238                                                 NaN         NaN
# 1239   [{'id': '25', 'description': 'Adventure'}, {'i...         NaN
# 5218   [{'id': '1', 'description': 'Action'}, {'id': ...         NaN
# 7970   [{'id': '23', 'description': 'Indie'}, {'id': ...         NaN
# 9408   [{'id': '25', 'description': 'Adventure'}, {'i...         NaN
# 19481             [{'id': '4', 'description': 'Casual'}]         NaN
# 21937  [{'id': '1', 'description': 'Action'}, {'id': ...         NaN
# 24874  [{'id': '25', 'description': 'Adventure'}, {'i...         NaN
# 25694  [{'id': '4', 'description': 'Casual'}, {'id': ...         NaN
# 25696  [{'id': '25', 'description': 'Adventure'}, {'i...         NaN
# 26851  [{'id': '1', 'description': 'Action'}, {'id': ...         NaN
#
#                                                   movies  \
# 652                                                  NaN
# 653                                                  NaN
# 654                                                  NaN
# 655                                                  NaN
# 1238                                                 NaN
# 1239                                                 NaN
# 5218                                                 NaN
# 7970                                                 NaN
# 9408   [{'id': 256663531, 'name': 'A Land Fit For Her...
# 19481                                                NaN
# 21937                                                NaN
# 24874  [{'id': 256739772, 'name': '3', 'thumbnail': '...
# 25694                                                NaN
# 25696  [{'id': 256729551, 'name': 'Teaser Beta 2018',...
# 26851  [{'id': 256745274, 'name': 'Nukalypse: The Fin...
#
#                                             achievements  \
# 652                                         {'total': 0}
# 653                                         {'total': 0}
# 654                                         {'total': 0}
# 655                                         {'total': 0}
# 1238                                        {'total': 0}
# 1239                                        {'total': 0}
# 5218   {'total': 1, 'highlighted': [{'name': 'First B...
# 7970   {'total': 4, 'highlighted': [{'name': 'We Begi...
# 9408                                        {'total': 0}
# 19481                                       {'total': 0}
# 21937                                       {'total': 0}
# 24874  {'total': 1552, 'highlighted': [{'name': 'Comp...
# 25694                                       {'total': 0}
# 25696                                                NaN
# 26851                                                NaN
#
#                                          release_date  \
# 652                {'coming_soon': False, 'date': ''}
# 653                {'coming_soon': False, 'date': ''}
# 654                {'coming_soon': False, 'date': ''}
# 655                {'coming_soon': False, 'date': ''}
# 1238               {'coming_soon': False, 'date': ''}
# 1239               {'coming_soon': False, 'date': ''}
# 5218    {'coming_soon': False, 'date': '2 Dec, 2015'}
# 7970    {'coming_soon': False, 'date': '2 Dec, 2015'}
# 9408    {'coming_soon': False, 'date': '3 May, 2016'}
# 19481   {'coming_soon': False, 'date': '1 Nov, 2017'}
# 21937  {'coming_soon': False, 'date': '18 Apr, 2018'}
# 24874   {'coming_soon': False, 'date': '5 Jan, 2019'}
# 25694  {'coming_soon': False, 'date': '17 Aug, 2018'}
# 25696               {'coming_soon': True, 'date': ''}
# 26851       {'coming_soon': True, 'date': 'Oct 2019'}
#
#                                             support_info background  \
# 652    {'url': 'https://telltale.com/support/', 'emai...        NaN
# 653    {'url': 'https://telltale.com/support/', 'emai...        NaN
# 654    {'url': 'https://telltale.com/support/', 'emai...        NaN
# 655    {'url': 'https://telltale.com/support/', 'emai...        NaN
# 1238                            {'url': '', 'email': ''}        NaN
# 1239   {'url': '', 'email': 'support@telltalegames.com'}        NaN
# 5218   {'url': 'http://intothewar.com', 'email': 'nan...        NaN
# 7970        {'url': '', 'email': 'Jemy.TLE@outlook.com'}        NaN
# 9408   {'url': 'http://landfitforheroes.com', 'email'...        NaN
# 19481                           {'url': '', 'email': ''}        NaN
# 21937  {'url': '', 'email': 'insanegamedev@outlook.com'}        NaN
# 24874      {'url': '', 'email': 'smagician13@yahoo.com'}        NaN
# 25694      {'url': '', 'email': 'usa631126453@gmai.com'}        NaN
# 25696  {'url': 'http://www.aridagame.com', 'email': '...        NaN
# 26851        {'url': '', 'email': 'nukalypse@gmail.com'}        NaN
#
#                                      content_descriptors  windows  mac  linux  \
# 652                           {'ids': [], 'notes': None}        1    1      0
# 653                           {'ids': [], 'notes': None}        1    1      0
# 654                           {'ids': [], 'notes': None}        1    1      0
# 655                           {'ids': [], 'notes': None}        1    1      0
# 1238                          {'ids': [], 'notes': None}        1    1      0
# 1239                          {'ids': [], 'notes': None}        1    1      0
# 5218                          {'ids': [], 'notes': None}        1    0      0
# 7970                          {'ids': [], 'notes': None}        1    0      0
# 9408                          {'ids': [], 'notes': None}        1    0      0
# 19481                         {'ids': [], 'notes': None}        1    1      0
# 21937                         {'ids': [], 'notes': None}        1    0      0
# 24874  {'ids': [1, 3, 5], 'notes': 'This Game may con...        1    0      0
# 25694               {'ids': [1, 2, 3, 5], 'notes': None}        1    0      0
# 25696                         {'ids': [], 'notes': None}        1    1      0
# 26851  {'ids': [2, 5], 'notes': 'Mild Violence and An...        1    0      0
#
#        price  english
# 652    -1.00        1
# 653    -1.00        1
# 654    -1.00        1
# 655    -1.00        1
# 1238   -1.00        1
# 1239   -1.00        1
# 5218   -1.00        1
# 7970    4.79        1
# 9408   -1.00        1
# 19481  -1.00        1
# 21937   0.00        1
# 24874   0.79        1
# 25694  -1.00        0
# 25696   0.00        1
# 26851   0.00        1

# %% [markdown]
# There is also a `movies` column with similar data. Whilst having more missing values, presumably for games without videos, it appears to contain names, thumbnails and links to various videos and trailers. It's unlikely we'll be needed them but we can include them in the export and remove them from our data set.

# %%
steam_data['movies'].isnull().sum()
# Out:
# 1893

# %%
with pd.option_context("display.max_colwidth", 1000):
    print(steam_data[steam_data['movies'].notnull()]['movies'].head(3))
# Out:
# 9                                                                                                                                                                                                                                                                                                                                                         [{'id': 904, 'name': 'Half-Life 2 Trailer', 'thumbnail': 'https://steamcdn-a.akamaihd.net/steam/apps/904/movie.jpg?t=1507237301', 'webm': {'480': 'http://steamcdn-a.akamaihd.net/steam/apps/904/movie480.webm?t=1507237301', 'max': 'http://steamcdn-a.akamaihd.net/steam/apps/904/movie_max.webm?t=1507237301'}, 'highlight': True}, {'id': 5724, 'name': 'Free Yourself', 'thumbnail': 'https://steamcdn-a.akamaihd.net/steam/apps/5724/movie.293x165.jpg?t=1507237311', 'webm': {'480': 'http://steamcdn-a.akamaihd.net/steam/apps/5724/movie480.webm?t=1507237311', 'max': 'http://steamcdn-a.akamaihd.net/steam/apps/5724/movie_max.webm?t=1507237311'}, 'highlight': False}]
# 16    [{'id': 915, 'name': 'HL2:EP1 Launch Teaser 4', 'thumbnail': 'https://steamcdn-a.akamaihd.net/steam/apps/915/movie.jpg?t=1512411168', 'webm': {'480': 'http://steamcdn-a.akamaihd.net/steam/apps/915/movie480.webm?t=1512411168', 'max': 'http://steamcdn-a.akamaihd.net/steam/apps/915/movie_max.webm?t=1512411168'}, 'highlight': False}, {'id': 914, 'name': 'HL2:EP1 Launch Teaser 3', 'thumbnail': 'https://steamcdn-a.akamaihd.net/steam/apps/914/movie.jpg?t=1512411159', 'webm': {'480': 'http://steamcdn-a.akamaihd.net/steam/apps/914/movie480.webm?t=1512411159', 'max': 'http://steamcdn-a.akamaihd.net/steam/apps/914/movie_max.webm?t=1512411159'}, 'highlight': False}, {'id': 912, 'name': 'HL2:EP1 Launch Teaser 1', 'thumbnail': 'https://steamcdn-a.akamaihd.net/steam/apps/912/movie.jpg?t=1512411140', 'webm': {'480': 'http://steamcdn-a.akamaihd.net/steam/apps/912/movie480.webm?t=1512411140', 'max': 'http://steamcdn-a.akamaihd.net/steam/apps/912/movie_max.webm?t=1512411140'}, 'highlight': False}, {'...
# 19    [{'id': 256698790, 'name': 'Jungle Inferno', 'thumbnail': 'https://steamcdn-a.akamaihd.net/steam/apps/256698790/movie.293x165.jpg?t=1519429751', 'webm': {'480': 'http://steamcdn-a.akamaihd.net/steam/apps/256698790/movie480.webm?t=1519429751', 'max': 'http://steamcdn-a.akamaihd.net/steam/apps/256698790/movie_max.webm?t=1519429751'}, 'highlight': True}, {'id': 5260, 'name': 'Team Fortress 2: Meet the Spy', 'thumbnail': 'https://steamcdn-a.akamaihd.net/steam/apps/5260/movie.293x165.jpg?t=1519430068', 'webm': {'480': 'http://steamcdn-a.akamaihd.net/steam/apps/5260/movie480.webm?t=1519430068', 'max': 'http://steamcdn-a.akamaihd.net/steam/apps/5260/movie_max.webm?t=1519430068'}, 'highlight': False}, {'id': 5032, 'name': 'Team Fortress 2: Meet the Scout (English)', 'thumbnail': 'https://steamcdn-a.akamaihd.net/steam/apps/5032/movie.jpg?t=1519429900', 'webm': {'480': 'http://steamcdn-a.akamaihd.net/steam/apps/5032/movie480.webm?t=1519429900', 'max': 'http://steamcdn-a.akamaihd.net/steam/ap...
# Name: movies, dtype: object

# %%
def process_images(df, export=False):
    """Remove image columns from dataframe, optionally exporting them to csv first."""
    df = df[df['screenshots'].notnull()].copy()
    
    if export:
        image_data = df[['steam_appid', 'header_image', 'screenshots', 'background', 'movies']]
        
        export_data(image_data, 'image_data')
        
    df = df.drop(['header_image', 'screenshots', 'background', 'movies'], axis=1)
    
    return df


def process(df):
    """Process data set. Will eventually contain calls to all functions we write."""
    
    # Copy the input dataframe to avoid accidentally modifying original data
    df = df.copy()
    
    # Remove duplicate rows - all appids should be unique
    df = df.drop_duplicates()
    
    # Remove collumns with more than 50% null values
    df = process_null_cols(df)
    
    # Process rest of columns
    df = process_type(df)
    df = process_name(df)
    df = process_age(df)
    df = process_platforms(df)
    df = process_price(df)
    df = process_descriptions(df)
    df = process_language(df)
    df = process_images(df, export=True)
    
    return df


steam_data = process(raw_steam_data)
steam_data.head()
# Out:
# Exported image data to '../data/exports/steam_image_data.csv'
#                         name  steam_appid required_age  \
# 0             Counter-Strike           10            3
# 1      Team Fortress Classic           20            3
# 2              Day of Defeat           30            3
# 3         Deathmatch Classic           40            3
# 4  Half-Life: Opposing Force           50            3
#
#                        website  \
# 0                          NaN
# 1                          NaN
# 2  http://www.dayofdefeat.com/
# 3                          NaN
# 4                          NaN
#
#                                      pc_requirements  \
# 0  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 1  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 2  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 3  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 4  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
#
#                                     mac_requirements  \
# 0  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 1  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 2  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 3  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 4  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
#
#                                   linux_requirements            developers  \
# 0  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 1  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 2  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 3  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 4  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...  ['Gearbox Software']
#
#   publishers packages                                     package_groups  \
# 0  ['Valve']      [7]  [{'name': 'default', 'title': 'Buy Counter-Str...
# 1  ['Valve']     [29]  [{'name': 'default', 'title': 'Buy Team Fortre...
# 2  ['Valve']     [30]  [{'name': 'default', 'title': 'Buy Day of Defe...
# 3  ['Valve']     [31]  [{'name': 'default', 'title': 'Buy Deathmatch ...
# 4  ['Valve']     [32]  [{'name': 'default', 'title': 'Buy Half-Life: ...
#
#                                           categories  \
# 0  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 1  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 2  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 3  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 4  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                    genres  achievements  \
# 0  [{'id': '1', 'description': 'Action'}]  {'total': 0}
# 1  [{'id': '1', 'description': 'Action'}]  {'total': 0}
# 2  [{'id': '1', 'description': 'Action'}]  {'total': 0}
# 3  [{'id': '1', 'description': 'Action'}]  {'total': 0}
# 4  [{'id': '1', 'description': 'Action'}]  {'total': 0}
#
#                                     release_date  \
# 0  {'coming_soon': False, 'date': '1 Nov, 2000'}
# 1  {'coming_soon': False, 'date': '1 Apr, 1999'}
# 2  {'coming_soon': False, 'date': '1 May, 2003'}
# 3  {'coming_soon': False, 'date': '1 Jun, 2001'}
# 4  {'coming_soon': False, 'date': '1 Nov, 1999'}
#
#                                         support_info  \
# 0  {'url': 'http://steamcommunity.com/app/10', 'e...
# 1                           {'url': '', 'email': ''}
# 2                           {'url': '', 'email': ''}
# 3                           {'url': '', 'email': ''}
# 4  {'url': 'https://help.steampowered.com', 'emai...
#
#                                  content_descriptors  windows  mac  linux  \
# 0  {'ids': [2, 5], 'notes': 'Includes intense vio...        1    1      1
# 1  {'ids': [2, 5], 'notes': 'Includes intense vio...        1    1      1
# 2                         {'ids': [], 'notes': None}        1    1      1
# 3                         {'ids': [], 'notes': None}        1    1      1
# 4                         {'ids': [], 'notes': None}        1    1      1
#
#    price  english
# 0   7.19        1
# 1   3.99        1
# 2   3.99        1
# 3   3.99        1
# 4   3.99        1

# %%
# inspect exported data
pd.read_csv('../data/exports/steam_image_data.csv').head()
# Out:
#    steam_appid                                       header_image  \
# 0           10  https://steamcdn-a.akamaihd.net/steam/apps/10/...
# 1           20  https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2           30  https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3           40  https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4           50  https://steamcdn-a.akamaihd.net/steam/apps/50/...
#
#                                          screenshots  \
# 0  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 1  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 2  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 3  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 4  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
#
#                                           background movies
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...    NaN
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...    NaN
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...    NaN
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...    NaN
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...    NaN

# %% [markdown]
# # Next Steps
#
# Will continue in the next part
