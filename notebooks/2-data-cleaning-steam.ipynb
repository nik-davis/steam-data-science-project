# %% [markdown]
# # Steam Data Cleaning (Part 1)
#
# *This forms part of a larger series of posts for my [blog](http://nik-davis.github.io) on downloading, processing and analysing data from the steam store. [See all posts here](http://nik-davis.github.io/tags/steam).*
#
# # TODO: Move some stuff to later in project - feature processing/engineering. Simple semicolon separated lists instead?

# %%
# view software version information

# http://raw.github.com/jrjohansson/version_information/master/version_information.py
# %load_ext version_information
# %reload_ext version_information

# %version_information numpy, pandas
# Out:
# Software versions
# Python 3.7.3 64bit [MSC v.1900 64 bit (AMD64)]
# IPython 7.5.0
# OS Windows 10 10.0.17763 SP0
# numpy 1.16.3
# pandas 0.24.2
# Mon Jun 03 15:47:30 2019 GMT Summer Time

# %% [markdown]
# <!-- PELICAN_BEGIN_SUMMARY -->
#
# In the first part of this project, we downloaded and generated data sets from the Steam Store API and SteamSpy API. We now need to take this raw data and prepare it in a process commonly referred to as [data cleaning](https://en.wikipedia.org/wiki/Data_cleansing).
#
# Currently the downloaded data is not in a very useful state. Many of the columns contain lengthy strings or missing values, which hinder analysis and are especially crippling to any machine learning techniques we may wish to implement. Data cleaning involves handling missing values, tidying up values, and ensuring data is neatly and consistently formatted.
#
# <!-- PELICAN_END_SUMMARY -->
#
# Data cleaning is often cited as being the lengthiest part of any project. As such, it will be broken up across a series of posts starting with this one. We will begin by taking care of the columns in the steam data that are easiest to deal with and outlining a framework for the process. Of course it could all be done in one go and a lot more concisely, however we'll be stepping through all the reasons for each decision and building the process iteratively.
#
# The main aims of this project are to investigate various sales and play-time statistics for games from the steam store, and see how different features of games affect the success of those games. Keeping this in mind will help inform our decisions about how to handle the various columns in our data set, however it may be a good idea to keep columns which may not seem useful to this particular project in order to provide a robust data set for future projects.
#
# In part 2, we'll take care of columns that are going to export separate data of some kind, in order to store it for later. Finally for the steam data, in part 3 we will walk through the process of optimising the handling of a column, before exporting the clean data.
#
# Once that is complete we will repeat the whole cleaning process for the steamspy data and combine the results in part 4, finishing with a complete data set ready for analysis.
#
# The raw data can be found and downloaded on [Kaggle](https://www.kaggle.com/nikdavis/steam-store-raw).
#
# ## API references:
#
# - https://partner.steamgames.com/doc/webapi
# - https://wiki.teamfortress.com/wiki/User:RJackson/StorefrontAPI
# - https://steamapi.xpaw.me/#
# - https://steamspy.com/api.php
#
# ## Import Libraries and Inspect Data
#
# To begin with, we'll import the required libraries and set customisation options, then take a look at the downloaded data by reading it into a pandas dataframe.

# %%
# standard library imports
from ast import literal_eval
import itertools
import time
import re

# third-party imports
import numpy as np
import pandas as pd

# customisations
pd.set_option("max_columns", 100)

# %%
# read in downloaded data
raw_steam_data = pd.read_csv('../data/raw/steam_app_data.csv')

# print out number of rows and columns
print('Rows:', raw_steam_data.shape[0])
print('Columns:', raw_steam_data.shape[1])

# view first five rows
raw_steam_data.head()
# Out:
# Rows: 29235
# Columns: 39
#    type                       name  steam_appid  required_age is_free  \
# 0  game             Counter-Strike           10           0.0   False
# 1  game      Team Fortress Classic           20           0.0   False
# 2  game              Day of Defeat           30           0.0   False
# 3  game         Deathmatch Classic           40           0.0   False
# 4  game  Half-Life: Opposing Force           50           0.0   False
#
#   controller_support  dlc                               detailed_description  \
# 0                NaN  NaN  Play the world's number 1 online action game. ...
# 1                NaN  NaN  One of the most popular online action games of...
# 2                NaN  NaN  Enlist in an intense brand of Axis vs. Allied ...
# 3                NaN  NaN  Enjoy fast-paced multiplayer gaming with Death...
# 4                NaN  NaN  Return to the Black Mesa Research Facility as ...
#
#                                       about_the_game  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                    short_description  fullgame  \
# 0  Play the world's number 1 online action game. ...       NaN
# 1  One of the most popular online action games of...       NaN
# 2  Enlist in an intense brand of Axis vs. Allied ...       NaN
# 3  Enjoy fast-paced multiplayer gaming with Death...       NaN
# 4  Return to the Black Mesa Research Facility as ...       NaN
#
#                                  supported_languages  \
# 0  English<strong>*</strong>, French<strong>*</st...
# 1  English, French, German, Italian, Spanish - Sp...
# 2  English, French, German, Italian, Spanish - Spain
# 3  English, French, German, Italian, Spanish - Sp...
# 4                    English, French, German, Korean
#
#                                         header_image  \
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...
#
#                        website  \
# 0                          NaN
# 1                          NaN
# 2  http://www.dayofdefeat.com/
# 3                          NaN
# 4                          NaN
#
#                                      pc_requirements  \
# 0  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 1  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 2  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 3  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 4  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
#
#                                     mac_requirements  \
# 0  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 1  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 2  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 3  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 4  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
#
#                                   linux_requirements legal_notice drm_notice  \
# 0  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...          NaN        NaN
# 1  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...          NaN        NaN
# 2  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...          NaN        NaN
# 3  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...          NaN        NaN
# 4  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...          NaN        NaN
#
#   ext_user_account_notice            developers publishers demos  \
# 0                     NaN             ['Valve']  ['Valve']   NaN
# 1                     NaN             ['Valve']  ['Valve']   NaN
# 2                     NaN             ['Valve']  ['Valve']   NaN
# 3                     NaN             ['Valve']  ['Valve']   NaN
# 4                     NaN  ['Gearbox Software']  ['Valve']   NaN
#
#                                       price_overview packages  \
# 0  {'currency': 'GBP', 'initial': 719, 'final': 7...      [7]
# 1  {'currency': 'GBP', 'initial': 399, 'final': 3...     [29]
# 2  {'currency': 'GBP', 'initial': 399, 'final': 3...     [30]
# 3  {'currency': 'GBP', 'initial': 399, 'final': 3...     [31]
# 4  {'currency': 'GBP', 'initial': 399, 'final': 3...     [32]
#
#                                       package_groups  \
# 0  [{'name': 'default', 'title': 'Buy Counter-Str...
# 1  [{'name': 'default', 'title': 'Buy Team Fortre...
# 2  [{'name': 'default', 'title': 'Buy Day of Defe...
# 3  [{'name': 'default', 'title': 'Buy Deathmatch ...
# 4  [{'name': 'default', 'title': 'Buy Half-Life: ...
#
#                                        platforms  \
# 0  {'windows': True, 'mac': True, 'linux': True}
# 1  {'windows': True, 'mac': True, 'linux': True}
# 2  {'windows': True, 'mac': True, 'linux': True}
# 3  {'windows': True, 'mac': True, 'linux': True}
# 4  {'windows': True, 'mac': True, 'linux': True}
#
#                                           metacritic reviews  \
# 0  {'score': 88, 'url': 'https://www.metacritic.c...     NaN
# 1                                                NaN     NaN
# 2  {'score': 79, 'url': 'https://www.metacritic.c...     NaN
# 3                                                NaN     NaN
# 4                                                NaN     NaN
#
#                                           categories  \
# 0  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 1  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 2  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 3  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 4  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                    genres  \
# 0  [{'id': '1', 'description': 'Action'}]
# 1  [{'id': '1', 'description': 'Action'}]
# 2  [{'id': '1', 'description': 'Action'}]
# 3  [{'id': '1', 'description': 'Action'}]
# 4  [{'id': '1', 'description': 'Action'}]
#
#                                          screenshots movies   recommendations  \
# 0  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 65735}
# 1  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN   {'total': 2802}
# 2  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN   {'total': 1992}
# 3  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN    {'total': 931}
# 4  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN   {'total': 4355}
#
#    achievements                                   release_date  \
# 0  {'total': 0}  {'coming_soon': False, 'date': '1 Nov, 2000'}
# 1  {'total': 0}  {'coming_soon': False, 'date': '1 Apr, 1999'}
# 2  {'total': 0}  {'coming_soon': False, 'date': '1 May, 2003'}
# 3  {'total': 0}  {'coming_soon': False, 'date': '1 Jun, 2001'}
# 4  {'total': 0}  {'coming_soon': False, 'date': '1 Nov, 1999'}
#
#                                         support_info  \
# 0  {'url': 'http://steamcommunity.com/app/10', 'e...
# 1                           {'url': '', 'email': ''}
# 2                           {'url': '', 'email': ''}
# 3                           {'url': '', 'email': ''}
# 4  {'url': 'https://help.steampowered.com', 'emai...
#
#                                           background  \
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...
#
#                                  content_descriptors
# 0  {'ids': [2, 5], 'notes': 'Includes intense vio...
# 1  {'ids': [2, 5], 'notes': 'Includes intense vio...
# 2                         {'ids': [], 'notes': None}
# 3                         {'ids': [], 'notes': None}
# 4                         {'ids': [], 'notes': None}

# %% [markdown]
# From a quick inspection of the data, we can see that we have a mixture of numeric and string columns, plenty of missing values, and a number of columns that look to be stored as dictionaries or lists.
#
# We can chain the `isnull()` and `sum()` methods to easily see how many missing values we have in each column. Immediately we can see that a number of columns have over 20,000 rows with missing data, and in a data set of roughly 30,000 rows these are unlikely to provide any meaningful information.

# %%
null_counts = raw_steam_data.isnull().sum()
null_counts
# Out:
# type                         149
# name                           1
# steam_appid                    0
# required_age                 149
# is_free                      149
# controller_support         23237
# dlc                        24260
# detailed_description         175
# about_the_game               175
# short_description            175
# fullgame                   29235
# supported_languages          163
# header_image                 149
# website                     9983
# pc_requirements              149
# mac_requirements             149
# linux_requirements           149
# legal_notice               19168
# drm_notice                 29077
# ext_user_account_notice    28723
# developers                   264
# publishers                   149
# demos                      27096
# price_overview              3712
# packages                    3370
# package_groups               149
# platforms                    149
# metacritic                 26254
# reviews                    23330
# categories                   714
# genres                       196
# screenshots                  177
# movies                      2078
# recommendations            22507
# achievements                2381
# release_date                 149
# support_info                 149
# background                   177
# content_descriptors          149
# dtype: int64

# %% [markdown]
# ## Initial Processing
#
# We will most likely have to handle each column individually, so we will write some functions to keep our methodology organised, and help iteratively develop the process.
#
# Our first function will remove the columns with more than 50% missing values, taking care of the columns with high null counts. We can do this by running a filter on the dataframe, as seen below.

# %%
threshold = raw_steam_data.shape[0] // 2

print('Drop columns with more than {} missing rows'.format(threshold))
print()

drop_rows = raw_steam_data.columns[null_counts > threshold]

print('Columns to drop: {}'.format(list(drop_rows)))
# Out:
# Drop columns with more than 14617 missing rows
#
# Columns to drop: ['controller_support', 'dlc', 'fullgame', 'legal_notice', 'drm_notice', 'ext_user_account_notice', 'demos', 'metacritic', 'reviews', 'recommendations']

# %% [markdown]
# We can then look at the type and name columns, thinning out our data set a little by removing apps without either.
#
# In the data collection stage, if no information was returned from an app's API request, only the name and appid was stored. We can easily identify these apps by looking at rows with missing data in the `type` column, as all other apps have a value here. As seen below, these rows contain no other information so we can safely remove them.

# %%
print('Rows to remove:', raw_steam_data[raw_steam_data['type'].isnull()].shape[0])

# preview rows with missing type data
raw_steam_data[raw_steam_data['type'].isnull()].head()
# Out:
# Rows to remove: 149
#     type                       name  steam_appid  required_age is_free  \
# 26   NaN  Half-Life: Opposing Force          852           NaN     NaN
# 147  NaN  Half-Life: Opposing Force         4330           NaN     NaN
# 256  NaN  Half-Life: Opposing Force         8740           NaN     NaN
# 264  NaN  Half-Life: Opposing Force         8955           NaN     NaN
# 336  NaN  Half-Life: Opposing Force        11610           NaN     NaN
#
#     controller_support  dlc detailed_description about_the_game  \
# 26                 NaN  NaN                  NaN            NaN
# 147                NaN  NaN                  NaN            NaN
# 256                NaN  NaN                  NaN            NaN
# 264                NaN  NaN                  NaN            NaN
# 336                NaN  NaN                  NaN            NaN
#
#     short_description  fullgame supported_languages header_image website  \
# 26                NaN       NaN                 NaN          NaN     NaN
# 147               NaN       NaN                 NaN          NaN     NaN
# 256               NaN       NaN                 NaN          NaN     NaN
# 264               NaN       NaN                 NaN          NaN     NaN
# 336               NaN       NaN                 NaN          NaN     NaN
#
#     pc_requirements mac_requirements linux_requirements legal_notice  \
# 26              NaN              NaN                NaN          NaN
# 147             NaN              NaN                NaN          NaN
# 256             NaN              NaN                NaN          NaN
# 264             NaN              NaN                NaN          NaN
# 336             NaN              NaN                NaN          NaN
#
#     drm_notice ext_user_account_notice developers publishers demos  \
# 26         NaN                     NaN        NaN        NaN   NaN
# 147        NaN                     NaN        NaN        NaN   NaN
# 256        NaN                     NaN        NaN        NaN   NaN
# 264        NaN                     NaN        NaN        NaN   NaN
# 336        NaN                     NaN        NaN        NaN   NaN
#
#     price_overview packages package_groups platforms metacritic reviews  \
# 26             NaN      NaN            NaN       NaN        NaN     NaN
# 147            NaN      NaN            NaN       NaN        NaN     NaN
# 256            NaN      NaN            NaN       NaN        NaN     NaN
# 264            NaN      NaN            NaN       NaN        NaN     NaN
# 336            NaN      NaN            NaN       NaN        NaN     NaN
#
#     categories genres screenshots movies recommendations achievements  \
# 26         NaN    NaN         NaN    NaN             NaN          NaN
# 147        NaN    NaN         NaN    NaN             NaN          NaN
# 256        NaN    NaN         NaN    NaN             NaN          NaN
# 264        NaN    NaN         NaN    NaN             NaN          NaN
# 336        NaN    NaN         NaN    NaN             NaN          NaN
#
#     release_date support_info background content_descriptors
# 26           NaN          NaN        NaN                 NaN
# 147          NaN          NaN        NaN                 NaN
# 256          NaN          NaN        NaN                 NaN
# 264          NaN          NaN        NaN                 NaN
# 336          NaN          NaN        NaN                 NaN

# %% [markdown]
# We can look at the counts of unique values in a column by using the pandas [Series.value_counts](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.value_counts.html) method. By checking the value counts we see that all rows either have a missing value, as noted above, or 'game' in the `type` column.
#
# Once the null rows are removed, we'll be able to remove this column as it doesn't provide us with any more useful information.

# %%
raw_steam_data['type'].value_counts(dropna=False)
# Out:
# game    29086
# NaN       149
# Name: type, dtype: int64

# %% [markdown]
# Taking a look now at the name column, we can check for rows which either have a null value or a string containing 'none'. This isn't recognised as a null value but should be treated as such.
#
# We achieve this by combining boolean filters using brackets and a vertical bar, `|`, symbolising a logical 'or'.
#
# There are only four rows which match these criteria, and they appear to be missing a lot of data in other columns so we should definitely remove them.

# %%
raw_steam_data[(raw_steam_data['name'].isnull()) | (raw_steam_data['name'] == 'none')]
# Out:
#       type  name  steam_appid  required_age is_free controller_support  dlc  \
# 4918  game  none       339860           0.0   False                NaN  NaN
# 6779  game  none       385020           0.0   False                NaN  NaN
# 7235  game   NaN       396420           0.0    True                NaN  NaN
# 7350  game  none       398970           0.0   False                NaN  NaN
#
#                                    detailed_description  \
# 4918                                                NaN
# 6779                   - discontinued - (please remove)
# 7235  Spookeningは3Dの恐怖ゲームで、あなたは毎夜に死んでゴーストとして復活します。<b...
# 7350                                                NaN
#
#                                          about_the_game  \
# 4918                                                NaN
# 6779                   - discontinued - (please remove)
# 7235  Spookeningは3Dの恐怖ゲームで、あなたは毎夜に死んでゴーストとして復活します。<b...
# 7350                                                NaN
#
#                                       short_description  fullgame  \
# 4918                                                NaN       NaN
# 6779                   - discontinued - (please remove)       NaN
# 7235  Spookeningは3Dの恐怖ゲームで、あなたは毎夜に死んでゴーストとして復活します。 村...       NaN
# 7350                                                NaN       NaN
#
#                                     supported_languages  \
# 4918  English<strong>*</strong><br><strong>*</strong...
# 6779  English, French, Italian, German, Spanish - Sp...
# 7235                                                NaN
# 7350  English<strong>*</strong><br><strong>*</strong...
#
#                                            header_image website  \
# 4918  https://steamcdn-a.akamaihd.net/steam/apps/339...     NaN
# 6779  https://steamcdn-a.akamaihd.net/steam/apps/385...     NaN
# 7235  https://steamcdn-a.akamaihd.net/steam/apps/396...     NaN
# 7350  https://steamcdn-a.akamaihd.net/steam/apps/398...     NaN
#
#                                         pc_requirements  \
# 4918  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 6779  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 7235  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 7350  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                        mac_requirements  \
# 4918                                                 []
# 6779  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 7235                                                 []
# 7350  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                      linux_requirements legal_notice  \
# 4918                                                 []          NaN
# 6779  {'minimum': '<strong>Minimum:</strong><br><ul ...          NaN
# 7235                                                 []          NaN
# 7350  {'minimum': '<strong>Minimum:</strong><br><ul ...          NaN
#
#      drm_notice ext_user_account_notice developers publishers  \
# 4918        NaN                     NaN        NaN       ['']
# 6779        NaN                     NaN   ['none']       ['']
# 7235        NaN                     NaN        NaN       ['']
# 7350        NaN                     NaN   ['none']   ['none']
#
#                                        demos price_overview packages  \
# 4918                                     NaN            NaN      NaN
# 6779                                     NaN            NaN      NaN
# 7235                                     NaN            NaN      NaN
# 7350  [{'appid': 516340, 'description': ''}]            NaN      NaN
#
#      package_groups                                        platforms  \
# 4918             []  {'windows': True, 'mac': False, 'linux': False}
# 6779             []    {'windows': True, 'mac': True, 'linux': True}
# 7235             []  {'windows': True, 'mac': False, 'linux': False}
# 7350             []    {'windows': True, 'mac': True, 'linux': True}
#
#      metacritic reviews                                         categories  \
# 4918        NaN     NaN  [{'id': 2, 'description': 'Single-player'}, {'...
# 6779        NaN     NaN  [{'id': 2, 'description': 'Single-player'}, {'...
# 7235        NaN     NaN                                                NaN
# 7350        NaN     NaN  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                                  genres screenshots movies  \
# 4918  [{'id': '25', 'description': 'Adventure'}, {'i...         NaN    NaN
# 6779  [{'id': '4', 'description': 'Casual'}, {'id': ...         NaN    NaN
# 7235                                                NaN         NaN    NaN
# 7350  [{'id': '25', 'description': 'Adventure'}, {'i...         NaN    NaN
#
#      recommendations                                       achievements  \
# 4918             NaN  {'total': 3, 'highlighted': [{'name': 'Master ...
# 6779             NaN                                       {'total': 0}
# 7235             NaN                                       {'total': 0}
# 7350             NaN  {'total': 35, 'highlighted': [{'name': "They'v...
#
#                                         release_date  \
# 4918  {'coming_soon': False, 'date': '27 Feb, 2015'}
# 6779   {'coming_soon': False, 'date': '4 Nov, 2015'}
# 7235   {'coming_soon': False, 'date': '1 Nov, 2016'}
# 7350   {'coming_soon': False, 'date': '5 Nov, 2015'}
#
#                   support_info background         content_descriptors
# 4918  {'url': '', 'email': ''}        NaN  {'ids': [], 'notes': None}
# 6779  {'url': '', 'email': ''}        NaN  {'ids': [], 'notes': None}
# 7235  {'url': '', 'email': ''}        NaN  {'ids': [], 'notes': None}
# 7350  {'url': '', 'email': ''}        NaN  {'ids': [], 'notes': None}

# %% [markdown]
# As we know for certain that all AppIDs should be unique, any rows with the same ID need to be handled.
#
# We can easily view duplicated rows using the [DataFrame.duplicated()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html) method of pandas. We can pass `keep=False` to view all duplicated rows, or leave the defaults (`keep='first'`) to skip over the first row and just show the rest of the duplicates. We can also pass a column label into `subset` if we want to filter by a single column.
#
# As we only want to remove the extra rows, we can keep the default behaviour.

# %%
duplicate_rows = raw_steam_data[raw_steam_data.duplicated()]

print('Duplicate rows to remove:', duplicate_rows.shape[0])

duplicate_rows.head(3)
# Out:
# Duplicate rows to remove: 7
#      type                     name  steam_appid  required_age is_free  \
# 31   game  SiN Episodes: Emergence         1300           0.0   False
# 32   game  SiN Episodes: Emergence         1300           0.0   False
# 356  game   Jagged Alliance 2 Gold         1620           0.0   False
#
#     controller_support  dlc  \
# 31                 NaN  NaN
# 32                 NaN  NaN
# 356                NaN  NaN
#
#                                   detailed_description  \
# 31   You are John Blade, commander of HardCorps, an...
# 32   You are John Blade, commander of HardCorps, an...
# 356  <p>The small country of Arulco has been taken ...
#
#                                         about_the_game  \
# 31   You are John Blade, commander of HardCorps, an...
# 32   You are John Blade, commander of HardCorps, an...
# 356  <p>The small country of Arulco has been taken ...
#
#                                      short_description  fullgame  \
# 31   You are John Blade, commander of HardCorps, an...       NaN
# 32   You are John Blade, commander of HardCorps, an...       NaN
# 356  The small country of Arulco has been taken ove...       NaN
#
#           supported_languages  \
# 31   English, Russian, French
# 32   English, Russian, French
# 356                   English
#
#                                           header_image  \
# 31   https://steamcdn-a.akamaihd.net/steam/apps/130...
# 32   https://steamcdn-a.akamaihd.net/steam/apps/130...
# 356  https://steamcdn-a.akamaihd.net/steam/apps/162...
#
#                              website  \
# 31                               NaN
# 32                               NaN
# 356  http://www.jaggedalliance2.com/
#
#                                        pc_requirements mac_requirements  \
# 31   {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...               []
# 32   {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...               []
# 356  {'minimum': '<p><strong>Minimum Configuration:...               []
#
#     linux_requirements legal_notice drm_notice ext_user_account_notice  \
# 31                  []          NaN        NaN                     NaN
# 32                  []          NaN        NaN                     NaN
# 356                 []          NaN        NaN                     NaN
#
#                    developers                publishers demos  \
# 31   ['Ritual Entertainment']  ['Ritual Entertainment']   NaN
# 32   ['Ritual Entertainment']  ['Ritual Entertainment']   NaN
# 356        ['Strategy First']        ['Strategy First']   NaN
#
#                                         price_overview packages  \
# 31   {'currency': 'GBP', 'initial': 719, 'final': 7...     [70]
# 32   {'currency': 'GBP', 'initial': 719, 'final': 7...     [70]
# 356  {'currency': 'GBP', 'initial': 1499, 'final': ...     [94]
#
#                                         package_groups  \
# 31   [{'name': 'default', 'title': 'Buy SiN Episode...
# 32   [{'name': 'default', 'title': 'Buy SiN Episode...
# 356  [{'name': 'default', 'title': 'Buy Jagged Alli...
#
#                                            platforms  \
# 31   {'windows': True, 'mac': False, 'linux': False}
# 32   {'windows': True, 'mac': False, 'linux': False}
# 356  {'windows': True, 'mac': False, 'linux': False}
#
#                                             metacritic reviews  \
# 31   {'score': 75, 'url': 'https://www.metacritic.c...     NaN
# 32   {'score': 75, 'url': 'https://www.metacritic.c...     NaN
# 356                                                NaN     NaN
#
#                                             categories  \
# 31   [{'id': 2, 'description': 'Single-player'}, {'...
# 32   [{'id': 2, 'description': 'Single-player'}, {'...
# 356        [{'id': 2, 'description': 'Single-player'}]
#
#                                        genres  \
# 31     [{'id': '1', 'description': 'Action'}]
# 32     [{'id': '1', 'description': 'Action'}]
# 356  [{'id': '2', 'description': 'Strategy'}]
#
#                                            screenshots movies recommendations  \
# 31   [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 265}
# 32   [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 265}
# 356  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             NaN
#
#      achievements                                    release_date  \
# 31   {'total': 0}  {'coming_soon': False, 'date': '10 May, 2006'}
# 32   {'total': 0}  {'coming_soon': False, 'date': '10 May, 2006'}
# 356  {'total': 0}   {'coming_soon': False, 'date': '6 Jul, 2006'}
#
#                  support_info  \
# 31   {'url': '', 'email': ''}
# 32   {'url': '', 'email': ''}
# 356  {'url': '', 'email': ''}
#
#                                             background  \
# 31   https://steamcdn-a.akamaihd.net/steam/apps/130...
# 32   https://steamcdn-a.akamaihd.net/steam/apps/130...
# 356  https://steamcdn-a.akamaihd.net/steam/apps/162...
#
#             content_descriptors
# 31   {'ids': [], 'notes': None}
# 32   {'ids': [], 'notes': None}
# 356  {'ids': [], 'notes': None}

# %% [markdown]
# Let's also quickly verify that we aren't missing any rows duplicated on just the `steam_appid` column by comparing the `duplicate_rows` dataframe with the one generated by passing `subset='steam_appid'` into the duplicated method.

# %%
duplicate_app_id_rows = raw_steam_data[raw_steam_data.duplicated(subset='steam_appid')]

print('True if same:', duplicate_app_id_rows.equals(duplicate_rows))
# Out:
# True if same: True

# %% [markdown]
# We're now ready to define functions implementing the filters we just looked at. This allows us to easily make changes in the future if we want to alter how the columns are handled, or want to choose a different cut-off threshold for getting rid of columns, for example.
#
# We also define a general purpose `process` function which will run all the processing functions we create on the data set. This will allow us to slowly add to it as we develop more functions and ensure we're cleaning the correct dataframe.
#
# Finally we run this function on the raw data, inspecting the first few rows and viewing how many rows and columns have been removed.

# %%
def drop_null_cols(df, thresh=0.5):
    """Drop columns with more than a certain proportion of missing values (Default 50%)."""
    cutoff_count = len(df) * thresh
    
    return df.dropna(thresh=cutoff_count, axis=1)


def process_name_type(df):
    """Remove null values in name and type columns, and remove type column.."""
    df = df[df['type'].notnull()]
    
    df = df[df['name'].notnull()]
    df = df[df['name'] != 'none']
    
    df = df.drop('type', axis=1)
    
    return df
    

def process(df):
    """Process data set. Will eventually contain calls to all functions we write."""
    
    # Copy the input dataframe to avoid accidentally modifying original data
    df = df.copy()
    
    # Remove duplicate rows - all appids should be unique
    df = df.drop_duplicates()
    
    # Remove collumns with more than 50% null values
    df = drop_null_cols(df)
    
    # Process rest of columns
    df = process_name_type(df)
    
    return df

print(raw_steam_data.shape)
steam_data = process(raw_steam_data)
print(steam_data.shape)
steam_data.head()
# Out:
# (29235, 39)
# (29075, 28)
#                         name  steam_appid  required_age is_free  \
# 0             Counter-Strike           10           0.0   False
# 1      Team Fortress Classic           20           0.0   False
# 2              Day of Defeat           30           0.0   False
# 3         Deathmatch Classic           40           0.0   False
# 4  Half-Life: Opposing Force           50           0.0   False
#
#                                 detailed_description  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                       about_the_game  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                    short_description  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                  supported_languages  \
# 0  English<strong>*</strong>, French<strong>*</st...
# 1  English, French, German, Italian, Spanish - Sp...
# 2  English, French, German, Italian, Spanish - Spain
# 3  English, French, German, Italian, Spanish - Sp...
# 4                    English, French, German, Korean
#
#                                         header_image  \
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...
#
#                        website  \
# 0                          NaN
# 1                          NaN
# 2  http://www.dayofdefeat.com/
# 3                          NaN
# 4                          NaN
#
#                                      pc_requirements  \
# 0  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 1  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 2  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 3  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 4  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
#
#                                     mac_requirements  \
# 0  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 1  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 2  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 3  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 4  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
#
#                                   linux_requirements            developers  \
# 0  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 1  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 2  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 3  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 4  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...  ['Gearbox Software']
#
#   publishers                                     price_overview packages  \
# 0  ['Valve']  {'currency': 'GBP', 'initial': 719, 'final': 7...      [7]
# 1  ['Valve']  {'currency': 'GBP', 'initial': 399, 'final': 3...     [29]
# 2  ['Valve']  {'currency': 'GBP', 'initial': 399, 'final': 3...     [30]
# 3  ['Valve']  {'currency': 'GBP', 'initial': 399, 'final': 3...     [31]
# 4  ['Valve']  {'currency': 'GBP', 'initial': 399, 'final': 3...     [32]
#
#                                       package_groups  \
# 0  [{'name': 'default', 'title': 'Buy Counter-Str...
# 1  [{'name': 'default', 'title': 'Buy Team Fortre...
# 2  [{'name': 'default', 'title': 'Buy Day of Defe...
# 3  [{'name': 'default', 'title': 'Buy Deathmatch ...
# 4  [{'name': 'default', 'title': 'Buy Half-Life: ...
#
#                                        platforms  \
# 0  {'windows': True, 'mac': True, 'linux': True}
# 1  {'windows': True, 'mac': True, 'linux': True}
# 2  {'windows': True, 'mac': True, 'linux': True}
# 3  {'windows': True, 'mac': True, 'linux': True}
# 4  {'windows': True, 'mac': True, 'linux': True}
#
#                                           categories  \
# 0  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 1  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 2  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 3  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 4  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                    genres  \
# 0  [{'id': '1', 'description': 'Action'}]
# 1  [{'id': '1', 'description': 'Action'}]
# 2  [{'id': '1', 'description': 'Action'}]
# 3  [{'id': '1', 'description': 'Action'}]
# 4  [{'id': '1', 'description': 'Action'}]
#
#                                          screenshots movies  achievements  \
# 0  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 1  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 2  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 3  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 4  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
#
#                                     release_date  \
# 0  {'coming_soon': False, 'date': '1 Nov, 2000'}
# 1  {'coming_soon': False, 'date': '1 Apr, 1999'}
# 2  {'coming_soon': False, 'date': '1 May, 2003'}
# 3  {'coming_soon': False, 'date': '1 Jun, 2001'}
# 4  {'coming_soon': False, 'date': '1 Nov, 1999'}
#
#                                         support_info  \
# 0  {'url': 'http://steamcommunity.com/app/10', 'e...
# 1                           {'url': '', 'email': ''}
# 2                           {'url': '', 'email': ''}
# 3                           {'url': '', 'email': ''}
# 4  {'url': 'https://help.steampowered.com', 'emai...
#
#                                           background  \
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...
#
#                                  content_descriptors
# 0  {'ids': [2, 5], 'notes': 'Includes intense vio...
# 1  {'ids': [2, 5], 'notes': 'Includes intense vio...
# 2                         {'ids': [], 'notes': None}
# 3                         {'ids': [], 'notes': None}
# 4                         {'ids': [], 'notes': None}

# %% [markdown]
# ## Processing Age
#
# Next we'll look at the `required_age` column. By looking at the value counts we can see that values are already stored as integers, and the values range from 0 to 20, with one likely error (1818). There are no missing values in this column, but the vast majority have a value of 0. We'll clean the column anyway, but this probably means it won't be of much use in analysis as there is little variance in the data.

# %%
steam_data['required_age'].value_counts(dropna=False).sort_index()
# Out:
# 0.0       28431
# 1.0           1
# 3.0          10
# 4.0           2
# 5.0           1
# 6.0           1
# 7.0           8
# 10.0          3
# 11.0          4
# 12.0         72
# 13.0         21
# 14.0          4
# 15.0         39
# 16.0        141
# 17.0         47
# 18.0        288
# 20.0          1
# 1818.0        1
# Name: required_age, dtype: int64

# %% [markdown]
# Whilst fairly useful in its current state, we may benefit from reducing the number of categories that ages fall into. For example, instead of comparing games rated as 5, 6, 7 or 8, we could compare games rated 5+ or 8+.
#
# To decide which categories (or bins) we should use, we will look at the [PEGI age ratings](https://pegi.info/) as this is the system used in the United Kingdom, where we're performing our analysis. Ratings fall into one of five categories (3, 7, 12, 16, 18), defining the minimum age recommended to play a game.
#
# Using this to inform our decision, we can use the [pandas.cut](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.cut.html) function to sort our data into each of these categories. Rows with 0 may mean they are unrated, unstated as in missing, or rated as suitable for everyone. Because we can't tell we'll leave these as they are. As the erroneous row (1818) is most likely meant to be rated 18 anyway, we can set the upper bound above this value to catch it inside this category.
#
# Below we define a `process_age` function to handle this, and add it into our `process` definition.

# %%
def process_age(df):
    """Format ratings in age column to be in line with the PEGI Age Ratings system."""
    # PEGI Age ratings: 3, 7, 12, 16, 18
    cut_points = [-1, 0, 3, 7, 12, 16, 2000]
    label_values = [0, 3, 7, 12, 16, 18]
    
    df['required_age'] = pd.cut(df['required_age'], bins=cut_points, labels=label_values)
    
    return df


def process(df):
    """Process data set. Will eventually contain calls to all functions we write."""
    
    # Copy the input dataframe to avoid accidentally modifying original data
    df = df.copy()
    
    # Remove duplicate rows - all appids should be unique
    df = df.drop_duplicates()
    
    # Remove collumns with more than 50% null values
    df = drop_null_cols(df)
    
    # Process rest of columns
    df = process_name_type(df)
    df = process_age(df)
    
    return df


steam_data = process(raw_steam_data)
steam_data['required_age'].value_counts().sort_index()
# Out:
# 0     28431
# 3        11
# 7        12
# 12       79
# 16      205
# 18      337
# Name: required_age, dtype: int64

# %% [markdown]
# ## Processing the Platforms Column
#
# Whilst we could look at the next column in the dataframe, `is_free`, it would make sense that this is linked to the `price_overview` column. Ultimately we may wish to combine these columns into one, where free games would have a price of 0.
#
# Looking at the `price_overview` column, we can see it is stored in a dictionary-like structure, with multiple keys and values. Handling both of these together might be somewhat trickty, so instead we'll look at a simpler example.

# %%
steam_data['price_overview'].head()
# Out:
# 0    {'currency': 'GBP', 'initial': 719, 'final': 7...
# 1    {'currency': 'GBP', 'initial': 399, 'final': 3...
# 2    {'currency': 'GBP', 'initial': 399, 'final': 3...
# 3    {'currency': 'GBP', 'initial': 399, 'final': 3...
# 4    {'currency': 'GBP', 'initial': 399, 'final': 3...
# Name: price_overview, dtype: object

# %% [markdown]
# The `platforms` column appears to contain a key for each of the main operating systems - windows, mac and linux - and a corresponding boolean value, set to True or False depending on the availability on that platform. This should be a reasonably straighforward place to start. We can separate this data out into three columns - one for each platform - filled with boolean values.

# %%
steam_data['platforms'].head()
# Out:
# 0    {'windows': True, 'mac': True, 'linux': True}
# 1    {'windows': True, 'mac': True, 'linux': True}
# 2    {'windows': True, 'mac': True, 'linux': True}
# 3    {'windows': True, 'mac': True, 'linux': True}
# 4    {'windows': True, 'mac': True, 'linux': True}
# Name: platforms, dtype: object

# %% [markdown]
# So far the cleaning process has been relatively simple, mainly requiring checking for null values and dropping some rows or columns. Already we can see that handling the platforms will be a little more complex.
#
# Our first hurdle is getting python to recognise the data in the columns as dictionaries rather than just strings. This will allow us to access the different values separately, without having to do some unnecessarily complicated string formatting. As we can see below, even though the data looks like a dictionary it is in fact stored as a string.

# %%
platforms_first_row = steam_data['platforms'].iloc[0]

print(type(platforms_first_row))

platforms_first_row
# Out:
# <class 'str'>
# "{'windows': True, 'mac': True, 'linux': True}"

# %% [markdown]
# We can get around this using the handy [literal_eval](https://docs.python.org/3/library/ast.html#ast.literal_eval) function from the built-in `ast` module. As the name suggests, this will allow us to evaluate the string, and then index into it as a
# dictionary.

# %%
eval_first_row = literal_eval(platforms_first_row)

print(type(eval_first_row))

eval_first_row['windows']
# Out:
# <class 'dict'>
# True

# %% [markdown]
# We also need to check for missing values, but fortunately it appears there aren't any in this column.

# %%
steam_data['platforms'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Putting this all together, we can use the pandas [Series.apply](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.apply.html) method to quickly evaluate all of the rows, then make calls to `apply` again to create the new columns for each platform.
#
# We could return the True/False value directly and store the values as boolean types, but since we'll be exporting the cleaned data to a csv file, let's store them as integers as this should reduce the file size slightly. Setting True as 1 and False as 0 can still be interpreted as a boolean type, but less data is used to store the information.

# %%
# def process_platforms(df):
#     """Split platforms column into separate boolean columns for each platform."""
#     # evaluate values in platforms column, so can index into dictionaries
#     df['platforms'] = df['platforms'].apply(lambda x: literal_eval(x))
    
#     # loop across keys (the platforms) which will be turned into columns
#     for platform in df['platforms'][0].keys():
#         # set 1 if value for platform in original column is True, or 0 if it's False
#         df[platform] = df['platforms'].apply(lambda x: 1 if x[platform] else 0)
    
#     # remove the original platforms column
#     df = df.drop('platforms', axis=1)
    
#     return df


# def process(df):
#     """Process data set. Will eventually contain calls to all functions we write."""
    
#     # Copy the input dataframe to avoid accidentally modifying original data
#     df = df.copy()
    
#     # Remove duplicate rows - all appids should be unique
#     df = df.drop_duplicates()
    
#     # Remove collumns with more than 50% null values
#     df = drop_null_cols(df)
    
#     # Process rest of columns
#     df = process_name_type(df)
#     df = process_age(df)
#     df = process_platforms(df)
    
#     return df


# steam_data = process(raw_steam_data)
# steam_data[['name', 'windows', 'mac', 'linux']].head()

# %% [markdown]
# # Investigating alternate platforms processing

# %%
def process_platforms(df):
    """Split platforms column into separate boolean columns for each platform."""
    # evaluate values in platforms column, so can index into dictionaries
    
    def parse_platforms(x):
        
        x_eval = literal_eval(x)
        output = []
        
        for key in x_eval.keys():
            if x_eval[key]:
                output.append(key)
        
        return ';'.join(output)
    
    df['platforms'] = df['platforms'].apply(parse_platforms)
    
#     # loop across keys (the platforms) which will be turned into columns
#     for platform in df['platforms'][0].keys():
#         # set 1 if value for platform in original column is True, or 0 if it's False
#         df[platform] = df['platforms'].apply(lambda x: 1 if x[platform] else 0)
    
#     # remove the original platforms column
#     df = df.drop('platforms', axis=1)
    
    return df


def process(df):
    """Process data set. Will eventually contain calls to all functions we write."""
    
    # Copy the input dataframe to avoid accidentally modifying original data
    df = df.copy()
    
    # Remove duplicate rows - all appids should be unique
    df = df.drop_duplicates()
    
    # Remove collumns with more than 50% null values
    df = drop_null_cols(df)
    
    # Process rest of columns
    df = process_name_type(df)
    df = process_age(df)
    df = process_platforms(df)
    
    return df


steam_data = process(raw_steam_data)
steam_data[['name', 'platforms']].head()
# Out:
#                         name          platforms
# 0             Counter-Strike  windows;mac;linux
# 1      Team Fortress Classic  windows;mac;linux
# 2              Day of Defeat  windows;mac;linux
# 3         Deathmatch Classic  windows;mac;linux
# 4  Half-Life: Opposing Force  windows;mac;linux

# %% [markdown]
# ## Processing Price
#
# Now we have built up some intuition around how to deal with data stored as dictionaries, let's return to the `is_free` and `price_overview` columns as we should now be able to handle them.
#
# First let's check how many null values there are in `price_overview`.

# %%
steam_data['price_overview'].isnull().sum()
# Out:
# 3559

# %% [markdown]
# Whilst that looks like a lot, we have to consider the impact that the `is_free` column might be having. Before jumping to conclusions let's check if there any rows with `is_free` marked as True and null values in the `price_overview` column.

# %%
free_and_null_price = steam_data[(steam_data['is_free']) & (steam_data['price_overview'].isnull())]

print(free_and_null_price.shape[0])
free_and_null_price.head()
# Out:
# 2713
#                                 name  steam_appid required_age is_free  \
# 14           Half-Life 2: Lost Coast          340            0    True
# 19                   Team Fortress 2          440            0    True
# 22                            Dota 2          570            0    True
# 24                       Alien Swarm          630            0    True
# 25  Counter-Strike: Global Offensive          730            0    True
#
#                                  detailed_description  \
# 14  Originally planned as a section of the Highway...
# 19  <h1>The Jungle Inferno Update</h1><p><a href="...
# 22  <strong>The most-played game on Steam.</strong...
# 24  Alien Swarm is a game and Source SDK release f...
# 25  Counter-Strike: Global Offensive (CS: GO) expa...
#
#                                        about_the_game  \
# 14  Originally planned as a section of the Highway...
# 19  <p><strong>"The most fun you can have online"<...
# 22  <strong>The most-played game on Steam.</strong...
# 24  Alien Swarm is a game and Source SDK release f...
# 25  Counter-Strike: Global Offensive (CS: GO) expa...
#
#                                     short_description  \
# 14  Originally planned as a section of the Highway...
# 19  Nine distinct classes provide a broad range of...
# 22  Every day, millions of players worldwide enter...
# 24  Co-operative multiplayer game and complete cod...
# 25  Counter-Strike: Global Offensive (CS: GO) expa...
#
#                                   supported_languages  \
# 14  English, French, German, Italian, Spanish - Sp...
# 19  English<strong>*</strong>, Danish, Dutch, Finn...
# 22  Bulgarian, Czech, Danish, Dutch, English<stron...
# 24                                            English
# 25  Czech, Danish, Dutch, English<strong>*</strong...
#
#                                          header_image  \
# 14  https://steamcdn-a.akamaihd.net/steam/apps/340...
# 19  https://steamcdn-a.akamaihd.net/steam/apps/440...
# 22  https://steamcdn-a.akamaihd.net/steam/apps/570...
# 24  https://steamcdn-a.akamaihd.net/steam/apps/630...
# 25  https://steamcdn-a.akamaihd.net/steam/apps/730...
#
#                             website  \
# 14        http://www.half-life2.com
# 19     http://www.teamfortress.com/
# 22            http://www.dota2.com/
# 24        http://www.alienswarm.com
# 25  http://blog.counter-strike.net/
#
#                                       pc_requirements  \
# 14  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 19  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 22  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 24  {'minimum': '<strong>Minimum:</strong><br>\t\t...
# 25  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                      mac_requirements  \
# 14                                                 []
# 19  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 22  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 24                                                 []
# 25  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                    linux_requirements  \
# 14                                                 []
# 19  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 22  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 24                                                 []
# 25  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                 developers publishers price_overview  \
# 14                               ['Valve']  ['Valve']            NaN
# 19                               ['Valve']  ['Valve']            NaN
# 22                               ['Valve']  ['Valve']            NaN
# 24                               ['Valve']  ['Valve']            NaN
# 25  ['Valve', 'Hidden Path Entertainment']  ['Valve']            NaN
#
#                    packages  \
# 14                      NaN
# 19    [197845, 330198, 469]
# 22         [197846, 330209]
# 24                      NaN
# 25  [329385, 298963, 54029]
#
#                                        package_groups          platforms  \
# 14                                                 []  windows;mac;linux
# 19  [{'name': 'default', 'title': 'Buy Team Fortre...  windows;mac;linux
# 22  [{'name': 'default', 'title': 'Buy Dota 2', 'd...  windows;mac;linux
# 24                                                 []            windows
# 25  [{'name': 'default', 'title': 'Buy Counter-Str...  windows;mac;linux
#
#                                            categories  \
# 14  [{'id': 2, 'description': 'Single-player'}, {'...
# 19  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 22  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 24  [{'id': 2, 'description': 'Single-player'}, {'...
# 25  [{'id': 1, 'description': 'Multi-player'}, {'i...
#
#                                                genres  \
# 14             [{'id': '1', 'description': 'Action'}]
# 19  [{'id': '1', 'description': 'Action'}, {'id': ...
# 22  [{'id': '1', 'description': 'Action'}, {'id': ...
# 24             [{'id': '1', 'description': 'Action'}]
# 25  [{'id': '1', 'description': 'Action'}, {'id': ...
#
#                                           screenshots  \
# 14  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 19  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 22  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 24  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 25  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
#
#                                                movies  \
# 14                                                NaN
# 19  [{'id': 256698790, 'name': 'Jungle Inferno', '...
# 22  [{'id': 256692021, 'name': 'Dota 2 - Join the ...
# 24                                                NaN
# 25  [{'id': 81958, 'name': 'CS:GO Trailer Long', '...
#
#                                          achievements  \
# 14                                       {'total': 0}
# 19  {'total': 520, 'highlighted': [{'name': 'Head ...
# 22                                                NaN
# 24  {'total': 66, 'highlighted': [{'name': 'Clear ...
# 25  {'total': 167, 'highlighted': [{'name': 'Someo...
#
#                                       release_date  \
# 14  {'coming_soon': False, 'date': '27 Oct, 2005'}
# 19  {'coming_soon': False, 'date': '10 Oct, 2007'}
# 22   {'coming_soon': False, 'date': '9 Jul, 2013'}
# 24  {'coming_soon': False, 'date': '19 Jul, 2010'}
# 25  {'coming_soon': False, 'date': '21 Aug, 2012'}
#
#                                          support_info  \
# 14                           {'url': '', 'email': ''}
# 19  {'url': 'http://steamcommunity.com/app/440', '...
# 22      {'url': 'http://dev.dota2.com/', 'email': ''}
# 24                           {'url': '', 'email': ''}
# 25                           {'url': '', 'email': ''}
#
#                                            background  \
# 14  https://steamcdn-a.akamaihd.net/steam/apps/340...
# 19  https://steamcdn-a.akamaihd.net/steam/apps/440...
# 22  https://steamcdn-a.akamaihd.net/steam/apps/570...
# 24  https://steamcdn-a.akamaihd.net/steam/apps/630...
# 25  https://steamcdn-a.akamaihd.net/steam/apps/730...
#
#                                   content_descriptors
# 14                         {'ids': [], 'notes': None}
# 19  {'ids': [2, 5], 'notes': 'Includes cartoon vio...
# 22                         {'ids': [], 'notes': None}
# 24                         {'ids': [], 'notes': None}
# 25  {'ids': [2, 5], 'notes': 'Includes intense vio...

# %% [markdown]
# It turns out this accounts for most of the missing values in the `price_overview` column, meaning we can handle these by setting the final price as 0. This makes intuitive sense - free games wouldn't have a price.
#
# This means that there are almost 850 rows which aren't free but have null values in the `price_overview` column. Let's investigate those next.

# %%
not_free_and_null_price = steam_data[(steam_data['is_free'] == False) & (steam_data['price_overview'].isnull())]

not_free_and_null_price.head()
# Out:
#                                   name  steam_appid required_age is_free  \
# 63             The Ship: Single Player         2420            0   False
# 75   RollerCoaster Tycoon® 3: Platinum         2700            0   False
# 220                          BioShock™         7670            0   False
# 234       Sam & Max 101: Culture Shock         8200            0   False
# 235   Sam & Max 102: Situation: Comedy         8210            0   False
#
#                                   detailed_description  \
# 63   For PC gamers who enjoy multiplayer games with...
# 75   Rollercoaster Tycoon 3 Platinum combines the e...
# 220  <h1>Special Offer</h1><p>Buying BioShock™ also...
# 234  <strong>Sam &amp; Max: Episode 1 - Culture Sho...
# 235  <strong>Sam &amp; Max: Episode 2 - Situation: ...
#
#                                         about_the_game  \
# 63   For PC gamers who enjoy multiplayer games with...
# 75   Rollercoaster Tycoon 3 Platinum combines the e...
# 220  BioShock is a shooter unlike any you've ever p...
# 234  <strong>Sam &amp; Max: Episode 1 - Culture Sho...
# 235  <strong>Sam &amp; Max: Episode 2 - Situation: ...
#
#                                      short_description  \
# 63   The Ship is a murder mystery alternative to tr...
# 75   Rollercoaster Tycoon 3 Platinum combines the e...
# 220  BioShock is a shooter unlike any you've ever p...
# 234  Sam &amp; Max: Episode 1 - Culture Shock - The...
# 235  Sam &amp; Max: Episode 2 - Situation: Comedy -...
#
#                                    supported_languages  \
# 63   English, French, German, Italian, Spanish - Sp...
# 75   English, French, Italian, German, Spanish - Sp...
# 220  English<strong>*</strong>, French<strong>*</st...
# 234                   English, French, German, Italian
# 235                           English, German, Italian
#
#                                           header_image  \
# 63   https://steamcdn-a.akamaihd.net/steam/apps/242...
# 75   https://steamcdn-a.akamaihd.net/steam/apps/270...
# 220  https://steamcdn-a.akamaihd.net/steam/apps/767...
# 234  https://steamcdn-a.akamaihd.net/steam/apps/820...
# 235  https://steamcdn-a.akamaihd.net/steam/apps/821...
#
#                                                website  \
# 63   http://www.blazinggriffin.com/games/the-ship-m...
# 75   http://www.atari.com/rollercoastertycoon/us/in...
# 220                        http://www.BioShockGame.com
# 234          http://store.steampowered.com/app/901660/
# 235          http://store.steampowered.com/app/901660/
#
#                                        pc_requirements  \
# 63   {'minimum': '<strong>Minimum:</strong> 1.8 GHz...
# 75   {'minimum': '<strong>Minimum: </strong><br>\t\...
# 220  {'minimum': '<h2 class="bb_tag"><strong>Minimu...
# 234  {'minimum': 'Windows XP or Vista, 1.5GHz proce...
# 235  {'minimum': 'Windows XP or Vista, 1.5GHz proce...
#
#                                       mac_requirements linux_requirements  \
# 63                                                  []                 []
# 75   {'minimum': '<ul class="bb_ul"><li><strong>OS:...                 []
# 220      {'minimum': 'Please See BioShock Remastered'}                 []
# 234                                                 []                 []
# 235                                                 []                 []
#
#                         developers                publishers price_overview  \
# 63             ['Outerlight Ltd.']  ['Blazing Griffin Ltd.']            NaN
# 75     ['Frontier', 'Aspyr (Mac)']  ['Atari', 'Aspyr (Mac)']            NaN
# 220  ['2K Boston', '2K Australia']                    ['2K']            NaN
# 234             ['Telltale Games']        ['Telltale Games']            NaN
# 235             ['Telltale Games']        ['Telltale Games']            NaN
#
#           packages                                     package_groups  \
# 63         [56669]  [{'name': 'default', 'title': 'Buy The Ship: S...
# 75             NaN                                                 []
# 220  [451, 127633]  [{'name': 'default', 'title': 'Buy BioShock™',...
# 234     [357, 539]  [{'name': 'default', 'title': 'Buy Sam & Max 1...
# 235     [358, 539]  [{'name': 'default', 'title': 'Buy Sam & Max 1...
#
#        platforms                                         categories  \
# 63       windows        [{'id': 2, 'description': 'Single-player'}]
# 75   windows;mac        [{'id': 2, 'description': 'Single-player'}]
# 220      windows  [{'id': 2, 'description': 'Single-player'}, {'...
# 234      windows        [{'id': 2, 'description': 'Single-player'}]
# 235      windows        [{'id': 2, 'description': 'Single-player'}]
#
#                                                 genres  \
# 63   [{'id': '1', 'description': 'Action'}, {'id': ...
# 75   [{'id': '28', 'description': 'Simulation'}, {'...
# 220  [{'id': '1', 'description': 'Action'}, {'id': ...
# 234  [{'id': '1', 'description': 'Action'}, {'id': ...
# 235  [{'id': '1', 'description': 'Action'}, {'id': ...
#
#                                            screenshots  \
# 63   [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 75   [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 220  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 234  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 235  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
#
#                                                 movies  achievements  \
# 63   [{'id': 2035597, 'name': 'the Ship:  Intro', '...  {'total': 0}
# 75                                                 NaN  {'total': 0}
# 220                                                NaN  {'total': 0}
# 234                                                NaN  {'total': 0}
# 235                                                NaN  {'total': 0}
#
#                                        release_date  \
# 63   {'coming_soon': False, 'date': '20 Nov, 2006'}
# 75   {'coming_soon': False, 'date': '12 Mar, 2008'}
# 220  {'coming_soon': False, 'date': '21 Aug, 2007'}
# 234  {'coming_soon': False, 'date': '15 Jun, 2007'}
# 235  {'coming_soon': False, 'date': '15 Jun, 2007'}
#
#                                           support_info  \
# 63                            {'url': '', 'email': ''}
# 75   {'url': 'http://www.atari.com/support/atari', ...
# 220             {'url': 'support.2k.com', 'email': ''}
# 234                           {'url': '', 'email': ''}
# 235                           {'url': '', 'email': ''}
#
#                                             background  \
# 63   https://steamcdn-a.akamaihd.net/steam/apps/242...
# 75   https://steamcdn-a.akamaihd.net/steam/apps/270...
# 220  https://steamcdn-a.akamaihd.net/steam/apps/767...
# 234  https://steamcdn-a.akamaihd.net/steam/apps/820...
# 235  https://steamcdn-a.akamaihd.net/steam/apps/821...
#
#             content_descriptors
# 63   {'ids': [], 'notes': None}
# 75   {'ids': [], 'notes': None}
# 220  {'ids': [], 'notes': None}
# 234  {'ids': [], 'notes': None}
# 235  {'ids': [], 'notes': None}

# %% [markdown]
# The first few rows contain some big, well-known games which appear to have pretty complete data. It looks like we can rule out data errors, so let's dig a little deeper and see if we can find out what is going on.
#
# We'll start by looking at the store pages for some of these titles. The url to an app on the steam website follows this structure:
#
#     https://store.steampowered.com/app/[steam_appid]
#
# This means we can easily generate these links using our above filter. We'll wrap it up in a function in case we want to use it later.

# %%
def print_steam_links(df):
    """Print links to store page for apps in a dataframe."""
    url_base = "https://store.steampowered.com/app/"
    
    for i, row in df.iterrows():
        appid = row['steam_appid']
        name = row['name']
        
        print(name + ':', url_base + str(appid))
        

print_steam_links(not_free_and_null_price[:5])
# Out:
# The Ship: Single Player: https://store.steampowered.com/app/2420
# RollerCoaster Tycoon® 3: Platinum: https://store.steampowered.com/app/2700
# BioShock™: https://store.steampowered.com/app/7670
# Sam & Max 101: Culture Shock: https://store.steampowered.com/app/8200
# Sam & Max 102: Situation: Comedy: https://store.steampowered.com/app/8210

# %% [markdown]
# For these games we can conclude that:
#
# - The Ship: Single Player is a tutorial, and comes as part of The Ship: Murder Party
# - RollerCoaster Tycoon 3: Platinum has been removed from steam (and another game website: [GOG](https://www.gog.com/))
#   - "A spokesperson for GOG told Eurogamer it pulled the game "due to expiring licensing rights", and stressed it'll talk with "new distribution rights holders" to bring the game back as soon as possible." Source: [Eurogamer](https://www.eurogamer.net/articles/2018-05-09-rollercoaster-tycoon-3-pulled-from-steam-gog)
# - BioShock has been replaced by BioShock Remastered
# - Sam & Max 101 is sold as part of a season, and this can be found in the `package_groups` column
#
# So we have a couple of options here. We could just drop these rows, we could try to figure out the price based on the `package_groups` column, or we could leave them for now and return to them later. We'll leave them for now, handling the two prices columns, then take a look at the packages next. It may also be that some of these rows are removed later in the cleaning process for other reasons.
#
# If we want to find rows similar to these and deal with each case individually, we could use the `.str.contains()` method, as seen below.

# %%
steam_data[steam_data['name'].str.contains("BioShock™")]
# Out:
#                         name  steam_appid required_age is_free  \
# 220                BioShock™         7670            0   False
# 7734    BioShock™ Remastered       409710           18   False
# 7735  BioShock™ 2 Remastered       409720           18   False
#
#                                    detailed_description  \
# 220   <h1>Special Offer</h1><p>Buying BioShock™ also...
# 7734  <h1>Special Offer</h1><p>Buying BioShock™ Rema...
# 7735  <h1>Special Offer</h1><p>Buying BioShock 2™ Re...
#
#                                          about_the_game  \
# 220   BioShock is a shooter unlike any you've ever p...
# 7734  BioShock is a shooter unlike any you've ever p...
# 7735  BioShock 2 provides players with the perfect b...
#
#                                       short_description  \
# 220   BioShock is a shooter unlike any you've ever p...
# 7734  BioShock is a shooter unlike any other, loaded...
# 7735  In BioShock 2, you step into the boots of the ...
#
#                                     supported_languages  \
# 220   English<strong>*</strong>, French<strong>*</st...
# 7734  English<strong>*</strong>, French<strong>*</st...
# 7735  English<strong>*</strong>, French<strong>*</st...
#
#                                            header_image  \
# 220   https://steamcdn-a.akamaihd.net/steam/apps/767...
# 7734  https://steamcdn-a.akamaihd.net/steam/apps/409...
# 7735  https://steamcdn-a.akamaihd.net/steam/apps/409...
#
#                            website  \
# 220    http://www.BioShockGame.com
# 7734   http://www.BioShockGame.com
# 7735  http://www.bioshockgame.com/
#
#                                         pc_requirements  \
# 220   {'minimum': '<h2 class="bb_tag"><strong>Minimu...
# 7734  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 7735  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                        mac_requirements  \
# 220       {'minimum': 'Please See BioShock Remastered'}
# 7734  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 7735  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                      linux_requirements  \
# 220                                                  []
# 7734  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 7735  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                              developers  \
# 220                       ['2K Boston', '2K Australia']
# 7734  ['2K Boston', '2K Australia', 'Blind Squirrel'...
# 7735  ['2K Marin', '2K China', 'Digital Extremes', '...
#
#                              publishers  \
# 220                              ['2K']
# 7734  ['2K', 'Feral Interactive (Mac)']
# 7735                             ['2K']
#
#                                          price_overview         packages  \
# 220                                                 NaN    [451, 127633]
# 7734  {'currency': 'GBP', 'initial': 999, 'final': 9...    [451, 127633]
# 7735  {'currency': 'GBP', 'initial': 1399, 'final': ...  [81419, 127633]
#
#                                          package_groups    platforms  \
# 220   [{'name': 'default', 'title': 'Buy BioShock™',...      windows
# 7734  [{'name': 'default', 'title': 'Buy BioShock™ R...  windows;mac
# 7735  [{'name': 'default', 'title': 'Buy BioShock™ 2...      windows
#
#                                              categories  \
# 220   [{'id': 2, 'description': 'Single-player'}, {'...
# 7734  [{'id': 2, 'description': 'Single-player'}, {'...
# 7735  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                                  genres  \
# 220   [{'id': '1', 'description': 'Action'}, {'id': ...
# 7734  [{'id': '1', 'description': 'Action'}, {'id': ...
# 7735  [{'id': '1', 'description': 'Action'}, {'id': ...
#
#                                             screenshots movies  \
# 220   [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN
# 7734  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN
# 7735  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN
#
#                                            achievements  \
# 220                                        {'total': 0}
# 7734  {'total': 65, 'highlighted': [{'name': 'Comple...
# 7735  {'total': 53, 'highlighted': [{'name': "Daddy'...
#
#                                         release_date  \
# 220   {'coming_soon': False, 'date': '21 Aug, 2007'}
# 7734  {'coming_soon': False, 'date': '15 Sep, 2016'}
# 7735  {'coming_soon': False, 'date': '15 Sep, 2016'}
#
#                                 support_info  \
# 220   {'url': 'support.2k.com', 'email': ''}
# 7734  {'url': 'support.2k.com', 'email': ''}
# 7735  {'url': 'support.2k.com', 'email': ''}
#
#                                              background  \
# 220   https://steamcdn-a.akamaihd.net/steam/apps/767...
# 7734  https://steamcdn-a.akamaihd.net/steam/apps/409...
# 7735  https://steamcdn-a.akamaihd.net/steam/apps/409...
#
#               content_descriptors
# 220    {'ids': [], 'notes': None}
# 7734   {'ids': [], 'notes': None}
# 7735  {'ids': [5], 'notes': None}

# %% [markdown]
# Now we need to figure out how to process the column.
#
# If we take a look at the data for the first row, we can see that there are a variety of formats in which the price is stored. There is a currency, GBP, which is perfect as we are performing our analysis in the UK. Next we have a number of different values for the price, so which one do we use?

# %%
steam_data['price_overview'][0]
# Out:
# "{'currency': 'GBP', 'initial': 719, 'final': 719, 'discount_percent': 0, 'initial_formatted': '', 'final_formatted': '£7.19'}"

# %% [markdown]
# If we inspect another row, we see that there is an active discount, applying an 80% price reduction to the title. It looks like `initial` contains the normal price before discount, and `final` contains the discounted price. `initial_formatted` and `final_formatted` contain the price formatted and displayed in the currency. We don't have to worry about these last two, as we'll be storing the price as a float (or integer) and if we wanted, we could format it like this when printing.
#
# With all this in mind, it looks like we'll be checking the value under the `currency` key, and using the value in the `initial` key.

# %%
steam_data['price_overview'][37]
# Out:
# "{'currency': 'GBP', 'initial': 2299, 'final': 459, 'discount_percent': 80, 'initial_formatted': '£22.99', 'final_formatted': '£4.59'}"

# %% [markdown]
# Now the preliminary investigation is complete we can begin definining our function.
#
# We start by evaluating the strings using `literal_eval` as before, however if there is a null value (caught by the try/except block) we return a properly formatted dictionary with -1 for the `initial` value. This will allow us to fill in a value of 0 for free games, then be left with an easily targetable value for the null rows.

# %%
def process_price(df):
    df = df.copy()
        
    def parse_price(x):
        try:
            return literal_eval(x)
        except ValueError:
            return {'currency': 'GBP', 'initial': -1}
    
    # evaluate as dictionary and set to -1 if missing
    df['price_overview'] = df['price_overview'].apply(parse_price)
    
    # Create columns from currency and initial values
    df['currency'] = df['price_overview'].apply(lambda x: x['currency'])
    df['price'] = df['price_overview'].apply(lambda x: x['initial'])
    
    # Set price of free games to 0
    df.loc[df['is_free'], 'price'] = 0
    
    return df

price_data = process_price(steam_data)[['name', 'currency', 'price']]
price_data.head()
# Out:
#                         name currency  price
# 0             Counter-Strike      GBP    719
# 1      Team Fortress Classic      GBP    399
# 2              Day of Defeat      GBP    399
# 3         Deathmatch Classic      GBP    399
# 4  Half-Life: Opposing Force      GBP    399

# %% [markdown]
# We're almost finished, but let's check if any games don't have GBP listed as the currency.

# %%
price_data[price_data['currency'] != 'GBP']
# Out:
#                                       name currency  price
# 991     Robin Hood: The Legend of Sherwood      USD    799
# 5767   Assassin’s Creed® Chronicles: India      EUR    999
# 27593                     Mortal Kombat 11      USD   5999
# 27995                         Pagan Online      EUR   2699

# %% [markdown]
# For some reason there are four games listed in either USD or EUR. We could use the current exchange rate to try and convert them into GBP, however as there are only four rows it's easier and safer to simply drop them.
#
# We can also divide the prices by 100 so they are displayed as floats in pounds.

# %%
def process_price(df):
    """Process price_overview column into formatted price column."""
    df = df.copy()
    
    def parse_price(x):
        try:
            return literal_eval(x)
        except ValueError:
            return {'currency': 'GBP', 'initial': -1}
    
    # evaluate as dictionary and set to -1 if missing
    df['price_overview'] = df['price_overview'].apply(parse_price)
    
    # create columns from currency and initial values
    df['currency'] = df['price_overview'].apply(lambda x: x['currency'])
    df['price'] = df['price_overview'].apply(lambda x: x['initial'])
    
    # set price of free games to 0
    df.loc[df['is_free'], 'price'] = 0
    
    # remove non-GBP rows
    df = df[df['currency'] == 'GBP']
    
    # change price to display in pounds (only applying to rows with a value greater than 0)
    df.loc[df['price'] > 0, 'price'] /= 100
    
    # remove columns no longer needed
    df = df.drop(['is_free', 'currency', 'price_overview'], axis=1)
    
    return df


def process(df):
    """Process data set. Will eventually contain calls to all functions we write."""
    
    # Copy the input dataframe to avoid accidentally modifying original data
    df = df.copy()
    
    # Remove duplicate rows - all appids should be unique
    df = df.drop_duplicates()
    
    # Remove collumns with more than 50% null values
    df = drop_null_cols(df)
    
    # Process rest of columns
    df = process_name_type(df)
    df = process_age(df)
    df = process_platforms(df)
    df = process_price(df)
    
    return df


steam_data = process(raw_steam_data)
steam_data[['name', 'price']].head()
# Out:
#                         name  price
# 0             Counter-Strike   7.19
# 1      Team Fortress Classic   3.99
# 2              Day of Defeat   3.99
# 3         Deathmatch Classic   3.99
# 4  Half-Life: Opposing Force   3.99

# %% [markdown]
# ## Processing Packages
#
# We can now take a look at the `packages` and `package_groups` columns to help decide what to do with rows that are missing price data. We're not incredibly interested in the columns themselves, as they don't appear to provide much new useful information, except which games come with others as part of a bundle.

# %%
# temporarily set a pandas option using with and option_context
with pd.option_context("display.max_colwidth", 500):
    display(steam_data[['steam_appid', 'packages', 'package_groups', 'price']].head())
# Out:
#    steam_appid packages  \
# 0           10      [7]
# 1           20     [29]
# 2           30     [30]
# 3           40     [31]
# 4           50     [32]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                  package_groups  \
# 0  [{'name': 'default', 'title': 'Buy Counter-Strike', 'description': '', 'selection_text': 'Select a purchase option', 'save_text': '', 'display_type': 0, 'is_recurring_subscription': 'false', 'subs': [{'packageid': 7, 'percent_savings_text': '', 'percent_savings': 0, 'option_text': 'Counter-Strike: Condition Zero - £7.19', 'option_description': '', 'can_get_free_license': '0', 'is_free_license': False, 'price_in_cents_with_discount': 719}]}]
# 1   [{'name': 'default', 'title': 'Buy Team Fortress Classic', 'description': '', 'selection_text': 'Select a purchase option', 'save_text': '', 'display_type': 0, 'is_recurring_subscription': 'false', 'subs': [{'packageid': 29, 'percent_savings_text': '', 'percent_savings': 0, 'option_text': 'Team Fortress Classic - £3.99', 'option_description': '', 'can_get_free_license': '0', 'is_free_license': False, 'price_in_cents_with_discount': 399}]}]
# 2                   [{'name': 'default', 'title': 'Buy Day of Defeat', 'description': '', 'selection_text': 'Select a purchase option', 'save_text': '', 'display_type': 0, 'is_recurring_subscription': 'false', 'subs': [{'packageid': 30, 'percent_savings_text': '', 'percent_savings': 0, 'option_text': 'Day of Defeat - £3.99', 'option_description': '', 'can_get_free_license': '0', 'is_free_license': False, 'price_in_cents_with_discount': 399}]}]
# 3         [{'name': 'default', 'title': 'Buy Deathmatch Classic', 'description': '', 'selection_text': 'Select a purchase option', 'save_text': '', 'display_type': 0, 'is_recurring_subscription': 'false', 'subs': [{'packageid': 31, 'percent_savings_text': '', 'percent_savings': 0, 'option_text': 'Deathmatch Classic - £3.99', 'option_description': '', 'can_get_free_license': '0', 'is_free_license': False, 'price_in_cents_with_discount': 399}]}]
# 4      [{'name': 'default', 'title': 'Buy Half-Life: Opposing Force', 'description': '', 'selection_text': 'Select a purchase option', 'save_text': '', 'display_type': 0, 'is_recurring_subscription': 'false', 'subs': [{'packageid': 32, 'percent_savings_text': '', 'percent_savings': 0, 'option_text': 'Opposing Force - £3.99', 'option_description': '', 'can_get_free_license': '0', 'is_free_license': False, 'price_in_cents_with_discount': 399}]}]
#
#    price
# 0   7.19
# 1   3.99
# 2   3.99
# 3   3.99
# 4   3.99

# %% [markdown]
# Overall we have 846 rows with missing price data, which we previously set to -1.

# %%
print(steam_data[steam_data['price'] == -1].shape[0])
# Out:
# 846

# %% [markdown]
# We can split these rows into two categories: those with `package_groups` data and those without.
#
# If we take a quick look at the `package_groups` column we see that there appear to be no null values. On closer inspection, we can find that rows without data are actually stored as empty lists.

# %%
print('Null counts:', steam_data['package_groups'].isnull().sum())
print('Empty list counts:', steam_data[steam_data['package_groups'] == "[]"].shape[0])
# Out:
# Null counts: 0
# Empty list counts: 3353

# %% [markdown]
# Using a combination of filters, we can find out how many rows have both missing `price` and `package_group` data and investigate. We'll count the rows and print links to some of the store pages and look for patterns.

# %%
missing_price_and_package = steam_data[(steam_data['price'] == -1) & (steam_data['package_groups'] == "[]")]

print('Number of rows:', missing_price_and_package.shape[0], '\n')

print('First few rows:\n')
print_steam_links(missing_price_and_package[:5])

print('\nLast few rows:\n')
print_steam_links(missing_price_and_package[-10:-5])

missing_price_and_package.head()
# Out:
# Number of rows: 799
#
# First few rows:
#
# RollerCoaster Tycoon® 3: Platinum: https://store.steampowered.com/app/2700
# Beijing 2008™ - The Official Video Game of the Olympic Games: https://store.steampowered.com/app/10520
# LUMINES™ Advance Pack: https://store.steampowered.com/app/11920
# Midnight Club 2: https://store.steampowered.com/app/12160
# Age of Booty™: https://store.steampowered.com/app/21600
#
# Last few rows:
#
# RoboVirus: https://store.steampowered.com/app/1001870
# soko loco deluxe: https://store.steampowered.com/app/1003730
# POCKET CAR : VRGROUND: https://store.steampowered.com/app/1004710
# The Princess, the Stray Cat, and Matters of the Heart: https://store.steampowered.com/app/1010600
# Mr Boom's Firework Factory: https://store.steampowered.com/app/1013670
#                                                   name  steam_appid  \
# 75                   RollerCoaster Tycoon® 3: Platinum         2700
# 311  Beijing 2008™ - The Official Video Game of the...        10520
# 337                              LUMINES™ Advance Pack        11920
# 344                                    Midnight Club 2        12160
# 536                                      Age of Booty™        21600
#
#     required_age                               detailed_description  \
# 75             0  Rollercoaster Tycoon 3 Platinum combines the e...
# 311            0  <p>                        Embrace the competi...
# 337            0  <p>Ready for the next challenge? Prepare yours...
# 344            0  Members of the world's most notorious illegal ...
# 536            0  Set in the swashbuckling era, Age of Booty™ is...
#
#                                         about_the_game  \
# 75   Rollercoaster Tycoon 3 Platinum combines the e...
# 311  <p>                        Embrace the competi...
# 337  <p>Ready for the next challenge? Prepare yours...
# 344  Members of the world's most notorious illegal ...
# 536  Set in the swashbuckling era, Age of Booty™ is...
#
#                                      short_description  \
# 75   Rollercoaster Tycoon 3 Platinum combines the e...
# 311  Embrace the competitive spirit of the world's ...
# 337  Ready for the next challenge? Prepare yourself...
# 344  The world's most notorious drivers meet each n...
# 536  Set in the swashbuckling era, Age of Booty™ is...
#
#                                    supported_languages  \
# 75   English, French, Italian, German, Spanish - Sp...
# 311                                            English
# 337  English, French, German, Italian, Spanish - Spain
# 344  English<strong>*</strong>, French, Italian, Ge...
# 536  English<strong>*</strong><br><strong>*</strong...
#
#                                           header_image  \
# 75   https://steamcdn-a.akamaihd.net/steam/apps/270...
# 311  https://steamcdn-a.akamaihd.net/steam/apps/105...
# 337  https://steamcdn-a.akamaihd.net/steam/apps/119...
# 344  https://steamcdn-a.akamaihd.net/steam/apps/121...
# 536  https://steamcdn-a.akamaihd.net/steam/apps/216...
#
#                                                website  \
# 75   http://www.atari.com/rollercoastertycoon/us/in...
# 311                   http://www.olympicvideogames.com
# 337                                                NaN
# 344         http://www.rockstargames.com/midnightclub2
# 536         http://www.certainaffinity.com/ageofbooty/
#
#                                        pc_requirements  \
# 75   {'minimum': '<strong>Minimum: </strong><br>\t\...
# 311  {'minimum': '<p><strong>Minimum:</strong></p> ...
# 337  {'minimum': '<p><strong>Minimum:</strong></p>\...
# 344  {'minimum': '<strong>Minimum:</strong><br>\t\t...
# 536  {'minimum': '<strong>Minimum:</strong>        ...
#
#                                       mac_requirements linux_requirements  \
# 75   {'minimum': '<ul class="bb_ul"><li><strong>OS:...                 []
# 311                                                 []                 []
# 337                                                 []                 []
# 344                                                 []                 []
# 536                                                 []                 []
#
#                       developers                publishers packages  \
# 75   ['Frontier', 'Aspyr (Mac)']  ['Atari', 'Aspyr (Mac)']      NaN
# 311                  ['Eurocom']                  ['SEGA']      NaN
# 337     ['Q Entertainment Inc.']  ['Q Entertainment Inc.']      NaN
# 344       ['Rockstar San Diego']        ['Rockstar Games']      NaN
# 536        ['Certain Affinity™']                ['Capcom']      NaN
#
#     package_groups    platforms  \
# 75              []  windows;mac
# 311             []      windows
# 337             []      windows
# 344             []      windows
# 536             []      windows
#
#                                             categories  \
# 75         [{'id': 2, 'description': 'Single-player'}]
# 311  [{'id': 2, 'description': 'Single-player'}, {'...
# 337        [{'id': 2, 'description': 'Single-player'}]
# 344  [{'id': 2, 'description': 'Single-player'}, {'...
# 536        [{'id': 2, 'description': 'Single-player'}]
#
#                                                 genres  \
# 75   [{'id': '28', 'description': 'Simulation'}, {'...
# 311            [{'id': '18', 'description': 'Sports'}]
# 337             [{'id': '4', 'description': 'Casual'}]
# 344             [{'id': '9', 'description': 'Racing'}]
# 536  [{'id': '4', 'description': 'Casual'}, {'id': ...
#
#                                            screenshots movies  achievements  \
# 75   [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 311  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 337  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 344  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 536  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
#
#                                        release_date  \
# 75   {'coming_soon': False, 'date': '12 Mar, 2008'}
# 311  {'coming_soon': False, 'date': '14 Aug, 2008'}
# 337  {'coming_soon': False, 'date': '18 Apr, 2008'}
# 344   {'coming_soon': False, 'date': '4 Jan, 2008'}
# 536   {'coming_soon': False, 'date': '9 Mar, 2009'}
#
#                                           support_info  \
# 75   {'url': 'http://www.atari.com/support/atari', ...
# 311                           {'url': '', 'email': ''}
# 337                           {'url': '', 'email': ''}
# 344                           {'url': '', 'email': ''}
# 536  {'url': 'http://www.capcom.co.jp/support/conta...
#
#                                             background  \
# 75   https://steamcdn-a.akamaihd.net/steam/apps/270...
# 311  https://steamcdn-a.akamaihd.net/steam/apps/105...
# 337  https://steamcdn-a.akamaihd.net/steam/apps/119...
# 344  https://steamcdn-a.akamaihd.net/steam/apps/121...
# 536  https://steamcdn-a.akamaihd.net/steam/apps/216...
#
#             content_descriptors  price
# 75   {'ids': [], 'notes': None}   -1.0
# 311  {'ids': [], 'notes': None}   -1.0
# 337  {'ids': [], 'notes': None}   -1.0
# 344  {'ids': [], 'notes': None}   -1.0
# 536  {'ids': [], 'notes': None}   -1.0

# %% [markdown]
# Most of the games - 799 of 846 - with missing price data fall into the above category. This probably means they can be safely removed.
#
# From following the links for the first few rows to the store page, it looks like they are currently unavailable or have been delisted from the store. Looking at the last few rows, it appears most of them haven't yet been released and haven't had a price set. We'll take care of all the unreleased games when we clean the `release_date` column, but we can remove all of these apps here.
#
# Let's now take a look at the rows that have missing price data but do have `package_groups` data. We may be interested in keeping these rows and extracting price data from the package data.

# %%
missing_price_have_package = steam_data.loc[(steam_data['price'] == -1) & (steam_data['package_groups'] != "[]"), ['name', 'steam_appid', 'package_groups', 'price']]

print('Number of rows:', missing_price_have_package.shape[0], '\n')

print('First few rows:\n')
print_steam_links(missing_price_have_package[:5])

print('\nLast few rows:\n')
print_steam_links(missing_price_have_package[-10:-5])

display(missing_price_have_package.head())
missing_price_have_package.iloc[-10:-5]
# Out:
# Number of rows: 47
#
# First few rows:
#
# The Ship: Single Player: https://store.steampowered.com/app/2420
# BioShock™: https://store.steampowered.com/app/7670
# Sam & Max 101: Culture Shock: https://store.steampowered.com/app/8200
# Sam & Max 102: Situation: Comedy: https://store.steampowered.com/app/8210
# Sam & Max 103: The Mole, the Mob and the Meatball: https://store.steampowered.com/app/8220
#
# Last few rows:
#
# Viscera Cleanup Detail: Shadow Warrior: https://store.steampowered.com/app/255520
# Space Hulk: Deathwing: https://store.steampowered.com/app/298900
# 7,62 Hard Life: https://store.steampowered.com/app/306290
# Letter Quest: Grimm's Journey: https://store.steampowered.com/app/328730
# Rad Rodgers: World One: https://store.steampowered.com/app/353580
#                                                   name  steam_appid  \
# 63                             The Ship: Single Player         2420
# 220                                          BioShock™         7670
# 234                       Sam & Max 101: Culture Shock         8200
# 235                   Sam & Max 102: Situation: Comedy         8210
# 236  Sam & Max 103: The Mole, the Mob and the Meatball         8220
#
#                                         package_groups  price
# 63   [{'name': 'default', 'title': 'Buy The Ship: S...   -1.0
# 220  [{'name': 'default', 'title': 'Buy BioShock™',...   -1.0
# 234  [{'name': 'default', 'title': 'Buy Sam & Max 1...   -1.0
# 235  [{'name': 'default', 'title': 'Buy Sam & Max 1...   -1.0
# 236  [{'name': 'default', 'title': 'Buy Sam & Max 1...   -1.0
#                                         name  steam_appid  \
# 2421  Viscera Cleanup Detail: Shadow Warrior       255520
# 3576                   Space Hulk: Deathwing       298900
# 3811                          7,62 Hard Life       306290
# 4504           Letter Quest: Grimm's Journey       328730
# 5514                  Rad Rodgers: World One       353580
#
#                                          package_groups  price
# 2421  [{'name': 'default', 'title': 'Buy Viscera Cle...   -1.0
# 3576  [{'name': 'default', 'title': 'Buy Space Hulk:...   -1.0
# 3811  [{'name': 'default', 'title': 'Buy 7,62 Hard L...   -1.0
# 4504  [{'name': 'default', 'title': "Buy Letter Ques...   -1.0
# 5514  [{'name': 'default', 'title': 'Buy Rad Rodgers...   -1.0

# %% [markdown]
# Looking at a selection of these rows, the games appear to be: supersceded by a newer release or remaster, part of a bigger bundle of games or episodic, or included by purchasing another game.
#
# Whilst we could extract prices from the `package_groups` data, the most sensible option seems to be removing these rows. There are only 47 rows this applies to, and any with a newer release will still have the re-release in the data.
#
# Since our logic interacts heavily with the price data we will update the `process_price` function rather than creating a new one.

# %%
def process_price(df):
    """Process price_overview column into formatted price column, and take care of package columns."""
    df = df.copy()
    
    def parse_price(x):
        try:
            return literal_eval(x)
        except ValueError:
            return {'currency': 'GBP', 'initial': -1}
    
    # evaluate as dictionary and set to -1 if missing
    df['price_overview'] = df['price_overview'].apply(parse_price)
    
    # create columns from currency and initial values
    df['currency'] = df['price_overview'].apply(lambda x: x['currency'])
    df['price'] = df['price_overview'].apply(lambda x: x['initial'])
    
    # set price of free games to 0
    df.loc[df['is_free'], 'price'] = 0
    
    # remove non-GBP rows
    df = df[df['currency'] == 'GBP']
    
    # remove rows where price is -1
    df = df[df['price'] != -1]
    
    # change price to display in pounds (can apply to all now -1 rows removed)
    df['price'] /= 100
    
    # remove columns no longer needed
    df = df.drop(['is_free', 'currency', 'price_overview', 'packages', 'package_groups'], axis=1)
    
    return df


def process(df):
    """Process data set. Will eventually contain calls to all functions we write."""
    
    # Copy the input dataframe to avoid accidentally modifying original data
    df = df.copy()
    
    # Remove duplicate rows - all appids should be unique
    df = df.drop_duplicates()
    
    # Remove collumns with more than 50% null values
    df = drop_null_cols(df)
    
    # Process rest of columns
    df = process_name_type(df)
    df = process_age(df)
    df = process_platforms(df)
    df = process_price(df)
    
    return df

steam_data = process(raw_steam_data)
steam_data.head()
# Out:
#                         name  steam_appid required_age  \
# 0             Counter-Strike           10            0
# 1      Team Fortress Classic           20            0
# 2              Day of Defeat           30            0
# 3         Deathmatch Classic           40            0
# 4  Half-Life: Opposing Force           50            0
#
#                                 detailed_description  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                       about_the_game  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                    short_description  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                  supported_languages  \
# 0  English<strong>*</strong>, French<strong>*</st...
# 1  English, French, German, Italian, Spanish - Sp...
# 2  English, French, German, Italian, Spanish - Spain
# 3  English, French, German, Italian, Spanish - Sp...
# 4                    English, French, German, Korean
#
#                                         header_image  \
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...
#
#                        website  \
# 0                          NaN
# 1                          NaN
# 2  http://www.dayofdefeat.com/
# 3                          NaN
# 4                          NaN
#
#                                      pc_requirements  \
# 0  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 1  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 2  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 3  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 4  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
#
#                                     mac_requirements  \
# 0  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 1  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 2  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 3  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 4  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
#
#                                   linux_requirements            developers  \
# 0  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 1  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 2  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 3  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 4  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...  ['Gearbox Software']
#
#   publishers          platforms  \
# 0  ['Valve']  windows;mac;linux
# 1  ['Valve']  windows;mac;linux
# 2  ['Valve']  windows;mac;linux
# 3  ['Valve']  windows;mac;linux
# 4  ['Valve']  windows;mac;linux
#
#                                           categories  \
# 0  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 1  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 2  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 3  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 4  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                    genres  \
# 0  [{'id': '1', 'description': 'Action'}]
# 1  [{'id': '1', 'description': 'Action'}]
# 2  [{'id': '1', 'description': 'Action'}]
# 3  [{'id': '1', 'description': 'Action'}]
# 4  [{'id': '1', 'description': 'Action'}]
#
#                                          screenshots movies  achievements  \
# 0  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 1  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 2  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 3  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 4  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
#
#                                     release_date  \
# 0  {'coming_soon': False, 'date': '1 Nov, 2000'}
# 1  {'coming_soon': False, 'date': '1 Apr, 1999'}
# 2  {'coming_soon': False, 'date': '1 May, 2003'}
# 3  {'coming_soon': False, 'date': '1 Jun, 2001'}
# 4  {'coming_soon': False, 'date': '1 Nov, 1999'}
#
#                                         support_info  \
# 0  {'url': 'http://steamcommunity.com/app/10', 'e...
# 1                           {'url': '', 'email': ''}
# 2                           {'url': '', 'email': ''}
# 3                           {'url': '', 'email': ''}
# 4  {'url': 'https://help.steampowered.com', 'emai...
#
#                                           background  \
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...
#
#                                  content_descriptors  price
# 0  {'ids': [2, 5], 'notes': 'Includes intense vio...   7.19
# 1  {'ids': [2, 5], 'notes': 'Includes intense vio...   3.99
# 2                         {'ids': [], 'notes': None}   3.99
# 3                         {'ids': [], 'notes': None}   3.99
# 4                         {'ids': [], 'notes': None}   3.99

# %% [markdown]
# The next columns in the data are descriptive columns - `detailed_description`, `about_the_game` and `short_description`. We won't be handling them now, instead returning to them in a later post dealing with export columns. These are columns where we will export all or some of the data to a separate csv file as part of the cleaning.
#
# ## Processing Langauges
#
# Beyond that, the next column is `supported_languages`. As we will be performing the analysis for an English company, we will only be interested in games available in English. Whilst we could remove non-english game at this stage, instead we will create a column marking english games with a boolean value - True or False.
#
# We begin as usual by looking for rows with null values.

# %%
steam_data['supported_languages'].isnull().sum()
# Out:
# 4

# %% [markdown]
# Taking a closer look at these apps, it doesn't look like there's anything wrong with them. It may be that the data simply wasn't supplied. As there are only 4 rows affected we will go ahead and remove these from the data set.

# %%
steam_data[steam_data['supported_languages'].isnull()]
# Out:
#                   name  steam_appid required_age  \
# 4866          Subsiege       338640            0
# 14560  MARS VR(全球使命VR)       596560            0
# 16386     Numberline 2       654970            0
# 26855        SNUSE 221       948070            0
#
#                                     detailed_description  \
# 4866   <img src="https://steamcdn-a.akamaihd.net/stea...
# 14560  1.\t4K level audio-visual experience <br />\r\...
# 16386  NumberLine 2 is the continuation of the popula...
# 26855  <strong> Hey. My name is *&amp;#!$.<br>Today I...
#
#                                           about_the_game  \
# 4866   <img src="https://steamcdn-a.akamaihd.net/stea...
# 14560  1.\t4K level audio-visual experience <br />\r\...
# 16386  NumberLine 2 is the continuation of the popula...
# 26855  <strong> Hey. My name is *&amp;#!$.<br>Today I...
#
#                                        short_description supported_languages  \
# 4866   Subsiege is an intense real-time tactic game w...                 NaN
# 14560  Welcome to 《Mars VR》. This is an immersive fir...                 NaN
# 16386  NumberLine 2 is the continuation of the popula...                 NaN
# 26855  Hey. My name is *&amp;#!$. Today I will tell y...                 NaN
#
#                                             header_image  \
# 4866   https://steamcdn-a.akamaihd.net/steam/apps/338...
# 14560  https://steamcdn-a.akamaihd.net/steam/apps/596...
# 16386  https://steamcdn-a.akamaihd.net/steam/apps/654...
# 26855  https://steamcdn-a.akamaihd.net/steam/apps/948...
#
#                          website  \
# 4866   http://subsiege-game.com/
# 14560   http://qqsm.zygames.com/
# 16386                        NaN
# 26855                        NaN
#
#                                          pc_requirements  \
# 4866   {'minimum': '<strong>Minimum:</strong><br><ul ...
# 14560  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 16386  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 26855  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                         mac_requirements  \
# 4866                                                  []
# 14560  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 16386                                                 []
# 26855                                                 []
#
#                                       linux_requirements  \
# 4866                                                  []
# 14560  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 16386                                                 []
# 26855                                                 []
#
#                                               developers  \
# 4866                                 ['Icebird Studios']
# 14560  ['Ying Pei Digital Technology Shanghai Co., Li...
# 16386                         ['V34D4R', 'Egor Magurin']
# 26855                                       ['SNUSE GM']
#
#                                     publishers platforms  \
# 4866                       ['Icebird Studios']   windows
# 14560  ['SHANGHAI ZHENYOU TECHNOLOGY CO.,LTD']   windows
# 16386                      ['Indovers Studio']   windows
# 26855                             ['SNUSE GM']   windows
#
#                                         categories  \
# 4866                                           NaN
# 14560  [{'id': 2, 'description': 'Single-player'}]
# 16386  [{'id': 2, 'description': 'Single-player'}]
# 26855  [{'id': 2, 'description': 'Single-player'}]
#
#                                                   genres  \
# 4866                                                 NaN
# 14560  [{'id': '73', 'description': 'Violent'}, {'id'...
# 16386  [{'id': '4', 'description': 'Casual'}, {'id': ...
# 26855  [{'id': '25', 'description': 'Adventure'}, {'i...
#
#                                              screenshots  \
# 4866   [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 14560  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 16386  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 26855  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
#
#                                                   movies  \
# 4866   [{'id': 256729398, 'name': 'Release Trailer', ...
# 14560  [{'id': 256681371, 'name': 'marsvr', 'thumbnai...
# 16386  [{'id': 256687192, 'name': 'Numberline 2 Trail...
# 26855  [{'id': 256745662, 'name': 'snuse', 'thumbnail...
#
#                                             achievements  \
# 4866                                        {'total': 0}
# 14560                                       {'total': 0}
# 16386  {'total': 60, 'highlighted': [{'name': '1st le...
# 26855                                       {'total': 0}
#
#                                          release_date  \
# 4866    {'coming_soon': False, 'date': '7 Sep, 2018'}
# 14560   {'coming_soon': False, 'date': '5 Apr, 2017'}
# 16386  {'coming_soon': False, 'date': '14 Jul, 2017'}
# 26855   {'coming_soon': False, 'date': '2 Apr, 2019'}
#
#                                             support_info  \
# 4866   {'url': 'http://subsiege-game.com/', 'email': ...
# 14560  {'url': 'http://www.zygames.com/contact', 'ema...
# 16386    {'url': '', 'email': 'radaew.zhenya@yandex.ru'}
# 26855             {'url': 'vk.com/nilow_i', 'email': ''}
#
#                                               background  \
# 4866   https://steamcdn-a.akamaihd.net/steam/apps/338...
# 14560  https://steamcdn-a.akamaihd.net/steam/apps/596...
# 16386  https://steamcdn-a.akamaihd.net/steam/apps/654...
# 26855  https://steamcdn-a.akamaihd.net/steam/apps/948...
#
#               content_descriptors  price
# 4866   {'ids': [], 'notes': None}  17.89
# 14560  {'ids': [], 'notes': None}   1.99
# 16386  {'ids': [], 'notes': None}   1.59
# 26855  {'ids': [], 'notes': None}   0.79

# %% [markdown]
# Next we'll take a look at the structure of the column. By looking at the value for the first row and the values for the most common rows, it looks like languages are stored as a string which can be anything from a comma-separated list of languages to a mix of html and headings. It seems reasonably safe to assume that if the app is in English, the word English will appear somewhere in this string. With this in mind we can simply search the string and return a value based on the result.

# %%
print(steam_data['supported_languages'][0])
steam_data['supported_languages'].value_counts().head(10)
# Out:
# English<strong>*</strong>, French<strong>*</strong>, German<strong>*</strong>, Italian<strong>*</strong>, Spanish - Spain<strong>*</strong>, Simplified Chinese<strong>*</strong>, Traditional Chinese<strong>*</strong>, Korean<strong>*</strong><br><strong>*</strong>languages with full audio support
# English                                                                                                        8512
# English<strong>*</strong><br><strong>*</strong>languages with full audio support                               7409
# English, Russian                                                                                                707
# English, Simplified Chinese                                                                                     280
# English, Japanese                                                                                               235
# English<strong>*</strong>, Russian<strong>*</strong><br><strong>*</strong>languages with full audio support     222
# English, French, Italian, German, Spanish - Spain                                                               180
# English, German                                                                                                 161
# Simplified Chinese                                                                                              157
# English, French                                                                                                 143
# Name: supported_languages, dtype: int64

# %% [markdown]
# It looks like English-only games make up a little over half the rows in our dataset (~16,000), and English plus other languages make up many more. We could create columns for any of the other languages by string searching, but for simplicity we'll focus on just the English ones.
#
# Using the Series.apply method once again, we can check if the string 'english' appears in each row. We define an anonymous function on the fly using a [lambda](https://docs.python.org/3/tutorial/controlflow.html?highlight=lambda#lambda-expressions) expression. This returns 1 if 'english' is found and 0 otherwise. As mentioned in the platforms section, this can be interpreted as a boolean value.
#
# The variable `x` will take on the value of each row as the expression is evaluated. We apply the `lower()` string method so capitalisation doesn't matter.

# %%
def process_language(df):
    """Process supported_languages column into a boolean 'is english' column."""
    df = df.copy()
    
    # drop rows with missing language data
    df = df.dropna(subset=['supported_languages'])
    
    df['english'] = df['supported_languages'].apply(lambda x: 1 if 'english' in x.lower() else 0)
    df = df.drop('supported_languages', axis=1)
    
    return df


def process(df):
    """Process data set. Will eventually contain calls to all functions we write."""
    
    # Copy the input dataframe to avoid accidentally modifying original data
    df = df.copy()
    
    # Remove duplicate rows - all appids should be unique
    df = df.drop_duplicates()
    
    # Remove collumns with more than 50% null values
    df = drop_null_cols(df)
    
    # Process rest of columns
    df = process_name_type(df)
    df = process_age(df)
    df = process_platforms(df)
    df = process_price(df)
    df = process_language(df)
    
    return df


steam_data = process(raw_steam_data)
steam_data[['name', 'english']].head()
# Out:
#                         name  english
# 0             Counter-Strike        1
# 1      Team Fortress Classic        1
# 2              Day of Defeat        1
# 3         Deathmatch Classic        1
# 4  Half-Life: Opposing Force        1

# %% [markdown]
# Before moving on, we can take a quick look at the results and see that most of the apps support English.

# %%
steam_data['english'].value_counts()
# Out:
# 1    27699
# 0      522
# Name: english, dtype: int64

# %% [markdown]
# ## Processing Developers and Publishers
#
# Again we'll skip the next few columns as we'll deal with them another time, and take a look at `developers` and `publishers`. They will most likely contain similar information so we can look at them together.
#
# We'll start by checking the null counts, noticing that while the publishers column doesn't appear to have any null values, if we search for empty lists we see that we have over 200 'hidden' null values.

# %%
print('Developers null counts:', steam_data['developers'].isnull().sum())
print('Developers empty list counts:', steam_data[steam_data['developers'] == "['']"].shape[0])

print('\npublishers null counts:', steam_data['publishers'].isnull().sum())
print('publishers empty list counts:', steam_data[steam_data['publishers'] == "['']"].shape[0])
# Out:
# Developers null counts: 104
# Developers empty list counts: 0
#
# publishers null counts: 0
# publishers empty list counts: 213

# %% [markdown]
# Ultimately we want a data set with no missing values. That means we have a few options for dealing with these two columns:
#
# - Remove all rows missing either developer or publisher information
# - Impute missing information by replacing the missing column with the column we have (i.e. if developers is missing, fill it with the value in publishers)
# - Fill missing information with 'Unknown' or 'None'
#
# We can investigate some of the rows with missing data to help inform our decision.

# %%
no_dev = steam_data[steam_data['developers'].isnull()]

print('Total games missing developer:', no_dev.shape[0], '\n')

print_steam_links(no_dev[:5])

no_pub = steam_data[steam_data['publishers'] == "['']"]

print('\nTotal games missing publisher:', no_pub.shape[0], '\n')
print_steam_links(no_pub[:5])

no_dev_or_pub = steam_data[(steam_data['developers'].isnull()) & (steam_data['publishers'] == "['']")]

print('\nTotal games missing developer and publisher:', no_dev_or_pub.shape[0], '\n')
print_steam_links(no_dev_or_pub[:5])
# Out:
# Total games missing developer: 104
#
# Tycoon City: New York: https://store.steampowered.com/app/9730
# Nikopol: Secrets of the Immortals: https://store.steampowered.com/app/11370
# Crash Time 2: https://store.steampowered.com/app/11390
# Hunting Unlimited 2010: https://store.steampowered.com/app/12690
# 18 Wheels of Steel: Extreme Trucker: https://store.steampowered.com/app/33730
#
# Total games missing publisher: 213
#
# RIP - Trilogy™: https://store.steampowered.com/app/2540
# Vigil: Blood Bitterness™: https://store.steampowered.com/app/2570
# Bullet Candy: https://store.steampowered.com/app/6600
# AudioSurf: https://store.steampowered.com/app/12900
# Everyday Shooter: https://store.steampowered.com/app/16300
#
# Total games missing developer and publisher: 67
#
# PlayClaw 5 - Game Recording and Streaming: https://store.steampowered.com/app/237370
# Artemis Spaceship Bridge Simulator: https://store.steampowered.com/app/247350
# A Walk in the Dark: https://store.steampowered.com/app/248730
# Forge Quest: https://store.steampowered.com/app/249950
# Vox: https://store.steampowered.com/app/252770

# %% [markdown]
# It appears we are looking at a mix of titles, smaller ones especially, and some of the smaller indie titles may have been self-published. Others simply have wrong or missing data, found by searching for the titles elsewhere. As our priority is creating a clean data set, and there are only a few hundred rows, it will be fine to remove them from the data.
#
# Let's take a look at the structure of the data. Below we inspect some rows near the beginning of the dataframe. It looks like both columns are stored as lists which can have one or multiple values. We'll have to evaluate the rows as before, so they are recognised as lists, then index into them accordingly.

# %%
steam_data[['developers', 'publishers']].iloc[24:28]
# Out:
#                                 developers                publishers
# 24                               ['Valve']                 ['Valve']
# 25  ['Valve', 'Hidden Path Entertainment']                 ['Valve']
# 27                         ['Mark Healey']           ['Mark Healey']
# 28                ['Tripwire Interactive']  ['Tripwire Interactive']

# %% [markdown]
# As we have some single values and some multiple, we have to decide how to handle them. Here are some potential solutions:
#
#  - Create a column for each value in the list (i.e. developer_1, developer_2)
#  - Create a column with the first value in the list and a column with the rest of the values (i.e. developer_1, other_developers)
#  - Create a column with the first value in the list and disregard the rest
#  - Combine all values into one column, simply unpacking the list
#
# Let's begin defining our function, and take a look at how many rows have multiple developers or publishers. After evaluating each row, we can find the length of the lists in each row by using the [Series.str.len()](http://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.len.html) method. By filtering only rows where the list has more than one element, we can find the number of rows with more than one value in each column.

# %%
def process_developers_and_publishers(df):
    # remove rows with missing data
    df = df[(df['developers'].notnull()) & (df['publishers'] != "['']")].copy()
    
    for col in ['developers', 'publishers']:
        df[col] = df[col].apply(lambda x: literal_eval(x))
        
        # filter dataframe to rows with lists longer than 1, and store the number of rows
        num_rows = df[df[col].str.len() > 1].shape[0]
        
        print('Rows in {} column with multiple values:'.format(col), num_rows)

process_developers_and_publishers(steam_data)
# Out:
# Rows in developers column with multiple values: 1720
# Rows in publishers column with multiple values: 884

# %% [markdown]
# It turns out that the vast majority have only one value for these columns. If we went with the first or second solutions above, we'd be left with columns with mostly missing data. We could go with the third option, but the first value in the list isn't necessarily the most important, and this seems unfair if multiple teams were involved.
#
# The best way forward seems to be the fourth option - if there are multiple values we combine them into the same column. We'll create a list in this case. We can achieve this by calling the [str.join()](https://docs.python.org/3/library/stdtypes.html#str.join) method on a string and passing the list of values into the function. If we pass a list with only one value, we get a string with just that value. If we pass a list with multiple values, we get a comma-separated list as desired. We can see this below.

# %%
', '.join(['one item'])
# Out:
# 'one item'

# %%
', '.join(['multiple', 'different', 'items'])
# Out:
# 'multiple, different, items'

# %% [markdown]
# We can't join on a comma as a number of developers and publishers have a comma in their name, a couple of which can be seen below.

# %%
steam_data.loc[steam_data['developers'].str.contains(",", na=False), ['steam_appid', 'developers', 'publishers']].head(4)
# Out:
#     steam_appid                              developers  \
# 25          730  ['Valve', 'Hidden Path Entertainment']
# 66         2520                     ['CINEMAX, s.r.o.']
# 73         2630        ['Infinity Ward', 'Aspyr (Mac)']
# 97         3300                  ['PopCap Games, Inc.']
#
#                        publishers
# 25                      ['Valve']
# 66            ['CINEMAX, s.r.o.']
# 73  ['Activision', 'Aspyr (Mac)']
# 97         ['PopCap Games, Inc.']

# %% [markdown]
# Instead we can join on a semi-colon (`;`). We have 3 rows which contains a semi-colon in the name, so we'll remove these. We'll be able to identify and split individual developer/publisher names in the future by handling it this way.

# %%
steam_data.loc[steam_data['developers'].str.contains(";", na=False), ['steam_appid', 'developers', 'publishers']]
# Out:
#        steam_appid                   developers             publishers
# 9550        460210              ['bool games;']        ['bool games;']
# 13489       568480  [';)', 'Quickdraw Studios']  ['Quickdraw Studios']
# 16871       665890               ['Semicolon;']         ['Semicolon;']

# %% [markdown]
# Now we're ready to finish the function we started. We'll abandon the for loop, as there is not too much repetition, and add it into the `process` function as always.

# %%
def process_developers_and_publishers(df):
    """Parse columns as semicolon-separated string."""
    # remove rows with missing data
    # df = df[(df['developers'].notnull()) & (df['publishers'] != "['']")].copy()
    df = df[df['developers'].notnull()].copy()
    
    # remove rows with semicolon in either column (~ means not)
    df = df[~(df['developers'].str.contains(';')) & ~(df['publishers'].str.contains(';'))]
    
    # create list for each
    df['developer'] = df['developers'].apply(lambda x: ';'.join(literal_eval(x)))
    df['publisher'] = df['publishers'].apply(lambda x: ';'.join(literal_eval(x)))
    
    df.loc[df['publisher'] == '', 'publisher'] = np.nan

    df = df.drop(['developers', 'publishers'], axis=1)
    
    return df


def process(df):
    """Process data set. Will eventually contain calls to all functions we write."""
    
    # Copy the input dataframe to avoid accidentally modifying original data
    df = df.copy()
    
    # Remove duplicate rows - all appids should be unique
    df = df.drop_duplicates()
    
    # Remove collumns with more than 50% null values
    df = drop_null_cols(df)
    
    # Process rest of columns
    df = process_name_type(df)
    df = process_age(df)
    df = process_platforms(df)
    df = process_price(df)
    df = process_language(df)
    df = process_developers_and_publishers(df)
    
    return df


steam_data = process(raw_steam_data)
steam_data[['name', 'steam_appid', 'developer', 'publisher']].head()
# Out:
#                         name  steam_appid         developer publisher
# 0             Counter-Strike           10             Valve     Valve
# 1      Team Fortress Classic           20             Valve     Valve
# 2              Day of Defeat           30             Valve     Valve
# 3         Deathmatch Classic           40             Valve     Valve
# 4  Half-Life: Opposing Force           50  Gearbox Software     Valve

# %%
steam_data[steam_data['publisher'].isnull()]
# Out:
#                                                     name  steam_appid  \
# 67                                        RIP - Trilogy™         2540
# 68                              Vigil: Blood Bitterness™         2570
# 190                                         Bullet Candy         6600
# 385                                            AudioSurf        12900
# 451                                     Everyday Shooter        16300
# 478                                             Dystopia        17580
# 623                                                 Cogs        26500
# 657                         Poker Night at the Inventory        31280
# 894                                       Super Meat Boy        40800
# 1039                               Pirates of Black Cove        49330
# 1138                                        Dustforce DX        65300
# 1183                                             Arcadia        72500
# 1307                                             Rochard       107800
# 1329                                          Smash Cars       111300
# 1332                                  Blocks That Matter       111800
# 1348                                           Lightfish       116120
# 1369                                     Before the Echo       200910
# 1486                                      Stellar Impact       207150
# 1749   Hamlet or the Last Game without MMORPG Feature...       222160
# 1839                                        Kingdom Wars       227180
# 2033                                   Legend of Dungeon       238280
# 2158                                        The Novelist       245150
# 2176                                         Perfection.       246360
# 2200                                               Gravi       247310
# 2212                                   Reach for the Sun       248290
# 2219                                  Salvation Prophecy       248450
# 2246                                              Delver       249630
# 2253                               Lilly Looking Through       250030
# 2361                             Kingdom Wars 2: Battles       253190
# 2376                                       Steam Marines       253630
# ...                                                  ...          ...
# 12673                           Peak Angle: Drift Online       547410
# 13297                                            Obscura       563420
# 13548                                           Chosen 2       569970
# 13861                             Zoop! - Hunter's Grimm       577460
# 14054                            Awesome Metal Detecting       582810
# 14193                                                 OR       586620
# 15146                             Steam 360 Video Player       613220
# 15630                                          Lazaretto       628350
# 15892                                 I wanna be The Cat       637880
# 15915                                         Animallica       638850
# 15936                                               1982       639650
# 16943                                               PION       667550
# 17053                                        Fallen Cube       670370
# 17107                        STRIPPER ANYA™ DEMON SLAYER       671630
# 17231                                         TerkEngine       674010
# 18168                                        Juice Fresh       697640
# 18393                                        Flat Worlds       703490
# 18495                    Stripper Anya™ 2 X-MiGuFighters       705700
# 18870                                             CEdges       715570
# 21014                                              scram       773920
# 21826                            eSail Sailing Simulator       794860
# 22717                                Ashi: Lake of Light       819040
# 23161                                          Time-Skip       833510
# 23456                                         Echoes III       841950
# 24827                                              _dive       878950
# 25070                                         UpBreakers       886120
# 27049                 Bright Memory(Early Access) / 光明记忆       955050
# 27895                      Call of Pixel: Close Quarters       987790
# 28090                                  A Christmas Peril       996650
# 28244                                          CrossTrix      1003690
#
#       required_age                               detailed_description  \
# 67               0  With the completion of the third title in the ...
# 68               0  <p>Vigil: Blood Bitterness plunges you into th...
# 190              0  Bullet Candy is a fast paced, action packed ar...
# 385              0  Ride your music.<br>\t\t\t\t\tAudiosurf is a m...
# 451              0  <p>Everyday Shooter is an album of games explo...
# 478              0  <strong>Dystopia</strong> is a cyberpunk game ...
# 623              0  <p>Cogs is a puzzle game where players build m...
# 657              0  ***Not Compatible with Mac OS 10.8.x and above...
# 894              0  Super Meat Boy is a tough as nails platformer ...
# 1039             0  Set in the golden age of pirates, this is your...
# 1138             0  <h1>Dustforce DX Update</h1><p>Dustforce DX is...
# 1183             0  Arcadia is a fun, casual little shooter. There...
# 1307             0  <p>Grab a G-Lifter - your new best friend! Use...
# 1329             0  <p>Real-time physics, innovative stunts and ne...
# 1332             0  When indie game developers Alexey and Markus a...
# 1348             0  <strong>LightFish</strong> is a highly addicti...
# 1369             0  <strong>Before the Echo</strong> combines elem...
# 1486             0  In space, war rages between allies and axis fo...
# 1749             0  <i>Hamlet or the Last Game without MMORPG Feat...
# 1839             0  Kingdom Wars is a free to play 3D MMORTS with ...
# 2033             0  As you journey deep into the dungeon, you will...
# 2158             0  The Novelist asks one central question: can yo...
# 2176             0  <strong>Perfection.</strong> is a simple, soot...
# 2200             0  <h1>Trading Cards</h1><p><img src="https://ste...
# 2212             0  <h2 class="bb_tag">Version 1.2 Out Now!</h2><i...
# 2219             0  Salvation Prophecy is a <strong><i>military sp...
# 2246             0  Delve into the shifting dungeons on your hunt ...
# 2253             0  What Lilly sees is about to change her life fo...
# 2361             0  <h1>Free Undead Cometh Expansion</h1><p><img s...
# 2376             0  Steam Marines is a squad based Roguelike set o...
# ...            ...                                                ...
# 12673            0  Peak Angle: Drift Online is a real-time massiv...
# 13297            0  <strong>WARNING: OBSCURA IS A PASSIVE VIEWING ...
# 13548            0  Chosen 2 is a heroic RPG sequel to Chosen. <br...
# 13861            0  Hunter's Grimm is a spooky adventure about hun...
# 14054            0  Metal Detecting is our number one hobby, and i...
# 14193            0  Do not underestimate the apparent simplicity o...
# 15146            0  The Steam 360 Video Player allows SteamVR comp...
# 15630            0  <strong>LAZARETTO</strong> is an immersive fir...
# 15892            0  <strong>I wanna be the Cat</strong> is a chall...
# 15915            0  Animallica is an adventure game set in a post-...
# 15936            0  1982 is a FREE retro inspired blasta-thon that...
# 16943            0  PION is a fast-paced and challenging top-down ...
# 17053            0  <h2 class="bb_tag"><strong>Description</strong...
# 17107            0  <strong>WARNING: NSFW</strong>-<i>Video &amp; ...
# 17231            0  A single game developed by TerkStudios, develo...
# 18168            0  In the game, you must make combinations on the...
# 18393            0  <h1>Join us on Discord</h1><p><a href="https:/...
# 18495            0  X-MiGu Fighters takes us back to the world of ...
# 18870            0  Change character's color based on which platfo...
# 21014            0  you are stuck in a dangerous area with no help...
# 21826            0  With <i>eSail</i> you learn how to raise the m...
# 22717            0  <img src="https://steamcdn-a.akamaihd.net/stea...
# 23161            0  Use creative abilities to explore the facility...
# 23456            0  Echoes is back with a bang and in 3D! More int...
# 24827            0  <h1>Update Notes</h1><p>Update 1.0.2<br><br>-f...
# 25070            0  <h1>Join our Discord</h1><p><a href="https://s...
# 27049            0  《Bright Memory》 is a first-person action shoot...
# 27895            0  PVP Free for All with PVE inspired by Call of ...
# 28090            0  The weather outside might be frightful, but in...
# 28244            0  CrossTrix is a crossword based puzzle game, wh...
#
#                                           about_the_game  \
# 67     With the completion of the third title in the ...
# 68     <p>Vigil: Blood Bitterness plunges you into th...
# 190    Bullet Candy is a fast paced, action packed ar...
# 385    Ride your music.<br>\t\t\t\t\tAudiosurf is a m...
# 451    <p>Everyday Shooter is an album of games explo...
# 478    <strong>Dystopia</strong> is a cyberpunk game ...
# 623    <p>Cogs is a puzzle game where players build m...
# 657    ***Not Compatible with Mac OS 10.8.x and above...
# 894    Super Meat Boy is a tough as nails platformer ...
# 1039   Set in the golden age of pirates, this is your...
# 1138   Clean up the world with style! As an acrobatic...
# 1183   Arcadia is a fun, casual little shooter. There...
# 1307   <p>Grab a G-Lifter - your new best friend! Use...
# 1329   <p>Real-time physics, innovative stunts and ne...
# 1332   When indie game developers Alexey and Markus a...
# 1348   <strong>LightFish</strong> is a highly addicti...
# 1369   <strong>Before the Echo</strong> combines elem...
# 1486   In space, war rages between allies and axis fo...
# 1749   <i>Hamlet or the Last Game without MMORPG Feat...
# 1839   Kingdom Wars is a free to play 3D MMORTS with ...
# 2033   As you journey deep into the dungeon, you will...
# 2158   The Novelist asks one central question: can yo...
# 2176   <strong>Perfection.</strong> is a simple, soot...
# 2200   Gravi is an intense puzzle-platformer that wil...
# 2212   <h2 class="bb_tag">Version 1.2 Out Now!</h2><i...
# 2219   Salvation Prophecy is a <strong><i>military sp...
# 2246   Delve into the shifting dungeons on your hunt ...
# 2253   What Lilly sees is about to change her life fo...
# 2361   Kingdom Wars 2: Battles brings a fresh perspec...
# 2376   Steam Marines is a squad based Roguelike set o...
# ...                                                  ...
# 12673  Peak Angle: Drift Online is a real-time massiv...
# 13297  <strong>WARNING: OBSCURA IS A PASSIVE VIEWING ...
# 13548  Chosen 2 is a heroic RPG sequel to Chosen. <br...
# 13861  Hunter's Grimm is a spooky adventure about hun...
# 14054  Metal Detecting is our number one hobby, and i...
# 14193  Do not underestimate the apparent simplicity o...
# 15146  The Steam 360 Video Player allows SteamVR comp...
# 15630  <strong>LAZARETTO</strong> is an immersive fir...
# 15892  <strong>I wanna be the Cat</strong> is a chall...
# 15915  Animallica is an adventure game set in a post-...
# 15936  1982 is a FREE retro inspired blasta-thon that...
# 16943  PION is a fast-paced and challenging top-down ...
# 17053  <h2 class="bb_tag"><strong>Description</strong...
# 17107  <strong>WARNING: NSFW</strong>-<i>Video &amp; ...
# 17231  A single game developed by TerkStudios, develo...
# 18168  In the game, you must make combinations on the...
# 18393  <img src="https://steamcdn-a.akamaihd.net/stea...
# 18495  X-MiGu Fighters takes us back to the world of ...
# 18870  Change character's color based on which platfo...
# 21014  you are stuck in a dangerous area with no help...
# 21826  With <i>eSail</i> you learn how to raise the m...
# 22717  <img src="https://steamcdn-a.akamaihd.net/stea...
# 23161  Use creative abilities to explore the facility...
# 23456  Echoes is back with a bang and in 3D! More int...
# 24827  <h2 class="bb_tag">This game is best experienc...
# 25070  <h2 class="bb_tag">When hearts break and two a...
# 27049  《Bright Memory》 is a first-person action shoot...
# 27895  PVP Free for All with PVE inspired by Call of ...
# 28090  The weather outside might be frightful, but in...
# 28244  CrossTrix is a crossword based puzzle game, wh...
#
#                                        short_description  \
# 67     With the completion of the third title in the ...
# 68     Vigil: Blood Bitterness plunges you into the d...
# 190    Bullet Candy is a fast paced, action packed ar...
# 385    Ride your music. Audiosurf is a music-adapting...
# 451    Everyday Shooter is an album of games explorin...
# 478    Dystopia is a cyberpunk game on the Source eng...
# 623    Cogs is a puzzle game where players build mach...
# 657    Prepare for a different kind of poker night in...
# 894    The infamous, tough-as-nails platformer comes ...
# 1039   Set in the golden age of pirates, this is your...
# 1138   Take control of a nimble janitor to rid the wo...
# 1183   Arcadia is a fun, casual little shooter. There...
# 1307   Fast-paced platforming action and mind-bending...
# 1329   Set on a beautiful resort island, the fast-pac...
# 1332   When indie game developers Alexey and Markus a...
# 1348   LightFish is a highly addictive arcade game, w...
# 1369   Before the Echo combines elements of both rhyt...
# 1486   In Stellar Impact you command a space battlesh...
# 1749   The original adventure game based on twisted W...
# 1839   Kingdom Wars is a free to play 3D MMORTS with ...
# 2033   Legend of Dungeon is a randomly generated acti...
# 2158   The Novelist asks one central question: can yo...
# 2176   Perfection. is a simple, soothing puzzle game ...
# 2200   Gravi is an intense puzzle-platformer that wil...
# 2212   Version 1.2 Out Now!Strategy mode is now avail...
# 2219   Salvation Prophecy is a military space epic. H...
# 2246   Delve into the shifting dungeons on your hunt ...
# 2253   What Lilly sees is about to change her life fo...
# 2361   KW2B brings massive sieges and survival to med...
# 2376   Steam Marines is a squad based Roguelike set o...
# ...                                                  ...
# 12673  Peak Angle: Drift Online is a real-time massiv...
# 13297  A new reality of fear. What you see may follow...
# 13548         Chosen 2 is a heroic RPG sequel to Chosen.
# 13861  For Sarai and Nicholas, life is simple: search...
# 14054                     The best treasure hunter game.
# 14193  Do not underestimate the apparent simplicity o...
# 15146  The Steam 360 Video Player allows SteamVR comp...
# 15630  Grab your headphones and play one of the most ...
# 15892  I wanna be the Cat is a challenging roguelite ...
# 15915  In Animallica you are racing against extinctio...
# 15936  1982 is a FREE retro inspired blasta-thon that...
# 16943  PION is a fast-paced and challenging top-down ...
# 17053  Fallen Cube is a puzzle game where you should ...
# 17107  Tired of everyone getting offended about every...
# 17231  Loneliness is a survival experience, mainly ta...
# 18168  You must make combinations in order to gain en...
# 18393  Flat Worlds is a VR space transport game set i...
# 18495  Tired of everyone getting offended about every...
# 18870  Change character's color based on which platfo...
# 21014  be a peasant to shoot guns and ride a choppa o...
# 21826  eSail Sailing Simulator is an authentic yacht ...
# 22717  Find the true path through the night and into ...
# 23161  A fast-paced first person puzzle game. Use tel...
# 23456  Echoes is back with a bang and in 3D! More int...
# 24827                            A story about escapism.
# 25070  Gloves off! Make your moving company the best!...
# 27049  《Bright Memory》is developed by an independent ...
# 27895  PVP Free for All with PVE inspired by Call of ...
# 28090  A Christmas Peril is a holiday action game wit...
# 28244  CrossTrix is a crossword based puzzle game, wh...
#
#                                             header_image  \
# 67     https://steamcdn-a.akamaihd.net/steam/apps/254...
# 68     https://steamcdn-a.akamaihd.net/steam/apps/257...
# 190    https://steamcdn-a.akamaihd.net/steam/apps/660...
# 385    https://steamcdn-a.akamaihd.net/steam/apps/129...
# 451    https://steamcdn-a.akamaihd.net/steam/apps/163...
# 478    https://steamcdn-a.akamaihd.net/steam/apps/175...
# 623    https://steamcdn-a.akamaihd.net/steam/apps/265...
# 657    https://steamcdn-a.akamaihd.net/steam/apps/312...
# 894    https://steamcdn-a.akamaihd.net/steam/apps/408...
# 1039   https://steamcdn-a.akamaihd.net/steam/apps/493...
# 1138   https://steamcdn-a.akamaihd.net/steam/apps/653...
# 1183   https://steamcdn-a.akamaihd.net/steam/apps/725...
# 1307   https://steamcdn-a.akamaihd.net/steam/apps/107...
# 1329   https://steamcdn-a.akamaihd.net/steam/apps/111...
# 1332   https://steamcdn-a.akamaihd.net/steam/apps/111...
# 1348   https://steamcdn-a.akamaihd.net/steam/apps/116...
# 1369   https://steamcdn-a.akamaihd.net/steam/apps/200...
# 1486   https://steamcdn-a.akamaihd.net/steam/apps/207...
# 1749   https://steamcdn-a.akamaihd.net/steam/apps/222...
# 1839   https://steamcdn-a.akamaihd.net/steam/apps/227...
# 2033   https://steamcdn-a.akamaihd.net/steam/apps/238...
# 2158   https://steamcdn-a.akamaihd.net/steam/apps/245...
# 2176   https://steamcdn-a.akamaihd.net/steam/apps/246...
# 2200   https://steamcdn-a.akamaihd.net/steam/apps/247...
# 2212   https://steamcdn-a.akamaihd.net/steam/apps/248...
# 2219   https://steamcdn-a.akamaihd.net/steam/apps/248...
# 2246   https://steamcdn-a.akamaihd.net/steam/apps/249...
# 2253   https://steamcdn-a.akamaihd.net/steam/apps/250...
# 2361   https://steamcdn-a.akamaihd.net/steam/apps/253...
# 2376   https://steamcdn-a.akamaihd.net/steam/apps/253...
# ...                                                  ...
# 12673  https://steamcdn-a.akamaihd.net/steam/apps/547...
# 13297  https://steamcdn-a.akamaihd.net/steam/apps/563...
# 13548  https://steamcdn-a.akamaihd.net/steam/apps/569...
# 13861  https://steamcdn-a.akamaihd.net/steam/apps/577...
# 14054  https://steamcdn-a.akamaihd.net/steam/apps/582...
# 14193  https://steamcdn-a.akamaihd.net/steam/apps/586...
# 15146  https://steamcdn-a.akamaihd.net/steam/apps/613...
# 15630  https://steamcdn-a.akamaihd.net/steam/apps/628...
# 15892  https://steamcdn-a.akamaihd.net/steam/apps/637...
# 15915  https://steamcdn-a.akamaihd.net/steam/apps/638...
# 15936  https://steamcdn-a.akamaihd.net/steam/apps/639...
# 16943  https://steamcdn-a.akamaihd.net/steam/apps/667...
# 17053  https://steamcdn-a.akamaihd.net/steam/apps/670...
# 17107  https://steamcdn-a.akamaihd.net/steam/apps/671...
# 17231  https://steamcdn-a.akamaihd.net/steam/apps/674...
# 18168  https://steamcdn-a.akamaihd.net/steam/apps/697...
# 18393  https://steamcdn-a.akamaihd.net/steam/apps/703...
# 18495  https://steamcdn-a.akamaihd.net/steam/apps/705...
# 18870  https://steamcdn-a.akamaihd.net/steam/apps/715...
# 21014  https://steamcdn-a.akamaihd.net/steam/apps/773...
# 21826  https://steamcdn-a.akamaihd.net/steam/apps/794...
# 22717  https://steamcdn-a.akamaihd.net/steam/apps/819...
# 23161  https://steamcdn-a.akamaihd.net/steam/apps/833...
# 23456  https://steamcdn-a.akamaihd.net/steam/apps/841...
# 24827  https://steamcdn-a.akamaihd.net/steam/apps/878...
# 25070  https://steamcdn-a.akamaihd.net/steam/apps/886...
# 27049  https://steamcdn-a.akamaihd.net/steam/apps/955...
# 27895  https://steamcdn-a.akamaihd.net/steam/apps/987...
# 28090  https://steamcdn-a.akamaihd.net/steam/apps/996...
# 28244  https://steamcdn-a.akamaihd.net/steam/apps/100...
#
#                                                  website  \
# 67                                                   NaN
# 68                                                   NaN
# 190                         http://www.charliesgames.com
# 385                           http://www.audio-surf.com/
# 451                      http://www.everydayshooter.com/
# 478                            http://dystopia-game.com/
# 623                              http://www.cogsgame.com
# 657              http://www.telltalegames.com/pokernight
# 894                          http://www.supermeatboy.com
# 1039                       http://www.blackcovegame.com/
# 1138                               http://hitboxteam.com
# 1183                 http://www.joshyy.com/games/arcadia
# 1307                      http://www.rochardthegame.com/
# 1329   http://www.facebook.com/pages/Smash-Cars/12434...
# 1332                  http://www.swingswingsubmarine.com
# 1348         http://www.eclipse-games.net/LightFish.html
# 1369                          http://www.playiridium.com
# 1486                                                 NaN
# 1749                    http://gameletgame.blogspot.com/
# 1839                               http://kingdomwars.ca
# 2033                     http://robotloveskitty.com/LoD/
# 2158                      http://www.thenovelistgame.com
# 2176                           http://perfectiongame.net
# 2200                                http://playgravi.com
# 2212   http://www.filamentgames.com/products/reach-su...
# 2219                    http://www.salvationprophecy.com
# 2246                           http://www.delvergame.com
# 2253                          http://www.geetagames.com/
# 2361                                     http://kw2b.com
# 2376                         http://www.SteamMarines.com
# ...                                                  ...
# 12673                                                NaN
# 13297                                                NaN
# 13548                                                NaN
# 13861                                                NaN
# 14054              http://www.awesomemetaldetecting.com/
# 14193                 http://www.backtobasicsgaming.com/
# 15146                                                NaN
# 15630                          http://lazarettogame.com/
# 15892                     http://www.iwannabethecat.com/
# 15915                         http://www.animallica.net/
# 15936                http://www.binaryzoo.com/1982_page/
# 16943                                                NaN
# 17053                     https://twitter.com/WourdGames
# 17107                           http://www.xmiguplay.com
# 17231                                                NaN
# 18168                                                NaN
# 18393                                  https://che.codes
# 18495                           http://www.xmiguplay.com
# 18870                                                NaN
# 21014                         https://discord.gg/JeGnHcW
# 21826                https://www.esailyachtsimulator.com
# 22717                                http://ashigame.com
# 23161                                                NaN
# 23456                                                NaN
# 24827                                                NaN
# 25070                      http://www.bootsmann-games.de
# 27049                                                NaN
# 27895                                                NaN
# 28090                                                NaN
# 28244                                                NaN
#
#                                          pc_requirements  \
# 67     {'minimum': '<strong>Minimum: </strong>Windows...
# 68     {'minimum': 'Windows XP/2000, 1.2 GHz Processo...
# 190    {'minimum': '<strong>Minimum: </strong><br>\t\...
# 385    {'minimum': '<strong>Minimum:</strong><br>\t\t...
# 451    {'minimum': '<ul>\n\t\t\t\t\t<li><strong>OS:</...
# 478    {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 623    {'minimum': '<ul>\n\t                    <li><...
# 657    {'minimum': '<strong>Minimum:</strong><br>\t\t...
# 894    {'minimum': '<ul class="bb_ul"><li><strong>OS:...
# 1039   {'minimum': '<ul class="bb_ul"><li><strong>OS:...
# 1138   {'minimum': '<ul class="bb_ul"><li><strong>OS:...
# 1183   {'minimum': '<ul class="bb_ul"><li><strong>OS:...
# 1307   {'minimum': '<strong>Minimum:</strong>\n\t\t\t...
# 1329   {'minimum': '<p><strong>Minimum:</strong></p>\...
# 1332   {'minimum': '<strong>Minimum:</strong><br>\t\t...
# 1348   {'minimum': '<ul class="bb_ul"><li><strong>OS:...
# 1369   {'minimum': '<ul class="bb_ul"><li><strong>OS:...
# 1486   {'minimum': '<ul class="bb_ul"><li><strong>OS:...
# 1749   {'minimum': '<ul class="bb_ul"><li><strong>OS:...
# 1839   {'minimum': '<strong>Minimum:</strong><br><ul ...
# 2033   {'minimum': '<strong>Minimum:</strong><br><ul ...
# 2158   {'minimum': '<strong>Minimum:</strong><br><ul ...
# 2176   {'minimum': '<strong>Minimum:</strong><br><ul ...
# 2200   {'minimum': '<strong>Minimum:</strong><br><ul ...
# 2212   {'minimum': '<strong>Minimum:</strong><br><ul ...
# 2219   {'minimum': '<strong>Minimum:</strong><br><ul ...
# 2246   {'minimum': '<strong>Minimum:</strong><br><ul ...
# 2253   {'minimum': '<strong>Minimum:</strong><br><ul ...
# 2361   {'minimum': '<strong>Minimum:</strong><br><ul ...
# 2376   {'minimum': '<strong>Minimum:</strong><br><ul ...
# ...                                                  ...
# 12673  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 13297  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 13548  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 13861  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 14054  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 14193  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 15146  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 15630  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 15892  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 15915  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 15936  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 16943  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 17053  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 17107  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 17231  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 18168  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 18393  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 18495  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 18870  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 21014  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 21826  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 22717  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 23161  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 23456  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 24827  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 25070  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 27049  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 27895  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 28090  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 28244  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                         mac_requirements  \
# 67                                                    []
# 68                                                    []
# 190                                                   []
# 385                                                   []
# 451                                                   []
# 478                                                   []
# 623    {'minimum': '<ul>\n\t<li><strong>OS:</strong> ...
# 657    {'minimum': '<strong>Minimum:</strong><br>\t\t...
# 894    {'minimum': '<ul class="bb_ul"><li><strong>OS:...
# 1039                                                  []
# 1138   {'minimum': '<ul class="bb_ul"><li><strong>OS:...
# 1183                                                  []
# 1307   {'minimum': '<ul>\n\t<li><strong>OS:</strong> ...
# 1329                                                  []
# 1332   {'minimum': '<strong>Minimum:</strong><br><ul ...
# 1348   {'minimum': '<ul class="bb_ul"><li><strong>Pro...
# 1369   {'minimum': '<ul class="bb_ul"><li><strong>OS:...
# 1486                                                  []
# 1749                                                  []
# 1839                                                  []
# 2033   {'minimum': '<strong>Minimum:</strong><br><ul ...
# 2158   {'minimum': '<strong>Minimum:</strong><br><ul ...
# 2176   {'minimum': '<strong>Minimum:</strong><br><ul ...
# 2200   {'minimum': '<strong>Minimum:</strong><br><ul ...
# 2212                                                  []
# 2219                                                  []
# 2246   {'minimum': '<strong>Minimum:</strong><br><ul ...
# 2253   {'minimum': '<strong>Minimum:</strong><br><ul ...
# 2361                                                  []
# 2376   {'minimum': '<strong>Minimum:</strong><br><ul ...
# ...                                                  ...
# 12673                                                 []
# 13297  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 13548                                                 []
# 13861                                                 []
# 14054                                                 []
# 14193                                                 []
# 15146  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 15630  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 15892                                                 []
# 15915                                                 []
# 15936  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 16943                                                 []
# 17053                                                 []
# 17107  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 17231  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 18168                                                 []
# 18393  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 18495                                                 []
# 18870                                                 []
# 21014  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 21826  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 22717  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 23161                                                 []
# 23456                                                 []
# 24827                                                 []
# 25070  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 27049                                                 []
# 27895                                                 []
# 28090  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 28244                                                 []
#
#                                       linux_requirements          platforms  \
# 67                                                    []            windows
# 68                                                    []            windows
# 190                                                   []            windows
# 385                                                   []            windows
# 451                                                   []            windows
# 478                                                   []      windows;linux
# 623                                                   []  windows;mac;linux
# 657                                                   []        windows;mac
# 894    {'minimum': '<ul class="bb_ul"><li><strong>OS:...  windows;mac;linux
# 1039                                                  []            windows
# 1138                                                  []  windows;mac;linux
# 1183                                                  []            windows
# 1307   {'minimum': '<ul>\n\t<li><strong>OS:</strong> ...  windows;mac;linux
# 1329                                                  []            windows
# 1332   {'minimum': '<strong>Minimum:</strong><br><ul ...  windows;mac;linux
# 1348                                                  []        windows;mac
# 1369   {'minimum': '<ul class="bb_ul"><li><strong>OS:...  windows;mac;linux
# 1486                                                  []            windows
# 1749                                                  []            windows
# 1839                                                  []            windows
# 2033   {'minimum': '<strong>Minimum:</strong><br><ul ...  windows;mac;linux
# 2158   {'minimum': '<strong>Minimum:</strong><br><ul ...  windows;mac;linux
# 2176   {'minimum': '<strong>Minimum:</strong><br><ul ...        windows;mac
# 2200   {'minimum': '<strong>Minimum:</strong><br><ul ...            windows
# 2212                                                  []            windows
# 2219   {'minimum': '<strong>Minimum:</strong><br><ul ...      windows;linux
# 2246   {'minimum': '<strong>Minimum:</strong><br><ul ...  windows;mac;linux
# 2253                                                  []        windows;mac
# 2361                                                  []            windows
# 2376   {'minimum': '<strong>Minimum:</strong><br><ul ...  windows;mac;linux
# ...                                                  ...                ...
# 12673                                                 []            windows
# 13297  {'minimum': '<strong>Minimum:</strong><br><ul ...            windows
# 13548                                                 []            windows
# 13861                                                 []            windows
# 14054                                                 []            windows
# 14193                                                 []            windows
# 15146  {'minimum': '<strong>Minimum:</strong><br><ul ...            windows
# 15630                                                 []        windows;mac
# 15892                                                 []            windows
# 15915                                                 []            windows
# 15936                                                 []            windows
# 16943                                                 []            windows
# 17053                                                 []            windows
# 17107  {'minimum': '<strong>Minimum:</strong><br><ul ...            windows
# 17231  {'minimum': '<strong>Minimum:</strong><br><ul ...            windows
# 18168                                                 []            windows
# 18393  {'minimum': '<strong>Minimum:</strong><br><ul ...            windows
# 18495                                                 []            windows
# 18870                                                 []            windows
# 21014  {'minimum': '<strong>Minimum:</strong><br><ul ...  windows;mac;linux
# 21826  {'minimum': '<strong>Minimum:</strong><br><ul ...        windows;mac
# 22717                                                 []        windows;mac
# 23161                                                 []            windows
# 23456                                                 []            windows
# 24827                                                 []            windows
# 25070  {'minimum': '<strong>Minimum:</strong><br><ul ...            windows
# 27049                                                 []            windows
# 27895                                                 []            windows
# 28090                                                 []        windows;mac
# 28244                                                 []            windows
#
#                                               categories  \
# 67     [{'id': 2, 'description': 'Single-player'}, {'...
# 68           [{'id': 2, 'description': 'Single-player'}]
# 190    [{'id': 2, 'description': 'Single-player'}, {'...
# 385    [{'id': 2, 'description': 'Single-player'}, {'...
# 451    [{'id': 2, 'description': 'Single-player'}, {'...
# 478    [{'id': 1, 'description': 'Multi-player'}, {'i...
# 623    [{'id': 2, 'description': 'Single-player'}, {'...
# 657    [{'id': 2, 'description': 'Single-player'}, {'...
# 894    [{'id': 2, 'description': 'Single-player'}, {'...
# 1039   [{'id': 2, 'description': 'Single-player'}, {'...
# 1138   [{'id': 2, 'description': 'Single-player'}, {'...
# 1183   [{'id': 2, 'description': 'Single-player'}, {'...
# 1307   [{'id': 2, 'description': 'Single-player'}, {'...
# 1329   [{'id': 2, 'description': 'Single-player'}, {'...
# 1332   [{'id': 2, 'description': 'Single-player'}, {'...
# 1348   [{'id': 2, 'description': 'Single-player'}, {'...
# 1369   [{'id': 2, 'description': 'Single-player'}, {'...
# 1486   [{'id': 1, 'description': 'Multi-player'}, {'i...
# 1749   [{'id': 2, 'description': 'Single-player'}, {'...
# 1839   [{'id': 2, 'description': 'Single-player'}, {'...
# 2033   [{'id': 2, 'description': 'Single-player'}, {'...
# 2158   [{'id': 2, 'description': 'Single-player'}, {'...
# 2176         [{'id': 2, 'description': 'Single-player'}]
# 2200   [{'id': 2, 'description': 'Single-player'}, {'...
# 2212   [{'id': 2, 'description': 'Single-player'}, {'...
# 2219   [{'id': 2, 'description': 'Single-player'}, {'...
# 2246   [{'id': 2, 'description': 'Single-player'}, {'...
# 2253   [{'id': 2, 'description': 'Single-player'}, {'...
# 2361   [{'id': 2, 'description': 'Single-player'}, {'...
# 2376   [{'id': 2, 'description': 'Single-player'}, {'...
# ...                                                  ...
# 12673  [{'id': 2, 'description': 'Single-player'}, {'...
# 13297        [{'id': 2, 'description': 'Single-player'}]
# 13548  [{'id': 2, 'description': 'Single-player'}, {'...
# 13861  [{'id': 2, 'description': 'Single-player'}, {'...
# 14054  [{'id': 2, 'description': 'Single-player'}, {'...
# 14193  [{'id': 2, 'description': 'Single-player'}, {'...
# 15146                                                NaN
# 15630  [{'id': 2, 'description': 'Single-player'}, {'...
# 15892  [{'id': 2, 'description': 'Single-player'}, {'...
# 15915  [{'id': 2, 'description': 'Single-player'}, {'...
# 15936  [{'id': 2, 'description': 'Single-player'}, {'...
# 16943  [{'id': 2, 'description': 'Single-player'}, {'...
# 17053  [{'id': 2, 'description': 'Single-player'}, {'...
# 17107  [{'id': 2, 'description': 'Single-player'}, {'...
# 17231  [{'id': 2, 'description': 'Single-player'}, {'...
# 18168  [{'id': 2, 'description': 'Single-player'}, {'...
# 18393        [{'id': 2, 'description': 'Single-player'}]
# 18495  [{'id': 2, 'description': 'Single-player'}, {'...
# 18870  [{'id': 2, 'description': 'Single-player'}, {'...
# 21014  [{'id': 2, 'description': 'Single-player'}, {'...
# 21826  [{'id': 2, 'description': 'Single-player'}, {'...
# 22717  [{'id': 2, 'description': 'Single-player'}, {'...
# 23161  [{'id': 2, 'description': 'Single-player'}, {'...
# 23456  [{'id': 2, 'description': 'Single-player'}, {'...
# 24827  [{'id': 2, 'description': 'Single-player'}, {'...
# 25070  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 27049  [{'id': 2, 'description': 'Single-player'}, {'...
# 27895  [{'id': 36, 'description': 'Online Multi-Playe...
# 28090  [{'id': 2, 'description': 'Single-player'}, {'...
# 28244  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                                   genres  \
# 67     [{'id': '4', 'description': 'Casual'}, {'id': ...
# 68     [{'id': '23', 'description': 'Indie'}, {'id': ...
# 190    [{'id': '4', 'description': 'Casual'}, {'id': ...
# 385               [{'id': '23', 'description': 'Indie'}]
# 451    [{'id': '23', 'description': 'Indie'}, {'id': ...
# 478    [{'id': '1', 'description': 'Action'}, {'id': ...
# 623    [{'id': '23', 'description': 'Indie'}, {'id': ...
# 657    [{'id': '4', 'description': 'Casual'}, {'id': ...
# 894               [{'id': '23', 'description': 'Indie'}]
# 1039            [{'id': '2', 'description': 'Strategy'}]
# 1138   [{'id': '1', 'description': 'Action'}, {'id': ...
# 1183   [{'id': '4', 'description': 'Casual'}, {'id': ...
# 1307   [{'id': '1', 'description': 'Action'}, {'id': ...
# 1329   [{'id': '1', 'description': 'Action'}, {'id': ...
# 1332   [{'id': '4', 'description': 'Casual'}, {'id': ...
# 1348   [{'id': '1', 'description': 'Action'}, {'id': ...
# 1369   [{'id': '23', 'description': 'Indie'}, {'id': ...
# 1486   [{'id': '1', 'description': 'Action'}, {'id': ...
# 1749   [{'id': '25', 'description': 'Adventure'}, {'i...
# 1839   [{'id': '37', 'description': 'Free to Play'}, ...
# 2033   [{'id': '1', 'description': 'Action'}, {'id': ...
# 2158   [{'id': '25', 'description': 'Adventure'}, {'i...
# 2176   [{'id': '4', 'description': 'Casual'}, {'id': ...
# 2200   [{'id': '70', 'description': 'Early Access'}, ...
# 2212   [{'id': '4', 'description': 'Casual'}, {'id': ...
# 2219   [{'id': '1', 'description': 'Action'}, {'id': ...
# 2246   [{'id': '1', 'description': 'Action'}, {'id': ...
# 2253   [{'id': '25', 'description': 'Adventure'}, {'i...
# 2361   [{'id': '23', 'description': 'Indie'}, {'id': ...
# 2376   [{'id': '23', 'description': 'Indie'}, {'id': ...
# ...                                                  ...
# 12673  [{'id': '29', 'description': 'Massively Multip...
# 13297  [{'id': '23', 'description': 'Indie'}, {'id': ...
# 13548  [{'id': '71', 'description': 'Sexual Content'}...
# 13861  [{'id': '1', 'description': 'Action'}, {'id': ...
# 14054  [{'id': '1', 'description': 'Action'}, {'id': ...
# 14193  [{'id': '4', 'description': 'Casual'}, {'id': ...
# 15146                                                NaN
# 15630  [{'id': '1', 'description': 'Action'}, {'id': ...
# 15892  [{'id': '1', 'description': 'Action'}, {'id': ...
# 15915  [{'id': '1', 'description': 'Action'}, {'id': ...
# 15936  [{'id': '1', 'description': 'Action'}, {'id': ...
# 16943  [{'id': '1', 'description': 'Action'}, {'id': ...
# 17053             [{'id': '23', 'description': 'Indie'}]
# 17107  [{'id': '1', 'description': 'Action'}, {'id': ...
# 17231  [{'id': '1', 'description': 'Action'}, {'id': ...
# 18168  [{'id': '4', 'description': 'Casual'}, {'id': ...
# 18393  [{'id': '23', 'description': 'Indie'}, {'id': ...
# 18495  [{'id': '1', 'description': 'Action'}, {'id': ...
# 18870  [{'id': '25', 'description': 'Adventure'}, {'i...
# 21014  [{'id': '1', 'description': 'Action'}, {'id': ...
# 21826  [{'id': '9', 'description': 'Racing'}, {'id': ...
# 22717  [{'id': '4', 'description': 'Casual'}, {'id': ...
# 23161  [{'id': '25', 'description': 'Adventure'}, {'i...
# 23456  [{'id': '1', 'description': 'Action'}, {'id': ...
# 24827  [{'id': '25', 'description': 'Adventure'}, {'i...
# 25070  [{'id': '1', 'description': 'Action'}, {'id': ...
# 27049  [{'id': '1', 'description': 'Action'}, {'id': ...
# 27895  [{'id': '1', 'description': 'Action'}, {'id': ...
# 28090  [{'id': '1', 'description': 'Action'}, {'id': ...
# 28244  [{'id': '4', 'description': 'Casual'}, {'id': ...
#
#                                              screenshots  \
# 67     [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 68     [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 190    [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 385    [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 451    [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 478    [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 623    [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 657    [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 894    [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 1039   [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 1138   [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 1183   [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 1307   [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 1329   [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 1332   [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 1348   [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 1369   [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 1486   [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 1749   [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 1839   [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 2033   [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 2158   [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 2176   [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 2200   [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 2212   [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 2219   [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 2246   [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 2253   [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 2361   [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 2376   [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# ...                                                  ...
# 12673  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 13297  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 13548  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 13861  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 14054  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 14193  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 15146  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 15630  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 15892  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 15915  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 15936  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 16943  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 17053  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 17107  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 17231  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 18168  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 18393  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 18495  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 18870  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 21014  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 21826  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 22717  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 23161  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 23456  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 24827  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 25070  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 27049  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 27895  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 28090  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 28244  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
#
#                                                   movies  \
# 67                                                   NaN
# 68                                                   NaN
# 190                                                  NaN
# 385    [{'id': 2030283, 'name': 'Audiosurf Trailer', ...
# 451                                                  NaN
# 478    [{'id': 256708878, 'name': 'Dystopia 1.2 Relea...
# 623                                                  NaN
# 657                                                  NaN
# ...
# 21014   {'coming_soon': False, 'date': '8 Jan, 2019'}
# 21826  {'coming_soon': False, 'date': '26 Mar, 2019'}
# 22717   {'coming_soon': False, 'date': '5 Jul, 2018'}
# 23161  {'coming_soon': False, 'date': '12 Apr, 2018'}
# 23456   {'coming_soon': False, 'date': '5 Sep, 2018'}
# 24827   {'coming_soon': False, 'date': '5 Jul, 2018'}
# 25070  {'coming_soon': False, 'date': '15 Nov, 2018'}
# 27049  {'coming_soon': False, 'date': '11 Jan, 2019'}
# 27895  {'coming_soon': False, 'date': '22 Jul, 2019'}
# 28090  {'coming_soon': False, 'date': '29 Dec, 2018'}
# 28244   {'coming_soon': False, 'date': '3 Jan, 2019'}
#
#                                             support_info  \
# 67                              {'url': '', 'email': ''}
# 68                              {'url': '', 'email': ''}
# 190    {'url': '', 'email': 'charlie@charliesgames.com'}
# 385                             {'url': '', 'email': ''}
# 451                             {'url': '', 'email': ''}
# 478    {'url': 'http://punyhumangames.com/contact.php...
# 623                             {'url': '', 'email': ''}
# 657    {'url': 'http://www.telltalegames.com/communit...
# 894     {'url': '', 'email': 'support@supermeatboy.com'}
# 1039    {'url': '', 'email': 'support@paradoxplaza.com'}
# 1138      {'url': '', 'email': 'contact@hitboxteam.com'}
# 1183             {'url': '', 'email': 'josh@joshyy.com'}
# 1307     {'url': '', 'email': 'support@recoilgames.com'}
# 1329   {'url': 'http://www.facebook.com/pages/Smash-C...
# 1332   {'url': '', 'email': 'guillaume@swingswingsubm...
# 1348   {'url': 'http://www.eclipse-games.net/Contact....
# 1369     {'url': '', 'email': 'iridium@playiridium.com'}
# 1486     {'url': '', 'email': 'support@headupgames.com'}
# 1749       {'url': '', 'email': 'mif2000mail@gmail.com'}
# 1839   {'url': 'http://kingdomwars.ca', 'email': 'sup...
# 2033   {'url': 'http://robotloveskitty.com/bugs/index...
# 2158   {'url': 'http://www.thenovelistgame.com/suppor...
# 2176   {'url': 'http://greg.style', 'email': 'banovg@...
# 2200   {'url': 'http://hashbanggames.com', 'email': '...
# 2212   {'url': 'http://www.filamentgames.com/contact-...
# 2219   {'url': 'http://www.salvationprophecy.com/foru...
# 2246   {'url': 'http://www.delvergame.com', 'email': ...
# 2253   {'url': 'http://geetagames.com/faq/', 'email':...
# 2361   {'url': 'kw2b.com', 'email': 'support@reveriew...
# 2376    {'url': '', 'email': 'yjseow@worthlessbums.com'}
# ...                                                  ...
# 12673  {'url': '', 'email': 'PeakAngleDeveloper@gmail...
# 13297        {'url': '', 'email': 'ObscuraVR@gmail.com'}
# 13548        {'url': '', 'email': 'ian@ip-builders.com'}
# 13861        {'url': '', 'email': 'ian@ip-builders.com'}
# 14054  {'url': 'http://awesomemetaldetecting.com/', '...
# 14193  {'url': 'http://www.backtobasicsgaming.com/#!c...
# 15146                           {'url': '', 'email': ''}
# 15630  {'url': '', 'email': 'support@LazarettoGame.com'}
# 15892  {'url': '', 'email': 'contact@iwannabethecat.c...
# 15915  {'url': 'http://www.animallica.net', 'email': ...
# 15936  {'url': 'http://www.binaryzoo.com/contact_page...
# 16943      {'url': '', 'email': 'piongamedev@gmail.com'}
# 17053  {'url': '', 'email': 'wourdgamescontact@gmail....
# 17107  {'url': 'http://www.xmiguplay.com', 'email': '...
# 17231  {'url': 'thempiresupport.blogspot.com', 'email...
# 18168       {'url': '', 'email': '55saetmi55@gmail.com'}
# 18393      {'url': '', 'email': 'flat.worlds@che.codes'}
# 18495  {'url': 'www.xmiguplay.com', 'email': 'info@xm...
# 18870    {'url': 'vadimalexepta@yandex.ru', 'email': ''}
# 21014  {'url': 'https://discord.gg/JeGnHcW', 'email':...
# 21826  {'url': 'https://www.esailyachtsimulator.com/s...
# 22717  {'url': 'http://ncellini.com/ashi-support', 'e...
# 23161   {'url': '', 'email': 'gamingvnetwork@gmail.com'}
# 23456  {'url': 'http://www.binaryzoo.com/contact_page...
# 24827     {'url': '', 'email': 'deothicgames@gmail.com'}
# 25070  {'url': 'http://www.bootsmann-games.de', 'emai...
# 27049           {'url': '', 'email': 'fyqdzg@gmail.com'}
# 27895      {'url': '', 'email': 'mokabbggame@gmail.com'}
# 28090  {'url': '', 'email': 'achristmasperil@gmail.com'}
# 28244       {'url': '', 'email': 'hockland@hotmail.com'}
#
#                                               background  \
# 67     https://steamcdn-a.akamaihd.net/steam/apps/254...
# 68     https://steamcdn-a.akamaihd.net/steam/apps/257...
# 190    https://steamcdn-a.akamaihd.net/steam/apps/660...
# 385    https://steamcdn-a.akamaihd.net/steam/apps/129...
# 451    https://steamcdn-a.akamaihd.net/steam/apps/163...
# 478    https://steamcdn-a.akamaihd.net/steam/apps/175...
# 623    https://steamcdn-a.akamaihd.net/steam/apps/265...
# 657    https://steamcdn-a.akamaihd.net/steam/apps/312...
# 894    https://steamcdn-a.akamaihd.net/steam/apps/408...
# 1039   https://steamcdn-a.akamaihd.net/steam/apps/493...
# 1138   https://steamcdn-a.akamaihd.net/steam/apps/653...
# 1183   https://steamcdn-a.akamaihd.net/steam/apps/725...
# 1307   https://steamcdn-a.akamaihd.net/steam/apps/107...
# 1329   https://steamcdn-a.akamaihd.net/steam/apps/111...
# 1332   https://steamcdn-a.akamaihd.net/steam/apps/111...
# 1348   https://steamcdn-a.akamaihd.net/steam/apps/116...
# 1369   https://steamcdn-a.akamaihd.net/steam/apps/200...
# 1486   https://steamcdn-a.akamaihd.net/steam/apps/207...
# 1749   https://steamcdn-a.akamaihd.net/steam/apps/222...
# 1839   https://steamcdn-a.akamaihd.net/steam/apps/227...
# 2033   https://steamcdn-a.akamaihd.net/steam/apps/238...
# 2158   https://steamcdn-a.akamaihd.net/steam/apps/245...
# 2176   https://steamcdn-a.akamaihd.net/steam/apps/246...
# 2200   https://steamcdn-a.akamaihd.net/steam/apps/247...
# 2212   https://steamcdn-a.akamaihd.net/steam/apps/248...
# 2219   https://steamcdn-a.akamaihd.net/steam/apps/248...
# 2246   https://steamcdn-a.akamaihd.net/steam/apps/249...
# 2253   https://steamcdn-a.akamaihd.net/steam/apps/250...
# 2361   https://steamcdn-a.akamaihd.net/steam/apps/253...
# 2376   https://steamcdn-a.akamaihd.net/steam/apps/253...
# ...                                                  ...
# 12673  https://steamcdn-a.akamaihd.net/steam/apps/547...
# 13297  https://steamcdn-a.akamaihd.net/steam/apps/563...
# 13548  https://steamcdn-a.akamaihd.net/steam/apps/569...
# 13861  https://steamcdn-a.akamaihd.net/steam/apps/577...
# 14054  https://steamcdn-a.akamaihd.net/steam/apps/582...
# 14193  https://steamcdn-a.akamaihd.net/steam/apps/586...
# 15146  https://steamcdn-a.akamaihd.net/steam/apps/613...
# 15630  https://steamcdn-a.akamaihd.net/steam/apps/628...
# 15892  https://steamcdn-a.akamaihd.net/steam/apps/637...
# 15915  https://steamcdn-a.akamaihd.net/steam/apps/638...
# 15936  https://steamcdn-a.akamaihd.net/steam/apps/639...
# 16943  https://steamcdn-a.akamaihd.net/steam/apps/667...
# 17053  https://steamcdn-a.akamaihd.net/steam/apps/670...
# 17107  https://steamcdn-a.akamaihd.net/steam/apps/671...
# 17231  https://steamcdn-a.akamaihd.net/steam/apps/674...
# 18168  https://steamcdn-a.akamaihd.net/steam/apps/697...
# 18393  https://steamcdn-a.akamaihd.net/steam/apps/703...
# 18495  https://steamcdn-a.akamaihd.net/steam/apps/705...
# 18870  https://steamcdn-a.akamaihd.net/steam/apps/715...
# 21014  https://steamcdn-a.akamaihd.net/steam/apps/773...
# 21826  https://steamcdn-a.akamaihd.net/steam/apps/794...
# 22717  https://steamcdn-a.akamaihd.net/steam/apps/819...
# 23161  https://steamcdn-a.akamaihd.net/steam/apps/833...
# 23456  https://steamcdn-a.akamaihd.net/steam/apps/841...
# 24827  https://steamcdn-a.akamaihd.net/steam/apps/878...
# 25070  https://steamcdn-a.akamaihd.net/steam/apps/886...
# 27049  https://steamcdn-a.akamaihd.net/steam/apps/955...
# 27895  https://steamcdn-a.akamaihd.net/steam/apps/987...
# 28090  https://steamcdn-a.akamaihd.net/steam/apps/996...
# 28244  https://steamcdn-a.akamaihd.net/steam/apps/100...
#
#                                      content_descriptors  price  english  \
# 67                            {'ids': [], 'notes': None}   3.99        1
# 68                            {'ids': [], 'notes': None}   0.00        1
# 190                           {'ids': [], 'notes': None}   2.79        1
# 385                           {'ids': [], 'notes': None}   6.99        1
# 451                           {'ids': [], 'notes': None}   7.19        1
# 478                           {'ids': [], 'notes': None}   0.00        1
# 623                           {'ids': [], 'notes': None}   4.79        1
# 657                           {'ids': [], 'notes': None}   3.99        1
# 894                           {'ids': [], 'notes': None}  10.99        1
# 1039                          {'ids': [], 'notes': None}   7.99        1
# 1138                          {'ids': [], 'notes': None}   6.99        1
# 1183                          {'ids': [], 'notes': None}   3.99        1
# 1307                          {'ids': [], 'notes': None}   7.99        1
# 1329                          {'ids': [], 'notes': None}   6.99        1
# 1332                          {'ids': [], 'notes': None}   3.99        1
# 1348                          {'ids': [], 'notes': None}   3.99        1
# 1369                          {'ids': [], 'notes': None}   3.99        1
# 1486                          {'ids': [], 'notes': None}   6.99        1
# 1749                          {'ids': [], 'notes': None}   3.99        1
# 1839                          {'ids': [], 'notes': None}   0.00        1
# 2033                          {'ids': [], 'notes': None}   6.99        1
# 2158                          {'ids': [], 'notes': None}   7.19        1
# 2176                          {'ids': [], 'notes': None}   1.99        1
# 2200                          {'ids': [], 'notes': None}   3.99        1
# 2212                          {'ids': [], 'notes': None}   3.99        1
# 2219                          {'ids': [], 'notes': None}  14.99        1
# 2246                          {'ids': [], 'notes': None}  11.39        1
# 2253                          {'ids': [], 'notes': None}   6.99        1
# 2361                          {'ids': [], 'notes': None}   7.19        1
# 2376                          {'ids': [], 'notes': None}  14.99        1
# ...                                                  ...    ...      ...
# 12673                         {'ids': [], 'notes': None}   5.59        1
# 13297                         {'ids': [], 'notes': None}   3.99        1
# 13548                         {'ids': [], 'notes': None}   3.99        1
# 13861                         {'ids': [], 'notes': None}   1.59        1
# 14054                         {'ids': [], 'notes': None}   7.19        1
# 14193                         {'ids': [], 'notes': None}   0.79        1
# 15146                         {'ids': [], 'notes': None}   0.00        1
# 15630                         {'ids': [], 'notes': None}   5.19        1
# 15892                         {'ids': [], 'notes': None}   5.19        1
# 15915                         {'ids': [], 'notes': None}  14.99        1
# 15936                         {'ids': [], 'notes': None}   0.00        1
# 16943                         {'ids': [], 'notes': None}  15.49        1
# 17053                         {'ids': [], 'notes': None}   2.09        1
# 17107  {'ids': [1, 2, 5], 'notes': "WARNING:  Game fe...   6.99        1
# 17231                         {'ids': [], 'notes': None}   7.19        1
# 18168                         {'ids': [], 'notes': None}   0.79        1
# 18393                         {'ids': [], 'notes': None}  11.39        1
# 18495  {'ids': [1, 2, 5], 'notes': 'This game has nud...   7.99        1
# 18870                         {'ids': [], 'notes': None}   0.79        1
# 21014                         {'ids': [], 'notes': None}   0.00        1
# 21826                         {'ids': [], 'notes': None}  15.99        1
# 22717                         {'ids': [], 'notes': None}   2.89        1
# 23161                         {'ids': [], 'notes': None}   2.89        1
# 23456                         {'ids': [], 'notes': None}   1.69        1
# 24827                         {'ids': [], 'notes': None}   1.99        1
# 25070                         {'ids': [], 'notes': None}   7.19        1
# 27049  {'ids': [2, 5], 'notes': 'This Game may contai...   5.19        1
# 27895                  {'ids': [2, 5], 'notes': 'Blood'}   0.00        1
# 28090                         {'ids': [], 'notes': None}   3.99        1
# 28244                         {'ids': [], 'notes': None}   7.19        1
#
#                              developer publisher
# 67                      Elephant Games       NaN
# 68                           Freegamer       NaN
# 190                         R C Knight       NaN
# 385                     Dylan Fitterer       NaN
# 451                       Queasy Games       NaN
# 478                         Puny Human       NaN
# 623                     Lazy 8 Studios       NaN
# 657                     Telltale Games       NaN
# 894                          Team Meat       NaN
# 1039                       Nitro Games       NaN
# 1138                       Hitbox Team       NaN
# 1183                            Joshyy       NaN
# 1307                      Recoil Games       NaN
# 1329                 Creat Studios Inc       NaN
# 1332             Swing Swing Submarine       NaN
# 1348                     Eclipse Games       NaN
# 1369                   Iridium Studios       NaN
# 1486              Tindalos Interactive       NaN
# 1749           Denis Galanin (mif2000)       NaN
# 1839             Reverie World Studios       NaN
# 2033                 Robot Loves Kitty       NaN
# 2158                  Orthogonal Games       NaN
# 2176                      Greg Lobanov       NaN
# 2200                    Hashbang Games       NaN
# 2212                    Filament Games       NaN
# 2219                   Firedance Games       NaN
# 2246                Priority Interrupt       NaN
# 2253                       Geeta Games       NaN
# 2361             Reverie World Studios       NaN
# 2376                    Worthless Bums       NaN
# ...                                ...       ...
# 12673                  Peak Angle Team       NaN
# 13297                     Obscura Team       NaN
# 13548                   Little Big Lee       NaN
# 13861                  Warfare Studios       NaN
# 14054        Nikita Markin;Artem Basko       NaN
# 14193                        Camagames       NaN
# 15146                            Valve       NaN
# 15630                      Iron Monkey       NaN
# 15892                           Nemega       NaN
# 15915          Animallica Games Studio       NaN
# 15936                       Binary Zoo       NaN
# 16943                     Oliver Chime       NaN
# 17053                              WRD       NaN
# 17107                  X-MiGuPLAY, LLC       NaN
# 17231                      TerkStudios       NaN
# 18168                      Candy Smith       NaN
# 18393                              Che       NaN
# 18495                  X-MiGuPLAY, LLC       NaN
# 18870                    vadimalexepta       NaN
# 21014                           spleen       NaN
# 21826                            eSail       NaN
# 22717                     Nick Cellini       NaN
# 23161                   GamingVNetwork       NaN
# 23456                       Binary Zoo       NaN
# 24827                          Deothic       NaN
# 25070                  Bootsmann Games       NaN
# 27049                      FYQD-Studio       NaN
# 27895                             Moka       NaN
# 28090  Petar Markovich;James Arkwright       NaN
# 28244                       Jason Free       NaN
#
# [146 rows x 25 columns]

# %% [markdown]
# ## Processing Achievements and Content Descriptors
#
# The final two columns we will take care of in this section are `achievements` and `content_descriptors`. Let's take a look at the null counts for each column and a small sample of rows.

# %%
print('Achievements null counts:', steam_data['achievements'].isnull().sum())
print('Content Decsriptors null counts:', steam_data['content_descriptors'].isnull().sum())

steam_data[['name', 'achievements', 'content_descriptors']].iloc[8:13]
# Out:
# Achievements null counts: 1946
# Content Decsriptors null counts: 0
#                       name                                       achievements  \
# 8    Half-Life: Blue Shift                                       {'total': 0}
# 9              Half-Life 2  {'total': 33, 'highlighted': [{'name': 'Defian...
# 10  Counter-Strike: Source  {'total': 147, 'highlighted': [{'name': 'Someo...
# 11       Half-Life: Source                                       {'total': 0}
# 12   Day of Defeat: Source  {'total': 54, 'highlighted': [{'name': 'Double...
#
#                                   content_descriptors
# 8                          {'ids': [], 'notes': None}
# 9                          {'ids': [], 'notes': None}
# 10  {'ids': [2, 5], 'notes': 'Includes intense vio...
# 11                         {'ids': [], 'notes': None}
# 12                         {'ids': [], 'notes': None}

# %% [markdown]
# It looks like both columns are stored as dictionaries, with standard formats if no details are provided or exist.
#
# Below we take a closer look at a single row from the achievements column.

# %%
literal_eval(steam_data['achievements'][9])
# Out:
# {'total': 33,
#  'highlighted': [{'name': 'Defiant',
#    'path': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/apps/220/hl2_hit_cancop_withcan.jpg'},
#   {'name': 'Submissive',
#    'path': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/apps/220/hl2_put_canintrash.jpg'},
#   {'name': 'Malcontent',
#    'path': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/apps/220/hl2_escape_apartmentraid.jpg'},
#   {'name': 'What cat?',
#    'path': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/apps/220/hl2_break_miniteleporter.jpg'},
#   {'name': 'Trusty Hardware',
#    'path': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/apps/220/hl2_get_crowbar.jpg'},
#   {'name': 'Barnacle Bowling',
#    'path': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/apps/220/hl2_kill_barnacleswithbarrel.jpg'},
#   {'name': "Anchor's Aweigh!",
#    'path': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/apps/220/hl2_get_airboat.jpg'},
#   {'name': 'Heavy Weapons',
#    'path': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/apps/220/hl2_get_airboatgun.jpg'},
#   {'name': 'Vorticough',
#    'path': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/apps/220/hl2_find_vortigauntcave.jpg'},
#   {'name': 'Revenge!',
#    'path': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/apps/220/hl2_kill_chopper.jpg'}]}

# %% [markdown]
# There are two keys in the top level of the dictionary: `total` and `highlighted`. The highlighted column looks too specific, being a selection of achievements specific to that game, so we will remove it. It may be worthwhile extracting the `total` value though.
#
# Now let's take a look at the `content_descriptors` column.

# %%
steam_data['content_descriptors'].value_counts().head(10)
# Out:
# {'ids': [], 'notes': None}                                                                                                                                                                    25943
# {'ids': [2, 5], 'notes': None}                                                                                                                                                                  428
# {'ids': [1, 5], 'notes': None}                                                                                                                                                                  253
# {'ids': [5], 'notes': None}                                                                                                                                                                     128
# {'ids': [1, 2, 5], 'notes': None}                                                                                                                                                               122
# {'ids': [2, 5], 'notes': 'This Game may contain content not appropriate for all ages, or may not be appropriate for viewing at work: Frequent Violence or Gore, General Mature Content'}          8
# {'ids': [2, 5], 'notes': 'Includes intense violence and blood.'}                                                                                                                                  7
# {'ids': [1, 5], 'notes': 'Our game has erotic content - girls in it get undressed during the session.'}                                                                                           6
# {'ids': [1, 3, 5], 'notes': 'This Game may contain content not appropriate for all ages, or may not be appropriate for viewing at work: Nudity or Sexual Content, General Mature Content'}        5
# {'ids': [1, 5], 'notes': 'This Game may contain content not appropriate for all ages, or may not be appropriate for viewing at work: Nudity or Sexual Content, General Mature Content'}           5
# Name: content_descriptors, dtype: int64

# %% [markdown]
# Content descriptors contain age-related warnings about the content of a game. They are identified by a numeric ID number, with optional notes supplied. Almost 26,000 rows have an empty list, indicating either no content descriptors or none provided. Because of this, and because the rows are highly specific to each game, we will drop this column entirely.
#
# Let's now define a function.

# %%
def process_achievements_and_descriptors(df):
    """Parse as total number of achievements."""
    df = df.copy()
    
    df = df.drop('content_descriptors', axis=1)
    
    def parse_achievements(x):
        try:
            return literal_eval(x)['total']
        except ValueError:
            # handle missing values
            if np.isnan(x):
                return 0
            else:
                # safety in case of other problem
                print(x)
        
    df['achievements'] = df['achievements'].apply(parse_achievements)
    
    return df


def process(df):
    """Process data set. Will eventually contain calls to all functions we write."""
    
    # Copy the input dataframe to avoid accidentally modifying original data
    df = df.copy()
    
    # Remove duplicate rows - all appids should be unique
    df = df.drop_duplicates()
    
    # Remove collumns with more than 50% null values
    df = drop_null_cols(df)
    
    # Process rest of columns
    df = process_name_type(df)
    df = process_age(df)
    df = process_platforms(df)
    df = process_price(df)
    df = process_language(df)
    df = process_developers_and_publishers(df)
    df = process_achievements_and_descriptors(df)
    
    return df


steam_data = process(raw_steam_data)
steam_data[['name', 'achievements']].head()
# Out:
#                         name  achievements
# 0             Counter-Strike             0
# 1      Team Fortress Classic             0
# 2              Day of Defeat             0
# 3         Deathmatch Classic             0
# 4  Half-Life: Opposing Force             0

# %% [markdown]
# We know that the first few rows have 0 total achievements so that's fine, but let's take a look at the value counts to verify everything went as expected.

# %%
with pd.option_context("display.max_rows", 12):
    display(steam_data['achievements'].value_counts().sort_index())
# Out:
# 0       12494
# 1         272
# 2         102
# 3         143
# 4         215
# 5         373
#         ...
# 4996        1
# 4997        1
# 4999        1
# 5000       96
# 5394        1
# 9821        1
# Name: achievements, Length: 411, dtype: int64

# %% [markdown]
# It looks like we were successful. We'll leave this column as it is for now, however we may wish to consider grouping the values together in bins, like we did for the age column. This is a decision we can make during the feature engineering stage of our analysis, and we can decide at that point if it will be more useful.

# %% [markdown]
# ## Export Partially Clean Data
#
# As I said at the beginning, data cleaning is a lengthy process. Already this part is more than long enough, and there's still plenty more to do. In the next part we'll take care of most of the remaining columns, and we'll be exporting a bunch of data too.
#
# Before we wrap up, let's take a look at the current state of the data, then export it ready to continue in part 2.

# %%
steam_data.head()
# Out:
#                         name  steam_appid required_age  \
# 0             Counter-Strike           10            0
# 1      Team Fortress Classic           20            0
# 2              Day of Defeat           30            0
# 3         Deathmatch Classic           40            0
# 4  Half-Life: Opposing Force           50            0
#
#                                 detailed_description  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                       about_the_game  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                    short_description  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                         header_image  \
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...
#
#                        website  \
# 0                          NaN
# 1                          NaN
# 2  http://www.dayofdefeat.com/
# 3                          NaN
# 4                          NaN
#
#                                      pc_requirements  \
# 0  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 1  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 2  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 3  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 4  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
#
#                                     mac_requirements  \
# 0  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 1  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 2  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 3  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 4  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
#
#                                   linux_requirements          platforms  \
# 0  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...  windows;mac;linux
# 1  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...  windows;mac;linux
# 2  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...  windows;mac;linux
# 3  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...  windows;mac;linux
# 4  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...  windows;mac;linux
#
#                                           categories  \
# 0  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 1  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 2  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 3  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 4  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                    genres  \
# 0  [{'id': '1', 'description': 'Action'}]
# 1  [{'id': '1', 'description': 'Action'}]
# 2  [{'id': '1', 'description': 'Action'}]
# 3  [{'id': '1', 'description': 'Action'}]
# 4  [{'id': '1', 'description': 'Action'}]
#
#                                          screenshots movies  achievements  \
# 0  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             0
# 1  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             0
# 2  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             0
# 3  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             0
# 4  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             0
#
#                                     release_date  \
# 0  {'coming_soon': False, 'date': '1 Nov, 2000'}
# 1  {'coming_soon': False, 'date': '1 Apr, 1999'}
# 2  {'coming_soon': False, 'date': '1 May, 2003'}
# 3  {'coming_soon': False, 'date': '1 Jun, 2001'}
# 4  {'coming_soon': False, 'date': '1 Nov, 1999'}
#
#                                         support_info  \
# 0  {'url': 'http://steamcommunity.com/app/10', 'e...
# 1                           {'url': '', 'email': ''}
# 2                           {'url': '', 'email': ''}
# 3                           {'url': '', 'email': ''}
# 4  {'url': 'https://help.steampowered.com', 'emai...
#
#                                           background  price  english  \
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...   7.19        1
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...   3.99        1
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...   3.99        1
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...   3.99        1
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...   3.99        1
#
#           developer publisher
# 0             Valve     Valve
# 1             Valve     Valve
# 2             Valve     Valve
# 3             Valve     Valve
# 4  Gearbox Software     Valve

# %%
steam_data.isnull().sum()
# Out:
# name                       0
# steam_appid                0
# required_age               0
# detailed_description      14
# about_the_game            14
# short_description         14
# header_image               0
# website                 9531
# pc_requirements            0
# mac_requirements           0
# linux_requirements         0
# platforms                  0
# categories               511
# genres                    38
# screenshots                5
# movies                  1782
# achievements               0
# release_date               0
# support_info               0
# background                 5
# price                      0
# english                    0
# developer                  0
# publisher                146
# dtype: int64

# %%
steam_data.to_csv('../data/exports/steam_clean_part_1.csv', index=False)

# %% [markdown]
# # Steam Data Cleaning (Part 2)
#
# *This is part of a larger series of notebooks on downloading, processing and analysing data from the steam store. [See all notebooks here.](../notebooks)*
#
# See https://github.com/jbwhit/OSCON-2015/blob/master/develop/2015-07-16-jw-example-notebook-setup.ipynb for local imports

# %%
# load extensions and magics

# http://raw.github.com/jrjohansson/version_information/master/version_information.py
# %load_ext version_information
# %reload_ext version_information

# %version_information numpy, pandas
# Out:
# Software versions
# Python 3.7.3 64bit [MSC v.1900 64 bit (AMD64)]
# IPython 7.5.0
# OS Windows 10 10.0.17763 SP0
# numpy 1.16.3
# pandas 0.24.2
# Mon Jun 03 15:52:33 2019 GMT Summer Time

# %% [markdown]
# # Exports
#
# **TODO**: genre and categories section writeup
#
# Welcome back to the second part in this Steam data cleaning series. Last time we (...)

# %%
# standard library imports
from ast import literal_eval
import itertools
import time
import re

# third-party imports
import numpy as np
import pandas as pd

# customisations
pd.set_option("max_columns", 100)

# %% [markdown]
# ## Import and Inspect Data
#
# Continuing from before, import and inspect data.

# %%
imported_steam_data = pd.read_csv('../data/exports/steam_clean_part_1.csv')

print('Rows:', imported_steam_data.shape[0])
print('Columns:', imported_steam_data.shape[1])
imported_steam_data.head()
# Out:
# Rows: 28114
# Columns: 24
#                         name  steam_appid  required_age  \
# 0             Counter-Strike           10             0
# 1      Team Fortress Classic           20             0
# 2              Day of Defeat           30             0
# 3         Deathmatch Classic           40             0
# 4  Half-Life: Opposing Force           50             0
#
#                                 detailed_description  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                       about_the_game  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                    short_description  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                         header_image  \
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...
#
#                        website  \
# 0                          NaN
# 1                          NaN
# 2  http://www.dayofdefeat.com/
# 3                          NaN
# 4                          NaN
#
#                                      pc_requirements  \
# 0  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 1  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 2  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 3  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 4  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
#
#                                     mac_requirements  \
# 0  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 1  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 2  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 3  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 4  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
#
#                                   linux_requirements          platforms  \
# 0  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...  windows;mac;linux
# 1  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...  windows;mac;linux
# 2  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...  windows;mac;linux
# 3  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...  windows;mac;linux
# 4  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...  windows;mac;linux
#
#                                           categories  \
# 0  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 1  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 2  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 3  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 4  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                    genres  \
# 0  [{'id': '1', 'description': 'Action'}]
# 1  [{'id': '1', 'description': 'Action'}]
# 2  [{'id': '1', 'description': 'Action'}]
# 3  [{'id': '1', 'description': 'Action'}]
# 4  [{'id': '1', 'description': 'Action'}]
#
#                                          screenshots movies  achievements  \
# 0  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             0
# 1  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             0
# 2  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             0
# 3  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             0
# 4  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             0
#
#                                     release_date  \
# 0  {'coming_soon': False, 'date': '1 Nov, 2000'}
# 1  {'coming_soon': False, 'date': '1 Apr, 1999'}
# 2  {'coming_soon': False, 'date': '1 May, 2003'}
# 3  {'coming_soon': False, 'date': '1 Jun, 2001'}
# 4  {'coming_soon': False, 'date': '1 Nov, 1999'}
#
#                                         support_info  \
# 0  {'url': 'http://steamcommunity.com/app/10', 'e...
# 1                           {'url': '', 'email': ''}
# 2                           {'url': '', 'email': ''}
# 3                           {'url': '', 'email': ''}
# 4  {'url': 'https://help.steampowered.com', 'emai...
#
#                                           background  price  english  \
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...   7.19        1
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...   3.99        1
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...   3.99        1
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...   3.99        1
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...   3.99        1
#
#           developer publisher
# 0             Valve     Valve
# 1             Valve     Valve
# 2             Valve     Valve
# 3             Valve     Valve
# 4  Gearbox Software     Valve

# %% [markdown]
# Look at the null count to see how we're doing after the first round of cleaning.

# %%
imported_steam_data.isnull().sum()
# Out:
# name                       0
# steam_appid                0
# required_age               0
# detailed_description      14
# about_the_game            14
# short_description         14
# header_image               0
# website                 9531
# pc_requirements            0
# mac_requirements           0
# linux_requirements         0
# platforms                  0
# categories               511
# genres                    38
# screenshots                5
# movies                  1782
# achievements               0
# release_date               0
# support_info               0
# background                 5
# price                      0
# english                    0
# developer                  0
# publisher                158
# dtype: int64

# %% [markdown]
# Strangely, just by exporting to and importing from csv, 12 null values have appeared in the publisher column. Let's take a look at a couple of these rows, by looking at them in the original, raw data.

# %%
raw_data = pd.read_csv('../data/raw/steam_app_data.csv')

raw_data[['name', 'steam_appid', 'publishers']][(raw_data['publishers'] == "['N/A']") | (raw_data['publishers'] == "['NA']")]
# Out:
#                                     name  steam_appid publishers
# 4860                                Alum       338420    ['N/A']
# 5431                      Scribble Space       351450    ['N/A']
# 5949                       Freshman Year       364450    ['N/A']
# 7676                              Cibele       408120    ['N/A']
# 8858                Fantasy Tales Online       442710     ['NA']
# 9895             Memoir En Code: Reissue       467940    ['N/A']
# 12663  The Morgue Fissure Between Worlds       547150    ['N/A']
# 14712                              Kimmy       600660    ['N/A']
# 14863                    Night of Terror       604200    ['N/A']
# 23124                     Negative World       832130    ['N/A']
# 26865           Journey Through Memories       948340    ['N/A']
# 27456                   Short Circuit VR       970800    ['N/A']

# %% [markdown]
# Interestingly, by handling the data as we did we exposed some hidden null values. Only by re-importing the data were they recognised as actual null values, rather than the 'N/A' string (or in one case, 'NA' string). When it comes to defining our `process` function, we'll drop these rows.
#
# Apart from that, it looks like all the null values are in columns we haven't yet cleaned, which is perfect.

# %% [markdown]
# ## Processing Description Columns
#
# We have a series of columns with descriptive text about each game: `detailed_description`, `about_the_game` and `short_description`. As the column names imply, these provide information about each game in string format. This is great for humans' understanding, but when it comes to machines is a lot trickier.
#
# These columns could be used as the basis for an interesting [recommender system](https://en.wikipedia.org/wiki/Recommender_system) or keyword analysis project, however they are not required in our current project. We'll be removing them as they likely take up large amounts of space, and will only serve to slow down our project.
#
# We'll inspect the columns anyway, in case we find anomalies, and also export just the description data to a separate file, in case we want to use it in a future investigation.

# %%
imported_steam_data[['detailed_description', 'about_the_game', 'short_description']].isnull().sum()
# Out:
# detailed_description    14
# about_the_game          14
# short_description       14
# dtype: int64

# %% [markdown]
# We have 14 rows with missing data for these columns, and chances are the 14 rows with missing `detailed_description` are the rows with missing `about_the_game` and `short_description` data too.
#
# By inspecting the individual rows below, we can see that this is true - all rows with missing data in one description column have missing data in the others as well.

# %%
imported_steam_data[imported_steam_data['detailed_description'].isnull()]
# Out:
#                         name  steam_appid  required_age detailed_description  \
# 92        Bejeweled 2 Deluxe         3300             0                  NaN
# 93            Chuzzle Deluxe         3310             0                  NaN
# 94      Insaniquarium Deluxe         3320             0                  NaN
# 96           AstroPop Deluxe         3340             0                  NaN
# 97          Bejeweled Deluxe         3350             0                  NaN
# 98         Big Money! Deluxe         3360             0                  NaN
# 99           Dynomite Deluxe         3380             0                  NaN
# 100  Feeding Frenzy 2 Deluxe         3390             0                  NaN
# 101      Hammer Heads Deluxe         3400             0                  NaN
# 103         Iggle Pop Deluxe         3420             0                  NaN
# 104      Pizza Frenzy Deluxe         3430             0                  NaN
# 105      Rocket Mania Deluxe         3440             0                  NaN
# 106      Typer Shark! Deluxe         3450             0                  NaN
# 107        Talismania Deluxe         3460             0                  NaN
#
#     about_the_game short_description  \
# 92             NaN               NaN
# 93             NaN               NaN
# 94             NaN               NaN
# 96             NaN               NaN
# 97             NaN               NaN
# 98             NaN               NaN
# 99             NaN               NaN
# 100            NaN               NaN
# 101            NaN               NaN
# 103            NaN               NaN
# 104            NaN               NaN
# 105            NaN               NaN
# 106            NaN               NaN
# 107            NaN               NaN
#
#                                           header_image website  \
# 92   https://steamcdn-a.akamaihd.net/steam/apps/330...     NaN
# 93   https://steamcdn-a.akamaihd.net/steam/apps/331...     NaN
# 94   https://steamcdn-a.akamaihd.net/steam/apps/332...     NaN
# 96   https://steamcdn-a.akamaihd.net/steam/apps/334...     NaN
# 97   https://steamcdn-a.akamaihd.net/steam/apps/335...     NaN
# 98   https://steamcdn-a.akamaihd.net/steam/apps/336...     NaN
# 99   https://steamcdn-a.akamaihd.net/steam/apps/338...     NaN
# 100  https://steamcdn-a.akamaihd.net/steam/apps/339...     NaN
# 101  https://steamcdn-a.akamaihd.net/steam/apps/340...     NaN
# 103  https://steamcdn-a.akamaihd.net/steam/apps/342...     NaN
# 104  https://steamcdn-a.akamaihd.net/steam/apps/343...     NaN
# 105  https://steamcdn-a.akamaihd.net/steam/apps/344...     NaN
# 106  https://steamcdn-a.akamaihd.net/steam/apps/345...     NaN
# 107  https://steamcdn-a.akamaihd.net/steam/apps/346...     NaN
#
#                                        pc_requirements  \
# 92   {'minimum': '<p><strong>Minimum Requirements:<...
# 93   {'minimum': '<p><strong>Minimum Requirements:<...
# 94   {'minimum': '<strong>Minimum Requirements:</st...
# 96   {'minimum': '<p><strong>Minimum Requirements:<...
# 97   {'minimum': '<p><strong>Minimum Requirements:<...
# 98   {'minimum': '<p><strong>Minimum Requirements:<...
# 99   {'minimum': '<p><strong>Minimum Requirements:<...
# 100  {'minimum': '<p><strong>Minimum Requirements:<...
# 101  {'minimum': '<p><strong>Minimum Requirements:<...
# 103  {'minimum': '<p><strong>Minimum Requirements:<...
# 104  {'minimum': '<p><strong>Minimum Requirements:<...
# 105  {'minimum': '<p><strong>Minimum Requirements:<...
# 106  {'minimum': '<p><strong>Minimum Requirements:<...
# 107  {'minimum': '<p><strong>Minimum Requirements:<...
#
#                                       mac_requirements linux_requirements  \
# 92   {'minimum': '<ul>\n\t<li><strong>OS:</strong> ...                 []
# 93   {'minimum': '<ul>\n\t<li><strong>OS:</strong> ...                 []
# 94                                                  []                 []
# 96                                                  []                 []
# 97                                                  []                 []
# 98                                                  []                 []
# 99                                                  []                 []
# 100                                                 []                 []
# 101                                                 []                 []
# 103                                                 []                 []
# 104                                                 []                 []
# 105                                                 []                 []
# 106                                                 []                 []
# 107                                                 []                 []
#
#        platforms                                   categories  \
# 92   windows;mac  [{'id': 2, 'description': 'Single-player'}]
# 93   windows;mac  [{'id': 2, 'description': 'Single-player'}]
# 94       windows  [{'id': 2, 'description': 'Single-player'}]
# 96       windows  [{'id': 2, 'description': 'Single-player'}]
# 97       windows  [{'id': 2, 'description': 'Single-player'}]
# 98       windows  [{'id': 2, 'description': 'Single-player'}]
# 99       windows  [{'id': 2, 'description': 'Single-player'}]
# 100      windows  [{'id': 2, 'description': 'Single-player'}]
# 101      windows  [{'id': 2, 'description': 'Single-player'}]
# 103      windows  [{'id': 2, 'description': 'Single-player'}]
# 104      windows  [{'id': 2, 'description': 'Single-player'}]
# 105      windows  [{'id': 2, 'description': 'Single-player'}]
# 106      windows  [{'id': 2, 'description': 'Single-player'}]
# 107      windows  [{'id': 2, 'description': 'Single-player'}]
#
#                                      genres  \
# 92   [{'id': '4', 'description': 'Casual'}]
# 93   [{'id': '4', 'description': 'Casual'}]
# 94   [{'id': '4', 'description': 'Casual'}]
# 96   [{'id': '4', 'description': 'Casual'}]
# 97   [{'id': '4', 'description': 'Casual'}]
# 98   [{'id': '4', 'description': 'Casual'}]
# 99   [{'id': '4', 'description': 'Casual'}]
# 100  [{'id': '4', 'description': 'Casual'}]
# 101  [{'id': '4', 'description': 'Casual'}]
# 103  [{'id': '4', 'description': 'Casual'}]
# 104  [{'id': '4', 'description': 'Casual'}]
# 105  [{'id': '4', 'description': 'Casual'}]
# 106  [{'id': '4', 'description': 'Casual'}]
# 107  [{'id': '4', 'description': 'Casual'}]
#
#                                            screenshots movies  achievements  \
# 92   [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             0
# 93   [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             0
# 94   [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             0
# 96   [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             0
# 97   [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             0
# 98   [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             0
# 99   [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             0
# 100  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             0
# 101  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             0
# 103  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             0
# 104  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             0
# 105  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             0
# 106  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             0
# 107  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             0
#
#                                        release_date              support_info  \
# 92   {'coming_soon': False, 'date': '30 Aug, 2006'}  {'url': '', 'email': ''}
# 93   {'coming_soon': False, 'date': '30 Aug, 2006'}  {'url': '', 'email': ''}
# 94   {'coming_soon': False, 'date': '30 Aug, 2006'}  {'url': '', 'email': ''}
# 96   {'coming_soon': False, 'date': '30 Aug, 2006'}  {'url': '', 'email': ''}
# 97   {'coming_soon': False, 'date': '30 Aug, 2006'}  {'url': '', 'email': ''}
# 98   {'coming_soon': False, 'date': '30 Aug, 2006'}  {'url': '', 'email': ''}
# 99   {'coming_soon': False, 'date': '30 Aug, 2006'}  {'url': '', 'email': ''}
# 100  {'coming_soon': False, 'date': '30 Aug, 2006'}  {'url': '', 'email': ''}
# 101  {'coming_soon': False, 'date': '30 Aug, 2006'}  {'url': '', 'email': ''}
# 103  {'coming_soon': False, 'date': '30 Aug, 2006'}  {'url': '', 'email': ''}
# 104  {'coming_soon': False, 'date': '30 Aug, 2006'}  {'url': '', 'email': ''}
# 105  {'coming_soon': False, 'date': '30 Aug, 2006'}  {'url': '', 'email': ''}
# 106  {'coming_soon': False, 'date': '30 Aug, 2006'}  {'url': '', 'email': ''}
# 107  {'coming_soon': False, 'date': '30 Aug, 2006'}  {'url': '', 'email': ''}
#
#                                             background  price  english  \
# 92   https://steamcdn-a.akamaihd.net/steam/apps/330...   4.25        1
# 93   https://steamcdn-a.akamaihd.net/steam/apps/331...   4.25        1
# 94   https://steamcdn-a.akamaihd.net/steam/apps/332...   4.25        1
# 96   https://steamcdn-a.akamaihd.net/steam/apps/334...   4.25        1
# 97   https://steamcdn-a.akamaihd.net/steam/apps/335...   4.25        1
# 98   https://steamcdn-a.akamaihd.net/steam/apps/336...   4.25        1
# 99   https://steamcdn-a.akamaihd.net/steam/apps/338...   4.25        1
# 100  https://steamcdn-a.akamaihd.net/steam/apps/339...   4.25        1
# 101  https://steamcdn-a.akamaihd.net/steam/apps/340...   4.25        1
# 103  https://steamcdn-a.akamaihd.net/steam/apps/342...   4.25        1
# 104  https://steamcdn-a.akamaihd.net/steam/apps/343...   4.25        1
# 105  https://steamcdn-a.akamaihd.net/steam/apps/344...   4.25        1
# 106  https://steamcdn-a.akamaihd.net/steam/apps/345...   4.25        1
# 107  https://steamcdn-a.akamaihd.net/steam/apps/346...   4.25        1
#
#               developer           publisher
# 92   PopCap Games, Inc.  PopCap Games, Inc.
# 93   PopCap Games, Inc.  PopCap Games, Inc.
# 94   PopCap Games, Inc.  PopCap Games, Inc.
# 96   PopCap Games, Inc.  PopCap Games, Inc.
# 97   PopCap Games, Inc.  PopCap Games, Inc.
# 98   PopCap Games, Inc.  PopCap Games, Inc.
# 99   PopCap Games, Inc.  PopCap Games, Inc.
# 100  PopCap Games, Inc.  PopCap Games, Inc.
# 101  PopCap Games, Inc.  PopCap Games, Inc.
# 103  PopCap Games, Inc.  PopCap Games, Inc.
# 104  PopCap Games, Inc.  PopCap Games, Inc.
# 105  PopCap Games, Inc.  PopCap Games, Inc.
# 106  PopCap Games, Inc.  PopCap Games, Inc.
# 107  PopCap Games, Inc.  PopCap Games, Inc.

# %% [markdown]
# Interestingly, all of these titles are games from 2006 developed and published by PopCap Games. My best guess is that they were developed previously and all added to the Steam store in one go after Valve allowed third-party titles.
#
# We'll remove these rows, as well as any with a description of less than 20 characters, like those below.

# %%
imported_steam_data[imported_steam_data['detailed_description'].str.len() <= 20]
# Out:
#                       name  steam_appid  required_age detailed_description  \
# 9883      Penguins Cretins       490990             0                  ...
# 19041            拼词游戏 2017       745840             0         带一点恐怖元素的休闲游戏
# 20982             God Test       797660             0             God Test
# 25149  В поисках Атлантиды       925640             0      Интересная игра
# 25281     东方百问~TouHouAsked       930840             0                 Null
#
#         about_the_game  short_description  \
# 9883               ...                ...
# 19041     带一点恐怖元素的休闲游戏  一款有一点恐怖元素的休闲益智游戏。
# 20982         God Test           God Test
# 25149  Интересная игра           Atlantis
# 25281             Null               Null
#
#                                             header_image  \
# 9883   https://steamcdn-a.akamaihd.net/steam/apps/490...
# 19041  https://steamcdn-a.akamaihd.net/steam/apps/745...
# 20982  https://steamcdn-a.akamaihd.net/steam/apps/797...
# 25149  https://steamcdn-a.akamaihd.net/steam/apps/925...
# 25281  https://steamcdn-a.akamaihd.net/steam/apps/930...
#
#                               website  \
# 9883                              NaN
# 19041                             NaN
# 20982                             NaN
# 25149  https://vk.com/atlantisforever
# 25281       https://asked.touhou.ren/
#
#                                          pc_requirements  \
# 9883   {'minimum': '<strong>Minimum:</strong><br><ul ...
# 19041  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 20982  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 25149  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 25281  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                         mac_requirements  \
# 9883   {'minimum': '<strong>Minimum:</strong><br><ul ...
# 19041  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 20982                                                 []
# 25149                                                 []
# 25281                                                 []
#
#                                       linux_requirements    platforms  \
# 9883   {'minimum': '<strong>Minimum:</strong><br><ul ...      windows
# 19041                                                 []  windows;mac
# 20982                                                 []      windows
# 25149                                                 []      windows
# 25281                                                 []      windows
#
#                                               categories  \
# 9883   [{'id': 2, 'description': 'Single-player'}, {'...
# 19041        [{'id': 2, 'description': 'Single-player'}]
# 20982  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 25149  [{'id': 2, 'description': 'Single-player'}, {'...
# 25281  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                                   genres  \
# 9883   [{'id': '1', 'description': 'Action'}, {'id': ...
# 19041  [{'id': '25', 'description': 'Adventure'}, {'i...
# 20982  [{'id': '1', 'description': 'Action'}, {'id': ...
# 25149  [{'id': '25', 'description': 'Adventure'}, {'i...
# 25281  [{'id': '4', 'description': 'Casual'}, {'id': ...
#
#                                              screenshots  \
# 9883   [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 19041  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 20982                                                NaN
# 25149  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 25281  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
#
#                                                   movies  achievements  \
# 9883                                                 NaN             0
# 19041  [{'id': 256699963, 'name': 'alpha', 'thumbnail...            11
# 20982                                                NaN             0
# 25149  [{'id': 256725871, 'name': 'Game', 'thumbnail'...             1
# 25281  [{'id': 256726640, 'name': 'TouHouAsked', 'thu...             2
#
#                                          release_date  \
# 9883   {'coming_soon': False, 'date': '22 Jun, 2016'}
# 19041  {'coming_soon': False, 'date': '29 Nov, 2017'}
# 20982  {'coming_soon': False, 'date': '18 Apr, 2018'}
# 25149   {'coming_soon': False, 'date': '1 Nov, 2018'}
# 25281   {'coming_soon': False, 'date': '7 Oct, 2018'}
#
#                                             support_info  \
# 9883        {'url': '', 'email': 'support@hfmgames.net'}
# 19041            {'url': '', 'email': '12668934@qq.com'}
# 20982  {'url': '', 'email': 'insanegamedev@outlook.com'}
# 25149  {'url': 'https://vk.com/atlantisforever', 'ema...
# 25281  {'url': 'https://asked.touhou.ren', 'email': '...
#
#                                               background  price  english  \
# 9883   https://steamcdn-a.akamaihd.net/steam/apps/490...   1.69        1
# 19041  https://steamcdn-a.akamaihd.net/steam/apps/745...   0.79        0
# 20982                                                NaN   0.00        1
# 25149  https://steamcdn-a.akamaihd.net/steam/apps/925...   1.69        0
# 25281  https://steamcdn-a.akamaihd.net/steam/apps/930...   0.79        0
#
#               developer         publisher
# 9883          HFM Games         HFM Games
# 19041          Mianwotu          Mianwotu
# 20982          God Test          God Test
# 25149         Dmitr Che         Dmitr Che
# 25281  Root Nine Studio  Root Nine Studio

# %% [markdown]
# To handle exporting the data to file, we'll write a reusable function which we can call upon for future columns. We will include the `steam_appid` column as it will allow us to match up these rows with rows in our primary data set later on, using a merge (like a join in SQL).

# %%
def export_data(df, filename, prefix='steam_', extension='.csv'):
    """Export dataframe to csv file, filename prepended with 'steam_'.
    
    filename : str without file extension
    """
    filepath = '../data/exports/' + prefix + filename + extension
    print_name = filename.replace('_', ' ')
    
    df.to_csv(filepath, index=False)
    
    print("Exported {} to '{}'".format(print_name, filepath))

# %% [markdown]
# We can now define a function to process and export the description columns. Notice we also remove the troublesome publisher rows.

# %%
def process_descriptions(df, export=False):
    """Export descriptions to external csv file then remove these columns."""
    # remove rows with missing description data
    df = df[df['detailed_description'].notnull()].copy()
    
    # remove rows with unusually small description
    df = df[df['detailed_description'].str.len() > 20]
    
    # by default we don't export, useful for calling function later
    if export:
        # create dataframe of description columns
        description_data = df[['steam_appid', 'detailed_description', 'about_the_game', 'short_description']]
        
        export_data(description_data, filename='description_data')
    
    # drop description columns from main dataframe
    df = df.drop(['detailed_description', 'about_the_game', 'short_description'], axis=1)
    
    return df


def process(df):
    """Process data set. Will eventually contain calls to all functions we write."""
    
    # drop rows with missing publisher and copy
    df = df[df['publisher'].notnull()].copy()
    
    # Process export columns
    df = process_descriptions(df, export=True)
    
    return df


steam_data = process(imported_steam_data)
# Out:
# Exported description data to '../data/exports/steam_description_data.csv'

# %%
# inspect exported data
pd.read_csv('../data/exports/steam_description_data.csv').head()
# Out:
#    steam_appid                               detailed_description  \
# 0           10  Play the world's number 1 online action game. ...
# 1           20  One of the most popular online action games of...
# 2           30  Enlist in an intense brand of Axis vs. Allied ...
# 3           40  Enjoy fast-paced multiplayer gaming with Death...
# 4           50  Return to the Black Mesa Research Facility as ...
#
#                                       about_the_game  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                    short_description
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...

# %% [markdown]
# ## Processing Media Columns
#
# Similar to the description columns, we have three columns that contain links to various images: `header_image`, `screenshots` and `background`. Whilst we won't be needing this data in this project, it could open the door to some interesting image analysis in the future. We will treat these columns in almost the same way, exporting the contents to a csv file then removing them from the dataset.
#
# Again, let's check for missing values.

# %%
image_cols = ['header_image', 'screenshots', 'background']

for col in image_cols:
    print(col+':', steam_data[col].isnull().sum())

steam_data[image_cols].head()
# Out:
# header_image: 0
# screenshots: 4
# background: 4
#                                         header_image  \
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...
#
#                                          screenshots  \
# 0  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 1  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 2  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 3  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 4  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
#
#                                           background
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...

# %% [markdown]
# As with the description columns, it is likely that the 4 rows with no `screenshots` data are the same rows with no `background` data. There are so few that it is probably safe to remove them.
#
# Before we make up our made let's inspect the rows in question. In part 1 of cleaning the data, we wrote a `print_steam_links` function to easily create links from a dataframe. To use it again, we could copy the code and define it here. Instead, we're going to use a handy trick in jupyter notebook. If we place the function in a separate python (.py) file inside the `src` folder, we can tell python to look there for local modules using `sys.path.append`. Next, we can import the function directly.

# %%
import sys
sys.path.append('../src/')

from datacleaning import print_steam_links

# %% [markdown]
# With the `print_steam_links` function now available, we can inspect the rows without screenshots. As we predicted, the rows without screenshots are also the rows without a background. It looks like two are unreleased, and if we'd dealt with the `release_date` column already these would already be removed. One was released recently (5 Jan, 2019), and perhaps didn't have screenshots at the time of downloading, and one simply doesn't have any. As we suspected, it's safe to remove all these rows.

# %%
no_screenshots = steam_data[steam_data['screenshots'].isnull()]

print_steam_links(no_screenshots)
no_screenshots
# Out:
# The Light Empire: https://store.steampowered.com/app/416220
# Girl and Goblin: https://store.steampowered.com/app/880510
# Arida: Backland's Awakening: https://store.steampowered.com/app/907760
# Nukalypse: The Final War: https://store.steampowered.com/app/947940
#                               name  steam_appid  required_age  \
# 7525              The Light Empire       416220             0
# 23832              Girl and Goblin       880510             0
# 24641  Arida: Backland's Awakening       907760             0
# 25769     Nukalypse: The Final War       947940             0
#
#                                             header_image  \
# 7525   https://steamcdn-a.akamaihd.net/steam/apps/416...
# 23832  https://steamcdn-a.akamaihd.net/steam/apps/880...
# 24641  https://steamcdn-a.akamaihd.net/steam/apps/907...
# 25769  https://steamcdn-a.akamaihd.net/steam/apps/947...
#
#                         website  \
# 7525                        NaN
# 23832                       NaN
# 24641  http://www.aridagame.com
# 25769                       NaN
#
#                                          pc_requirements  \
# 7525   {'minimum': '<strong>Minimum:</strong><br><ul ...
# 23832  {'minimum': '<strong>最低配置:</strong><br><ul cla...
# 24641  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 25769  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                         mac_requirements  \
# 7525                                                  []
# 23832                                                 []
# 24641  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 25769  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                       linux_requirements    platforms  \
# 7525                                                  []      windows
# 23832                                                 []      windows
# 24641  {'minimum': '<strong>Minimum:</strong><br><ul ...  windows;mac
# 25769  {'minimum': '<strong>Minimum:</strong><br><ul ...      windows
#
#                                               categories  \
# 7525   [{'id': 2, 'description': 'Single-player'}, {'...
# 23832  [{'id': 2, 'description': 'Single-player'}, {'...
# 24641  [{'id': 2, 'description': 'Single-player'}, {'...
# 25769  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                                   genres screenshots  \
# 7525   [{'id': '23', 'description': 'Indie'}, {'id': ...         NaN
# 23832  [{'id': '25', 'description': 'Adventure'}, {'i...         NaN
# 24641  [{'id': '25', 'description': 'Adventure'}, {'i...         NaN
# 25769  [{'id': '1', 'description': 'Action'}, {'id': ...         NaN
#
#                                                   movies  achievements  \
# 7525                                                 NaN             4
# 23832  [{'id': 256739772, 'name': '3', 'thumbnail': '...          1552
# 24641  [{'id': 256729551, 'name': 'Teaser Beta 2018',...             0
# 25769  [{'id': 256745274, 'name': 'Nukalypse: The Fin...             0
#
#                                         release_date  \
# 7525   {'coming_soon': False, 'date': '2 Dec, 2015'}
# 23832  {'coming_soon': False, 'date': '5 Jan, 2019'}
# 24641              {'coming_soon': True, 'date': ''}
# 25769      {'coming_soon': True, 'date': 'Oct 2019'}
#
#                                             support_info background  price  \
# 7525        {'url': '', 'email': 'Jemy.TLE@outlook.com'}        NaN   4.79
# 23832      {'url': '', 'email': 'smagician13@yahoo.com'}        NaN   0.79
# 24641  {'url': 'http://www.aridagame.com', 'email': '...        NaN   0.00
# 25769        {'url': '', 'email': 'nukalypse@gmail.com'}        NaN   0.00
#
#        english          developer          publisher
# 7525         1               Jemy               Jemy
# 23832        1       Inverse Game       Inverse Game
# 24641        1      Aoca Game Lab      Aoca Game Lab
# 25769        1  Zion Games Studio  Zion Games Studio

# %% [markdown]
# There is also a `movies` column with similar data. Whilst having more missing values, presumably for games without videos, it appears to contain names, thumbnails and links to various videos and trailers. It's unlikely we'll need them but we can include them in the export and remove them from our data set.

# %%
steam_data['movies'].isnull().sum()
# Out:
# 1746

# %%
with pd.option_context("display.max_colwidth", 1000):
    print(steam_data[steam_data['movies'].notnull()]['movies'].head(2))
# Out:
# 9                                                                                                                                                                                                                                                                                                                                                         [{'id': 904, 'name': 'Half-Life 2 Trailer', 'thumbnail': 'https://steamcdn-a.akamaihd.net/steam/apps/904/movie.jpg?t=1507237301', 'webm': {'480': 'http://steamcdn-a.akamaihd.net/steam/apps/904/movie480.webm?t=1507237301', 'max': 'http://steamcdn-a.akamaihd.net/steam/apps/904/movie_max.webm?t=1507237301'}, 'highlight': True}, {'id': 5724, 'name': 'Free Yourself', 'thumbnail': 'https://steamcdn-a.akamaihd.net/steam/apps/5724/movie.293x165.jpg?t=1507237311', 'webm': {'480': 'http://steamcdn-a.akamaihd.net/steam/apps/5724/movie480.webm?t=1507237311', 'max': 'http://steamcdn-a.akamaihd.net/steam/apps/5724/movie_max.webm?t=1507237311'}, 'highlight': False}]
# 16    [{'id': 915, 'name': 'HL2:EP1 Launch Teaser 4', 'thumbnail': 'https://steamcdn-a.akamaihd.net/steam/apps/915/movie.jpg?t=1512411168', 'webm': {'480': 'http://steamcdn-a.akamaihd.net/steam/apps/915/movie480.webm?t=1512411168', 'max': 'http://steamcdn-a.akamaihd.net/steam/apps/915/movie_max.webm?t=1512411168'}, 'highlight': False}, {'id': 914, 'name': 'HL2:EP1 Launch Teaser 3', 'thumbnail': 'https://steamcdn-a.akamaihd.net/steam/apps/914/movie.jpg?t=1512411159', 'webm': {'480': 'http://steamcdn-a.akamaihd.net/steam/apps/914/movie480.webm?t=1512411159', 'max': 'http://steamcdn-a.akamaihd.net/steam/apps/914/movie_max.webm?t=1512411159'}, 'highlight': False}, {'id': 912, 'name': 'HL2:EP1 Launch Teaser 1', 'thumbnail': 'https://steamcdn-a.akamaihd.net/steam/apps/912/movie.jpg?t=1512411140', 'webm': {'480': 'http://steamcdn-a.akamaihd.net/steam/apps/912/movie480.webm?t=1512411140', 'max': 'http://steamcdn-a.akamaihd.net/steam/apps/912/movie_max.webm?t=1512411140'}, 'highlight': False}, {'...
# Name: movies, dtype: object

# %% [markdown]
# We can now put this all together and define a `process_media` function, adding it in to `process` as before.

# %%
def process_media(df, export=False):
    """Remove media columns from dataframe, optionally exporting them to csv first."""
    df = df[df['screenshots'].notnull()].copy()
    
    if export:
        media_data = df[['steam_appid', 'header_image', 'screenshots', 'background', 'movies']]
        
        export_data(media_data, 'media_data')
        
    df = df.drop(['header_image', 'screenshots', 'background', 'movies'], axis=1)
    
    return df


def process(df):
    """Process data set. Will eventually contain calls to all functions we write."""
    
    # drop rows with missing publisher and copy
    df = df[df['publisher'].notnull()].copy()
    
    # Process export columns
    df = process_descriptions(df)
    df = process_media(df, export=True)
    
    return df


steam_data = process(imported_steam_data)
# Out:
# Exported media data to '../data/exports/steam_media_data.csv'

# %%
# inspect exported data
pd.read_csv('../data/exports/steam_media_data.csv').head()
# Out:
#    steam_appid                                       header_image  \
# 0           10  https://steamcdn-a.akamaihd.net/steam/apps/10/...
# 1           20  https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2           30  https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3           40  https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4           50  https://steamcdn-a.akamaihd.net/steam/apps/50/...
#
#                                          screenshots  \
# 0  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 1  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 2  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 3  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 4  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
#
#                                           background movies
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...    NaN
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...    NaN
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...    NaN
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...    NaN
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...    NaN

# %% [markdown]
# Before we move on, we can inspect the memory savings of removing these columns by comparing the output of the [DataFrame.info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.info.html) method. If we pass `memory_usage="deep"` we get the true memory usage of each DataFrame. Without this, pandas estimates the amount used. This is because of the way python stores object (string) columns under the hood. Essentially python keeps track of a list of pointers which point to the actual strings in memory. It's a bit like if you hid a bunch of items around the house, and kept a list of where everything was. You couldn't tell the total size of everything just by looking at the list, but you could take a rough guess. Only by following the list and inspecting each individual item could you get an exact figure.
#
# The blog post '[Why Python Is Slow](https://jakevdp.github.io/blog/2014/05/09/why-python-is-slow/)' goes into more detail, but all we need to be aware of is that by passing the parameter we ensure we get the true value of memory usage. We also pass `verbose=False` to truncate unnecessary output.
#
# We can see that already we have shrunk the memory usage from almost 300 MB to just under 60 MB. This is great because in general, the smaller the memory footprint the faster our code will run in future. And of course, we're not finished yet.

# %%
print('Imported Data:\n')
imported_steam_data.info(verbose=False, memory_usage="deep")

print('\nData with descriptions and media removed:\n')
steam_data.info(verbose=False, memory_usage="deep")
# Out:
# Imported Data:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28114 entries, 0 to 28113
# Columns: 24 entries, name to publisher
# dtypes: float64(1), int64(4), object(19)
# memory usage: 297.7 MB
#
# Data with descriptions and media removed:
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27933 entries, 0 to 28113
# Columns: 17 entries, name to publisher
# dtypes: float64(1), int64(4), object(12)
# memory usage: 60.3 MB

# %% [markdown]
# ## Website and Support Info
#
# Next we will look at the `website` and `support_info` columns. Seen below, they both contain links to external websites. The website column is simply stored as a string whereas the support info column is stored as a dictionary of `url` and `email`.
#
# There are a large number of rows with no website listed, and while there are no null values in the `support_info` column, it looks like many will have empty `url` and `email` values inside the data.
#
# For our dataset we'll be dropping both these columns, as they are far too specific to be useful in our analysis. As you may have guessed, we will extract and export this data as we have done before. If not useful, it could be interesting at a later date.

# %%
print('website null counts:', imported_steam_data['website'].isnull().sum())
print('support_info null counts:', imported_steam_data['support_info'].isnull().sum())

with pd.option_context("display.max_colwidth", 100): # ensures strings not cut short
    display(imported_steam_data[['name', 'website', 'support_info']][75:80])
# Out:
# website null counts: 9531
# support_info null counts: 0
#                       name  \
# 75             X3: Reunion
# 76     X3: Terran Conflict
# 77  X: Beyond the Frontier
# 78              X: Tension
# 79               X Rebirth
#
#                                                website  \
# 75         http://www.egosoft.com/games/x3/info_en.php
# 76       http://www.egosoft.com/games/x3tc/info_en.php
# 77          http://www.egosoft.com/games/x/info_en.php
# 78  http://www.egosoft.com/games/x_tension/info_en.php
# 79  http://www.egosoft.com/games/x_rebirth/info_en.php
#
#                                                                            support_info
# 75                                                             {'url': '', 'email': ''}
# 76                                             {'url': '', 'email': 'info@egosoft.com'}
# 77                                                             {'url': '', 'email': ''}
# 78                                                             {'url': '', 'email': ''}
# 79  {'url': 'http://www.egosoft.com/support/index_en.php', 'email': 'info@egosoft.com'}

# %% [markdown]
# We're going to split the support info into two separate columns. We'll keep all the code that parses the columns inside the export `if` statement, so it only runs if we wish to export to csv. We don't need to worry that the rows with missing website data contain `NaN` whereas the other two columns contain a blank string (`''`) for missing data, as once we have exported to csv they will be represented the same way.

# %%
def process_info(df, export=False):
    """Drop support information from dataframe, optionally exporting beforehand."""
    if export:
        support_info = df[['steam_appid', 'website', 'support_info']].copy()
        
        support_info['support_info'] = support_info['support_info'].apply(lambda x: literal_eval(x))
        support_info['support_url'] = support_info['support_info'].apply(lambda x: x['url'])
        support_info['support_email'] = support_info['support_info'].apply(lambda x: x['email'])
        
        support_info = support_info.drop('support_info', axis=1)
        
        support_info = support_info[(support_info['website'].notnull()) | (support_info['support_url'] != '') | (support_info['support_email'] != '')]

        export_data(support_info, 'support_info')
    
    df = df.drop(['website', 'support_info'], axis=1)
    
    return df


def process(df):
    """Process data set. Will eventually contain calls to all functions we write."""
    
    # drop rows with missing publisher and copy
    df = df[df['publisher'].notnull()].copy()
    
    # Process export columns
    df = process_descriptions(df)
    df = process_media(df)
    df = process_info(df, export=True)
    
    return df


steam_data = process(imported_steam_data)
# Out:
# Exported support info to '../data/exports/steam_support_info.csv'

# %%
# inspect exported file
pd.read_csv('../data/exports/steam_support_info.csv').head()
# Out:
#    steam_appid                      website                       support_url  \
# 0           10                          NaN  http://steamcommunity.com/app/10
# 1           30  http://www.dayofdefeat.com/                               NaN
# 2           50                          NaN     https://help.steampowered.com
# 3           70    http://www.half-life.com/  http://steamcommunity.com/app/70
# 4           80                          NaN  http://steamcommunity.com/app/80
#
#   support_email
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %% [markdown]
# ## System Requirements
#
# At first it looks like we have data for every row.

# %%
req_cols = ['pc_requirements', 'mac_requirements', 'linux_requirements']

print('null counts:\n')

for col in req_cols:
    print(col+':', steam_data[col].isnull().sum())
# Out:
# null counts:
#
# pc_requirements: 0
# mac_requirements: 0
# linux_requirements: 0

# %% [markdown]
# However if we look at the data a little more closely, we see that some rows actually have an empty list. These won't appear as null rows, but once evaluated these rows won't provide any information and are essentially useless to us, so can be thought of as such.

# %%
steam_data[['steam_appid', 'pc_requirements', 'mac_requirements', 'linux_requirements']].tail()
# Out:
#        steam_appid                                    pc_requirements  \
# 28109      1065230  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 28110      1065570  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 28111      1065650  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 28112      1066700  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 28113      1069460  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                         mac_requirements linux_requirements
# 28109                                                 []                 []
# 28110                                                 []                 []
# 28111                                                 []                 []
# 28112  {'minimum': '<strong>Minimum:</strong><br><ul ...                 []
# 28113  {'minimum': '<strong>Minimum:</strong><br><ul ...                 []

# %% [markdown]
# We can check how many rows in each requirements column have empty lists using a simple boolean filter. By checking the first value in the shape parameter, we can get a count for how many empty lists there are.

# %%
print('Empty list counts:\n')

for col in req_cols:
    print(col+':', steam_data[steam_data[col] == '[]'].shape[0])
# Out:
# Empty list counts:
#
# pc_requirements: 13
# mac_requirements: 16487
# linux_requirements: 19422

# %% [markdown]
# That's over half of the rows for both mac and linux requirements. That probably means that there is not enough data in these two columns to be useful for our analysis.
#
# It turns out most games are developed solely for windows, with the growth in mac and linux ports only growing in recent years. Naturally it would make sense that any games that aren't supported on mac or linux would not have corresponding requirements.
#
# As we have already cleaned our platforms column, we can check how many rows actually have missing data by comparing rows with empty lists in the requirements with data in the respective platform columns (mac/linux). If a row has an empty list in the requirements column but a 1 (True) in the platform column, it means the data is missing.

# %%
for col in ['mac_requirements', 'linux_requirements']:
    platform = col.split('_')[0]
    print(platform+':', steam_data[(steam_data[col] == '[]') & (steam_data['platforms'].str.contains(platform))].shape[0])
# Out:
# mac: 134
# linux: 155

# %% [markdown]
# Whilst not an insignificant number, this means that the vast majority of rows are as they should be, and we're not looking at too many data errors.
#
# Let's also have a look for missing values in the pc/windows column. We couldn't include it in our previous loop as the columns have different names, something we may wish to change later.

# %%
print('windows:', steam_data[(steam_data['pc_requirements'] == '[]') & (steam_data['platforms'].str.contains('windows'))].shape[0])
# Out:
# windows: 9

# %% [markdown]
# 11 rows have missing system requirements. We can take a look at some of them below, and follow the links to the steam pages to try and discover if anything is amiss.

# %%
missing_windows_requirements = steam_data[(steam_data['pc_requirements'] == '[]') & (steam_data['platforms'].str.contains('windows'))]

print_steam_links(missing_windows_requirements[:5])
missing_windows_requirements.head()
# Out:
# Uplink: https://store.steampowered.com/app/1510
# Battlestations: Midway: https://store.steampowered.com/app/6870
# Grand Theft Auto 2: https://store.steampowered.com/app/12180
# Shift 2 Unleashed: https://store.steampowered.com/app/47920
# iBomber Defense: https://store.steampowered.com/app/104000
#                         name  steam_appid  required_age pc_requirements  \
# 31                    Uplink         1510             0              []
# 191   Battlestations: Midway         6870             0              []
# 314       Grand Theft Auto 2        12180             0              []
# 931        Shift 2 Unleashed        47920             0              []
# 1165         iBomber Defense       104000             0              []
#
#      mac_requirements linux_requirements          platforms  \
# 31                 []                 []  windows;mac;linux
# 191                []                 []            windows
# 314                []                 []            windows
# 931                []                 []            windows
# 1165               []                 []        windows;mac
#
#                                              categories  \
# 31          [{'id': 2, 'description': 'Single-player'}]
# 191         [{'id': 2, 'description': 'Single-player'}]
# 314         [{'id': 2, 'description': 'Single-player'}]
# 931   [{'id': 2, 'description': 'Single-player'}, {'...
# 1165  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                                  genres  achievements  \
# 31    [{'id': '23', 'description': 'Indie'}, {'id': ...             0
# 191              [{'id': '1', 'description': 'Action'}]             0
# 314              [{'id': '1', 'description': 'Action'}]             0
# 931              [{'id': '9', 'description': 'Racing'}]             0
# 1165  [{'id': '23', 'description': 'Indie'}, {'id': ...            22
#
#                                         release_date  price  english  \
# 31    {'coming_soon': False, 'date': '23 Aug, 2006'}   6.99        1
# 191   {'coming_soon': False, 'date': '15 Mar, 2007'}   4.99        1
# 314    {'coming_soon': False, 'date': '4 Jan, 2008'}   0.00        1
# 931   {'coming_soon': False, 'date': '31 Mar, 2011'}  19.99        1
# 1165  {'coming_soon': False, 'date': '26 May, 2011'}   2.99        1
#
#                   developer              publisher
# 31    Introversion Software  Introversion Software
# 191       Eidos Interactive            Square Enix
# 314          Rockstar North         Rockstar Games
# 931    Slightly Mad Studios        Electronic Arts
# 1165           Cobra Mobile           Cobra Mobile

# %% [markdown]
# There doesn't appear to be any common issue in these rows - some of the games are quite old but that's about it. It may simply be that no requirements were supplied when the games were added to the steam store.
#
# Let's say that the fictional company we're doing analysis for is interested in developing for windows only. Also we can assume that a cross-platform game will have similar requirements in terms of hardware for each platform it supports. With this in mind we can safely drop both the mac and linux requirements columns, as we already know which games support these operating systems by our cleaned platform columns. That means we can focus on the pc_requirements column, which has information for almost every game in our data.
#
# Now we will take a look at a couple of rows from the dataset to see how the data is stored.

# %%
display(steam_data['pc_requirements'].iloc[0])
display(steam_data['pc_requirements'].iloc[2000])
display(steam_data['pc_requirements'].iloc[15000])
# Out:
# "{'minimum': '\\r\\n\\t\\t\\t<p><strong>Minimum:</strong> 500 mhz processor, 96mb ram, 16mb video card, Windows XP, Mouse, Keyboard, Internet Connection<br /></p>\\r\\n\\t\\t\\t<p><strong>Recommended:</strong> 800 mhz processor, 128mb ram, 32mb+ video card, Windows XP, Mouse, Keyboard, Internet Connection<br /></p>\\r\\n\\t\\t\\t'}"
# '{\'minimum\': \'<strong>Minimum:</strong><br><ul class="bb_ul"><li><strong>OS:</strong> Windows XP or higher<br></li><li><strong>Processor:</strong> 1 GHz<br></li><li><strong>Memory:</strong> 512 MB RAM<br></li><li><strong>Graphics:</strong> OpenGL compatible graphics chip<br></li><li><strong>Storage:</strong> 2 GB available space</li></ul>\'}'
# '{\'minimum\': \'<strong>Minimum:</strong><br><ul class="bb_ul"><li><strong>OS:</strong> Windows 10<br></li><li><strong>Processor:</strong> Intel Core i7<br></li><li><strong>Memory:</strong> 8 GB RAM<br></li><li><strong>Graphics:</strong> GTX 1070 or equivalent<br></li><li><strong>DirectX:</strong> Version 12<br></li><li><strong>Storage:</strong> 20 GB available space</li></ul>\'}'

# %% [markdown]
# In short: it's a mess. It looks like the data is stored as a dictionary, as we've seen before. There is definitely a key for 'minimum', but apart from that it is hard to see at a glance. The strings are full of html formatting, which is presumably parsed to display the information on the website. It also looks like there are different categories like Processor and Memory for some, but not all, rows.
#
# Let's take a stab and cleaning out some of the unnessecary formatting and see if it becomes clearer.
#
# By creating a dataframe from a selection of rows, we can easily and quickly make changes using the pandas .str accessor, allowing us to use python string formatting and regular expressions.

# %%
view_requirements = steam_data['pc_requirements'].iloc[[0, 2000, 15000]].copy()

view_requirements = (view_requirements
                         .str.replace(r'\\[rtn]', '')
                         .str.replace(r'<[pbr]{1,2}>', ' ')
                         .str.replace(r'<[\/"=\w\s]+>', '')
                    )

for i, row in view_requirements.iteritems():
    display(row)
# Out:
# "{'minimum': ' Minimum: 500 mhz processor, 96mb ram, 16mb video card, Windows XP, Mouse, Keyboard, Internet Connection Recommended: 800 mhz processor, 128mb ram, 32mb+ video card, Windows XP, Mouse, Keyboard, Internet Connection'}"
# "{'minimum': 'Minimum: OS: Windows XP or higher Processor: 1 GHz Memory: 512 MB RAM Graphics: OpenGL compatible graphics chip Storage: 2 GB available space'}"
# "{'minimum': 'Minimum: OS: Windows 10 Processor: Intel Core i7 Memory: 8 GB RAM Graphics: GTX 1070 or equivalent DirectX: Version 12 Storage: 20 GB available space'}"

# %% [markdown]
# We can now see more clearly the contents and structure of these rows. Some rows have both Minimum and Recommended requirements inside a 'minimum' key, some have separate 'minimum' and 'recommended' keys. Some have headings like 'Processor:' and 'Storage:' before various components, others simply have a list of components. Some state particular speeds for components, like 2 Ghz CPU, others state specific models, like 'Intel Core 2 Duo', amongst this information.
#
# It seems like it would be possible to extract invidivual component information from this data, however it would be a lengthy and complex process recquiring the handling of many exceptions and invididual cases. Whilst we may wish to tackle this in the future, as it could provide an interesting window into how the demands of gaming have changed over the years, it won't necessarily provide us with useful information for our current objectives.
#
# With that in mind, it seems best to proceed by cleaning the data slightly so it is readable, exporting to an external csv for future use, then removing the columns from our dataframe.

# %%
def process_requirements(df, export=False):
    if export:
        requirements = df[['steam_appid', 'pc_requirements']].copy()
        
        requirements = requirements[requirements['pc_requirements'] != '[]']
        
        requirements['requirements_clean'] = (requirements['pc_requirements']
                                                  .str.replace(r'\\[rtn]', '')
                                                  .str.replace(r'<[pbr]{1,2}>', ' ')
                                                  .str.replace(r'<[\/"=\w\s]+>', '')
                                             )
        
        requirements['requirements_clean'] = requirements['requirements_clean'].apply(lambda x: literal_eval(x))
        
        requirements['minimum'] = requirements['requirements_clean'].apply(lambda x: x['minimum'].replace('Minimum:', '').strip() if 'minimum' in x.keys() else np.nan)
        requirements['recommended'] = requirements['requirements_clean'].apply(lambda x: x['recommended'].replace('Recommended:', '').strip() if 'recommended' in x.keys() else np.nan)
        
        requirements = requirements.drop('requirements_clean', axis=1)
        
        export_data(requirements, 'requirements_data')
        
    df = df.drop(['pc_requirements', 'mac_requirements', 'linux_requirements'], axis=1)
    
    return df

def process(df):
    """Process data set. Will eventually contain calls to all functions we write."""
    
    # drop rows with missing publisher and copy
    df = df[df['publisher'].notnull()].copy()
    
    # Process export columns
    df = process_descriptions(df)
    df = process_media(df)
    df = process_info(df)
    df = process_requirements(df, export=True)
    
    return df


steam_data = process(imported_steam_data)
# Out:
# Exported requirements data to '../data/exports/steam_requirements_data.csv'

# %%
# verify export
pd.read_csv('../data/exports/steam_requirements_data.csv').head()
# Out:
#    steam_appid                                    pc_requirements  \
# 0           10  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 1           20  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 2           30  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 3           40  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 4           50  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
#
#                                              minimum recommended
# 0  500 mhz processor, 96mb ram, 16mb video card, ...         NaN
# 1  500 mhz processor, 96mb ram, 16mb video card, ...         NaN
# 2  500 mhz processor, 96mb ram, 16mb video card, ...         NaN
# 3  500 mhz processor, 96mb ram, 16mb video card, ...         NaN
# 4  500 mhz processor, 96mb ram, 16mb video card, ...         NaN

# %% [markdown]
# ### Processing Categories and Genres
#
# Drop rows with missing categories/genres?

# %%
print(steam_data['categories'].isnull().sum())
# Out:
# 509

# %%
print(steam_data['categories'][0])

with pd.option_context("display.max_colwidth", 1000):
    display(steam_data['categories'].head())
# Out:
# [{'id': 1, 'description': 'Multi-player'}, {'id': 36, 'description': 'Online Multi-Player'}, {'id': 37, 'description': 'Local Multi-Player'}, {'id': 8, 'description': 'Valve Anti-Cheat enabled'}]
# 0    [{'id': 1, 'description': 'Multi-player'}, {'id': 36, 'description': 'Online Multi-Player'}, {'id': 37, 'description': 'Local Multi-Player'}, {'id': 8, 'description': 'Valve Anti-Cheat enabled'}]
# 1    [{'id': 1, 'description': 'Multi-player'}, {'id': 36, 'description': 'Online Multi-Player'}, {'id': 37, 'description': 'Local Multi-Player'}, {'id': 8, 'description': 'Valve Anti-Cheat enabled'}]
# 2                                                                                                       [{'id': 1, 'description': 'Multi-player'}, {'id': 8, 'description': 'Valve Anti-Cheat enabled'}]
# 3    [{'id': 1, 'description': 'Multi-player'}, {'id': 36, 'description': 'Online Multi-Player'}, {'id': 37, 'description': 'Local Multi-Player'}, {'id': 8, 'description': 'Valve Anti-Cheat enabled'}]
# 4                                                            [{'id': 2, 'description': 'Single-player'}, {'id': 1, 'description': 'Multi-player'}, {'id': 8, 'description': 'Valve Anti-Cheat enabled'}]
# Name: categories, dtype: object

# %%
print_steam_links(steam_data[steam_data['categories'].isnull()].tail(20))
# Out:
# MOTiON by RADiCAL: https://store.steampowered.com/app/999900
# The Marvellous Machine: https://store.steampowered.com/app/1000510
# iDancer: https://store.steampowered.com/app/1004740
# SubnetPing: https://store.steampowered.com/app/1008160
# YouTube Center: https://store.steampowered.com/app/1009330
# Discord Bot - Controls: https://store.steampowered.com/app/1010170
# Wallpaper Maker （造物主视频桌面）: https://store.steampowered.com/app/1010800
# Nero GameVR: https://store.steampowered.com/app/1011110
# Greenland Melting: https://store.steampowered.com/app/1012510
# VEGAS Movie Studio 16 Steam Edition: https://store.steampowered.com/app/1016810
# VEGAS Movie Studio 16 Platinum Steam Edition: https://store.steampowered.com/app/1016840
# Planet Evolution PC Live Wallpaper: https://store.steampowered.com/app/1017060
# Screenbits - Screen Recorder: https://store.steampowered.com/app/1018680
# Wondershare Video Converter Ultimate: https://store.steampowered.com/app/1025020
# ACID Music Studio 11 Steam Edition: https://store.steampowered.com/app/1026920
# MocuMocuVRM: https://store.steampowered.com/app/1027280
# 眼睛（眼球）结构研究: https://store.steampowered.com/app/1035340
# Grand Dude Simulator: https://store.steampowered.com/app/1037960
# My Stunt Life: https://store.steampowered.com/app/1045650
# Juice FX: https://store.steampowered.com/app/1046770

# %%
print(steam_data['genres'].isnull().sum())
# Out:
# 37

# %%
print(steam_data['genres'][0])

with pd.option_context("display.max_colwidth", 1000):
    display(steam_data['genres'].iloc[100:105])
# Out:
# [{'id': '1', 'description': 'Action'}]
# 116    [{'id': '2', 'description': 'Strategy'}, {'id': '4', 'description': 'Casual'}]
# 117                                            [{'id': '4', 'description': 'Casual'}]
# 118                                            [{'id': '4', 'description': 'Casual'}]
# 119                                          [{'id': '2', 'description': 'Strategy'}]
# 120                                            [{'id': '4', 'description': 'Casual'}]
# Name: genres, dtype: object

# %%
print_steam_links(steam_data[steam_data['genres'].isnull()].head(10))
print_steam_links(steam_data[steam_data['genres'].isnull()].tail(10))
# Out:
# Hot Dish: https://store.steampowered.com/app/12570
# Dr. Daisy Pet Vet: https://store.steampowered.com/app/12580
# Call of Cthulhu®: Dark Corners of the Earth: https://store.steampowered.com/app/22340
# Super Granny Collection: https://store.steampowered.com/app/36270
# Sacrifice: https://store.steampowered.com/app/38440
# Nancy Drew® Dossier: Resorting to Danger!: https://store.steampowered.com/app/42200
# Air Forte: https://store.steampowered.com/app/55020
# Sonic Adventure DX: https://store.steampowered.com/app/71250
# Portal 2 - The Final Hours: https://store.steampowered.com/app/104600
# Sonic CD: https://store.steampowered.com/app/200940
# EatWell: https://store.steampowered.com/app/678870
# No Lights: https://store.steampowered.com/app/682910
# Cyborg Arena: https://store.steampowered.com/app/706440
# M.I.A. - Overture: https://store.steampowered.com/app/712060
# VEHICLES FURY: https://store.steampowered.com/app/749290
# The Big Three: https://store.steampowered.com/app/823390
# BlueberryNOVA: https://store.steampowered.com/app/825550
# SPECKLE: Chill Puzzle Game: https://store.steampowered.com/app/873160
# River Relaxation VR: https://store.steampowered.com/app/938760
# SpaBerry VR Experience: https://store.steampowered.com/app/992080

# %%
steam_data[(steam_data['genres'].isnull()) | (steam_data['categories'].isnull())]
# Out:
#                                                name  steam_appid  \
# 338                                        Hot Dish        12570
# 339                               Dr. Daisy Pet Vet        12580
# 366       Tom Clancy's Ghost Recon® Island Thunder™        13630
# 508     Call of Cthulhu®: Dark Corners of the Earth        22340
# 709                             Westward Collection        36150
# 713                         Super Granny Collection        36270
# 766                                       Sacrifice        38440
# 785                       Painkiller: Black Edition        39530
# 837       Nancy Drew® Dossier: Resorting to Danger!        42200
# 936                        Might & Magic: Heroes VI        48220
# 972                                       Air Forte        55020
# 1034                            Dive to the Titanic        65200
# 1073                             Sonic Adventure DX        71250
# 1156                                         Silo 2       100400
# 1169                     Portal 2 - The Final Hours       104600
# 1246                                       Sonic CD       200940
# 1269               Sonic the Hedgehog 4 - Episode I       202530
# 1350                     Painkiller: Recurring Evil       206760
# 1540                         Mixcraft 8 Home Studio       218760
# 1573                                      ACDSee 15       220960
# 1578                                 iPi Recorder 2       221220
# 1622                          RPG Maker VX Ace Lite       224280
# 1672                                  DisplayFusion       227260
# 1685     Action! - Gameplay Recording and Streaming       228180
# 1704                 Resident Evil 6 Benchmark Tool       229950
# 1758                                      Black Ink       233680
# 1819                                       PCMark 8       236890
# 1891                                     Ohm Studio       241660
# 1892                       Actual Multiple Monitors       241680
# 1896               Middle-earth™: Shadow of Mordor™       241930
# ...                                             ...          ...
# 26669                         Movavi Photo Editor 5       982520
# 26679                                Cappasity Demo       982830
# 26775                      ACID Pro 8 Steam Edition       987010
# 26855                                   HEXMAPMAKER       991080
# 26877                        SpaBerry VR Experience       992080
# 26904                              Lossless Scaling       993090
# 26908                        Bobs Track Builder Pro       993270
# 26975                                        SUBURI       996150
# 27042                                          RONE       999840
# 27043                   NASA's Exoplanet Excursions       999880
# 27044                             MOTiON by RADiCAL       999900
# 27053                        The Marvellous Machine      1000510
# 27156                                       iDancer      1004740
# 27222                                    SubnetPing      1008160
# 27252                                YouTube Center      1009330
# 27269                        Discord Bot - Controls      1010170
# 27285                     Wallpaper Maker （造物主视频桌面）      1010800
# 27296                                   Nero GameVR      1011110
# 27326                             Greenland Melting      1012510
# 27428           VEGAS Movie Studio 16 Steam Edition      1016810
# 27429  VEGAS Movie Studio 16 Platinum Steam Edition      1016840
# 27433            Planet Evolution PC Live Wallpaper      1017060
# 27462                  Screenbits - Screen Recorder      1018680
# 27587          Wondershare Video Converter Ultimate      1025020
# 27626            ACID Music Studio 11 Steam Edition      1026920
# 27632                                   MocuMocuVRM      1027280
# 27773                                    眼睛（眼球）结构研究      1035340
# 27827                          Grand Dude Simulator      1037960
# 27933                                 My Stunt Life      1045650
# 27950                                      Juice FX      1046770
#
#        required_age          platforms  \
# 338               0            windows
# 339               0            windows
# 366               0            windows
# 508               0            windows
# 709               0            windows
# 713               0            windows
# 766               0            windows
# 785               0            windows
# 837               0            windows
# 936               0            windows
# 972               0        windows;mac
# 1034              0            windows
# 1073              0            windows
# 1156              0        windows;mac
# 1169              0        windows;mac
# 1246              0            windows
# 1269              0            windows
# 1350             18            windows
# 1540              0            windows
# 1573              0            windows
# 1578              0            windows
# 1622              0            windows
# 1672              0            windows
# 1685              0            windows
# 1704              0            windows
# 1758              0            windows
# 1819              0            windows
# 1891              0        windows;mac
# 1892              0            windows
# 1896              0  windows;mac;linux
# ...             ...                ...
# 26669             0            windows
# 26679             0            windows
# 26775             0            windows
# 26855             0            windows
# 26877             0            windows
# 26904             0            windows
# 26908             0            windows
# 26975             0            windows
# 27042             0            windows
# 27043             0            windows
# 27044             0            windows
# 27053             0            windows
# 27156             0            windows
# 27222             0            windows
# 27252             0            windows
# 27269             0            windows
# 27285             0            windows
# 27296             0            windows
# 27326             0            windows
# 27428             0            windows
# 27429             0            windows
# 27433             0            windows
# 27462             0            windows
# 27587             0            windows
# 27626             0            windows
# 27632             0            windows
# 27773             0            windows
# 27827             0            windows
# 27933             0            windows
# 27950             0            windows
#
#                                               categories  \
# 338          [{'id': 2, 'description': 'Single-player'}]
# 339          [{'id': 2, 'description': 'Single-player'}]
# 366                                                  NaN
# 508          [{'id': 2, 'description': 'Single-player'}]
# 709                                                  NaN
# 713          [{'id': 2, 'description': 'Single-player'}]
# 766          [{'id': 2, 'description': 'Single-player'}]
# 785                                                  NaN
# 837          [{'id': 2, 'description': 'Single-player'}]
# 936                                                  NaN
# 972    [{'id': 2, 'description': 'Single-player'}, {'...
# 1034                                                 NaN
# 1073   [{'id': 2, 'description': 'Single-player'}, {'...
# 1156                                                 NaN
# 1169         [{'id': 2, 'description': 'Single-player'}]
# 1246         [{'id': 2, 'description': 'Single-player'}]
# 1269   [{'id': 2, 'description': 'Single-player'}, {'...
# 1350                                                 NaN
# 1540                                                 NaN
# 1573                                                 NaN
# 1578                                                 NaN
# 1622                                                 NaN
# 1672                                                 NaN
# 1685                                                 NaN
# 1704                                                 NaN
# 1758                                                 NaN
# 1819                                                 NaN
# 1891                                                 NaN
# 1892                                                 NaN
# 1896   [{'id': 2, 'description': 'Single-player'}, {'...
# ...                                                  ...
# 26669                                                NaN
# 26679                                                NaN
# 26775                                                NaN
# 26855                                                NaN
# 26877                                                NaN
# 26904                                                NaN
# 26908                                                NaN
# 26975                                                NaN
# 27042                                                NaN
# 27043                                                NaN
# 27044                                                NaN
# 27053                                                NaN
# 27156                                                NaN
# 27222                                                NaN
# 27252                                                NaN
# 27269                                                NaN
# 27285                                                NaN
# 27296                                                NaN
# 27326                                                NaN
# 27428                                                NaN
# 27429                                                NaN
# 27433                                                NaN
# 27462                                                NaN
# 27587                                                NaN
# 27626                                                NaN
# 27632                                                NaN
# 27773                                                NaN
# 27827                                                NaN
# 27933                                                NaN
# 27950                                                NaN
#
#                                                   genres  achievements  \
# 338                                                  NaN             0
# 339                                                  NaN             0
# 366               [{'id': '1', 'description': 'Action'}]             0
# 508                                                  NaN             0
# 709               [{'id': '4', 'description': 'Casual'}]             0
# 713                                                  NaN             0
# 766                                                  NaN             0
# 785               [{'id': '1', 'description': 'Action'}]             0
# 837                                                  NaN             0
# 936    [{'id': '3', 'description': 'RPG'}, {'id': '2'...             0
# 972                                                  NaN            10
# 1034         [{'id': '28', 'description': 'Simulation'}]             0
# 1073                                                 NaN            15
# 1156   [{'id': '51', 'description': 'Animation & Mode...             0
# 1169                                                 NaN             0
# 1246                                                 NaN            12
# 1269                                                 NaN            12
# 1350              [{'id': '1', 'description': 'Action'}]             0
# 1540   [{'id': '52', 'description': 'Audio Production...             0
# 1573      [{'id': '55', 'description': 'Photo Editing'}]             0
# 1578   [{'id': '51', 'description': 'Animation & Mode...             0
# 1622                                                 NaN             0
# 1672          [{'id': '57', 'description': 'Utilities'}]             0
# 1685   [{'id': '52', 'description': 'Audio Production...             0
# 1704          [{'id': '57', 'description': 'Utilities'}]             0
# 1758   [{'id': '51', 'description': 'Animation & Mode...             0
# 1819          [{'id': '57', 'description': 'Utilities'}]             0
# 1891   [{'id': '52', 'description': 'Audio Production...             0
# 1892          [{'id': '57', 'description': 'Utilities'}]             0
# 1896                                                 NaN            74
# ...                                                  ...           ...
# 26669  [{'id': '53', 'description': 'Design & Illustr...             0
# 26679  [{'id': '54', 'description': 'Education'}, {'i...             0
# 26775  [{'id': '52', 'description': 'Audio Production'}]             0
# 26855         [{'id': '57', 'description': 'Utilities'}]             0
# 26877                                                NaN             0
# 26904         [{'id': '57', 'description': 'Utilities'}]             0
# 26908  [{'id': '51', 'description': 'Animation & Mode...             0
# 26975  [{'id': '54', 'description': 'Education'}, {'i...             0
# 27042  [{'id': '53', 'description': 'Design & Illustr...             0
# 27043         [{'id': '54', 'description': 'Education'}]             0
# 27044  [{'id': '51', 'description': 'Animation & Mode...             0
# 27053         [{'id': '54', 'description': 'Education'}]             0
# 27156         [{'id': '57', 'description': 'Utilities'}]             0
# 27222         [{'id': '57', 'description': 'Utilities'}]             0
# 27252  [{'id': '57', 'description': 'Utilities'}, {'i...             0
# 27269         [{'id': '57', 'description': 'Utilities'}]             0
# 27285         [{'id': '57', 'description': 'Utilities'}]             0
# 27296  [{'id': '60', 'description': 'Game Development'}]             0
# 27326         [{'id': '54', 'description': 'Education'}]             0
# 27428  [{'id': '52', 'description': 'Audio Production...             0
# 27429  [{'id': '52', 'description': 'Audio Production...             0
# 27433  [{'id': '53', 'description': 'Design & Illustr...             0
# 27462  [{'id': '56', 'description': 'Software Trainin...             0
# 27587  [{'id': '52', 'description': 'Audio Production...             0
# 27626  [{'id': '52', 'description': 'Audio Production'}]             0
# 27632         [{'id': '57', 'description': 'Utilities'}]             0
# 27773         [{'id': '54', 'description': 'Education'}]             0
# 27827  [{'id': '1', 'description': 'Action'}, {'id': ...             0
# 27933  [{'id': '4', 'description': 'Casual'}, {'id': ...             0
# 27950  [{'id': '51', 'description': 'Animation & Mode...             0
#
#                                          release_date   price  english  \
# 338    {'coming_soon': False, 'date': '29 Jul, 2008'}    5.99        1
# 339    {'coming_soon': False, 'date': '29 Jul, 2008'}    5.99        1
# 366    {'coming_soon': False, 'date': '15 Jul, 2008'}    4.29        1
# 508    {'coming_soon': False, 'date': '16 Jun, 2009'}    3.99        1
# 709    {'coming_soon': False, 'date': '17 Jul, 2009'}   10.99        1
# 713    {'coming_soon': False, 'date': '17 Jul, 2009'}   10.99        1
# 766    {'coming_soon': False, 'date': '19 Aug, 2009'}    6.99        1
# 785    {'coming_soon': False, 'date': '24 Jan, 2007'}    8.99        1
# 837    {'coming_soon': False, 'date': '19 Nov, 2009'}    5.19        1
# 936    {'coming_soon': False, 'date': '13 Oct, 2011'}   16.99        1
# 972    {'coming_soon': False, 'date': '29 Sep, 2010'}    6.99        1
# 1034   {'coming_soon': False, 'date': '17 Dec, 2010'}    7.19        1
# 1073    {'coming_soon': False, 'date': '4 Mar, 2011'}    5.59        1
# 1156   {'coming_soon': False, 'date': '19 Dec, 2012'}   75.99        1
# 1169   {'coming_soon': False, 'date': '17 May, 2011'}    1.59        1
# 1246   {'coming_soon': False, 'date': '19 Jan, 2012'}    3.99        1
# 1269   {'coming_soon': False, 'date': '19 Jan, 2012'}    5.99        1
# 1350   {'coming_soon': False, 'date': '29 Feb, 2012'}    8.99        1
# 1540   {'coming_soon': False, 'date': '10 May, 2017'}   29.99        1
# 1573   {'coming_soon': False, 'date': '11 Dec, 2012'}   29.99        1
# 1578               {'coming_soon': False, 'date': ''}    0.00        1
# 1622               {'coming_soon': False, 'date': ''}    0.00        1
# 1672   {'coming_soon': False, 'date': '29 Mar, 2013'}   27.79        1
# 1685    {'coming_soon': False, 'date': '8 May, 2014'}   29.99        1
# 1704               {'coming_soon': False, 'date': ''}    0.00        1
# 1758    {'coming_soon': False, 'date': '8 Feb, 2016'}   44.99        1
# 1819   {'coming_soon': False, 'date': '21 Oct, 2013'}   18.99        1
# 1891    {'coming_soon': False, 'date': '9 Dec, 2013'}    0.00        1
# 1892   {'coming_soon': False, 'date': '16 Dec, 2014'}   18.99        1
# 1896   {'coming_soon': False, 'date': '30 Sep, 2014'}   15.99        1
# ...                                               ...     ...      ...
# 26669  {'coming_soon': False, 'date': '19 Dec, 2018'}   29.95        1
# 26679  {'coming_soon': False, 'date': '13 Dec, 2018'}    0.00        1
# 26775  {'coming_soon': False, 'date': '23 Jan, 2019'}  119.00        1
# 26855   {'coming_soon': False, 'date': '3 Jan, 2019'}    2.89        1
# 26877  {'coming_soon': False, 'date': '18 Dec, 2018'}    0.00        1
# 26904  {'coming_soon': False, 'date': '28 Dec, 2018'}    3.99        1
# 26908   {'coming_soon': False, 'date': '4 Jan, 2019'}    7.19        1
# 26975   {'coming_soon': False, 'date': '7 Jan, 2019'}    4.79        1
# 27042  {'coming_soon': False, 'date': '18 Dec, 2018'}    3.99        1
# 27043  {'coming_soon': False, 'date': '18 Apr, 2019'}    0.00        1
# 27044   {'coming_soon': False, 'date': '4 Jan, 2019'}    0.00        1
# 27053  {'coming_soon': False, 'date': '11 Feb, 2019'}    2.29        1
# 27156  {'coming_soon': False, 'date': '21 Jan, 2019'}    2.89        1
# 27222  {'coming_soon': False, 'date': '13 Feb, 2019'}    3.99        1
# 27252  {'coming_soon': False, 'date': '31 Jan, 2019'}   19.49        1
# 27269  {'coming_soon': False, 'date': '23 Jan, 2019'}    1.69        1
# 27285   {'coming_soon': False, 'date': '3 Apr, 2019'}    0.00        0
# 27296  {'coming_soon': False, 'date': '15 Apr, 2019'}    0.00        1
# 27326  {'coming_soon': False, 'date': '18 Mar, 2019'}    0.00        1
# 27428  {'coming_soon': False, 'date': '18 Mar, 2019'}   39.99        1
# 27429  {'coming_soon': False, 'date': '14 Mar, 2019'}   52.99        1
# 27433  {'coming_soon': False, 'date': '22 Feb, 2019'}    2.09        1
# 27462  {'coming_soon': False, 'date': '15 Feb, 2019'}    7.19        1
# 27587  {'coming_soon': False, 'date': '31 Mar, 2019'}   46.49        1
# 27626   {'coming_soon': False, 'date': '5 Apr, 2019'}   44.99        1
# 27632  {'coming_soon': False, 'date': '21 Feb, 2019'}    2.89        1
# 27773  {'coming_soon': False, 'date': '10 Mar, 2019'}   15.49        0
# 27827  {'coming_soon': False, 'date': '12 Mar, 2019'}    3.99        1
# 27933  {'coming_soon': False, 'date': '27 Mar, 2019'}    0.79        1
# 27950  {'coming_soon': False, 'date': '26 Mar, 2019'}   15.49        1
#
#                                                developer  \
# 338                                              Zemnott
# 339                                              Zemnott
# 366                              Red Storm Entertainment
# 508                                Headfirst Productions
# 709                                        Sandlot Games
# 713                                        Sandlot Games
# 766                                  Shiny Entertainment
# 785                                       People Can Fly
# 837                                      HeR Interactive
# 936                                            Blackhole
# 972                                         Blendo Games
# 1034                                         TML-Studios
# 1073                                                SEGA
# 1156                                Nevercenter Ltd. Co.
# 1169                                      Geoff Keighley
# 1246                                       Blit Software
# 1269                                                SEGA
# 1350                                             Med-Art
# 1540                                     Acoustica, Inc.
# 1573                      ACD Systems International Inc.
# 1578                                           iPi Soft
# 1622                                            KADOKAWA
# 1672                            Binary Fortress Software
# 1685                                            Mirillis
# 1704                                              Capcom
# 1758                                              Bleank
# 1819                                                  UL
# 1891                                             GRAOUMF
# 1892                                        Actual Tools
# 1896   Monolith Productions;Feral Interactive (Mac);F...
# ...                                                  ...
# 26669                                             Movavi
# 26679                                     Cappasity Inc.
# 26775                                MAGIX Software GmbH
# 26855                                            urksoft
# 26877                                     VisionWerx Inc
# 26904                                                THS
# 26908                                     Brendon Pywell
# 26975                                            SHI LIN
# 27042                    StudioBento;Paperticket Studios
# 27043      Caltech/IPAC;NASA's Jet Propulsion Laboratory
# 27044                                            RADiCAL
# 27053                                   1337 Game Design
# 27156                                Totem Entertainment
# 27222                               Dennis Sven Mittmann
# 27252                                    Benjamin Werner
# 27269                                     zit_x_us;hazel
# 27285                                      Dream.Machine
# 27296                                            Nero AG
# 27326              Emblematic Group;X-Rez Studio;Realtra
# 27428                                MAGIX Software GmbH
# 27429                                MAGIX Software GmbH
# 27433                                3dm_live_wallpapers
# 27462                                          M CHEHRAZ
# 27587                                        Wondershare
# 27626                                MAGIX Software GmbH
# 27632                                               Vrai
# 27773                                         上海皋城软件有限公司
# 27827                                              Kiddy
# 27933                                          RewindApp
# 27950   Manuel Jesús Bolaños Gómez;Davit Masia Coscollar
#
#                                            publisher
# 338                                         ValuSoft
# 339                                         ValuSoft
# 366                                          Ubisoft
# 508                               Bethesda Softworks
# 709                                    Sandlot Games
# 713                                    Sandlot Games
# 766                                   Interplay Inc.
# 785                                       THQ Nordic
# 837                                  HeR Interactive
# 936                                          Ubisoft
# 972                                     Blendo Games
# 1034                          astragon Entertainment
# 1073                                            SEGA
# 1156                            Nevercenter Ltd. Co.
# 1169                                  Geoff Keighley
# 1246                                            SEGA
# 1269                                            SEGA
# 1350                                      THQ Nordic
# 1540                                 Acoustica, Inc.
# 1573                  ACD Systems International Inc.
# 1578                                       iPi Soft
# 1622                                          Degica
# 1672                        Binary Fortress Software
# 1685                                        Mirillis
# 1704                                          Capcom
# 1758                                          Bleank
# 1819                                              UL
# 1891                                       Ohm Force
# 1892                                    Actual Tools
# 1896                WB Games;Feral Interactive (Mac)
# ...                                              ...
# 26669                                         Movavi
# 26679                                 Cappasity Inc.
# 26775                            MAGIX Software GmbH
# 26855                                        urksoft
# 26877                                 VisionWerx Inc
# 26904                                            THS
# 26908                                 Brendon Pywell
# 26975                                        SHI LIN
# 27042                                    StudioBento
# 27043  Caltech/IPAC;NASA's Jet Propulsion Laboratory
# 27044                         RADiCAL Solutions, LLC
# 27053                               1337 Game Design
# 27156                            Totem Entertainment
# 27222                           Dennis Sven Mittmann
# 27252                                Benjamin Werner
# 27269                                       zit_x_us
# 27285                                  Dream.Machine
# 27296                                        Nero AG
# 27326                                 Frontline;NOVA
# 27428                            MAGIX Software GmbH
# 27429                            MAGIX Software GmbH
# 27433                            3dm_live_wallpapers
# 27462                                      M CHEHRAZ
# 27587                                    Wondershare
# 27626                            MAGIX Software GmbH
# 27632                                           Vrai
# 27773                                     上海皋城软件有限公司
# 27827                                          Kiddy
# 27933                                      RewindApp
# 27950                     Manuel Jesús Bolaños Gómez
#
# [542 rows x 12 columns]

# %%
def process_categories_and_genres(df, export=False):
    df = df[df['genres'].notnull()].copy()
    df = df[df['categories'].notnull()].copy()
    
    df['genres'] = df['genres'].apply(lambda x: ';'.join(item['description'] for item in literal_eval(x)))
    df['categories'] = df['categories'].apply(lambda x: ';'.join(item['description'] for item in literal_eval(x)))
    
    return df


def process(df):
    """Process data set. Will eventually contain calls to all functions we write."""
    
    # drop rows with missing publisher and copy
    df = df[df['publisher'].notnull()].copy()
    
    # Process export columns
    df = process_descriptions(df)
    df = process_media(df)
    df = process_info(df)
    df = process_requirements(df)
    df = process_categories_and_genres(df)
    
    return df


steam_data = process(imported_steam_data)

# %% [markdown]
# ## Export

# %%
steam_data.head()
# Out:
#                         name  steam_appid  required_age          platforms  \
# 0             Counter-Strike           10             0  windows;mac;linux
# 1      Team Fortress Classic           20             0  windows;mac;linux
# 2              Day of Defeat           30             0  windows;mac;linux
# 3         Deathmatch Classic           40             0  windows;mac;linux
# 4  Half-Life: Opposing Force           50             0  windows;mac;linux
#
#                                           categories  genres  achievements  \
# 0  Multi-player;Online Multi-Player;Local Multi-P...  Action             0
# 1  Multi-player;Online Multi-Player;Local Multi-P...  Action             0
# 2              Multi-player;Valve Anti-Cheat enabled  Action             0
# 3  Multi-player;Online Multi-Player;Local Multi-P...  Action             0
# 4  Single-player;Multi-player;Valve Anti-Cheat en...  Action             0
#
#                                     release_date  price  english  \
# 0  {'coming_soon': False, 'date': '1 Nov, 2000'}   7.19        1
# 1  {'coming_soon': False, 'date': '1 Apr, 1999'}   3.99        1
# 2  {'coming_soon': False, 'date': '1 May, 2003'}   3.99        1
# 3  {'coming_soon': False, 'date': '1 Jun, 2001'}   3.99        1
# 4  {'coming_soon': False, 'date': '1 Nov, 1999'}   3.99        1
#
#           developer publisher
# 0             Valve     Valve
# 1             Valve     Valve
# 2             Valve     Valve
# 3             Valve     Valve
# 4  Gearbox Software     Valve

# %%
steam_data.isnull().sum()
# Out:
# name            0
# steam_appid     0
# required_age    0
# platforms       0
# categories      0
# genres          0
# achievements    0
# release_date    0
# price           0
# english         0
# developer       0
# publisher       0
# dtype: int64

# %%
steam_data.to_csv("../data/exports/steam_clean_part_2.csv", index=False)

# %% [markdown]
# # Steam Data Cleaning (Part 3)
#
# *This is part of a larger series of notebooks on downloading, processing and analysing data from the steam store. [See all notebooks here.](../notebooks)*

# %%
# load extensions and magics

# http://raw.github.com/jrjohansson/version_information/master/version_information.py
# %load_ext version_information
# %reload_ext version_information

# %version_information numpy, pandas
# Out:
# Software versions
# Python 3.7.3 64bit [MSC v.1900 64 bit (AMD64)]
# IPython 7.5.0
# OS Windows 10 10.0.17763 SP0
# numpy 1.16.3
# pandas 0.24.2
# Fri May 24 12:07:27 2019 GMT Summer Time

# %% [markdown]
# # Release Data optimisation and combining
#
# Almost finished with steam data. Final column then combine

# %%
# standard library imports
from ast import literal_eval
import itertools
import time
import re
import sys
sys.path.append('../src/')

# third-party imports
import numpy as np
import pandas as pd

# local imports
from datacleaning import print_steam_links

# customisations
pd.set_option("max_columns", 100)

# %% [markdown]
# ## Import and Inspect Data

# %%
imported_steam_data = pd.read_csv('../data/exports/steam_clean_part_2.csv')

print('Rows:', imported_steam_data.shape[0])
print('Columns:', imported_steam_data.shape[1])
imported_steam_data.head()
# Out:
# Rows: 27391
# Columns: 12
#                         name  steam_appid  required_age          platforms  \
# 0             Counter-Strike           10             0  windows;mac;linux
# 1      Team Fortress Classic           20             0  windows;mac;linux
# 2              Day of Defeat           30             0  windows;mac;linux
# 3         Deathmatch Classic           40             0  windows;mac;linux
# 4  Half-Life: Opposing Force           50             0  windows;mac;linux
#
#                                           categories  genres  achievements  \
# 0  Multi-player;Online Multi-Player;Local Multi-P...  Action             0
# 1  Multi-player;Online Multi-Player;Local Multi-P...  Action             0
# 2              Multi-player;Valve Anti-Cheat enabled  Action             0
# 3  Multi-player;Online Multi-Player;Local Multi-P...  Action             0
# 4  Single-player;Multi-player;Valve Anti-Cheat en...  Action             0
#
#                                     release_date  price  english  \
# 0  {'coming_soon': False, 'date': '1 Nov, 2000'}   7.19        1
# 1  {'coming_soon': False, 'date': '1 Apr, 1999'}   3.99        1
# 2  {'coming_soon': False, 'date': '1 May, 2003'}   3.99        1
# 3  {'coming_soon': False, 'date': '1 Jun, 2001'}   3.99        1
# 4  {'coming_soon': False, 'date': '1 Nov, 1999'}   3.99        1
#
#           developer publisher
# 0             Valve     Valve
# 1             Valve     Valve
# 2             Valve     Valve
# 3             Valve     Valve
# 4  Gearbox Software     Valve

# %% [markdown]
# Check null counts

# %%
imported_steam_data.isnull().sum()
# Out:
# name            0
# steam_appid     0
# required_age    0
# platforms       0
# categories      0
# genres          0
# achievements    0
# release_date    0
# price           0
# english         0
# developer       0
# publisher       0
# dtype: int64

# %% [markdown]
# ### Processing and Optimising Release Date
#
# The final column to clean, release date, provides some interesting optimisation and learning challenges. We've encountered some columns with a similar structure already, so we can use what we've learned so far, but now we have some dates to handle.
#
# First we shall inspect the raw format of the column. As we can see below, it is stored as a dictionary-like string object containing values for `coming_soon` and `date`. From the first few rows it would appear that the dates are stored in a uniform format - day as an integer, month as a 3-character string abbreviation, a comma, then the year as a four-digit number. We can parse this either using the python built-in datetime module, or as we already have pandas imported, we can use the [pd.to_datetime](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.to_datetime.html) function.
#
# Also, as our analysis will involve looking at ownership and sales data, looking at games that are not released yet will not be useful to us. Intuitively, we can drop any titles which are marked as coming soon, presumably having this value set to true. As a side note, once parsed it may be worth checking that no release dates in our data are beyond the current date, just to make doubly sure none slip through.

# %%
display(imported_steam_data['release_date'][0])
# Out:
# "{'coming_soon': False, 'date': '1 Nov, 2000'}"

# %%
imported_steam_data[['name', 'release_date']].head()
# Out:
#                         name                                   release_date
# 0             Counter-Strike  {'coming_soon': False, 'date': '1 Nov, 2000'}
# 1      Team Fortress Classic  {'coming_soon': False, 'date': '1 Apr, 1999'}
# 2              Day of Defeat  {'coming_soon': False, 'date': '1 May, 2003'}
# 3         Deathmatch Classic  {'coming_soon': False, 'date': '1 Jun, 2001'}
# 4  Half-Life: Opposing Force  {'coming_soon': False, 'date': '1 Nov, 1999'}

# %% [markdown]
# As usual, one of the first steps we'll take is to check for null values. Luckily, it seems that the cleaning we have performed already has removed any null values from our data set, as seen below. We may still have some hidden empty values of course.

# %%
print('Null values:\n')
# print('Raw data:', imported_steam_data['release_date'].isnull().sum())
print('Partially cleaned:', imported_steam_data['release_date'].isnull().sum())
# Out:
# Null values:
#
# Partially cleaned: 0

# %% [markdown]
# Exploring the data using the value_counts method brings a couple of data issues to light.
#
# In the raw data, we can see that 64 rows have data but date is an empty string, ''. Like we've seen before, this means they do not have null values, but may need to be treated as such depending on the reason. This may be data corruption, or it may be another reason entirely. We will probably have to decide what to do with these cases and investigate further.
#
# Another issue we can notice is that while most of the dates are stored in the format we saw previously (dd mmm, yyyy), at least a couple are simply stored as the month and year (e.g. 'May 2019'). This means that the dates aren't all stored uniformly so we will have to take care when parsing them.
#
# # May have to change this and discover later

# %%
display(imported_steam_data['release_date'].value_counts().head())

imported_steam_data['release_date'].value_counts().tail()
# Out:
# {'coming_soon': False, 'date': '13 Jul, 2018'}    64
# {'coming_soon': False, 'date': '31 Jan, 2019'}    58
# {'coming_soon': False, 'date': '5 Apr, 2016'}     56
# {'coming_soon': False, 'date': '16 Nov, 2018'}    56
# {'coming_soon': False, 'date': '31 May, 2018'}    55
# Name: release_date, dtype: int64
# {'coming_soon': False, 'date': '24 Sep, 2007'}    1
# {'coming_soon': False, 'date': '19 Sep, 2008'}    1
# {'coming_soon': False, 'date': '31 Jul, 2009'}    1
# {'coming_soon': False, 'date': '11 Dec, 2012'}    1
# {'coming_soon': False, 'date': '1 Apr, 2006'}     1
# Name: release_date, dtype: int64

# %% [markdown]
# Before we move on, let's quickly inspect some of the rows which have a blank date.
#
# It looks like some are special re-releases, like anniversary or game of the year editions, some are early access and not officially released yet, and others simply have a missing date. Apart from that there don't appear to be any clear patterns emerging, so as there are only 22 rows it may be best to remove them.

# %%
no_release_date = imported_steam_data[imported_steam_data['release_date'] == "{'coming_soon': False, 'date': ''}"]

print('Rows with no release date:', no_release_date.shape[0], '\n')
print_steam_links(no_release_date.head())
no_release_date.head()
# Out:
# Rows with no release date: 22
#
# Borderlands Game of the Year: https://store.steampowered.com/app/8980
# Sherlock Holmes: The Mystery of the Persian Carpet: https://store.steampowered.com/app/11180
# 1... 2... 3... KICK IT! (Drop That Beat Like an Ugly Baby): https://store.steampowered.com/app/15540
# The Great Art Race: https://store.steampowered.com/app/33580
# SpellForce 2 - Anniversary Edition: https://store.steampowered.com/app/39550
#                                                   name  steam_appid  \
# 224                       Borderlands Game of the Year         8980
# 275  Sherlock Holmes: The Mystery of the Persian Ca...        11180
# 366  1... 2... 3... KICK IT! (Drop That Beat Like a...        15540
# 634                                 The Great Art Race        33580
# 757                 SpellForce 2 - Anniversary Edition        39550
#
#      required_age platforms  \
# 224            18   windows
# 275             0   windows
# 366             0   windows
# 634             0   windows
# 757             0   windows
#
#                                             categories  \
# 224  Single-player;Multi-player;Co-op;Steam Achieve...
# 275                                      Single-player
# 366  Single-player;Steam Achievements;Steam Trading...
# 634                                      Single-player
# 757  Single-player;Multi-player;Online Multi-Player...
#
#                         genres  achievements  \
# 224                 Action;RPG            80
# 275           Adventure;Casual             0
# 366  Action;Early Access;Indie             1
# 634        Simulation;Strategy             0
# 757               RPG;Strategy             0
#
#                            release_date  price  english  \
# 224  {'coming_soon': False, 'date': ''}  24.99        1
# 275  {'coming_soon': False, 'date': ''}   6.99        1
# 366  {'coming_soon': False, 'date': ''}   6.99        1
# 634  {'coming_soon': False, 'date': ''}   3.99        1
# 757  {'coming_soon': False, 'date': ''}  13.99        1
#
#                       developer               publisher
# 224            Gearbox Software                      2K
# 275                   Frogwares               Frogwares
# 366         Dejobaan Games, LLC     Dejobaan Games, LLC
# 634  Ascaron Entertainment ltd.  Assemble Entertainment
# 757         Phenomic;THQ Nordic              THQ Nordic

# %% [markdown]
# Taking a look at the format of the column, we'll need to be using literal_eval once more. Apart from that it should be straightforward enough to extract the date.

# %%
print(type(imported_steam_data['release_date'].iloc[0]))

imported_steam_data['release_date'].iloc[0]
# Out:
# <class 'str'>
# "{'coming_soon': False, 'date': '1 Nov, 2000'}"

# %%
print(type(literal_eval(imported_steam_data['release_date'].iloc[0])))

literal_eval(imported_steam_data['release_date'].iloc[0])['date']
# Out:
# <class 'dict'>
# '1 Nov, 2000'

# %% [markdown]
# Once extracted, we can use the pd.to_datetime functon to interpret and store dates as datetime objects. This will be particularly useful as it will allow us to search and sort our dataset when it comes to performing analysis. Say for example we only wish to examine games released in 2010, by converting our dates to a python-recognisable format this will be very easy to achieve.
#
# As seen below, we can supply the to_datetime function with our date and pandas will automatically interpret the format. We can then inspect it or print an attribute like the year. We can also provide pandas with the format explicitly, so it knows what to look for and how to parse it, which may be [quicker for large sets of data](https://stackoverflow.com/questions/32034689/why-is-pandas-to-datetime-slow-for-non-standard-time-format-such-as-2014-12-31).

# %%
timestamp = pd.to_datetime(literal_eval(imported_steam_data['release_date'].iloc[0])['date'])

print(timestamp)
print(timestamp.year)

pd.to_datetime(literal_eval(imported_steam_data['release_date'].iloc[0])['date'], format='%d %b, %Y')
# Out:
# 2000-11-01 00:00:00
# 2000
# Timestamp('2000-11-01 00:00:00')

# %% [markdown]
# Now we are ready to begin defining our function. As we only want to keep unreleased games, we first values from the coming_soon key, and keep only those where the value is False. Next we extract the release date, and set missing dates to np.nan, the default way of storing null values in pandas.
#
# Then, using the formats we learned previously, we interpret those datesusing the to_datetime function. Once complete we pass over the dataframe once more with a general call to to_datetime, catching any dates we missed.
#
# Finally we drop the columns we no longer need and return the dataframe.
#
# Whilst functional, the process is quite slow. We can use the %timeit magic to test how long it takes to run our function, and we can see that on average it takes almost four seconds. Whilst manageable, we could certainly benefit from optimising our code, as this could quickly add up in larger data sets, where increasing efficiency can prove invaluable.

# %%
def process_release_date(df):
    df = df.copy()
    
    df['coming_soon'] = df['release_date'].apply(lambda x: literal_eval(x)['coming_soon'])
    # Only want to keep released games
    df = df[df['coming_soon'] == False].copy()
    
    # extract release date and set missing dates to null
    df['date'] = df['release_date'].apply(lambda x: literal_eval(x)['date'])
    df.loc[df['date'] == '', 'date'] = np.nan
    
    # Parse the date formats we have discovered
    df['datetime'] = pd.to_datetime(df['date'], format='%d %b, %Y', errors='ignore')
    df['datetime'] = pd.to_datetime(df['datetime'], format='%b %Y', errors='ignore')
    
    # Parse the rest of the date formats
    df['release_date'] = pd.to_datetime(df['datetime'])
    
    df = df.drop(['coming_soon', 'date', 'datetime'], axis=1)
    return df

# %timeit process_release_date(imported_steam_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslibs/np_datetime.pyx in pandas._libs.tslibs.np_datetime._string_to_dts()
#
# ValueError: Month out of range in datetime string "20 Dec, 2018"
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-b37c03b8914b> in <module>
#      20     return df
#      21
# ---> 22 get_ipython().run_line_magic('timeit', 'process_release_date(imported_steam_data)')
#
# ~\Miniconda3\envs\py37\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2305                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2306             with self.builtin_trap:
# -> 2307                 result = fn(*args, **kwargs)
#    2308             return result
#    2309
#
# <C:\Users\nikda\Miniconda3\envs\py37\lib\site-packages\decorator.py:decorator-gen-61> in timeit(self, line, cell, local_ns)
#
# ~\Miniconda3\envs\py37\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\Miniconda3\envs\py37\lib\site-packages\IPython\core\magics\execution.py in timeit(self, line, cell, local_ns)
#    1149                     break
#    1150
# -> 1151         all_runs = timer.repeat(repeat, number)
#    1152         best = min(all_runs) / number
#    1153         worst = max(all_runs) / number
#
# ~\Miniconda3\envs\py37\lib\timeit.py in repeat(self, repeat, number)
#     202         r = []
#     203         for i in range(repeat):
# --> 204             t = self.timeit(number)
#     205             r.append(t)
#     206         return r
#
# ~\Miniconda3\envs\py37\lib\site-packages\IPython\core\magics\execution.py in timeit(self, number)
#     159         gc.disable()
#     160         try:
# --> 161             timing = self.inner(it, self.timer)
#     162         finally:
#     163             if gcold:
#
# <magic-timeit> in inner(_it, _timer)
#
# <ipython-input-10-b37c03b8914b> in process_release_date(df)
#      15
#      16     # Parse the rest of the date formats
# ---> 17     df['release_date'] = pd.to_datetime(df['datetime'])
#      18
#      19     df = df.drop(['coming_soon', 'date', 'datetime'], axis=1)
#
# ~\Miniconda3\envs\py37\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin, cache)
#     590         else:
#     591             from pandas import Series
# --> 592             values = convert_listlike(arg._values, True, format)
#     593             result = Series(values, index=arg.index, name=arg.name)
#     594     elif isinstance(arg, (ABCDataFrame, compat.MutableMapping)):
#
# ~\Miniconda3\envs\py37\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, box, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     300             arg, dayfirst=dayfirst, yearfirst=yearfirst,
#     301             utc=utc, errors=errors, require_iso8601=require_iso8601,
# --> 302             allow_object=True)
#     303
#     304     if tz_parsed is not None:
#
# ~\Miniconda3\envs\py37\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1855             dayfirst=dayfirst,
#    1856             yearfirst=yearfirst,
# -> 1857             require_iso8601=require_iso8601
#    1858         )
#    1859     except ValueError as e:
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ~\Miniconda3\envs\py37\lib\site-packages\dateutil\parser\_parser.py in parse(timestr, parserinfo, **kwargs)
#    1356         return parser(parserinfo).parse(timestr, **kwargs)
#    1357     else:
# -> 1358         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1359
#    1360
#
# ~\Miniconda3\envs\py37\lib\site-packages\dateutil\parser\_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     644                                                       second=0, microsecond=0)
#     645
# --> 646         res, skipped_tokens = self._parse(timestr, **kwargs)
#     647
#     648         if res is None:
#
# ~\Miniconda3\envs\py37\lib\site-packages\dateutil\parser\_parser.py in _parse(self, timestr, dayfirst, yearfirst, fuzzy, fuzzy_with_tokens)
#     741                 if value is not None:
#     742                     # Numeric token
# --> 743                     i = self._parse_numeric_token(l, i, info, ymd, res, fuzzy)
#     744
#     745                 # Check weekday
#
# ~\Miniconda3\envs\py37\lib\site-packages\dateutil\parser\_parser.py in _parse_numeric_token(self, tokens, idx, info, ymd, res, fuzzy)
#     983
#     984         elif idx + 1 >= len_l or info.jump(tokens[idx + 1]):
# --> 985             if idx + 2 < len_l and info.ampm(tokens[idx + 2]) is not None:
#     986                 # 12 am
#     987                 hour = int(value)
#
# KeyboardInterrupt:

# %% [markdown]
# There are a few areas we can investigate to make improvements. When initially parsing the date, we end up calling literal_eval twice, which may be a source of slowdown. We also loop over the entire dataset multiple times when calling the to_datetime function.
#
# We'll investigate which part is causing the greatest slowdown, but we can be certain that reducing the traversals over the data set will most likely provide significant gains. There are also a few other issues that we'll dive into over the course of our optimisation process.
#
# First, let's find out where the main slowdowns are. As we just saw we can use the %timeit magic to time our function. We can also use the in-built time module to inspect parts of our code.

# %%
def process_release_date(df):
    df = df.copy()
    
    eval_start = time.time()
    
    df['coming_soon'] = df['release_date'].apply(lambda x: literal_eval(x)['coming_soon'])
    df = df[df['coming_soon'] == False].copy()
    df['date'] = df['release_date'].apply(lambda x: literal_eval(x)['date'])
    
    print('Evaluation run-time:', time.time() - eval_start)
    
    df.loc[df['date'] == '', 'date'] = None
    
    first_parse_start = time.time()
    
    df['datetime'] = pd.to_datetime(df['date'], format='%d %b, %Y', errors='ignore')
    df['datetime'] = pd.to_datetime(df['datetime'], format='%b %Y', errors='ignore')
    
    print('First parse run-time:', time.time() - first_parse_start)
    
    second_parse_start = time.time()
    
    df['release_date'] = pd.to_datetime(df['datetime'])
    
    print('Final parse run-time:', time.time() - second_parse_start)
    
    df = df.drop(['coming_soon', 'date', 'datetime'], axis=1)
    return df

function_start = time.time()
process_release_date(imported_steam_data)
print('\nTotal run-time:', time.time() - function_start)

# %% [markdown]
# Immediately we can see that the majority of run-time is taken up by the final call to pd.to_datetime. This suggests that the first two calls are not functioning as expected - they are possibly terminating after the first error instead of skipping over it as desired - and most of the work is being done by the final call. Now it makes sense why it is slow - pandas has to figure out how each date is formatted, and since we know we have some variations this may be slowing it down considerably.
#
# Whilst the evaluation run-time is much shorter, our multiple calls to literal_eval may be slowing the function as well, so we may wish to investigate that. As we know the biggest slowdown, we should begin there.
#
# We now know that handling our dates in their current form is slow, and we know that we have some different formats mixed in there. Whilst there are likely many possible solutions to this problem, using regular expressions (or regex) comes to mind as they tend to excel at pattern matching in strings.
#
# We know for sure two of the patterns, so let's build a regex for each of those. Then we can iteratively add more as we discover any other patterns. A powerful and useful tool for building and testing regex can be found at [regexr.com](https://regexr.com/).

# %%
pattern = r'[\d]{1,2} [A-Za-z]{3}, [\d]{4}'
string = '13 Jul, 2018'

print(re.search(pattern, string))

pattern = r'[A-Za-z]{3} [\d]{4}'
string = 'Apr 2016'

print(re.search(pattern, string))

# %% [markdown]
# Using these two patterns we can start building out our function. We're going to apply a function to the date column which searches for each pattern, returning a standardised date string which we will then feed into the to_datetime function.
#
# Our first search matches the 'mmm yyyy' pattern, like 'Apr 2019'. As we don't know the particular day for these matches we will assume it is the first of the month, returning '1 Apr 2019' in this example.
#
# If we don't match this, we'll check for the second case. Our second match will be the 'dd mmm, yyyy' pattern, like '13 Jul, 2018'. In this case we will simply return the match with the comma removed, to become '13 Jul 2018'.
#
# Finally we'll check for the empty string, and return it for now.
#
# For anything else we'll simply print the string so we know what else we should be searching for.

# %%
def process_release_date(df):
    df = df.copy()
    
    df['coming_soon'] = df['release_date'].apply(lambda x: literal_eval(x)['coming_soon'])
    df = df[df['coming_soon'] == False].copy()
    df['date'] = df['release_date'].apply(lambda x: literal_eval(x)['date'])
    
    def parse_date(x):
        if re.search(r'[A-Za-z]{3} [\d]{4}', x):
            return '1 ' + x 
        elif re.search(r'[\d]{1,2} [A-Za-z]{3}, [\d]{4}', x):
            return x.replace(',', '')
        elif x == '':
            return x
        else:
            print(x)
            
    df['date'] = df['date'].apply(parse_date)
    df['release_date'] = pd.to_datetime(df['date'], infer_datetime_format=True)
    
    df = df.drop(['coming_soon', 'date'], axis=1)
    
    return df

result = process_release_date(imported_steam_data)

# %% [markdown]
# It looks like we've caught all of the patterns and don't have any to take care of.
#
# Previously we used the `infer_datetime_format` parameter of to_datetime, which can speed up the process. However, as we now know exactly the format our dates will be in, we can explicitly set it ourselves, which should be the fastest way of doing things.
#
# We also need to decide how to handle our missing dates - those with the empty strings. For now let's change the way the function handles errors from raise to coerce, which returns NaT (not a time) instead.
#
# We can now rewrite our function and time it as we did before.

# %%
def process_release_date_old(df):
    df = df.copy()
    
    df['coming_soon'] = df['release_date'].apply(lambda x: literal_eval(x)['coming_soon'])
    df = df[df['coming_soon'] == False].copy()
    df['date'] = df['release_date'].apply(lambda x: literal_eval(x)['date'])
    
    # Simple parsing
    df['release_date'] = pd.to_datetime(df['date'])
    
    df = df.drop(['coming_soon', 'date'], axis=1)
    
    return df


def process_release_date_new(df):
    df = df.copy()
    
    df['coming_soon'] = df['release_date'].apply(lambda x: literal_eval(x)['coming_soon'])
    df = df[df['coming_soon'] == False].copy()
    df['date'] = df['release_date'].apply(lambda x: literal_eval(x)['date'])
    
    # Complex parsing
    def parse_date(x):
        if re.search(r'[A-Za-z]{3} [\d]{4}', x):
            return '1 ' + x
        elif re.search(r'[\d]{1,2} [A-Za-z]{3}, [\d]{4}', x):
            return x.replace(',', '')
        elif x == '':
            return x
        else:
            # Should be everything, print out anything left just in case
            print(x)
            
    df['date'] = df['date'].apply(parse_date)
    df['release_date'] = pd.to_datetime(df['date'], format='%d %b %Y', errors='coerce')
    
    df = df.drop(['coming_soon', 'date'], axis=1)
    
    return df

print('Testing date parsing:\n')
# %timeit process_release_date_old(imported_steam_data)
# %timeit process_release_date_new(imported_steam_data)

# %% [markdown]
# Our results show that the new method is almost four times faster, so we're on the right track.
#
# Another optimisation we can make here is checking which part of the if/elif statements has the most matches. It makes sense to order our statements from most matches to least, so for the majority of rows we only have to search through once.
#
# To do this, instead of returning the date we'll return a number for each match. We can then print the value counts for the column and see which is the most frequent.

# %%
def optimise_regex_order(df):
    df = df.copy()
    
    df['coming_soon'] = df['release_date'].apply(lambda x: literal_eval(x)['coming_soon'])
    df = df[df['coming_soon'] == False].copy()
    df['date'] = df['release_date'].apply(lambda x: literal_eval(x)['date'])
    
    def parse_date(x):
        if re.search(r'[A-Za-z]{3} [\d]{4}', x):
            return '0: mmm yyyy' # '1 ' + x
        elif re.search(r'[\d]{1,2} [A-Za-z]{3}, [\d]{4}', x):
            return '1: dd mmm, yyyy' # x.replace(',', '')
        elif x == '':
            return '2: empty' # pass
        else:
            # Should be everything, print out anything left just in case
            print(x)
            
    df['release_date'] = df['date'].apply(parse_date)
    
    return df


result = optimise_regex_order(imported_steam_data)

result['release_date'].value_counts()

# %% [markdown]
# By far the majority of dates are in the 'dd mmm, yyyy' format, which is second in our if/else statements. This means that for all these rows we are unnecessarily searching the string twice. Simply by reordering our searches we should see a minor performance improvement.

# %%
def process_release_date_unordered(df):
    df = df.copy()
    
    df['coming_soon'] = df['release_date'].apply(lambda x: literal_eval(x)['coming_soon'])
    df = df[df['coming_soon'] == False].copy()
    df['date'] = df['release_date'].apply(lambda x: literal_eval(x)['date'])
    
    def parse_date(x):
        if re.search(r'[A-Za-z]{3} [\d]{4}', x):
            return '1 ' + x
        elif re.search(r'[\d]{1,2} [A-Za-z]{3}, [\d]{4}', x):
            return x.replace(',', '')
        elif x == '':
            return x
        else:
            # Should be everything, print out anything left just in case
            print(x)
            
    df['release_date'] = df['date'].apply(parse_date)
    df['release_date'] = pd.to_datetime(df['date'], format='%d %b %Y', errors='coerce')
    df = df.drop(['coming_soon', 'date'], axis=1)
    
    return df


def process_release_date_ordered(df):
    df = df.copy()
    
    df['coming_soon'] = df['release_date'].apply(lambda x: literal_eval(x)['coming_soon'])
    df = df[df['coming_soon'] == False].copy()
    df['date'] = df['release_date'].apply(lambda x: literal_eval(x)['date'])
    
    def parse_date(x):
        if re.search(r'[\d]{1,2} [A-Za-z]{3}, [\d]{4}', x):
            return x.replace(',', '')
        elif re.search(r'[A-Za-z]{3} [\d]{4}', x):
            return '1 ' + x
        elif x == '':
            return x
        else:
            # Should be everything, print out anything left just in case
            print(x)
            
    df['release_date'] = df['date'].apply(parse_date)
    df['release_date'] = pd.to_datetime(df['date'], format='%d %b %Y', errors='coerce')
    df = df.drop(['coming_soon', 'date'], axis=1)
    
    return df


# %timeit process_release_date_unordered(imported_steam_data)
# %timeit process_release_date_ordered(imported_steam_data)

# %% [markdown]
# It's an improvement, if only slightly, so we'll keep it. If anything this goes to show how fast regex pattern matching is, as there was hardly any slowdown in searching every string twice.
#
# Now parsing is well-optimised we can move on to the evaluation section.

# %%
# Testing evaluation methods
def evaluation_method_original(df):
    df = df.copy()
    
    df['coming_soon'] = df['release_date'].apply(lambda x: literal_eval(x)['coming_soon'])    
    df = df[df['coming_soon'] == False].copy()
    df['release_date'] = df['release_date'].apply(lambda x: literal_eval(x)['date'])
    
    return df


def evaluation_method_1(df):
    df = df.copy()
    
    df['release_date'] = df['release_date'].apply(lambda x: literal_eval(x))
    
    df['coming_soon'] = df['release_date'].apply(lambda x: x['coming_soon'])
    df = df[df['coming_soon'] == False].copy()
    
    df['release_date'] = df['release_date'].apply(lambda x: x['date'])
    
    return df


def evaluation_method_2(df):
    df = df.copy()
    
    df['release_date'] = df['release_date'].apply(lambda x: literal_eval(x))
    df_2 = df['release_date'].transform([lambda x: x['coming_soon'], lambda x: x['date']])
    df = pd.concat([df, df_2], axis=1)
    
    return df


def evaluation_method_3(df):
    df = df.copy()
    
    def eval_date(x):
        x = literal_eval(x)
        if x['coming_soon']:
            return np.nan
        else:
            return x['date']
    
    df['release_date'] = df['release_date'].apply(eval_date)
    df = df[df['release_date'].notnull()]  # could change to drop when '' and deal with missing release dates also
    
    return df


# %timeit evaluation_method_original(imported_steam_data)

# %timeit evaluation_method_1(imported_steam_data)
# %timeit evaluation_method_2(imported_steam_data)
# %timeit evaluation_method_3(imported_steam_data)

# %% [markdown]
# It looks like we may have been right in our assumption that multiple calls to literal_eval were slowing down the function - by calling it once instead of twice we almost halved the run-time.
#
# Of our new methods the final one was just about the fastest, which is useful because it contains flexible custom logic we can modify if needed. Let's put everything together into our final function, and time it once more to see the improvements we've made.
#
# We'll make a couple of changes so we can easily remove missing values at the end, which should mean we end up with clean release dates.

# %%
def process_release_date(df):
    df = df.copy()
    
    def eval_date(x):
        x = literal_eval(x)
        if x['coming_soon']:
            return '' # return blank string so can drop missing at end
        else:
            return x['date']
    
    df['release_date'] = df['release_date'].apply(eval_date)
    
    def parse_date(x):
        if re.search(r'[\d]{1,2} [A-Za-z]{3}, [\d]{4}', x):
            return x.replace(',', '')
        elif re.search(r'[A-Za-z]{3} [\d]{4}', x):
            return '1 ' + x
        elif x == '':
            return np.nan
        else:
            # Should be everything, print out anything left just in case
            print(x)
            
    df['release_date'] = df['release_date'].apply(parse_date)
    df['release_date'] = pd.to_datetime(df['release_date'], format='%d %b %Y', errors='coerce')
    
    df = df[df['release_date'].notnull()]
    
    return df

# %timeit process_release_date(imported_steam_data)

# %% [markdown]
# Referring back to our original time of 3.6s, we've achieved a 7x speed increase. That's almost an order of magnitude improvement.
#
# We'll now update our process function, run it on our data set, and move on to some final checks.

# %%
# def process(df):
#     """Process data set. Will eventually contain calls to all functions we write."""
    
#     # Copy the input dataframe to avoid accidentally modifying original data
#     df = df.copy()
    
#     # Remove duplicate rows - all appids should be unique
#     df = df.drop_duplicates()
    
#     # Remove collumns with more than 50% null values
#     df = process_null_cols(df)
    
#     # Process rest of columns
#     df = df.drop(['achievements', 'content_descriptors'], axis=1)
#     df = process_type(df)
#     df = process_name(df)
#     df = process_age(df)
#     df = process_platforms(df)
#     df = process_price(df)
#     df = process_language(df)
#     df = process_developers_and_publishers(df)
#     df = process_release_date(df)
    
#     # Process columns which export data
#     df = process_descriptions(df, export=True)
#     df = process_images(df, export=True)
#     df = process_info(df, export=True)
#     df = process_requirements(df, export=True)
#     df = process_categories(df, export=True)
#     df = process_genres(df, export=True)
    
#     return df

steam_data = process_release_date(imported_steam_data)
steam_data.head()
# Out:
#                         name  steam_appid  required_age          platforms  \
# 0             Counter-Strike           10             0  windows;mac;linux
# 1      Team Fortress Classic           20             0  windows;mac;linux
# 2              Day of Defeat           30             0  windows;mac;linux
# 3         Deathmatch Classic           40             0  windows;mac;linux
# 4  Half-Life: Opposing Force           50             0  windows;mac;linux
#
#                                           categories  genres  achievements  \
# 0  Multi-player;Online Multi-Player;Local Multi-P...  Action             0
# 1  Multi-player;Online Multi-Player;Local Multi-P...  Action             0
# 2              Multi-player;Valve Anti-Cheat enabled  Action             0
# 3  Multi-player;Online Multi-Player;Local Multi-P...  Action             0
# 4  Single-player;Multi-player;Valve Anti-Cheat en...  Action             0
#
#   release_date  price  english         developer publisher
# 0   2000-11-01   7.19        1             Valve     Valve
# 1   1999-04-01   3.99        1             Valve     Valve
# 2   2003-05-01   3.99        1             Valve     Valve
# 3   2001-06-01   3.99        1             Valve     Valve
# 4   1999-11-01   3.99        1  Gearbox Software     Valve

# %% [markdown]
# ## Final Steps
#
# TODO: Could get rid of price > 60 here
# TODO: check size
#
# Our data set is hopefully complete. Before we export it to csv, let's check if we have any null values.

# %%
steam_data[steam_data['price'] > 60]
# Out:
#                                                     name  steam_appid  \
# 1117                                          3DCoat 4.8       100980
# 1878                                          Wing IDE 5       244830
# 1928                                Clickteam Fusion 2.5       248170
# 2012                               Leadwerks Game Engine       251810
# 2073                               Aartform Curvy 3D 3.0       253670
# 3862         Command: Modern Air / Naval Operations WOTY       321410
# 3976                   AppGameKit: Easy Game Development       325180
# 5410                                        RPG Maker MV       363890
# 5699                      Gary Grigsby's War in the East       370540
# 7727                                      The Music Room       431030
# 8023                       3DF Zephyr Lite Steam Edition       438450
# 9330       Crazy Stone Deep Learning -The First Edition-       479330
# 10076                                      Houdini Indie       502570
# 10668                        Tactics: Bludgeons Blessing       517500
# 10955                                         Silhouette       526310
# 12261                                        Emission VR       561690
# 12567                                     articy:draft 3       570090
# 13107                         GameMaker Studio 2 Desktop       585410
# 13115                             GameMaker Studio 2 Web       585600
# 13116                             GameMaker Studio 2 UWP       585610
# 13117                          GameMaker Studio 2 Mobile       585620
# 14889                     Gary Grigsby's War in the West       644710
# 14980                                     CrisisActionVR       648070
# 17225                                     Tactics 2: War       707770
# 18393                         最強の囲碁 ～名人への道～ / Igo Meijin       741390
# 18631                                       RealFlight 8       748460
# 18874  CyberLink PowerDVD 18 Ultra - Media player, vi...       755320
# 21273                                 ADR-Labelling Game       821800
# 23922                                        Cine Tracer       904960
# 25835                                         Bible Test       977200
#
#        required_age          platforms  \
# 1117              0            windows
# 1878              0  windows;mac;linux
# 1928              0            windows
# 2012              0            windows
# 2073              0            windows
# 3862              0            windows
# 3976              0  windows;mac;linux
# 5410              0  windows;mac;linux
# 5699              0            windows
# 7727              0            windows
# 8023              0            windows
# 9330              0            windows
# 10076             0            windows
# 10668             0        windows;mac
# 10955             0            windows
# 12261             0            windows
# 12567             0            windows
# 13107             0        windows;mac
# 13115             0        windows;mac
# 13116             0        windows;mac
# 13117             0        windows;mac
# 14889             0            windows
# 14980             0            windows
# 17225             0        windows;mac
# 18393             0            windows
# 18631             0            windows
# 18874             0            windows
# 21273             0            windows
# 23922             0        windows;mac
# 25835             0            windows
#
#                                               categories  \
# 1117                                         Steam Cloud
# 1878                                       Single-player
# 1928   Single-player;Multi-player;MMO;Co-op;Shared/Sp...
# 2012   Single-player;Steam Achievements;Steam Worksho...
# 2073                                       Single-player
# 3862   Single-player;Steam Workshop;Includes level ed...
# 3976                                      Steam Workshop
# 5410      Steam Trading Cards;Partial Controller Support
# 5699                          Single-player;Multi-player
# 7727                                          VR Support
# 8023                                 Steam Trading Cards
# 9330                                       Single-player
# 10076             Partial Controller Support;Steam Cloud
# 10668                  Single-player;Steam Trading Cards
# 10955           Single-player;Partial Controller Support
# 12261  Single-player;Steam Achievements;Full controll...
# 12567      Single-player;Steam Trading Cards;Steam Cloud
# 13107                                   In-App Purchases
# 13115                                   In-App Purchases
# 13116                                   In-App Purchases
# 13117                                   In-App Purchases
# 14889     Single-player;Multi-player;Shared/Split Screen
# 14980  Single-player;Multi-player;Online Multi-Player...
# 17225                                      Single-player
# 18393                         Single-player;Multi-player
# 18631  Single-player;Multi-player;Partial Controller ...
# 18874                         Partial Controller Support
# 21273                                      Single-player
# 23922                                      Single-player
# 25835                   Single-player;Steam Achievements
#
#                                                   genres  achievements  \
# 1117                                Animation & Modeling             0
# 1878                                           Utilities             0
# 1928   Animation & Modeling;Education;Utilities;Web P...             0
# 2012   Animation & Modeling;Design & Illustration;Edu...             3
# 2073                                Animation & Modeling             0
# 3862                                 Simulation;Strategy             0
# 3976   Animation & Modeling;Design & Illustration;Edu...             0
# 5410                Design & Illustration;Web Publishing             0
# 5699                                 Simulation;Strategy             0
# 7727                                    Audio Production             0
# 8023   Animation & Modeling;Design & Illustration;Vid...             0
# 9330                                     Casual;Strategy             0
# 10076  Animation & Modeling;Design & Illustration;Gam...             0
# 10668                         Action;Simulation;Strategy             0
# 10955                       Adventure;Indie;Early Access             0
# 12261                             Action;Adventure;Indie             6
# 12567          Design & Illustration;Education;Utilities             0
# 13107  Animation & Modeling;Design & Illustration;Edu...             0
# 13115  Animation & Modeling;Design & Illustration;Edu...             0
# 13116  Animation & Modeling;Design & Illustration;Edu...             0
# 13117  Animation & Modeling;Design & Illustration;Edu...             0
# 14889                                         Simulation             0
# 14980  Violent;Gore;Action;Adventure;Indie;Massively ...            20
# 17225                         Action;Simulation;Strategy             0
# 18393                                    Casual;Strategy             0
# 18631                            Indie;Racing;Simulation             0
# 18874                     Animation & Modeling;Utilities             0
# 21273                                         Simulation             0
# 23922                            Simulation;Early Access             0
# 25835                  Adventure;Casual;Indie;Simulation             5
#
#       release_date   price  english                              developer  \
# 1117    2012-10-02   95.99        1                                Pilgway
# 1878    2014-04-30   60.99        1                               Wingware
# 1928    2013-12-05   69.99        1                              Clickteam
# 2012    2014-01-06   78.99        1                     Leadwerks Software
# 2073    2013-11-12   75.99        1                               Aartform
# 3862    2014-09-26   60.99        1                            WarfareSims
# 3976    2014-11-21   60.99        1                      The Game Creators
# 5410    2015-10-23   60.99        1                    KADOKAWA;Yoji Ojima
# 5699    2015-07-09   60.99        1                             2by3 Games
# 7727    2017-08-17   98.99        1                            Chroma Coda
# 8023    2016-02-02  154.99        1                             3Dflow SRL
# 9330    2016-05-25   60.99        1  UNBALANCE Corporation;Rémi Coulom SAS
# 10076   2018-10-10  209.99        1                                 SideFX
# 10668   2017-07-04  154.99        1                       Capt. McCay Soft
# 10955   2016-11-13  154.99        1                        Apeirogon Games
# 12261   2016-11-30   75.99        1                            VRSpec Team
# 12567   2017-02-16   74.99        1                     ByteRockers' Games
# 13107   2017-03-08   75.99        1                        YoYo Games Ltd.
# 13115   2017-03-08  114.99        1                        YoYo Games Ltd.
# 13116   2017-03-08  303.99        1                        YoYo Games Ltd.
# 13117   2017-03-08  154.99        1                        YoYo Games Ltd.
# 14889   2017-08-03   60.99        1                             2by3 Games
# 14980   2017-09-11  154.99        1                           Pixel Wonder
# 17225   2017-09-22  154.99        1                        Capt McCay Soft
# 18393   2017-12-04   62.99        0                  UNBALANCE Corporation
# 18631   2018-03-21   78.99        1                    Knife Edge Software
# 18874   2018-06-12   79.99        1                              CyberLink
# 21273   2018-04-12  421.99        1                Suomen Kuljetusturva Oy
# 23922   2018-09-28   69.99        1                           Matt Workman
# 25835   2018-11-27  154.99        1                        FIRST_UKRAINIAN
#
#                      publisher
# 1117                   Pilgway
# 1878                  Wingware
# 1928                 Clickteam
# 2012        Leadwerks Software
# 2073                  Aartform
# 3862           Slitherine Ltd.
# 3976         The Game Creators
# 5410                    Degica
# 5699           Slitherine Ltd.
# 7727               Chroma Coda
# 8023                3Dflow SRL
# 9330     UNBALANCE Corporation
# 10076                   SideFX
# 10668         Capt. McCay Soft
# 10955          Apeirogon Games
# 12261              VRSpec Team
# 12567          articy Software
# 13107          YoYo Games Ltd.
# 13115          YoYo Games Ltd.
# 13116          YoYo Games Ltd.
# 13117          YoYo Games Ltd.
# 14889          Slitherine Ltd.
# 14980             Pixel Wonder
# 17225          Capt McCay Soft
# 18393    UNBALANCE Corporation
# 18631            Horizon Hobby
# 18874               Koch Media
# 21273  Suomen Kuljetusturva Oy
# 23922  Cinematography Database
# 25835          FIRST_UKRAINIAN

# %%
steam_data.info(verbose=False, memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27332 entries, 0 to 27390
# Columns: 12 entries, name to publisher
# dtypes: datetime64[ns](1), float64(1), int64(4), object(6)
# memory usage: 13.9 MB

# %%
steam_data.isnull().sum()
# Out:
# name            0
# steam_appid     0
# required_age    0
# platforms       0
# categories      0
# genres          0
# achievements    0
# release_date    0
# price           0
# english         0
# developer       0
# publisher       0
# dtype: int64

# %% [markdown]
# Looks good. We also want to check that no games slipped through that aren't released yet (data scraped on or before 1st May 2019).

# %%
steam_data[steam_data['release_date'] > '2019-05-01']
# Out:
# Empty DataFrame
# Columns: [name, steam_appid, required_age, platforms, categories, genres, achievements, release_date, price, english, developer, publisher]
# Index: []

# %% [markdown]
# ### Combining and exporting data frames
#
# Now that we're happy with our dataframe we are ready to export to file and finish this part of the project.
#
# First we export steam_data, then we merge genre_data and category_data into a new dataframe, check it for missing values, then export it.

# %%
steam_data.to_csv('../data/steam_data_clean.csv', index=False)
steam_data.head()
# Out:
#                         name  steam_appid  required_age          platforms  \
# 0             Counter-Strike           10             0  windows;mac;linux
# 1      Team Fortress Classic           20             0  windows;mac;linux
# 2              Day of Defeat           30             0  windows;mac;linux
# 3         Deathmatch Classic           40             0  windows;mac;linux
# 4  Half-Life: Opposing Force           50             0  windows;mac;linux
#
#                                           categories  genres  achievements  \
# 0  Multi-player;Online Multi-Player;Local Multi-P...  Action             0
# 1  Multi-player;Online Multi-Player;Local Multi-P...  Action             0
# 2              Multi-player;Valve Anti-Cheat enabled  Action             0
# 3  Multi-player;Online Multi-Player;Local Multi-P...  Action             0
# 4  Single-player;Multi-player;Valve Anti-Cheat en...  Action             0
#
#   release_date  price  english         developer publisher
# 0   2000-11-01   7.19        1             Valve     Valve
# 1   1999-04-01   3.99        1             Valve     Valve
# 2   2003-05-01   3.99        1             Valve     Valve
# 3   2001-06-01   3.99        1             Valve     Valve
# 4   1999-11-01   3.99        1  Gearbox Software     Valve

# %% [markdown]
# # Next steps
#
# We could clean some of the data we exported, like description and requirements.
#
# We are now ready to move on to cleaning our steamspy data.
